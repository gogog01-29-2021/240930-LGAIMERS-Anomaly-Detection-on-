# %% [markdown]
# # 제품 이상여부 판별 프로젝트 (본선)

# %% [markdown]
# ## 1. 데이터 불러오기

# %% [markdown]
# ### 필수 라이브러리

# %%
# !pip install hyperopt lightgbm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: hyperopt in ./.local/lib/python3.10/site-packages (0.2.7)
# Requirement already satisfied: lightgbm in ./.local/lib/python3.10/site-packages (4.5.0)
# Requirement already satisfied: six in ./.local/lib/python3.10/site-packages (from hyperopt) (1.16.0)
# Requirement already satisfied: future in ./.local/lib/python3.10/site-packages (from hyperopt) (1.0.0)
# Requirement already satisfied: tqdm in ./.local/lib/python3.10/site-packages (from hyperopt) (4.66.5)
# Requirement already satisfied: scipy in ./.local/lib/python3.10/site-packages (from hyperopt) (1.14.1)
# Requirement already satisfied: networkx>=2.2 in ./.local/lib/python3.10/site-packages (from hyperopt) (3.2.1)
# Requirement already satisfied: py4j in ./.local/lib/python3.10/site-packages (from hyperopt) (0.10.9.7)
# Requirement already satisfied: cloudpickle in ./.local/lib/python3.10/site-packages (from hyperopt) (3.0.0)
# Requirement already satisfied: numpy in ./.local/lib/python3.10/site-packages (from hyperopt) (1.23.5)
#
# [notice] A new release of pip is available: 23.0.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
import os
from pprint import pprint

import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
)
from sklearn.model_selection import train_test_split
from tqdm import tqdm

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, f1_score, precision_score, recall_score
from sklearn.model_selection import train_test_split, StratifiedKFold
import lightgbm as lgb
from sklearn.utils.class_weight import compute_class_weight
from sklearn.preprocessing import LabelEncoder
from hyperopt import hp, fmin, tpe, Trials, STATUS_OK

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 모든 열 출력
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### 데이터 읽어오기

# %%
ROOT_DIR = "data"
RANDOM_STATE = 110

# Load data
train_data = pd.read_csv(os.path.join(ROOT_DIR, "train.csv"))
train_data
# Out:
#       Wip Line_Dam Process Desc._Dam     Equipment_Dam Model.Suffix_Dam  \
# 0          IVI-OB6     Dam Dispenser  Dam dispenser #1      AJX75334505
# 1          IVI-OB6     Dam Dispenser  Dam dispenser #1      AJX75334505
# 2          IVI-OB6     Dam Dispenser  Dam dispenser #2      AJX75334501
# 3          IVI-OB6     Dam Dispenser  Dam dispenser #2      AJX75334501
# 4          IVI-OB6     Dam Dispenser  Dam dispenser #1      AJX75334501
# ...            ...               ...               ...              ...
# 40501      IVI-OB6     Dam Dispenser  Dam dispenser #1      AJX75334501
# 40502      IVI-OB6     Dam Dispenser  Dam dispenser #2      AJX75334501
# 40503      IVI-OB6     Dam Dispenser  Dam dispenser #1      AJX75334501
# 40504      IVI-OB6     Dam Dispenser  Dam dispenser #2      AJX75334501
# 40505      IVI-OB6     Dam Dispenser  Dam dispenser #1      AJX75334501
#
#       Workorder_Dam     Collect Date_Dam  Insp. Seq No._Dam  \
# 0        4F1XA938-1  2024-04-25 11:10:00                  1
# 1        3KPM0016-2  2023-09-19 14:30:00                  1
# 2        4E1X9167-1  2024-03-05 09:30:00                  1
# 3        3K1X0057-1  2023-09-25 15:40:00                  1
# 4        3HPM0007-1  2023-06-27 13:20:00                  1
# ...             ...                  ...                ...
# 40501    3J1XF434-2  2023-09-14 15:50:00                  1
# 40502    4E1XC796-1  2024-04-10 14:20:00                  1
# 40503    4C1XD438-1  2024-02-22 08:40:00                  1
# 40504    3I1XA258-1  2023-07-25 11:00:00                  1
# 40505    3G1XA501-1  2023-05-31 01:40:00                  1
#
#       Insp Judge Code_Dam  CURE END POSITION X Collect Result_Dam  \
# 0                      OK                                   240.0
# 1                      OK                                   240.0
# 2                      OK                                  1000.0
# 3                      OK                                  1000.0
# 4                      OK                                   240.0
# ...                   ...                                     ...
# 40501                  OK                                   240.0
# 40502                  OK                                  1000.0
# 40503                  OK                                   240.0
# 40504                  OK                                  1000.0
# 40505                  OK                                   240.0
#
#        CURE END POSITION X Unit Time_Dam  CURE END POSITION X Judge Value_Dam  \
# 0                                    NaN                                  NaN
# 1                                    NaN                                  NaN
# 2                                    NaN                                  NaN
# 3                                    NaN                                  NaN
# 4                                    NaN                                  NaN
# ...                                  ...                                  ...
# 40501                                NaN                                  NaN
# 40502                                NaN                                  NaN
# 40503                                NaN                                  NaN
# 40504                                NaN                                  NaN
# 40505                                NaN                                  NaN
#
#        CURE END POSITION Z Collect Result_Dam  \
# 0                                         2.5
# 1                                         2.5
# 2                                        12.5
# 3                                        12.5
# 4                                         2.5
# ...                                       ...
# 40501                                     2.5
# 40502                                    12.5
# 40503                                     2.5
# 40504                                    12.5
# 40505                                     2.5
#
#        CURE END POSITION Z Unit Time_Dam  CURE END POSITION Z Judge Value_Dam  \
# 0                                    NaN                                  NaN
# 1                                    NaN                                  NaN
# 2                                    NaN                                  NaN
# 3                                    NaN                                  NaN
# 4                                    NaN                                  NaN
# ...                                  ...                                  ...
# 40501                                NaN                                  NaN
# 40502                                NaN                                  NaN
# 40503                                NaN                                  NaN
# 40504                                NaN                                  NaN
# 40505                                NaN                                  NaN
#
#        CURE END POSITION Θ Collect Result_Dam  \
# 0                                         -90
# 1                                         -90
# 2                                          90
# 3                                          90
# 4                                         -90
# ...                                       ...
# 40501                                     -90
# 40502                                      90
# 40503                                     -90
# 40504                                      90
# 40505                                     -90
#
#        CURE END POSITION Θ Unit Time_Dam  CURE END POSITION Θ Judge Value_Dam  \
# 0                                    NaN                                  NaN
# 1                                    NaN                                  NaN
# 2                                    NaN                                  NaN
# 3                                    NaN                                  NaN
# 4                                    NaN                                  NaN
# ...                                  ...                                  ...
# 40501                                NaN                                  NaN
# 40502                                NaN                                  NaN
# 40503                                NaN                                  NaN
# 40504                                NaN                                  NaN
# 40505                                NaN                                  NaN
#
#        CURE SPEED Collect Result_Dam  CURE SPEED Unit Time_Dam  \
# 0                                100                       NaN
# 1                                 70                       NaN
# 2                                 85                       NaN
# 3                                 70                       NaN
# 4                                 70                       NaN
# ...                              ...                       ...
# 40501                             70                       NaN
# 40502                            100                       NaN
# 40503                            100                       NaN
# 40504                             70                       NaN
# 40505                             70                       NaN
#
#        CURE SPEED Judge Value_Dam  CURE STANDBY POSITION X Collect Result_Dam  \
# 0                             NaN                                        1150
# 1                             NaN                                        1150
# 2                             NaN                                        1150
# 3                             NaN                                        1150
# 4                             NaN                                        1150
# ...                           ...                                         ...
# 40501                         NaN                                        1150
# 40502                         NaN                                        1150
# 40503                         NaN                                        1150
# 40504                         NaN                                        1150
# 40505                         NaN                                        1150
#
#        CURE STANDBY POSITION X Unit Time_Dam  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 40501                                    NaN
# 40502                                    NaN
# 40503                                    NaN
# 40504                                    NaN
# 40505                                    NaN
#
#        CURE STANDBY POSITION X Judge Value_Dam  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 40501                                      NaN
# 40502                                      NaN
# 40503                                      NaN
# 40504                                      NaN
# 40505                                      NaN
#
#        CURE STANDBY POSITION Z Collect Result_Dam  \
# 0                                            33.5
# 1                                            33.5
# 2                                            33.5
# 3                                            33.5
# 4                                            33.5
# ...                                           ...
# 40501                                        33.5
# 40502                                        33.5
# 40503                                        33.5
# 40504                                        33.5
# 40505                                        33.5
#
#        CURE STANDBY POSITION Z Unit Time_Dam  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 40501                                    NaN
# 40502                                    NaN
# 40503                                    NaN
# 40504                                    NaN
# 40505                                    NaN
#
#        CURE STANDBY POSITION Z Judge Value_Dam  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 40501                                      NaN
# 40502                                      NaN
# 40503                                      NaN
# 40504                                      NaN
# 40505                                      NaN
#
#        CURE STANDBY POSITION Θ Collect Result_Dam  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
# ...                                           ...
# 40501                                           0
# 40502                                           0
# 40503                                           0
# 40504                                           0
# 40505                                           0
#
#        CURE STANDBY POSITION Θ Unit Time_Dam  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 40501                                    NaN
# 40502                                    NaN
# 40503                                    NaN
# 40504                                    NaN
# 40505                                    NaN
#
#        CURE STANDBY POSITION Θ Judge Value_Dam  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 40501                                      NaN
# 40502                                      NaN
# 40503                                      NaN
# 40504                                      NaN
# 40505                                      NaN
#
#        CURE START POSITION X Collect Result_Dam  \
# 0                                          1030
# 1                                          1030
# 2                                           280
# 3                                           280
# 4                                          1030
# ...                                         ...
# 40501                                      1030
# 40502                                       280
# 40503                                      1030
# 40504                                       280
# 40505                                      1030
#
#        CURE START POSITION X Unit Time_Dam  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 40501                                  NaN
# 40502                                  NaN
# 40503                                  NaN
# 40504                                  NaN
# 40505                                  NaN
#
#        CURE START POSITION X Judge Value_Dam  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 40501                                    NaN
# 40502                                    NaN
# 40503                                    NaN
# 40504                                    NaN
# 40505                                    NaN
#
#        CURE START POSITION Z Collect Result_Dam  \
# 0                                          33.5
# 1                                          33.5
# 2                                          33.5
# 3                                          33.5
# 4                                          33.5
# ...                                         ...
# 40501                                      33.5
# 40502                                      33.5
# 40503                                      33.5
# 40504                                      33.5
# 40505                                      33.5
#
#        CURE START POSITION Z Unit Time_Dam  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 40501                                  NaN
# 40502                                  NaN
# 40503                                  NaN
# 40504                                  NaN
# 40505                                  NaN
#
#        CURE START POSITION Z Judge Value_Dam  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 40501                                    NaN
# 40502                                    NaN
# 40503                                    NaN
# 40504                                    NaN
# 40505                                    NaN
#
#        CURE START POSITION Θ Collect Result_Dam  \
# 0                                           -90
# 1                                           -90
# 2                                            90
# 3                                            90
# 4                                           -90
# ...                                         ...
# 40501                                       -90
# 40502                                        90
# 40503                                       -90
# 40504                                        90
# 40505                                       -90
#
#        CURE START POSITION Θ Unit Time_Dam  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 40501                                  NaN
# 40502                                  NaN
# 40503                                  NaN
# 40504                                  NaN
# 40505                                  NaN
#
#        CURE START POSITION Θ Judge Value_Dam  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 40501                                    NaN
# 40502                                    NaN
# 40503                                    NaN
# 40504                                    NaN
# 40505                                    NaN
#
#        DISCHARGED SPEED OF RESIN Collect Result_Dam  \
# 0                                                16
# 1                                                10
# 2                                                16
# 3                                                10
# 4                                                10
# ...                                             ...
# 40501                                            10
# 40502                                            16
# 40503                                            16
# 40504                                            10
# 40505                                            10
#
#        DISCHARGED SPEED OF RESIN Unit Time_Dam  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 40501                                      NaN
# 40502                                      NaN
# 40503                                      NaN
# 40504                                      NaN
# 40505                                      NaN
#
#        DISCHARGED SPEED OF RESIN Judge Value_Dam  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 40501                                        NaN
# 40502                                        NaN
# 40503                                        NaN
# 40504                                        NaN
# 40505                                        NaN
#
#        DISCHARGED TIME OF RESIN(Stage1) Collect Result_Dam  \
# 0                                                   14.9
# 1                                                   21.3
# 2                                                   14.7
# 3                                                   21.3
# 4                                                    9.7
# ...                                                  ...
# 40501                                               17.0
# 40502                                               14.9
# 40503                                               14.2
# 40504                                                9.7
# 40505                                                9.6
#
#        DISCHARGED TIME OF RESIN(Stage1) Unit Time_Dam  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 40501                                             NaN
# 40502                                             NaN
# 40503                                             NaN
# 40504                                             NaN
# 40505                                             NaN
#
#        DISCHARGED TIME OF RESIN(Stage1) Judge Value_Dam  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 40501                                               NaN
# 40502                                               NaN
# 40503                                               NaN
# 40504                                               NaN
# 40505                                               NaN
#
#        DISCHARGED TIME OF RESIN(Stage2) Collect Result_Dam  \
# 0                                                    8.4
# 1                                                    4.9
# 2                                                    8.5
# 3                                                    8.4
# 4                                                    4.9
# ...                                                  ...
# 40501                                                5.0
# 40502                                                8.5
# 40503                                                8.2
# 40504                                                4.9
# 40505                                                3.9
#
#        DISCHARGED TIME OF RESIN(Stage2) Unit Time_Dam  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 40501                                             NaN
# 40502                                             NaN
# 40503                                             NaN
# 40504                                             NaN
# 40505                                             NaN
#
#        DISCHARGED TIME OF RESIN(Stage2) Judge Value_Dam  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 40501                                               NaN
# 40502                                               NaN
# 40503                                               NaN
# 40504                                               NaN
# 40505                                               NaN
#
#        DISCHARGED TIME OF RESIN(Stage3) Collect Result_Dam  \
# 0                                                   14.7
# 1                                                   21.3
# 2                                                   14.7
# 3                                                   21.3
# 4                                                    9.6
# ...                                                  ...
# 40501                                               17.0
# 40502                                               14.7
# 40503                                               14.3
# 40504                                                9.7
# 40505                                                9.7
#
#        DISCHARGED TIME OF RESIN(Stage3) Unit Time_Dam  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 40501                                             NaN
# 40502                                             NaN
# 40503                                             NaN
# 40504                                             NaN
# 40505                                             NaN
#
#        DISCHARGED TIME OF RESIN(Stage3) Judge Value_Dam  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 40501                                               NaN
# 40502                                               NaN
# 40503                                               NaN
# 40504                                               NaN
# 40505                                               NaN
#
#        Dispense Volume(Stage1) Collect Result_Dam  \
# 0                                            1.04
# 1                                            1.49
# 2                                            1.61
# 3                                            1.49
# 4                                            0.67
# ...                                           ...
# 40501                                        1.19
# 40502                                        1.04
# 40503                                        0.99
# 40504                                        0.67
# 40505                                        0.67
#
#        Dispense Volume(Stage1) Unit Time_Dam  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 40501                                    NaN
# 40502                                    NaN
# 40503                                    NaN
# 40504                                    NaN
# 40505                                    NaN
#
#        Dispense Volume(Stage1) Judge Value_Dam  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 40501                                      NaN
# 40502                                      NaN
# 40503                                      NaN
# 40504                                      NaN
# 40505                                      NaN
#
#        Dispense Volume(Stage2) Collect Result_Dam  \
# 0                                            0.58
# 1                                            0.34
# 2                                            0.93
# 3                                            0.58
# 4                                            0.34
# ...                                           ...
# 40501                                        0.35
# 40502                                        0.59
# 40503                                        0.57
# 40504                                        0.34
# 40505                                        0.27
#
#        Dispense Volume(Stage2) Unit Time_Dam  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 40501                                    NaN
# 40502                                    NaN
# 40503                                    NaN
# 40504                                    NaN
# 40505                                    NaN
#
#        Dispense Volume(Stage2) Judge Value_Dam  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 40501                                      NaN
# 40502                                      NaN
# 40503                                      NaN
# 40504                                      NaN
# 40505                                      NaN
#
#        Dispense Volume(Stage3) Collect Result_Dam  \
# 0                                            1.02
# 1                                            1.49
# 2                                            1.61
# 3                                            1.49
# 4                                            0.67
# ...                                           ...
# 40501                                        1.19
# 40502                                        1.02
# 40503                                        1.00
# 40504                                        0.67
# 40505                                        0.67
#
#        Dispense Volume(Stage3) Unit Time_Dam  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 40501                                    NaN
# 40502                                    NaN
# 40503                                    NaN
# 40504                                    NaN
# 40505                                    NaN
#
#        Dispense Volume(Stage3) Judge Value_Dam  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 40501                                      NaN
# 40502                                      NaN
# 40503                                      NaN
# 40504                                      NaN
# 40505                                      NaN
#
#       HEAD NORMAL COORDINATE X AXIS(Stage1) Collect Result_Dam  \
# 0                                                    NaN
# 1                                                  550.3
# 2                                                     OK
# 3                                                  162.4
# 4                                                    549
# ...                                                  ...
# 40501                                              550.3
# 40502                                                NaN
# 40503                                                 OK
# 40504                                              162.4
# 40505                                                549
#
#        HEAD NORMAL COORDINATE X AXIS(Stage1) Unit Time_Dam  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 40501                                                NaN
# 40502                                                NaN
# 40503                                                NaN
# 40504                                                NaN
# 40505                                                NaN
#
#       HEAD NORMAL COORDINATE X AXIS(Stage1) Judge Value_Dam  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                     OK
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 40501                                                NaN
# 40502                                                NaN
# 40503                                                 OK
# 40504                                                NaN
# 40505                                                NaN
#
#        HEAD NORMAL COORDINATE X AXIS(Stage2) Collect Result_Dam  \
# 0                                                  550.5
# 1                                                  463.8
# 2                                                  162.4
# 3                                                  465.5
# 4                                                  462.5
# ...                                                  ...
# 40501                                              463.8
# 40502                                              163.5
# 40503                                              550.6
# 40504                                              465.1
# 40505                                              463.0
#
#        HEAD NORMAL COORDINATE X AXIS(Stage2) Unit Time_Dam  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 40501                                                NaN
# 40502                                                NaN
# 40503                                                NaN
# 40504                                                NaN
# 40505                                                NaN
#
#        HEAD NORMAL COORDINATE X AXIS(Stage2) Judge Value_Dam  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 40501                                                NaN
# 40502                                                NaN
# 40503                                                NaN
# 40504                                                NaN
# 40505                                                NaN
#
#        HEAD NORMAL COORDINATE X AXIS(Stage3) Collect Result_Dam  \
# 0                                                  464.3
# 1                                                  160.8
# 2                                                  465.4
# 3                                                  552.0
# 4                                                  159.5
# ...                                                  ...
# 40501                                              160.8
# 40502                                              466.2
# 40503                                              463.9
# 40504                                              551.3
# 40505                                              160.5
#
#        HEAD NORMAL COORDINATE X AXIS(Stage3) Unit Time_Dam  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 40501                                                NaN
# 40502                                                NaN
# 40503                                                NaN
# 40504                                                NaN
# 40505                                                NaN
#
#        HEAD NORMAL COORDINATE X AXIS(Stage3) Judge Value_Dam  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 40501                                                NaN
# 40502                                                NaN
# 40503                                                NaN
# 40504                                                NaN
# 40505                                                NaN
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage1) Collect Result_Dam  \
# 0                                                  161.4
# 1                                                  377.3
# 2                                                  551.7
# 3                                                 1271.8
# 4                                                  377.5
# ...                                                  ...
# 40501                                              377.3
# 40502                                              553.1
# 40503                                              161.5
# 40504                                             1269.0
# 40505                                              377.5
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage1) Unit Time_Dam  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 40501                                                NaN
# 40502                                                NaN
# 40503                                                NaN
# 40504                                                NaN
# 40505                                                NaN
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage1) Judge Value_Dam  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 40501                                                NaN
# 40502                                                NaN
# 40503                                                NaN
# 40504                                                NaN
# 40505                                                NaN
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage2) Collect Result_Dam  \
# 0                                                  384.0
# 1                                                  377.3
# 2                                                 1271.8
# 3                                                 1270.7
# 4                                                  377.0
# ...                                                  ...
# 40501                                              377.3
# 40502                                             1281.0
# 40503                                              377.6
# 40504                                             1268.4
# 40505                                              377.0
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage2) Unit Time_Dam  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 40501                                                NaN
# 40502                                                NaN
# 40503                                                NaN
# 40504                                                NaN
# 40505                                                NaN
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage2) Judge Value_Dam  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 40501                                                NaN
# 40502                                                NaN
# 40503                                                NaN
# 40504                                                NaN
# 40505                                                NaN
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage3) Collect Result_Dam  \
# 0                                                  383.1
# 1                                                  377.3
# 2                                                 1383.9
# 3                                                 1271.8
# 4                                                  377.5
# ...                                                  ...
# 40501                                              377.3
# 40502                                             1393.5
# 40503                                              377.1
# 40504                                             1269.0
# 40505                                              377.5
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage3) Unit Time_Dam  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 40501                                                NaN
# 40502                                                NaN
# 40503                                                NaN
# 40504                                                NaN
# 40505                                                NaN
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage3) Judge Value_Dam  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 40501                                                NaN
# 40502                                                NaN
# 40503                                                NaN
# 40504                                                NaN
# 40505                                                NaN
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage1) Collect Result_Dam  \
# 0                                                 384.00
# 1                                                 282.15
# 2                                                1271.80
# 3                                                 282.15
# 4                                                 284.80
# ...                                                  ...
# 40501                                             282.15
# 40502                                            1281.20
# 40503                                             378.00
# 40504                                             282.15
# 40505                                             284.80
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage1) Unit Time_Dam  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 40501                                                NaN
# 40502                                                NaN
# 40503                                                NaN
# 40504                                                NaN
# 40505                                                NaN
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage1) Judge Value_Dam  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...
# 40502                                      NaN
# 40503                                      NaN
# 40504                                      NaN
# 40505                                      NaN
#
#        Head Clean Position Y Collect Result_Fill2  \
# 0                                             119
# 1                                              50
# 2                                             119
# 3                                              50
# 4                                              50
# ...                                           ...
# 40501                                          50
# 40502                                         119
# 40503                                         119
# 40504                                          50
# 40505                                          50
#
#        Head Clean Position Y Unit Time_Fill2  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 40501                                    NaN
# 40502                                    NaN
# 40503                                    NaN
# 40504                                    NaN
# 40505                                    NaN
#
#        Head Clean Position Y Judge Value_Fill2  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 40501                                      NaN
# 40502                                      NaN
# 40503                                      NaN
# 40504                                      NaN
# 40505                                      NaN
#
#        Head Clean Position Z Collect Result_Fill2  \
# 0                                            50.0
# 1                                            91.8
# 2                                            50.0
# 3                                            91.8
# 4                                            91.8
# ...                                           ...
# 40501                                        91.8
# 40502                                        50.0
# 40503                                        50.0
# 40504                                        91.8
# 40505                                        91.8
#
#        Head Clean Position Z Unit Time_Fill2  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 40501                                    NaN
# 40502                                    NaN
# 40503                                    NaN
# 40504                                    NaN
# 40505                                    NaN
#
#        Head Clean Position Z Judge Value_Fill2  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 40501                                      NaN
# 40502                                      NaN
# 40503                                      NaN
# 40504                                      NaN
# 40505                                      NaN
#
#        Head Purge Position X Collect Result_Fill2  \
# 0                                            91.8
# 1                                           270.0
# 2                                            91.8
# 3                                           270.0
# 4                                           270.0
# ...                                           ...
# 40501                                       270.0
# 40502                                        91.8
# 40503                                        91.8
# 40504                                       270.0
# 40505                                       270.0
#
#        Head Purge Position X Unit Time_Fill2  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 40501                                    NaN
# 40502                                    NaN
# 40503                                    NaN
# 40504                                    NaN
# 40505                                    NaN
#
#        Head Purge Position X Judge Value_Fill2  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 40501                                      NaN
# 40502                                      NaN
# 40503                                      NaN
# 40504                                      NaN
# 40505                                      NaN
#
#        Head Purge Position Y Collect Result_Fill2  \
# 0                                             270
# 1                                              50
# 2                                             270
# 3                                              50
# 4                                              50
# ...                                           ...
# 40501                                          50
# 40502                                         270
# 40503                                         270
# 40504                                          50
# 40505                                          50
#
#        Head Purge Position Y Unit Time_Fill2  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 40501                                    NaN
# 40502                                    NaN
# 40503                                    NaN
# 40504                                    NaN
# 40505                                    NaN
#
#        Head Purge Position Y Judge Value_Fill2  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 40501                                      NaN
# 40502                                      NaN
# 40503                                      NaN
# 40504                                      NaN
# 40505                                      NaN
#
#        Head Purge Position Z Collect Result_Fill2  \
# 0                                              50
# 1                                              85
# 2                                              50
# 3                                              85
# 4                                              85
# ...                                           ...
# 40501                                          85
# 40502                                          50
# 40503                                          50
# 40504                                          85
# 40505                                          85
#
#        Head Purge Position Z Unit Time_Fill2  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 40501                                    NaN
# 40502                                    NaN
# 40503                                    NaN
# 40504                                    NaN
# 40505                                    NaN
#
#        Head Purge Position Z Judge Value_Fill2  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 40501                                      NaN
# 40502                                      NaN
# 40503                                      NaN
# 40504                                      NaN
# 40505                                      NaN
#
#        Machine Tact time Collect Result_Fill2  \
# 0                                     114.612
# 1                                      19.600
# 2                                     114.612
# 3                                      19.900
# 4                                      19.700
# ...                                       ...
# 40501                                  19.200
# 40502                                 114.612
# 40503                                  85.000
# 40504                                  20.100
# 40505                                  19.400
#
#        Machine Tact time Unit Time_Fill2  Machine Tact time Judge Value_Fill2  \
# 0                                    NaN                                  NaN
# 1                                    NaN                                  NaN
# 2                                    NaN                                  NaN
# 3                                    NaN                                  NaN
# 4                                    NaN                                  NaN
# ...                                  ...                                  ...
# 40501                                NaN                                  NaN
# 40502                                NaN                                  NaN
# 40503                                NaN                                  NaN
# 40504                                NaN                                  NaN
# 40505                                NaN                                  NaN
#
#        PalletID Collect Result_Fill2  PalletID Unit Time_Fill2  \
# 0                               19.9                       NaN
# 1                                7.0                       NaN
# 2                               19.8                       NaN
# 3                               12.0                       NaN
# 4                                8.0                       NaN
# ...                              ...                       ...
# 40501                            1.0                       NaN
# 40502                           20.5                       NaN
# 40503                           19.7                       NaN
# 40504                           13.0                       NaN
# 40505                            3.0                       NaN
#
#        PalletID Judge Value_Fill2  Production Qty Collect Result_Fill2  \
# 0                             NaN                                    7
# 1                             NaN                                  185
# 2                             NaN                                   10
# 3                             NaN                                  268
# 4                             NaN                                  121
# ...                           ...                                  ...
# 40501                         NaN                                  318
# 40502                         NaN                                   14
# 40503                         NaN                                    1
# 40504                         NaN                                  117
# 40505                         NaN                                  320
#
#        Production Qty Unit Time_Fill2  Production Qty Judge Value_Fill2  \
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                                 NaN                               NaN
# ...                               ...                               ...
# 40501                             NaN                               NaN
# 40502                             NaN                               NaN
# 40503                             NaN                               NaN
# 40504                             NaN                               NaN
# 40505                             NaN                               NaN
#
#        Receip No Collect Result_Fill2  Receip No Unit Time_Fill2  \
# 0                                 127                        NaN
# 1                                   1                        NaN
# 2                                  73                        NaN
# 3                                   1                        NaN
# 4                                   1                        NaN
# ...                               ...                        ...
# 40501                               1                        NaN
# 40502                             197                        NaN
# 40503                              27                        NaN
# 40504                               1                        NaN
# 40505                               1                        NaN
#
#        Receip No Judge Value_Fill2  WorkMode Collect Result_Fill2  \
# 0                              NaN                              1
# 1                              NaN                              0
# 2                              NaN                              1
# 3                              NaN                              0
# 4                              NaN                              0
# ...                            ...                            ...
# 40501                          NaN                              0
# 40502                          NaN                              1
# 40503                          NaN                              1
# 40504                          NaN                              0
# 40505                          NaN                              0
#
#        WorkMode Unit Time_Fill2  WorkMode Judge Value_Fill2    target
# 0                           NaN                         NaN    Normal
# 1                           NaN                         NaN    Normal
# 2                           NaN                         NaN    Normal
# 3                           NaN                         NaN    Normal
# 4                           NaN                         NaN    Normal
# ...                         ...                         ...       ...
# 40501                       NaN                         NaN    Normal
# 40502                       NaN                         NaN    Normal
# 40503                       NaN                         NaN    Normal
# 40504                       NaN                         NaN    Normal
# 40505                       NaN                         NaN  AbNormal
#
# [40506 rows x 468 columns]

# %%
test = pd.read_csv(os.path.join(ROOT_DIR, "test.csv"))
test
# Out:
#                                  Set ID Wip Line_Dam Process Desc._Dam  \
# 0      0001be084fbc4aaa9d921f39e595961b      IVI-OB6     Dam Dispenser
# 1      0005bbd180064abd99e63f9ed3e1ac80      IVI-OB6     Dam Dispenser
# 2      000948934c4140d883d670adcb609584      IVI-OB6     Dam Dispenser
# 3      000a6bfd02874c6296dc7b2e9c5678a7      IVI-OB6     Dam Dispenser
# 4      0018e78ce91343678716e2ea27a51c95      IVI-OB6     Dam Dispenser
# ...                                 ...          ...               ...
# 17356  ffea508b59934d689b540f95eb3fa730      IVI-OB6     Dam Dispenser
# 17357  ffed8923c8a448a98afc641b770be153      IVI-OB6     Dam Dispenser
# 17358  fff1e73734da40adbe805359b3efb462      IVI-OB6     Dam Dispenser
# 17359  fff8e38bdd09470baf95f71e92075dec      IVI-OB6     Dam Dispenser
# 17360  fffa83e0a13d4c2db4fd8bf905b517d4      IVI-OB6     Dam Dispenser
#
#           Equipment_Dam Model.Suffix_Dam Workorder_Dam     Collect Date_Dam  \
# 0      Dam dispenser #2      AJX75334501    3J1XF767-1  2023-09-15 13:20:00
# 1      Dam dispenser #2      AJX75334501    4B1XD472-2  2024-02-06 16:50:00
# 2      Dam dispenser #1      AJX75334501    3H1XE355-1  2023-07-14 11:30:00
# 3      Dam dispenser #2      AJX75334501    3L1XA128-1  2023-11-03 08:00:00
# 4      Dam dispenser #1      AJX75334501    4A1XA639-1  2023-12-23 14:00:00
# ...                 ...              ...           ...                  ...
# 17356  Dam dispenser #2      AJX75334501    3K1XB597-1  2023-10-18 11:10:00
# 17357  Dam dispenser #2      AJX75334501    4A1XB974-1  2024-01-02 15:00:00
# 17358  Dam dispenser #1      AJX75334501    3L1XA998-1  2023-11-15 09:10:00
# 17359  Dam dispenser #1      AJX75334501    3F1XC376-1  2023-05-18 14:20:00
# 17360  Dam dispenser #1      AJX75334501    3J1XC756-1  2023-08-23 09:30:00
#
#        Insp. Seq No._Dam Insp Judge Code_Dam  \
# 0                      1                  OK
# 1                      1                  OK
# 2                      1                  OK
# 3                      1                  OK
# 4                      1                  OK
# ...                  ...                 ...
# 17356                  1                  OK
# 17357                  1                  OK
# 17358                  1                  OK
# 17359                  1                  OK
# 17360                  1                  OK
#
#        CURE END POSITION X Collect Result_Dam  \
# 0                                      1000.0
# 1                                      1000.0
# 2                                       240.0
# 3                                      1000.0
# 4                                       240.0
# ...                                       ...
# 17356                                  1000.0
# 17357                                  1000.0
# 17358                                   240.0
# 17359                                   240.0
# 17360                                   240.0
#
#        CURE END POSITION X Unit Time_Dam  CURE END POSITION X Judge Value_Dam  \
# 0                                    NaN                                  NaN
# 1                                    NaN                                  NaN
# 2                                    NaN                                  NaN
# 3                                    NaN                                  NaN
# 4                                    NaN                                  NaN
# ...                                  ...                                  ...
# 17356                                NaN                                  NaN
# 17357                                NaN                                  NaN
# 17358                                NaN                                  NaN
# 17359                                NaN                                  NaN
# 17360                                NaN                                  NaN
#
#        CURE END POSITION Z Collect Result_Dam  \
# 0                                        12.5
# 1                                        12.5
# 2                                         2.5
# 3                                        12.5
# 4                                         2.5
# ...                                       ...
# 17356                                    12.5
# 17357                                    12.5
# 17358                                     2.5
# 17359                                     2.5
# 17360                                     2.5
#
#        CURE END POSITION Z Unit Time_Dam  CURE END POSITION Z Judge Value_Dam  \
# 0                                    NaN                                  NaN
# 1                                    NaN                                  NaN
# 2                                    NaN                                  NaN
# 3                                    NaN                                  NaN
# 4                                    NaN                                  NaN
# ...                                  ...                                  ...
# 17356                                NaN                                  NaN
# 17357                                NaN                                  NaN
# 17358                                NaN                                  NaN
# 17359                                NaN                                  NaN
# 17360                                NaN                                  NaN
#
#        CURE END POSITION Θ Collect Result_Dam  \
# 0                                          90
# 1                                          90
# 2                                         -90
# 3                                          90
# 4                                         -90
# ...                                       ...
# 17356                                      90
# 17357                                      90
# 17358                                     -90
# 17359                                     -90
# 17360                                     -90
#
#        CURE END POSITION Θ Unit Time_Dam  CURE END POSITION Θ Judge Value_Dam  \
# 0                                    NaN                                  NaN
# 1                                    NaN                                  NaN
# 2                                    NaN                                  NaN
# 3                                    NaN                                  NaN
# 4                                    NaN                                  NaN
# ...                                  ...                                  ...
# 17356                                NaN                                  NaN
# 17357                                NaN                                  NaN
# 17358                                NaN                                  NaN
# 17359                                NaN                                  NaN
# 17360                                NaN                                  NaN
#
#        CURE SPEED Collect Result_Dam  CURE SPEED Unit Time_Dam  \
# 0                                 70                       NaN
# 1                                 70                       NaN
# 2                                 70                       NaN
# 3                                 70                       NaN
# 4                                 70                       NaN
# ...                              ...                       ...
# 17356                             70                       NaN
# 17357                             70                       NaN
# 17358                             70                       NaN
# 17359                             70                       NaN
# 17360                             70                       NaN
#
#        CURE SPEED Judge Value_Dam  CURE STANDBY POSITION X Collect Result_Dam  \
# 0                             NaN                                        1150
# 1                             NaN                                        1150
# 2                             NaN                                        1150
# 3                             NaN                                        1150
# 4                             NaN                                        1150
# ...                           ...                                         ...
# 17356                         NaN                                        1150
# 17357                         NaN                                        1150
# 17358                         NaN                                        1150
# 17359                         NaN                                        1150
# 17360                         NaN                                        1150
#
#        CURE STANDBY POSITION X Unit Time_Dam  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 17356                                    NaN
# 17357                                    NaN
# 17358                                    NaN
# 17359                                    NaN
# 17360                                    NaN
#
#        CURE STANDBY POSITION X Judge Value_Dam  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 17356                                      NaN
# 17357                                      NaN
# 17358                                      NaN
# 17359                                      NaN
# 17360                                      NaN
#
#        CURE STANDBY POSITION Z Collect Result_Dam  \
# 0                                            33.5
# 1                                            33.5
# 2                                            33.5
# 3                                            33.5
# 4                                            33.5
# ...                                           ...
# 17356                                        33.5
# 17357                                        33.5
# 17358                                        33.5
# 17359                                        33.5
# 17360                                        33.5
#
#        CURE STANDBY POSITION Z Unit Time_Dam  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 17356                                    NaN
# 17357                                    NaN
# 17358                                    NaN
# 17359                                    NaN
# 17360                                    NaN
#
#        CURE STANDBY POSITION Z Judge Value_Dam  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 17356                                      NaN
# 17357                                      NaN
# 17358                                      NaN
# 17359                                      NaN
# 17360                                      NaN
#
#        CURE STANDBY POSITION Θ Collect Result_Dam  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
# ...                                           ...
# 17356                                           0
# 17357                                           0
# 17358                                           0
# 17359                                           0
# 17360                                           0
#
#        CURE STANDBY POSITION Θ Unit Time_Dam  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 17356                                    NaN
# 17357                                    NaN
# 17358                                    NaN
# 17359                                    NaN
# 17360                                    NaN
#
#        CURE STANDBY POSITION Θ Judge Value_Dam  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 17356                                      NaN
# 17357                                      NaN
# 17358                                      NaN
# 17359                                      NaN
# 17360                                      NaN
#
#        CURE START POSITION X Collect Result_Dam  \
# 0                                           280
# 1                                           280
# 2                                          1030
# 3                                           280
# 4                                          1030
# ...                                         ...
# 17356                                       280
# 17357                                       280
# 17358                                      1030
# 17359                                      1030
# 17360                                      1030
#
#        CURE START POSITION X Unit Time_Dam  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 17356                                  NaN
# 17357                                  NaN
# 17358                                  NaN
# 17359                                  NaN
# 17360                                  NaN
#
#        CURE START POSITION X Judge Value_Dam  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 17356                                    NaN
# 17357                                    NaN
# 17358                                    NaN
# 17359                                    NaN
# 17360                                    NaN
#
#        CURE START POSITION Z Collect Result_Dam  \
# 0                                          33.5
# 1                                          33.5
# 2                                          33.5
# 3                                          33.5
# 4                                          33.5
# ...                                         ...
# 17356                                      33.5
# 17357                                      33.5
# 17358                                      33.5
# 17359                                      33.5
# 17360                                      33.5
#
#        CURE START POSITION Z Unit Time_Dam  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 17356                                  NaN
# 17357                                  NaN
# 17358                                  NaN
# 17359                                  NaN
# 17360                                  NaN
#
#        CURE START POSITION Z Judge Value_Dam  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 17356                                    NaN
# 17357                                    NaN
# 17358                                    NaN
# 17359                                    NaN
# 17360                                    NaN
#
#        CURE START POSITION Θ Collect Result_Dam  \
# 0                                            90
# 1                                            90
# 2                                           -90
# 3                                            90
# 4                                           -90
# ...                                         ...
# 17356                                        90
# 17357                                        90
# 17358                                       -90
# 17359                                       -90
# 17360                                       -90
#
#        CURE START POSITION Θ Unit Time_Dam  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 17356                                  NaN
# 17357                                  NaN
# 17358                                  NaN
# 17359                                  NaN
# 17360                                  NaN
#
#        CURE START POSITION Θ Judge Value_Dam  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 17356                                    NaN
# 17357                                    NaN
# 17358                                    NaN
# 17359                                    NaN
# 17360                                    NaN
#
#        DISCHARGED SPEED OF RESIN Collect Result_Dam  \
# 0                                                10
# 1                                                16
# 2                                                10
# 3                                                10
# 4                                                16
# ...                                             ...
# 17356                                            10
# 17357                                            16
# 17358                                            16
# 17359                                            10
# 17360                                            10
#
#        DISCHARGED SPEED OF RESIN Unit Time_Dam  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 17356                                      NaN
# 17357                                      NaN
# 17358                                      NaN
# 17359                                      NaN
# 17360                                      NaN
#
#        DISCHARGED SPEED OF RESIN Judge Value_Dam  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 17356                                        NaN
# 17357                                        NaN
# 17358                                        NaN
# 17359                                        NaN
# 17360                                        NaN
#
#        DISCHARGED TIME OF RESIN(Stage1) Collect Result_Dam  \
# 0                                                   17.0
# 1                                                   14.2
# 2                                                    9.7
# 3                                                   21.3
# 4                                                   13.2
# ...                                                  ...
# 17356                                               21.3
# 17357                                               13.2
# 17358                                               13.2
# 17359                                                9.7
# 17360                                               17.0
#
#        DISCHARGED TIME OF RESIN(Stage1) Unit Time_Dam  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 17356                                             NaN
# 17357                                             NaN
# 17358                                             NaN
# 17359                                             NaN
# 17360                                             NaN
#
#        DISCHARGED TIME OF RESIN(Stage1) Judge Value_Dam  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 17356                                               NaN
# 17357                                               NaN
# 17358                                               NaN
# 17359                                               NaN
# 17360                                               NaN
#
#        DISCHARGED TIME OF RESIN(Stage2) Collect Result_Dam  \
# 0                                                    4.9
# 1                                                    8.3
# 2                                                    4.9
# 3                                                   10.6
# 4                                                    7.5
# ...                                                  ...
# 17356                                               10.6
# 17357                                                7.6
# 17358                                                6.6
# 17359                                                3.9
# 17360                                                4.9
#
#        DISCHARGED TIME OF RESIN(Stage2) Unit Time_Dam  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 17356                                             NaN
# 17357                                             NaN
# 17358                                             NaN
# 17359                                             NaN
# 17360                                             NaN
#
#        DISCHARGED TIME OF RESIN(Stage2) Judge Value_Dam  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 17356                                               NaN
# 17357                                               NaN
# 17358                                               NaN
# 17359                                               NaN
# 17360                                               NaN
#
#        DISCHARGED TIME OF RESIN(Stage3) Collect Result_Dam  \
# 0                                                   17.0
# 1                                                   14.2
# 2                                                    9.7
# 3                                                   21.3
# 4                                                   13.2
# ...                                                  ...
# 17356                                               21.3
# 17357                                               13.2
# 17358                                               13.2
# 17359                                                9.7
# 17360                                               17.1
#
#        DISCHARGED TIME OF RESIN(Stage3) Unit Time_Dam  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 17356                                             NaN
# 17357                                             NaN
# 17358                                             NaN
# 17359                                             NaN
# 17360                                             NaN
#
#        DISCHARGED TIME OF RESIN(Stage3) Judge Value_Dam  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 17356                                               NaN
# 17357                                               NaN
# 17358                                               NaN
# 17359                                               NaN
# 17360                                               NaN
#
#        Dispense Volume(Stage1) Collect Result_Dam  \
# 0                                            1.19
# 1                                            0.99
# 2                                            0.67
# 3                                            1.49
# 4                                            0.92
# ...                                           ...
# 17356                                        1.49
# 17357                                        0.92
# 17358                                        1.45
# 17359                                        0.67
# 17360                                        1.19
#
#        Dispense Volume(Stage1) Unit Time_Dam  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 17356                                    NaN
# 17357                                    NaN
# 17358                                    NaN
# 17359                                    NaN
# 17360                                    NaN
#
#        Dispense Volume(Stage1) Judge Value_Dam  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 17356                                      NaN
# 17357                                      NaN
# 17358                                      NaN
# 17359                                      NaN
# 17360                                      NaN
#
#        Dispense Volume(Stage2) Collect Result_Dam  \
# 0                                            0.34
# 1                                            0.58
# 2                                            0.34
# 3                                            0.74
# 4                                            0.52
# ...                                           ...
# 17356                                        0.74
# 17357                                        0.53
# 17358                                        0.72
# 17359                                        0.27
# 17360                                        0.34
#
#        Dispense Volume(Stage2) Unit Time_Dam  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 17356                                    NaN
# 17357                                    NaN
# 17358                                    NaN
# 17359                                    NaN
# 17360                                    NaN
#
#        Dispense Volume(Stage2) Judge Value_Dam  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 17356                                      NaN
# 17357                                      NaN
# 17358                                      NaN
# 17359                                      NaN
# 17360                                      NaN
#
#        Dispense Volume(Stage3) Collect Result_Dam  \
# 0                                            1.19
# 1                                            0.99
# 2                                            0.67
# 3                                            1.49
# 4                                            0.92
# ...                                           ...
# 17356                                        1.49
# 17357                                        0.92
# 17358                                        1.45
# 17359                                        0.67
# 17360                                        1.19
#
#        Dispense Volume(Stage3) Unit Time_Dam  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 17356                                    NaN
# 17357                                    NaN
# 17358                                    NaN
# 17359                                    NaN
# 17360                                    NaN
#
#        Dispense Volume(Stage3) Judge Value_Dam  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 17356                                      NaN
# 17357                                      NaN
# 17358                                      NaN
# 17359                                      NaN
# 17360                                      NaN
#
#       HEAD NORMAL COORDINATE X AXIS(Stage1) Collect Result_Dam  \
# 0                                                  162.4
# 1                                                     OK
# 2                                                  549.5
# 3                                                    NaN
# 4                                                     OK
# ...                                                  ...
# 17356                                                NaN
# 17357                                                 OK
# 17358                                                NaN
# 17359                                                549
# 17360                                                550
#
#        HEAD NORMAL COORDINATE X AXIS(Stage1) Unit Time_Dam  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 17356                                                NaN
# 17357                                                NaN
# 17358                                                NaN
# 17359                                                NaN
# 17360                                                NaN
#
#       HEAD NORMAL COORDINATE X AXIS(Stage1) Judge Value_Dam  \
# 0                                                    NaN
# 1                                                     OK
# 2                                                    NaN
# 3                                                    NaN
# 4                                                     OK
# ...                                                  ...
# 17356                                                NaN
# 17357                                                 OK
# 17358                                                NaN
# 17359                                                NaN
# 17360                                                NaN
#
#        HEAD NORMAL COORDINATE X AXIS(Stage2) Collect Result_Dam  \
# 0                                                  465.3
# 1                                                  162.4
# 2                                                  463.0
# 3                                                  164.2
# 4                                                  550.4
# ...                                                  ...
# 17356                                              162.4
# 17357                                              162.7
# 17358                                              551.5
# 17359                                              463.0
# 17360                                              463.5
#
#        HEAD NORMAL COORDINATE X AXIS(Stage2) Unit Time_Dam  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 17356                                                NaN
# 17357                                                NaN
# 17358                                                NaN
# 17359                                                NaN
# 17360                                                NaN
#
#        HEAD NORMAL COORDINATE X AXIS(Stage2) Judge Value_Dam  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 17356                                                NaN
# 17357                                                NaN
# 17358                                                NaN
# 17359                                                NaN
# 17360                                                NaN
#
#        HEAD NORMAL COORDINATE X AXIS(Stage3) Collect Result_Dam  \
# 0                                                  551.3
# 1                                                  465.4
# 2                                                  160.0
# 3                                                  467.1
# 4                                                  463.7
# ...                                                  ...
# 17356                                              465.5
# 17357                                              465.7
# 17358                                              465.0
# 17359                                              160.5
# 17360                                              160.5
#
#        HEAD NORMAL COORDINATE X AXIS(Stage3) Unit Time_Dam  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 17356                                                NaN
# 17357                                                NaN
# 17358                                                NaN
# 17359                                                NaN
# 17360                                                NaN
#
#        HEAD NORMAL COORDINATE X AXIS(Stage3) Judge Value_Dam  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 17356                                                NaN
# 17357                                                NaN
# 17358                                                NaN
# 17359                                                NaN
# 17360                                                NaN
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage1) Collect Result_Dam  \
# 0                                                 1271.3
# 1                                                  551.7
# 2                                                  377.5
# 3                                                  553.6
# 4                                                  161.3
# ...                                                  ...
# 17356                                              552.0
# 17357                                              552.0
# 17358                                              162.3
# 17359                                              377.5
# 17360                                              377.3
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage1) Unit Time_Dam  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 17356                                                NaN
# 17357                                                NaN
# 17358                                                NaN
# 17359                                                NaN
# 17360                                                NaN
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage1) Judge Value_Dam  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 17356                                                NaN
# 17357                                                NaN
# 17358                                                NaN
# 17359                                                NaN
# 17360                                                NaN
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage2) Collect Result_Dam  \
# 0                                                 1270.7
# 1                                                 1271.8
# 2                                                  377.0
# 3                                                 1271.8
# 4                                                  377.6
# ...                                                  ...
# 17356                                             1271.8
# 17357                                             1271.8
# 17358                                              377.6
# 17359                                              377.0
# 17360                                              377.3
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage2) Unit Time_Dam  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 17356                                                NaN
# 17357                                                NaN
# 17358                                                NaN
# 17359                                                NaN
# 17360                                                NaN
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage2) Judge Value_Dam  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 17356                                                NaN
# 17357                                                NaN
# 17358                                                NaN
# 17359                                                NaN
# 17360                                                NaN
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage3) Collect Result_Dam  \
# 0                                                 1271.3
# 1                                                 1383.9
# 2                                                  377.5
# 3                                                 1270.7
# 4                                                  377.1
# ...                                                  ...
# 17356                                             1270.7
# 17357                                             1383.9
# 17358                                              377.1
# 17359                                              377.5
# 17360                                              377.3
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage3) Unit Time_Dam  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 17356                                                NaN
# 17357                                                NaN
# 17358                                                NaN
# 17359                                                NaN
# 17360                                                NaN
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage3) Judge Value_Dam  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 17356                                                NaN
# 17357                                                NaN
# 17358                                                NaN
# 17359                                                NaN
# 17360                                                NaN
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage1) Collect Result_Dam  \
# 0                                                 282.15
# 1                                                1271.80
# 2                                                 284.60
# 3                                                1271.80
# 4                                                 377.60
# ...                                                  ...
# 17356                                            1271.80
# 17357                                            1271.80
# 17358                                             377.60
# 17359                                             284.80
# 17360                                             282.15
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage1) Unit Time_Dam  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 17356                                                NaN
# 17357                                                NaN
# 17358                                                NaN
# ...
# 17356                                      NaN
# 17357                                      NaN
# 17358                                      NaN
# 17359                                      NaN
# 17360                                      NaN
#
#        Head Clean Position Y Collect Result_Fill2  \
# 0                                              50
# 1                                             119
# 2                                              50
# 3                                             119
# 4                                             119
# ...                                           ...
# 17356                                         119
# 17357                                         119
# 17358                                         119
# 17359                                          50
# 17360                                          50
#
#        Head Clean Position Y Unit Time_Fill2  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 17356                                    NaN
# 17357                                    NaN
# 17358                                    NaN
# 17359                                    NaN
# 17360                                    NaN
#
#        Head Clean Position Y Judge Value_Fill2  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 17356                                      NaN
# 17357                                      NaN
# 17358                                      NaN
# 17359                                      NaN
# 17360                                      NaN
#
#        Head Clean Position Z Collect Result_Fill2  \
# 0                                            91.8
# 1                                            50.0
# 2                                            91.8
# 3                                            50.0
# 4                                            50.0
# ...                                           ...
# 17356                                        50.0
# 17357                                        50.0
# 17358                                        50.0
# 17359                                        91.8
# 17360                                        91.8
#
#        Head Clean Position Z Unit Time_Fill2  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 17356                                    NaN
# 17357                                    NaN
# 17358                                    NaN
# 17359                                    NaN
# 17360                                    NaN
#
#        Head Clean Position Z Judge Value_Fill2  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 17356                                      NaN
# 17357                                      NaN
# 17358                                      NaN
# 17359                                      NaN
# 17360                                      NaN
#
#        Head Purge Position X Collect Result_Fill2  \
# 0                                           270.0
# 1                                            91.8
# 2                                           270.0
# 3                                            91.8
# 4                                            91.8
# ...                                           ...
# 17356                                        91.8
# 17357                                        91.8
# 17358                                        91.8
# 17359                                       270.0
# 17360                                       270.0
#
#        Head Purge Position X Unit Time_Fill2  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 17356                                    NaN
# 17357                                    NaN
# 17358                                    NaN
# 17359                                    NaN
# 17360                                    NaN
#
#        Head Purge Position X Judge Value_Fill2  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 17356                                      NaN
# 17357                                      NaN
# 17358                                      NaN
# 17359                                      NaN
# 17360                                      NaN
#
#        Head Purge Position Y Collect Result_Fill2  \
# 0                                              50
# 1                                             270
# 2                                              50
# 3                                             270
# 4                                             270
# ...                                           ...
# 17356                                         270
# 17357                                         270
# 17358                                         270
# 17359                                          50
# 17360                                          50
#
#        Head Purge Position Y Unit Time_Fill2  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 17356                                    NaN
# 17357                                    NaN
# 17358                                    NaN
# 17359                                    NaN
# 17360                                    NaN
#
#        Head Purge Position Y Judge Value_Fill2  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 17356                                      NaN
# 17357                                      NaN
# 17358                                      NaN
# 17359                                      NaN
# 17360                                      NaN
#
#        Head Purge Position Z Collect Result_Fill2  \
# 0                                              85
# 1                                              50
# 2                                              85
# 3                                              50
# 4                                              50
# ...                                           ...
# 17356                                          50
# 17357                                          50
# 17358                                          50
# 17359                                          85
# 17360                                          85
#
#        Head Purge Position Z Unit Time_Fill2  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 17356                                    NaN
# 17357                                    NaN
# 17358                                    NaN
# 17359                                    NaN
# 17360                                    NaN
#
#        Head Purge Position Z Judge Value_Fill2  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 17356                                      NaN
# 17357                                      NaN
# 17358                                      NaN
# 17359                                      NaN
# 17360                                      NaN
#
#        Machine Tact time Collect Result_Fill2  \
# 0                                        19.8
# 1                                        85.0
# 2                                        19.7
# 3                                        85.0
# 4                                        85.0
# ...                                       ...
# 17356                                    85.0
# 17357                                    85.0
# 17358                                    85.0
# 17359                                    18.9
# 17360                                    19.3
#
#        Machine Tact time Unit Time_Fill2  Machine Tact time Judge Value_Fill2  \
# 0                                    NaN                                  NaN
# 1                                    NaN                                  NaN
# 2                                    NaN                                  NaN
# 3                                    NaN                                  NaN
# 4                                    NaN                                  NaN
# ...                                  ...                                  ...
# 17356                                NaN                                  NaN
# 17357                                NaN                                  NaN
# 17358                                NaN                                  NaN
# 17359                                NaN                                  NaN
# 17360                                NaN                                  NaN
#
#        PalletID Collect Result_Fill2  PalletID Unit Time_Fill2  \
# 0                               13.0                       NaN
# 1                               19.8                       NaN
# 2                                1.0                       NaN
# 3                               20.0                       NaN
# 4                               19.8                       NaN
# ...                              ...                       ...
# 17356                           19.5                       NaN
# 17357                           19.8                       NaN
# 17358                           20.5                       NaN
# 17359                            1.0                       NaN
# 17360                            2.0                       NaN
#
#        PalletID Judge Value_Fill2  Production Qty Collect Result_Fill2  \
# 0                             NaN                                  195
# 1                             NaN                                   14
# 2                             NaN                                   98
# 3                             NaN                                   14
# 4                             NaN                                    1
# ...                           ...                                  ...
# 17356                         NaN                                   14
# 17357                         NaN                                   12
# 17358                         NaN                                    4
# 17359                         NaN                                  117
# 17360                         NaN                                   71
#
#        Production Qty Unit Time_Fill2  Production Qty Judge Value_Fill2  \
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                                 NaN                               NaN
# ...                               ...                               ...
# 17356                             NaN                               NaN
# 17357                             NaN                               NaN
# 17358                             NaN                               NaN
# 17359                             NaN                               NaN
# 17360                             NaN                               NaN
#
#        Receip No Collect Result_Fill2  Receip No Unit Time_Fill2  \
# 0                                   1                        NaN
# 1                                 256                        NaN
# 2                                   1                        NaN
# 3                                   0                        NaN
# 4                                 215                        NaN
# ...                               ...                        ...
# 17356                             131                        NaN
# 17357                             279                        NaN
# 17358                              66                        NaN
# 17359                               1                        NaN
# 17360                               1                        NaN
#
#        Receip No Judge Value_Fill2  WorkMode Collect Result_Fill2  \
# 0                              NaN                              0
# 1                              NaN                              1
# 2                              NaN                              0
# 3                              NaN                              1
# 4                              NaN                              1
# ...                            ...                            ...
# 17356                          NaN                              1
# 17357                          NaN                              1
# 17358                          NaN                              1
# 17359                          NaN                              0
# 17360                          NaN                              0
#
#        WorkMode Unit Time_Fill2  WorkMode Judge Value_Fill2  target
# 0                           NaN                         NaN     NaN
# 1                           NaN                         NaN     NaN
# 2                           NaN                         NaN     NaN
# 3                           NaN                         NaN     NaN
# 4                           NaN                         NaN     NaN
# ...                         ...                         ...     ...
# 17356                       NaN                         NaN     NaN
# 17357                       NaN                         NaN     NaN
# 17358                       NaN                         NaN     NaN
# 17359                       NaN                         NaN     NaN
# 17360                       NaN                         NaN     NaN
#
# [17361 rows x 469 columns]

# %% [markdown]
# ## 2. 수기 데이터 읽어오기

# %% [markdown]
# 수기 데이터는 제조 환경과 관련된 정보들이 담겨있는 데이터입니다.

# %%
df_hand = pd.read_excel(os.path.join(ROOT_DIR, "hand_data.xlsx"))
df_hand
# Out:
#         day start_time  end_time  Dam Thickness - 1time / day  \
# 0    240319   08:00:00  10:30:00                        454.0
# 1    240319   10:45:00  12:00:00                        454.0
# 2    240319   13:00:00  15:00:00                        454.0
# 3    240319   15:15:00  18:00:00                        454.0
# 4    240319   18:30:00  20:00:00                          NaN
# ..      ...        ...       ...                          ...
# 100  240428   08:00:00  10:30:00                        478.0
# 101  240428   10:45:00  12:00:00                        478.0
# 102  240428   13:00:00  15:00:00                        478.0
# 103  240428   15:15:00  18:00:00                        478.0
# 104  240428   18:30:00  20:00:00                        478.0
#
#      Fill thickness - 1time / day  Fill cure energy (mJ) - Every break time  \
# 0                           193.0                                    1728.0
# 1                           193.0                                    1754.0
# 2                           193.0                                    1708.0
# 3                           193.0                                    1751.0
# 4                             NaN                                       NaN
# ..                            ...                                       ...
# 100                         232.0                                    1642.0
# 101                         232.0                                    1679.0
# 102                         232.0                                    1552.0
# 103                         232.0                                    1552.0
# 104                         232.0                                    1494.0
#
#      Fill cure power (mW) - Every break time  Line Temp. - Every break time  \
# 0                                     2919.0                           23.4
# 1                                     2962.0                           24.0
# 2                                     2887.0                           24.5
# 3                                     2946.0                           24.7
# 4                                        NaN                            NaN
# ..                                       ...                            ...
# 100                                   2952.0                           24.6
# 101                                   2942.0                           24.8
# 102                                   2941.0                           24.6
# 103                                   2934.0                           24.3
# 104                                   2928.0                           24.2
#
#      Line humidity - Every break time  OCR gap - Line#1 stage1  \
# 0                                56.6                      1.2
# 1                                50.9                      1.2
# 2                                49.6                      1.2
# 3                                53.4                      1.2
# 4                                 NaN                      NaN
# ..                                ...                      ...
# 100                              53.0                      1.0
# 101                              52.7                      1.0
# 102                              55.5                      1.0
# 103                              54.6                      1.0
# 104                              55.4                      1.0
#
#      OCR gap - Line#1 stage2  OCR gap - Line#1 stage3  \
# 0                      1.000                    1.200
# 1                      1.000                    1.200
# 2                      1.000                    1.200
# 3                      1.000                    1.200
# 4                        NaN                      NaN
# ..                       ...                      ...
# 100                    1.232                    1.466
# 101                    1.232                    1.466
# 102                    1.232                    1.466
# 103                    1.232                    1.466
# 104                    1.232                    1.466
#
#      OCR gap - Line #2 stage1  OCR gap - Line #2 stage2  \
# 0                         1.2                     0.900
# 1                         1.2                     0.900
# 2                         1.2                     0.900
# 3                         1.2                     1.200
# 4                         NaN                       NaN
# ..                        ...                       ...
# 100                       1.2                     1.167
# 101                       1.2                     1.167
# 102                       1.2                     1.167
# 103                       1.2                     1.167
# 104                       1.2                     1.167
#
#      OCR gap - Line #2 stage3
# 0                         1.4
# 1                         1.4
# 2                         1.4
# 3                         1.4
# 4                         NaN
# ..                        ...
# 100                       1.5
# 101                       1.5
# 102                       1.5
# 103                       1.5
# 104                       1.5
#
# [105 rows x 15 columns]

# %%
drop_col=[]
for col in train_data.columns:
  nullcount = train_data[col].isnull().sum()
  nunique = train_data[col].nunique()
  if nullcount == len(train_data):
    drop_col.append(col)
  if (nunique==1) & (nullcount == 0):
    drop_col.append(col)
    
train_data = train_data.drop(drop_col, axis=1)
test = test.drop(drop_col, axis=1)


train_data
# Out:
#           Equipment_Dam Model.Suffix_Dam Workorder_Dam     Collect Date_Dam  \
# 0      Dam dispenser #1      AJX75334505    4F1XA938-1  2024-04-25 11:10:00
# 1      Dam dispenser #1      AJX75334505    3KPM0016-2  2023-09-19 14:30:00
# 2      Dam dispenser #2      AJX75334501    4E1X9167-1  2024-03-05 09:30:00
# 3      Dam dispenser #2      AJX75334501    3K1X0057-1  2023-09-25 15:40:00
# 4      Dam dispenser #1      AJX75334501    3HPM0007-1  2023-06-27 13:20:00
# ...                 ...              ...           ...                  ...
# 40501  Dam dispenser #1      AJX75334501    3J1XF434-2  2023-09-14 15:50:00
# 40502  Dam dispenser #2      AJX75334501    4E1XC796-1  2024-04-10 14:20:00
# 40503  Dam dispenser #1      AJX75334501    4C1XD438-1  2024-02-22 08:40:00
# 40504  Dam dispenser #2      AJX75334501    3I1XA258-1  2023-07-25 11:00:00
# 40505  Dam dispenser #1      AJX75334501    3G1XA501-1  2023-05-31 01:40:00
#
#        CURE END POSITION X Collect Result_Dam  \
# 0                                       240.0
# 1                                       240.0
# 2                                      1000.0
# 3                                      1000.0
# 4                                       240.0
# ...                                       ...
# 40501                                   240.0
# 40502                                  1000.0
# 40503                                   240.0
# 40504                                  1000.0
# 40505                                   240.0
#
#        CURE END POSITION Z Collect Result_Dam  \
# 0                                         2.5
# 1                                         2.5
# 2                                        12.5
# 3                                        12.5
# 4                                         2.5
# ...                                       ...
# 40501                                     2.5
# 40502                                    12.5
# 40503                                     2.5
# 40504                                    12.5
# 40505                                     2.5
#
#        CURE END POSITION Θ Collect Result_Dam  CURE SPEED Collect Result_Dam  \
# 0                                         -90                            100
# 1                                         -90                             70
# 2                                          90                             85
# 3                                          90                             70
# 4                                         -90                             70
# ...                                       ...                            ...
# 40501                                     -90                             70
# 40502                                      90                            100
# 40503                                     -90                            100
# 40504                                      90                             70
# 40505                                     -90                             70
#
#        CURE START POSITION X Collect Result_Dam  \
# 0                                          1030
# 1                                          1030
# 2                                           280
# 3                                           280
# 4                                          1030
# ...                                         ...
# 40501                                      1030
# 40502                                       280
# 40503                                      1030
# 40504                                       280
# 40505                                      1030
#
#        CURE START POSITION Θ Collect Result_Dam  \
# 0                                           -90
# 1                                           -90
# 2                                            90
# 3                                            90
# 4                                           -90
# ...                                         ...
# 40501                                       -90
# 40502                                        90
# 40503                                       -90
# 40504                                        90
# 40505                                       -90
#
#        DISCHARGED SPEED OF RESIN Collect Result_Dam  \
# 0                                                16
# 1                                                10
# 2                                                16
# 3                                                10
# 4                                                10
# ...                                             ...
# 40501                                            10
# 40502                                            16
# 40503                                            16
# 40504                                            10
# 40505                                            10
#
#        DISCHARGED TIME OF RESIN(Stage1) Collect Result_Dam  \
# 0                                                   14.9
# 1                                                   21.3
# 2                                                   14.7
# 3                                                   21.3
# 4                                                    9.7
# ...                                                  ...
# 40501                                               17.0
# 40502                                               14.9
# 40503                                               14.2
# 40504                                                9.7
# 40505                                                9.6
#
#        DISCHARGED TIME OF RESIN(Stage2) Collect Result_Dam  \
# 0                                                    8.4
# 1                                                    4.9
# 2                                                    8.5
# 3                                                    8.4
# 4                                                    4.9
# ...                                                  ...
# 40501                                                5.0
# 40502                                                8.5
# 40503                                                8.2
# 40504                                                4.9
# 40505                                                3.9
#
#        DISCHARGED TIME OF RESIN(Stage3) Collect Result_Dam  \
# 0                                                   14.7
# 1                                                   21.3
# 2                                                   14.7
# 3                                                   21.3
# 4                                                    9.6
# ...                                                  ...
# 40501                                               17.0
# 40502                                               14.7
# 40503                                               14.3
# 40504                                                9.7
# 40505                                                9.7
#
#        Dispense Volume(Stage1) Collect Result_Dam  \
# 0                                            1.04
# 1                                            1.49
# 2                                            1.61
# 3                                            1.49
# 4                                            0.67
# ...                                           ...
# 40501                                        1.19
# 40502                                        1.04
# 40503                                        0.99
# 40504                                        0.67
# 40505                                        0.67
#
#        Dispense Volume(Stage2) Collect Result_Dam  \
# 0                                            0.58
# 1                                            0.34
# 2                                            0.93
# 3                                            0.58
# 4                                            0.34
# ...                                           ...
# 40501                                        0.35
# 40502                                        0.59
# 40503                                        0.57
# 40504                                        0.34
# 40505                                        0.27
#
#        Dispense Volume(Stage3) Collect Result_Dam  \
# 0                                            1.02
# 1                                            1.49
# 2                                            1.61
# 3                                            1.49
# 4                                            0.67
# ...                                           ...
# 40501                                        1.19
# 40502                                        1.02
# 40503                                        1.00
# 40504                                        0.67
# 40505                                        0.67
#
#       HEAD NORMAL COORDINATE X AXIS(Stage1) Collect Result_Dam  \
# 0                                                    NaN
# 1                                                  550.3
# 2                                                     OK
# 3                                                  162.4
# 4                                                    549
# ...                                                  ...
# 40501                                              550.3
# 40502                                                NaN
# 40503                                                 OK
# 40504                                              162.4
# 40505                                                549
#
#       HEAD NORMAL COORDINATE X AXIS(Stage1) Judge Value_Dam  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                     OK
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 40501                                                NaN
# 40502                                                NaN
# 40503                                                 OK
# 40504                                                NaN
# 40505                                                NaN
#
#        HEAD NORMAL COORDINATE X AXIS(Stage2) Collect Result_Dam  \
# 0                                                  550.5
# 1                                                  463.8
# 2                                                  162.4
# 3                                                  465.5
# 4                                                  462.5
# ...                                                  ...
# 40501                                              463.8
# 40502                                              163.5
# 40503                                              550.6
# 40504                                              465.1
# 40505                                              463.0
#
#        HEAD NORMAL COORDINATE X AXIS(Stage3) Collect Result_Dam  \
# 0                                                  464.3
# 1                                                  160.8
# 2                                                  465.4
# 3                                                  552.0
# 4                                                  159.5
# ...                                                  ...
# 40501                                              160.8
# 40502                                              466.2
# 40503                                              463.9
# 40504                                              551.3
# 40505                                              160.5
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage1) Collect Result_Dam  \
# 0                                                  161.4
# 1                                                  377.3
# 2                                                  551.7
# 3                                                 1271.8
# 4                                                  377.5
# ...                                                  ...
# 40501                                              377.3
# 40502                                              553.1
# 40503                                              161.5
# 40504                                             1269.0
# 40505                                              377.5
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage2) Collect Result_Dam  \
# 0                                                  384.0
# 1                                                  377.3
# 2                                                 1271.8
# 3                                                 1270.7
# 4                                                  377.0
# ...                                                  ...
# 40501                                              377.3
# 40502                                             1281.0
# 40503                                              377.6
# 40504                                             1268.4
# 40505                                              377.0
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage3) Collect Result_Dam  \
# 0                                                  383.1
# 1                                                  377.3
# 2                                                 1383.9
# 3                                                 1271.8
# 4                                                  377.5
# ...                                                  ...
# 40501                                              377.3
# 40502                                             1393.5
# 40503                                              377.1
# 40504                                             1269.0
# 40505                                              377.5
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage1) Collect Result_Dam  \
# 0                                                 384.00
# 1                                                 282.15
# 2                                                1271.80
# 3                                                 282.15
# 4                                                 284.80
# ...                                                  ...
# 40501                                             282.15
# 40502                                            1281.20
# 40503                                             378.00
# 40504                                             282.15
# 40505                                             284.80
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage2) Collect Result_Dam  \
# 0                                                 274.51
# 1                                                 282.15
# 2                                                 274.33
# 3                                                 282.15
# 4                                                 284.80
# ...                                                  ...
# 40501                                             282.15
# 40502                                             274.33
# 40503                                             274.78
# 40504                                             282.15
# 40505                                             284.80
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage3) Collect Result_Dam  \
# 0                                                 274.51
# 1                                                 282.15
# 2                                                 274.33
# 3                                                 282.15
# 4                                                 284.80
# ...                                                  ...
# 40501                                             282.15
# 40502                                             274.33
# 40503                                             274.78
# 40504                                             282.15
# 40505                                             284.80
#
#        HEAD Standby Position X Collect Result_Dam  \
# 0                                          274.51
# 1                                          257.00
# 2                                          274.33
# 3                                          257.00
# 4                                          257.00
# ...                                           ...
# 40501                                      257.00
# 40502                                      274.33
# 40503                                      274.78
# 40504                                      257.00
# 40505                                      257.00
#
#        HEAD Standby Position Y Collect Result_Dam  \
# 0                                             257
# 1                                              66
# 2                                             257
# 3                                              66
# 4                                              66
# ...                                           ...
# 40501                                          66
# 40502                                         257
# 40503                                         257
# 40504                                          66
# 40505                                          66
#
#        HEAD Standby Position Z Collect Result_Dam  \
# 0                                              66
# 1                                               0
# 2                                              66
# 3                                               0
# 4                                               0
# ...                                           ...
# 40501                                           0
# 40502                                          66
# 40503                                          66
# 40504                                           0
# 40505                                           0
#
#        Head Clean Position X Collect Result_Dam  \
# 0                                           0.0
# 1                                         127.5
# 2                                           0.0
# 3                                         127.5
# 4                                         127.5
# ...                                         ...
# 40501                                     127.5
# 40502                                       0.0
# 40503                                       0.0
# 40504                                     127.5
# 40505                                     127.5
#
#        Head Clean Position Y Collect Result_Dam  \
# 0                                         127.5
# 1                                          66.0
# 2                                         127.5
# 3                                          66.0
# 4                                          66.0
# ...                                         ...
# 40501                                      66.0
# 40502                                     127.5
# 40503                                     127.5
# 40504                                      66.0
# 40505                                      66.0
#
#        Head Clean Position Z Collect Result_Dam  \
# 0                                         66.00
# 1                                        130.85
# 2                                         66.00
# 3                                        130.85
# 4                                        133.50
# ...                                         ...
# 40501                                    130.85
# 40502                                     66.00
# 40503                                     66.00
# 40504                                    130.85
# 40505                                    133.50
#
#        Head Purge Position X Collect Result_Dam  \
# 0                                         124.0
# 1                                         257.0
# 2                                         124.0
# 3                                         257.0
# 4                                         257.0
# ...                                         ...
# 40501                                     257.0
# 40502                                     124.0
# 40503                                     124.0
# 40504                                     257.0
# 40505                                     257.0
#
#        Head Purge Position Y Collect Result_Dam  \
# 0                                           257
# 1                                            66
# 2                                           257
# 3                                            66
# 4                                            66
# ...                                         ...
# 40501                                        66
# 40502                                       257
# 40503                                       257
# 40504                                        66
# 40505                                        66
#
#        Head Purge Position Z Collect Result_Dam  \
# 0                                         66.00
# 1                                        130.85
# 2                                         66.00
# 3                                        130.85
# 4                                        133.50
# ...                                         ...
# 40501                                    130.85
# 40502                                     66.00
# 40503                                     66.00
# 40504                                    130.85
# 40505                                    133.50
#
#        Head Zero Position X Collect Result_Dam  \
# 0                                       130.85
# 1                                       505.00
# 2                                       130.85
# 3                                       505.00
# 4                                       505.00
# ...                                        ...
# 40501                                   505.00
# 40502                                   130.85
# 40503                                   130.85
# 40504                                   505.00
# 40505                                   505.00
#
#        Head Zero Position Y Collect Result_Dam  \
# 0                                        505.0
# 1                                        300.0
# 2                                        505.0
# 3                                        300.0
# 4                                        300.0
# ...                                        ...
# 40501                                    300.0
# 40502                                    505.0
# 40503                                    505.0
# 40504                                    300.0
# 40505                                    303.5
#
#        Head Zero Position Z Collect Result_Dam  \
# 0                                        300.0
# 1                                        265.0
# 2                                        300.0
# 3                                        265.0
# 4                                        265.0
# ...                                        ...
# 40501                                    265.0
# 40502                                    300.0
# 40503                                    300.0
# 40504                                    265.0
# 40505                                    265.0
#
#        Machine Tact time Collect Result_Dam  PalletID Collect Result_Dam  \
# 0                                    265.00                         58.5
# 1                                     65.10                          7.0
# 2                                    265.02                         76.9
# 3                                     70.50                         12.0
# 4                                     88.30                          8.0
# ...                                     ...                          ...
# 40501                                 56.70                          1.0
# 40502                                265.00                         78.5
# 40503                                265.02                         69.5
# 40504                                 57.70                         13.0
# 40505                                 92.10                          3.0
#
#        Production Qty Collect Result_Dam  Receip No Collect Result_Dam  \
# 0                                      7                           127
# 1                                    185                             1
# 2                                     10                            73
# 3                                    268                             1
# 4                                    121                             1
# ...                                  ...                           ...
# 40501                                318                             1
# 40502                                 14                           197
# 40503                                  1                            27
# 40504                                117                             1
# 40505                                320                             1
#
#        Stage1 Circle1 Distance Speed Collect Result_Dam  \
# 0                                                     1
# 1                                                  4000
# 2                                                     1
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                                 1
# 40503                                                 1
# 40504                                              9000
# 40505                                              9000
#
#        Stage1 Circle2 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage1 Circle3 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage1 Circle4 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage1 Line1 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage1 Line2 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage1 Line3 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage1 Line4 Distance Speed Collect Result_Dam  \
# 0                                                5600
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5600
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage2 Circle1 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  9000
# 2                                                  5800
# 3                                                  5000
# 4                                                  9000
# ...                                                 ...
# 40501                                              9000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                             12000
#
#        Stage2 Circle2 Distance Speed Collect Result_Dam  \
# 0                                                  5300
# 1                                                  9000
# 2                                                  5300
# 3                                                  5000
# 4                                                  9000
# ...                                                 ...
# 40501                                              9000
# 40502                                              5300
# 40503                                              5500
# 40504                                              9000
# 40505                                             12000
#
#        Stage2 Circle3 Distance Speed Collect Result_Dam  \
# 0                                                  5300
# 1                                                  9000
# 2                                                  5300
# 3                                                  5000
# 4                                                  9000
# ...                                                 ...
# 40501                                              9000
# 40502                                              5300
# 40503                                              5500
# 40504                                              9000
# 40505                                             12000
#
#        Stage2 Circle4 Distance Speed Collect Result_Dam  \
# 0                                                  5300
# 1                                                  9000
# 2                                                  5300
# 3                                                  5000
# 4                                                  9000
# ...                                                 ...
# 40501                                              9000
# 40502                                              5300
# 40503                                              5500
# 40504                                              9000
# 40505                                             12000
#
#        Stage2 Line1 Distance Speed Collect Result_Dam  \
# 0                                                5300
# 1                                                9000
# 2                                                5300
# 3                                                5000
# 4                                                9000
# ...                                               ...
# 40501                                            9000
# 40502                                            5300
# 40503                                            5500
# 40504                                            9000
# 40505                                           12000
#
#        Stage2 Line2 Distance Speed Collect Result_Dam  \
# 0                                                5300
# 1                                                9000
# 2                                                5300
# 3                                                5000
# 4                                                9000
# ...                                               ...
# 40501                                            9000
# 40502                                            5300
# 40503                                            5500
# 40504                                            9000
# 40505                                           12000
#
#        Stage2 Line3 Distance Speed Collect Result_Dam  \
# 0                                                5300
# 1                                                9000
# 2                                                5300
# 3                                                5000
# 4                                                9000
# ...                                               ...
# 40501                                            9000
# 40502                                            5300
# 40503                                            5500
# 40504                                            9000
# 40505                                           12000
#
#        Stage2 Line4 Distance Speed Collect Result_Dam  \
# 0                                                5300
# 1                                                9000
# 2                                                5300
# 3                                                5000
# 4                                                9000
# ...                                               ...
# 40501                                            9000
# 40502                                            5300
# 40503                                            5500
# 40504                                            9000
# 40505                                           12000
#
#        Stage3 Circle1 Distance Speed Collect Result_Dam  \
# 0                                                  5300
# 1                                                  4000
# 2                                                  5300
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5300
# 40503                                              5500
# 40504                                              9000
# 40505                                              9000
#
#        Stage3 Circle2 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage3 Circle3 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage3 Circle4 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage3 Line1 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage3 Line2 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage3 Line3 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage3 Line4 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        THICKNESS 1 Collect Result_Dam  THICKNESS 2 Collect Result_Dam  \
# 0                                5800                           0.000
# 1                                   0                           0.000
# 2                                5800                           0.012
# 3                                   0                           0.000
# 4                                   0                           0.000
# ...                               ...                             ...
# 40501                               0                           0.000
# 40502                            5800                          -0.019
# 40503                            6000                           0.000
# 40504                               0                           0.000
# 40505                               0                           0.000
#
#        THICKNESS 3 Collect Result_Dam  WorkMode Collect Result_Dam  \
# 0                               0.000                        0.000
# 1                               0.000                        7.000
# 2                              -0.022                        0.003
# 3                               0.000                        7.000
# 4                               0.000                        7.000
# ...                               ...                          ...
# 40501                           0.000                        7.000
# 40502                          -0.021                       -0.118
# 40503                           0.000                        0.000
# 40504                           0.000                        7.000
# 40505                           0.000                        7.000
#
#       Model.Suffix_AutoClave Workorder_AutoClave Collect Date_AutoClave  \
# 0                AJX75334505          4F1XA938-1    2024-04-25 11:50:00
# 1                AJX75334505          3KPM0016-2    2023-09-19 15:00:00
# 2                AJX75334501          4E1X9167-1    2024-03-05 10:10:00
# 3                AJX75334501          3K1X0057-1    2023-09-25 16:20:00
# 4                AJX75334501          3HPM0007-1    2023-06-27 14:00:00
# ...                      ...                 ...                    ...
# 40501            AJX75334501          3J1XF434-2    2023-09-14 16:30:00
# 40502            AJX75334501          4E1XC796-1    2024-04-10 15:00:00
# 40503            AJX75334501          4C1XD438-1    2024-02-22 09:20:00
# 40504            AJX75334501          3I1XA258-1    2023-07-25 11:40:00
# 40505            AJX75334501          3G1XA501-1    2023-05-31 02:10:00
#
#        1st Pressure Collect Result_AutoClave  \
# 0                                      0.312
# 1                                      0.311
# 2                                      0.315
# 3                                      0.299
# 4                                      0.302
# ...                                      ...
# 40501                                  0.300
# 40502                                  0.305
# 40503                                  0.309
# 40504                                  0.302
# 40505                                  0.305
#
#        1st Pressure 1st Pressure Unit Time_AutoClave  \
# 0                                                240
# 1                                                241
# 2                                                241
# 3                                                241
# 4                                                240
# ...                                              ...
# 40501                                            241
# 40502                                            240
# 40503                                            241
# 40504                                            241
# 40505                                            300
#
#        2nd Pressure Collect Result_AutoClave  \
# 0                                      0.493
# 1                                      0.311
# 2                                      0.490
# 3                                      0.300
# 4                                      0.302
# ...                                      ...
# 40501                                  0.300
# 40502                                  0.493
# 40503                                  0.490
# 40504                                  0.303
# 40505                                  0.305
#
#        2nd Pressure Unit Time_AutoClave  \
# 0                                     1
# 1                                   121
# 2                                     1
# 3                                   121
# 4                                   120
# ...                                 ...
# 40501                               121
# 40502                                 1
# 40503                                 1
# 40504                               121
# 40505                                60
#
# ...
# 40503                                                 OK
# 40504                                                305
# 40505                                              835.5
#
#       HEAD NORMAL COORDINATE X AXIS(Stage1) Judge Value_Fill2  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                     OK
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 40501                                                NaN
# 40502                                                NaN
# 40503                                                 OK
# 40504                                                NaN
# 40505                                                NaN
#
#        HEAD NORMAL COORDINATE X AXIS(Stage2) Collect Result_Fill2  \
# 0                                                  835.5
# 1                                                  458.0
# 2                                                  305.0
# 3                                                  499.8
# 4                                                  458.0
# ...                                                  ...
# 40501                                              458.0
# 40502                                              304.8
# 40503                                              835.5
# 40504                                              499.8
# 40505                                              458.0
#
#        HEAD NORMAL COORDINATE X AXIS(Stage3) Collect Result_Fill2  \
# 0                                                  458.0
# 1                                                  156.0
# 2                                                  499.8
# 3                                                  694.0
# 4                                                  156.0
# ...                                                  ...
# 40501                                              156.0
# 40502                                              499.8
# 40503                                              458.0
# 40504                                              694.0
# 40505                                              156.0
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage1) Collect Result_Fill2  \
# 0                                                  156.0
# 1                                                  428.0
# 2                                                  694.0
# 3                                                 1324.2
# 4                                                  428.0
# ...                                                  ...
# 40501                                              428.0
# 40502                                              692.8
# 40503                                              156.0
# 40504                                             1324.2
# 40505                                              428.0
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage2) Collect Result_Fill2  \
# 0                                                  428.0
# 1                                                  427.9
# 2                                                 1324.2
# 3                                                 1324.2
# 4                                                  427.9
# ...                                                  ...
# 40501                                              427.9
# 40502                                             1324.2
# 40503                                              428.0
# 40504                                             1324.2
# 40505                                              427.9
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage3) Collect Result_Fill2  \
# 0                                                  427.9
# 1                                                  428.0
# 2                                                 1324.2
# 3                                                 1324.2
# 4                                                  428.0
# ...                                                  ...
# 40501                                              428.0
# 40502                                             1324.2
# 40503                                              427.9
# 40504                                             1324.2
# 40505                                              428.0
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage1) Collect Result_Fill2  \
# 0                                                  428.0
# 1                                                  243.7
# 2                                                 1324.2
# 3                                                  243.5
# 4                                                  243.7
# ...                                                  ...
# 40501                                              243.7
# 40502                                             1324.2
# 40503                                              428.0
# 40504                                              243.5
# 40505                                              243.7
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage2) Collect Result_Fill2  \
# 0                                                  243.7
# 1                                                  243.7
# 2                                                  243.5
# 3                                                  243.5
# 4                                                  243.7
# ...                                                  ...
# 40501                                              243.7
# 40502                                              243.5
# 40503                                              243.7
# 40504                                              243.5
# 40505                                              243.7
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage3) Collect Result_Fill2  \
# 0                                                  243.7
# 1                                                  243.7
# 2                                                  243.5
# 3                                                  243.5
# 4                                                  243.7
# ...                                                  ...
# 40501                                              243.7
# 40502                                              243.5
# 40503                                              243.7
# 40504                                              243.5
# 40505                                              243.7
#
#        HEAD Standby Position X Collect Result_Fill2  \
# 0                                             243.7
# 1                                             270.0
# 2                                             243.5
# 3                                             270.0
# 4                                             270.0
# ...                                             ...
# 40501                                         270.0
# 40502                                         243.5
# 40503                                         243.7
# 40504                                         270.0
# 40505                                         270.0
#
#        HEAD Standby Position Y Collect Result_Fill2  \
# 0                                               270
# 1                                                50
# 2                                               270
# 3                                                50
# 4                                                50
# ...                                             ...
# 40501                                            50
# 40502                                           270
# 40503                                           270
# 40504                                            50
# 40505                                            50
#
#        HEAD Standby Position Z Collect Result_Fill2  \
# 0                                                50
# 1                                               -10
# 2                                                50
# 3                                               -10
# 4                                               -10
# ...                                             ...
# 40501                                           -10
# 40502                                            50
# 40503                                            50
# 40504                                           -10
# 40505                                           -10
#
#        Head Clean Position X Collect Result_Fill2  \
# 0                                             -10
# 1                                             119
# 2                                             -10
# 3                                             119
# 4                                             119
# ...                                           ...
# 40501                                         119
# 40502                                         -10
# 40503                                         -10
# 40504                                         119
# 40505                                         119
#
#        Head Clean Position Y Collect Result_Fill2  \
# 0                                             119
# 1                                              50
# 2                                             119
# 3                                              50
# 4                                              50
# ...                                           ...
# 40501                                          50
# 40502                                         119
# 40503                                         119
# 40504                                          50
# 40505                                          50
#
#        Head Clean Position Z Collect Result_Fill2  \
# 0                                            50.0
# 1                                            91.8
# 2                                            50.0
# 3                                            91.8
# 4                                            91.8
# ...                                           ...
# 40501                                        91.8
# 40502                                        50.0
# 40503                                        50.0
# 40504                                        91.8
# 40505                                        91.8
#
#        Head Purge Position X Collect Result_Fill2  \
# 0                                            91.8
# 1                                           270.0
# 2                                            91.8
# 3                                           270.0
# 4                                           270.0
# ...                                           ...
# 40501                                       270.0
# 40502                                        91.8
# 40503                                        91.8
# 40504                                       270.0
# 40505                                       270.0
#
#        Head Purge Position Y Collect Result_Fill2  \
# 0                                             270
# 1                                              50
# 2                                             270
# 3                                              50
# 4                                              50
# ...                                           ...
# 40501                                          50
# 40502                                         270
# 40503                                         270
# 40504                                          50
# 40505                                          50
#
#        Head Purge Position Z Collect Result_Fill2  \
# 0                                              50
# 1                                              85
# 2                                              50
# 3                                              85
# 4                                              85
# ...                                           ...
# 40501                                          85
# 40502                                          50
# 40503                                          50
# 40504                                          85
# 40505                                          85
#
#        Machine Tact time Collect Result_Fill2  PalletID Collect Result_Fill2  \
# 0                                     114.612                           19.9
# 1                                      19.600                            7.0
# 2                                     114.612                           19.8
# 3                                      19.900                           12.0
# 4                                      19.700                            8.0
# ...                                       ...                            ...
# 40501                                  19.200                            1.0
# 40502                                 114.612                           20.5
# 40503                                  85.000                           19.7
# 40504                                  20.100                           13.0
# 40505                                  19.400                            3.0
#
#        Production Qty Collect Result_Fill2  Receip No Collect Result_Fill2  \
# 0                                        7                             127
# 1                                      185                               1
# 2                                       10                              73
# 3                                      268                               1
# 4                                      121                               1
# ...                                    ...                             ...
# 40501                                  318                               1
# 40502                                   14                             197
# 40503                                    1                              27
# 40504                                  117                               1
# 40505                                  320                               1
#
#        WorkMode Collect Result_Fill2    target
# 0                                  1    Normal
# 1                                  0    Normal
# 2                                  1    Normal
# 3                                  0    Normal
# 4                                  0    Normal
# ...                              ...       ...
# 40501                              0    Normal
# 40502                              1    Normal
# 40503                              1    Normal
# 40504                              0    Normal
# 40505                              0  AbNormal
#
# [40506 rows x 155 columns]

# %%
cols=["Model.Suffix_Dam","Model.Suffix_AutoClave","Model.Suffix_Fill1","Model.Suffix_Fill2"]

train_data["Model.Suffix"]= train_data["Model.Suffix_Dam"]
train_data = train_data.drop(cols, axis=1)

cols=["Model.Suffix_Dam","Model.Suffix_AutoClave","Model.Suffix_Fill1","Model.Suffix_Fill2"]

test["Model.Suffix"]= test["Model.Suffix_Dam"]
test = test.drop(cols, axis=1)


cols=["Workorder_Dam","Workorder_AutoClave","Workorder_Fill1","Workorder_Fill2"]

train_data["Workorder"]= train_data["Workorder_Dam"]
train_data = train_data.drop(cols, axis=1)

cols=["Workorder_Dam","Workorder_AutoClave","Workorder_Fill1","Workorder_Fill2"]

test["Workorder"]= test["Workorder_Dam"]
test = test.drop(cols, axis=1)

# %%
train_data['running_time'] = pd.to_datetime(train_data['Collect Date_AutoClave']) - pd.to_datetime(train_data['Collect Date_Dam'])
train_data['running_time_m'] = train_data['running_time'].dt.total_seconds() / 60

# %%
train_data['Collect Date_Dam'] = pd.to_datetime(train_data['Collect Date_Dam'])
train_data['month'] = train_data['Collect Date_Dam'].dt.month
train_data['day'] = train_data['Collect Date_Dam'].dt.day
train_data['hour'] = train_data['Collect Date_Dam'].dt.hour

# %%
train_data['out_of_hour'] = 0  # 기본값으로 0 설정
train_data.loc[(train_data['hour'] < 8) | (train_data['hour'] > 20), 'out_of_hour'] = 1  # 조건을 만족하는 경우 a열에 1을 할당

# %%
train_data
# Out:
#           Equipment_Dam    Collect Date_Dam  \
# 0      Dam dispenser #1 2024-04-25 11:10:00
# 1      Dam dispenser #1 2023-09-19 14:30:00
# 2      Dam dispenser #2 2024-03-05 09:30:00
# 3      Dam dispenser #2 2023-09-25 15:40:00
# 4      Dam dispenser #1 2023-06-27 13:20:00
# ...                 ...                 ...
# 40501  Dam dispenser #1 2023-09-14 15:50:00
# 40502  Dam dispenser #2 2024-04-10 14:20:00
# 40503  Dam dispenser #1 2024-02-22 08:40:00
# 40504  Dam dispenser #2 2023-07-25 11:00:00
# 40505  Dam dispenser #1 2023-05-31 01:40:00
#
#        CURE END POSITION X Collect Result_Dam  \
# 0                                       240.0
# 1                                       240.0
# 2                                      1000.0
# 3                                      1000.0
# 4                                       240.0
# ...                                       ...
# 40501                                   240.0
# 40502                                  1000.0
# 40503                                   240.0
# 40504                                  1000.0
# 40505                                   240.0
#
#        CURE END POSITION Z Collect Result_Dam  \
# 0                                         2.5
# 1                                         2.5
# 2                                        12.5
# 3                                        12.5
# 4                                         2.5
# ...                                       ...
# 40501                                     2.5
# 40502                                    12.5
# 40503                                     2.5
# 40504                                    12.5
# 40505                                     2.5
#
#        CURE END POSITION Θ Collect Result_Dam  CURE SPEED Collect Result_Dam  \
# 0                                         -90                            100
# 1                                         -90                             70
# 2                                          90                             85
# 3                                          90                             70
# 4                                         -90                             70
# ...                                       ...                            ...
# 40501                                     -90                             70
# 40502                                      90                            100
# 40503                                     -90                            100
# 40504                                      90                             70
# 40505                                     -90                             70
#
#        CURE START POSITION X Collect Result_Dam  \
# 0                                          1030
# 1                                          1030
# 2                                           280
# 3                                           280
# 4                                          1030
# ...                                         ...
# 40501                                      1030
# 40502                                       280
# 40503                                      1030
# 40504                                       280
# 40505                                      1030
#
#        CURE START POSITION Θ Collect Result_Dam  \
# 0                                           -90
# 1                                           -90
# 2                                            90
# 3                                            90
# 4                                           -90
# ...                                         ...
# 40501                                       -90
# 40502                                        90
# 40503                                       -90
# 40504                                        90
# 40505                                       -90
#
#        DISCHARGED SPEED OF RESIN Collect Result_Dam  \
# 0                                                16
# 1                                                10
# 2                                                16
# 3                                                10
# 4                                                10
# ...                                             ...
# 40501                                            10
# 40502                                            16
# 40503                                            16
# 40504                                            10
# 40505                                            10
#
#        DISCHARGED TIME OF RESIN(Stage1) Collect Result_Dam  \
# 0                                                   14.9
# 1                                                   21.3
# 2                                                   14.7
# 3                                                   21.3
# 4                                                    9.7
# ...                                                  ...
# 40501                                               17.0
# 40502                                               14.9
# 40503                                               14.2
# 40504                                                9.7
# 40505                                                9.6
#
#        DISCHARGED TIME OF RESIN(Stage2) Collect Result_Dam  \
# 0                                                    8.4
# 1                                                    4.9
# 2                                                    8.5
# 3                                                    8.4
# 4                                                    4.9
# ...                                                  ...
# 40501                                                5.0
# 40502                                                8.5
# 40503                                                8.2
# 40504                                                4.9
# 40505                                                3.9
#
#        DISCHARGED TIME OF RESIN(Stage3) Collect Result_Dam  \
# 0                                                   14.7
# 1                                                   21.3
# 2                                                   14.7
# 3                                                   21.3
# 4                                                    9.6
# ...                                                  ...
# 40501                                               17.0
# 40502                                               14.7
# 40503                                               14.3
# 40504                                                9.7
# 40505                                                9.7
#
#        Dispense Volume(Stage1) Collect Result_Dam  \
# 0                                            1.04
# 1                                            1.49
# 2                                            1.61
# 3                                            1.49
# 4                                            0.67
# ...                                           ...
# 40501                                        1.19
# 40502                                        1.04
# 40503                                        0.99
# 40504                                        0.67
# 40505                                        0.67
#
#        Dispense Volume(Stage2) Collect Result_Dam  \
# 0                                            0.58
# 1                                            0.34
# 2                                            0.93
# 3                                            0.58
# 4                                            0.34
# ...                                           ...
# 40501                                        0.35
# 40502                                        0.59
# 40503                                        0.57
# 40504                                        0.34
# 40505                                        0.27
#
#        Dispense Volume(Stage3) Collect Result_Dam  \
# 0                                            1.02
# 1                                            1.49
# 2                                            1.61
# 3                                            1.49
# 4                                            0.67
# ...                                           ...
# 40501                                        1.19
# 40502                                        1.02
# 40503                                        1.00
# 40504                                        0.67
# 40505                                        0.67
#
#       HEAD NORMAL COORDINATE X AXIS(Stage1) Collect Result_Dam  \
# 0                                                    NaN
# 1                                                  550.3
# 2                                                     OK
# 3                                                  162.4
# 4                                                    549
# ...                                                  ...
# 40501                                              550.3
# 40502                                                NaN
# 40503                                                 OK
# 40504                                              162.4
# 40505                                                549
#
#       HEAD NORMAL COORDINATE X AXIS(Stage1) Judge Value_Dam  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                     OK
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 40501                                                NaN
# 40502                                                NaN
# 40503                                                 OK
# 40504                                                NaN
# 40505                                                NaN
#
#        HEAD NORMAL COORDINATE X AXIS(Stage2) Collect Result_Dam  \
# 0                                                  550.5
# 1                                                  463.8
# 2                                                  162.4
# 3                                                  465.5
# 4                                                  462.5
# ...                                                  ...
# 40501                                              463.8
# 40502                                              163.5
# 40503                                              550.6
# 40504                                              465.1
# 40505                                              463.0
#
#        HEAD NORMAL COORDINATE X AXIS(Stage3) Collect Result_Dam  \
# 0                                                  464.3
# 1                                                  160.8
# 2                                                  465.4
# 3                                                  552.0
# 4                                                  159.5
# ...                                                  ...
# 40501                                              160.8
# 40502                                              466.2
# 40503                                              463.9
# 40504                                              551.3
# 40505                                              160.5
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage1) Collect Result_Dam  \
# 0                                                  161.4
# 1                                                  377.3
# 2                                                  551.7
# 3                                                 1271.8
# 4                                                  377.5
# ...                                                  ...
# 40501                                              377.3
# 40502                                              553.1
# 40503                                              161.5
# 40504                                             1269.0
# 40505                                              377.5
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage2) Collect Result_Dam  \
# 0                                                  384.0
# 1                                                  377.3
# 2                                                 1271.8
# 3                                                 1270.7
# 4                                                  377.0
# ...                                                  ...
# 40501                                              377.3
# 40502                                             1281.0
# 40503                                              377.6
# 40504                                             1268.4
# 40505                                              377.0
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage3) Collect Result_Dam  \
# 0                                                  383.1
# 1                                                  377.3
# 2                                                 1383.9
# 3                                                 1271.8
# 4                                                  377.5
# ...                                                  ...
# 40501                                              377.3
# 40502                                             1393.5
# 40503                                              377.1
# 40504                                             1269.0
# 40505                                              377.5
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage1) Collect Result_Dam  \
# 0                                                 384.00
# 1                                                 282.15
# 2                                                1271.80
# 3                                                 282.15
# 4                                                 284.80
# ...                                                  ...
# 40501                                             282.15
# 40502                                            1281.20
# 40503                                             378.00
# 40504                                             282.15
# 40505                                             284.80
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage2) Collect Result_Dam  \
# 0                                                 274.51
# 1                                                 282.15
# 2                                                 274.33
# 3                                                 282.15
# 4                                                 284.80
# ...                                                  ...
# 40501                                             282.15
# 40502                                             274.33
# 40503                                             274.78
# 40504                                             282.15
# 40505                                             284.80
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage3) Collect Result_Dam  \
# 0                                                 274.51
# 1                                                 282.15
# 2                                                 274.33
# 3                                                 282.15
# 4                                                 284.80
# ...                                                  ...
# 40501                                             282.15
# 40502                                             274.33
# 40503                                             274.78
# 40504                                             282.15
# 40505                                             284.80
#
#        HEAD Standby Position X Collect Result_Dam  \
# 0                                          274.51
# 1                                          257.00
# 2                                          274.33
# 3                                          257.00
# 4                                          257.00
# ...                                           ...
# 40501                                      257.00
# 40502                                      274.33
# 40503                                      274.78
# 40504                                      257.00
# 40505                                      257.00
#
#        HEAD Standby Position Y Collect Result_Dam  \
# 0                                             257
# 1                                              66
# 2                                             257
# 3                                              66
# 4                                              66
# ...                                           ...
# 40501                                          66
# 40502                                         257
# 40503                                         257
# 40504                                          66
# 40505                                          66
#
#        HEAD Standby Position Z Collect Result_Dam  \
# 0                                              66
# 1                                               0
# 2                                              66
# 3                                               0
# 4                                               0
# ...                                           ...
# 40501                                           0
# 40502                                          66
# 40503                                          66
# 40504                                           0
# 40505                                           0
#
#        Head Clean Position X Collect Result_Dam  \
# 0                                           0.0
# 1                                         127.5
# 2                                           0.0
# 3                                         127.5
# 4                                         127.5
# ...                                         ...
# 40501                                     127.5
# 40502                                       0.0
# 40503                                       0.0
# 40504                                     127.5
# 40505                                     127.5
#
#        Head Clean Position Y Collect Result_Dam  \
# 0                                         127.5
# 1                                          66.0
# 2                                         127.5
# 3                                          66.0
# 4                                          66.0
# ...                                         ...
# 40501                                      66.0
# 40502                                     127.5
# 40503                                     127.5
# 40504                                      66.0
# 40505                                      66.0
#
#        Head Clean Position Z Collect Result_Dam  \
# 0                                         66.00
# 1                                        130.85
# 2                                         66.00
# 3                                        130.85
# 4                                        133.50
# ...                                         ...
# 40501                                    130.85
# 40502                                     66.00
# 40503                                     66.00
# 40504                                    130.85
# 40505                                    133.50
#
#        Head Purge Position X Collect Result_Dam  \
# 0                                         124.0
# 1                                         257.0
# 2                                         124.0
# 3                                         257.0
# 4                                         257.0
# ...                                         ...
# 40501                                     257.0
# 40502                                     124.0
# 40503                                     124.0
# 40504                                     257.0
# 40505                                     257.0
#
#        Head Purge Position Y Collect Result_Dam  \
# 0                                           257
# 1                                            66
# 2                                           257
# 3                                            66
# 4                                            66
# ...                                         ...
# 40501                                        66
# 40502                                       257
# 40503                                       257
# 40504                                        66
# 40505                                        66
#
#        Head Purge Position Z Collect Result_Dam  \
# 0                                         66.00
# 1                                        130.85
# 2                                         66.00
# 3                                        130.85
# 4                                        133.50
# ...                                         ...
# 40501                                    130.85
# 40502                                     66.00
# 40503                                     66.00
# 40504                                    130.85
# 40505                                    133.50
#
#        Head Zero Position X Collect Result_Dam  \
# 0                                       130.85
# 1                                       505.00
# 2                                       130.85
# 3                                       505.00
# 4                                       505.00
# ...                                        ...
# 40501                                   505.00
# 40502                                   130.85
# 40503                                   130.85
# 40504                                   505.00
# 40505                                   505.00
#
#        Head Zero Position Y Collect Result_Dam  \
# 0                                        505.0
# 1                                        300.0
# 2                                        505.0
# 3                                        300.0
# 4                                        300.0
# ...                                        ...
# 40501                                    300.0
# 40502                                    505.0
# 40503                                    505.0
# 40504                                    300.0
# 40505                                    303.5
#
#        Head Zero Position Z Collect Result_Dam  \
# 0                                        300.0
# 1                                        265.0
# 2                                        300.0
# 3                                        265.0
# 4                                        265.0
# ...                                        ...
# 40501                                    265.0
# 40502                                    300.0
# 40503                                    300.0
# 40504                                    265.0
# 40505                                    265.0
#
#        Machine Tact time Collect Result_Dam  PalletID Collect Result_Dam  \
# 0                                    265.00                         58.5
# 1                                     65.10                          7.0
# 2                                    265.02                         76.9
# 3                                     70.50                         12.0
# 4                                     88.30                          8.0
# ...                                     ...                          ...
# 40501                                 56.70                          1.0
# 40502                                265.00                         78.5
# 40503                                265.02                         69.5
# 40504                                 57.70                         13.0
# 40505                                 92.10                          3.0
#
#        Production Qty Collect Result_Dam  Receip No Collect Result_Dam  \
# 0                                      7                           127
# 1                                    185                             1
# 2                                     10                            73
# 3                                    268                             1
# 4                                    121                             1
# ...                                  ...                           ...
# 40501                                318                             1
# 40502                                 14                           197
# 40503                                  1                            27
# 40504                                117                             1
# 40505                                320                             1
#
#        Stage1 Circle1 Distance Speed Collect Result_Dam  \
# 0                                                     1
# 1                                                  4000
# 2                                                     1
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                                 1
# 40503                                                 1
# 40504                                              9000
# 40505                                              9000
#
#        Stage1 Circle2 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage1 Circle3 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage1 Circle4 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage1 Line1 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage1 Line2 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage1 Line3 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage1 Line4 Distance Speed Collect Result_Dam  \
# 0                                                5600
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5600
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage2 Circle1 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  9000
# 2                                                  5800
# 3                                                  5000
# 4                                                  9000
# ...                                                 ...
# 40501                                              9000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                             12000
#
#        Stage2 Circle2 Distance Speed Collect Result_Dam  \
# 0                                                  5300
# 1                                                  9000
# 2                                                  5300
# 3                                                  5000
# 4                                                  9000
# ...                                                 ...
# 40501                                              9000
# 40502                                              5300
# 40503                                              5500
# 40504                                              9000
# 40505                                             12000
#
#        Stage2 Circle3 Distance Speed Collect Result_Dam  \
# 0                                                  5300
# 1                                                  9000
# 2                                                  5300
# 3                                                  5000
# 4                                                  9000
# ...                                                 ...
# 40501                                              9000
# 40502                                              5300
# 40503                                              5500
# 40504                                              9000
# 40505                                             12000
#
#        Stage2 Circle4 Distance Speed Collect Result_Dam  \
# 0                                                  5300
# 1                                                  9000
# 2                                                  5300
# 3                                                  5000
# 4                                                  9000
# ...                                                 ...
# 40501                                              9000
# 40502                                              5300
# 40503                                              5500
# 40504                                              9000
# 40505                                             12000
#
#        Stage2 Line1 Distance Speed Collect Result_Dam  \
# 0                                                5300
# 1                                                9000
# 2                                                5300
# 3                                                5000
# 4                                                9000
# ...                                               ...
# 40501                                            9000
# 40502                                            5300
# 40503                                            5500
# 40504                                            9000
# 40505                                           12000
#
#        Stage2 Line2 Distance Speed Collect Result_Dam  \
# 0                                                5300
# 1                                                9000
# 2                                                5300
# 3                                                5000
# 4                                                9000
# ...                                               ...
# 40501                                            9000
# 40502                                            5300
# 40503                                            5500
# 40504                                            9000
# 40505                                           12000
#
#        Stage2 Line3 Distance Speed Collect Result_Dam  \
# 0                                                5300
# 1                                                9000
# 2                                                5300
# 3                                                5000
# 4                                                9000
# ...                                               ...
# 40501                                            9000
# 40502                                            5300
# 40503                                            5500
# 40504                                            9000
# 40505                                           12000
#
#        Stage2 Line4 Distance Speed Collect Result_Dam  \
# 0                                                5300
# 1                                                9000
# 2                                                5300
# 3                                                5000
# 4                                                9000
# ...                                               ...
# 40501                                            9000
# 40502                                            5300
# 40503                                            5500
# 40504                                            9000
# 40505                                           12000
#
#        Stage3 Circle1 Distance Speed Collect Result_Dam  \
# 0                                                  5300
# 1                                                  4000
# 2                                                  5300
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5300
# 40503                                              5500
# 40504                                              9000
# 40505                                              9000
#
#        Stage3 Circle2 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage3 Circle3 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage3 Circle4 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage3 Line1 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage3 Line2 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage3 Line3 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage3 Line4 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        THICKNESS 1 Collect Result_Dam  THICKNESS 2 Collect Result_Dam  \
# 0                                5800                           0.000
# 1                                   0                           0.000
# 2                                5800                           0.012
# 3                                   0                           0.000
# 4                                   0                           0.000
# ...                               ...                             ...
# 40501                               0                           0.000
# 40502                            5800                          -0.019
# 40503                            6000                           0.000
# 40504                               0                           0.000
# 40505                               0                           0.000
#
#        THICKNESS 3 Collect Result_Dam  WorkMode Collect Result_Dam  \
# 0                               0.000                        0.000
# 1                               0.000                        7.000
# 2                              -0.022                        0.003
# 3                               0.000                        7.000
# 4                               0.000                        7.000
# ...                               ...                          ...
# 40501                           0.000                        7.000
# 40502                          -0.021                       -0.118
# 40503                           0.000                        0.000
# 40504                           0.000                        7.000
# 40505                           0.000                        7.000
#
#       Collect Date_AutoClave  1st Pressure Collect Result_AutoClave  \
# 0        2024-04-25 11:50:00                                  0.312
# 1        2023-09-19 15:00:00                                  0.311
# 2        2024-03-05 10:10:00                                  0.315
# 3        2023-09-25 16:20:00                                  0.299
# 4        2023-06-27 14:00:00                                  0.302
# ...                      ...                                    ...
# 40501    2023-09-14 16:30:00                                  0.300
# 40502    2024-04-10 15:00:00                                  0.305
# 40503    2024-02-22 09:20:00                                  0.309
# 40504    2023-07-25 11:40:00                                  0.302
# 40505    2023-05-31 02:10:00                                  0.305
#
#        1st Pressure 1st Pressure Unit Time_AutoClave  \
# 0                                                240
# 1                                                241
# 2                                                241
# 3                                                241
# 4                                                240
# ...                                              ...
# 40501                                            241
# 40502                                            240
# 40503                                            241
# 40504                                            241
# 40505                                            300
#
#        2nd Pressure Collect Result_AutoClave  \
# 0                                      0.493
# 1                                      0.311
# 2                                      0.490
# 3                                      0.300
# 4                                      0.302
# ...                                      ...
# 40501                                  0.300
# 40502                                  0.493
# 40503                                  0.490
# 40504                                  0.303
# 40505                                  0.305
#
#        2nd Pressure Unit Time_AutoClave  \
# 0                                     1
# 1                                   121
# 2                                     1
# 3                                   121
# 4                                   120
# ...                                 ...
# 40501                               121
# 40502                                 1
# 40503                                 1
# 40504                               121
# 40505                                60
#
#        3rd Pressure Collect Result_AutoClave  \
# 0                                      0.499
# 1                                      0.498
# 2                                      0.498
# 3                                      0.500
# 4                                      0.498
# ...                                      ...
# 40501                                  0.500
# 40502                                  0.498
# 40503                                  0.498
# 40504                                  0.499
# 40505                                  0.498
#
#        3rd Pressure Unit Time_AutoClave  \
# 0                                   120
# 1                                   121
# 2                                   121
# 3                                   121
# 4                                   120
# ...                                 ...
# 40501                               121
# 40502                               120
# 40503                               121
# ...
# 1                                                  458.0
# 2                                                  305.0
# 3                                                  499.8
# 4                                                  458.0
# ...                                                  ...
# 40501                                              458.0
# 40502                                              304.8
# 40503                                              835.5
# 40504                                              499.8
# 40505                                              458.0
#
#        HEAD NORMAL COORDINATE X AXIS(Stage3) Collect Result_Fill2  \
# 0                                                  458.0
# 1                                                  156.0
# 2                                                  499.8
# 3                                                  694.0
# 4                                                  156.0
# ...                                                  ...
# 40501                                              156.0
# 40502                                              499.8
# 40503                                              458.0
# 40504                                              694.0
# 40505                                              156.0
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage1) Collect Result_Fill2  \
# 0                                                  156.0
# 1                                                  428.0
# 2                                                  694.0
# 3                                                 1324.2
# 4                                                  428.0
# ...                                                  ...
# 40501                                              428.0
# 40502                                              692.8
# 40503                                              156.0
# 40504                                             1324.2
# 40505                                              428.0
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage2) Collect Result_Fill2  \
# 0                                                  428.0
# 1                                                  427.9
# 2                                                 1324.2
# 3                                                 1324.2
# 4                                                  427.9
# ...                                                  ...
# 40501                                              427.9
# 40502                                             1324.2
# 40503                                              428.0
# 40504                                             1324.2
# 40505                                              427.9
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage3) Collect Result_Fill2  \
# 0                                                  427.9
# 1                                                  428.0
# 2                                                 1324.2
# 3                                                 1324.2
# 4                                                  428.0
# ...                                                  ...
# 40501                                              428.0
# 40502                                             1324.2
# 40503                                              427.9
# 40504                                             1324.2
# 40505                                              428.0
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage1) Collect Result_Fill2  \
# 0                                                  428.0
# 1                                                  243.7
# 2                                                 1324.2
# 3                                                  243.5
# 4                                                  243.7
# ...                                                  ...
# 40501                                              243.7
# 40502                                             1324.2
# 40503                                              428.0
# 40504                                              243.5
# 40505                                              243.7
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage2) Collect Result_Fill2  \
# 0                                                  243.7
# 1                                                  243.7
# 2                                                  243.5
# 3                                                  243.5
# 4                                                  243.7
# ...                                                  ...
# 40501                                              243.7
# 40502                                              243.5
# 40503                                              243.7
# 40504                                              243.5
# 40505                                              243.7
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage3) Collect Result_Fill2  \
# 0                                                  243.7
# 1                                                  243.7
# 2                                                  243.5
# 3                                                  243.5
# 4                                                  243.7
# ...                                                  ...
# 40501                                              243.7
# 40502                                              243.5
# 40503                                              243.7
# 40504                                              243.5
# 40505                                              243.7
#
#        HEAD Standby Position X Collect Result_Fill2  \
# 0                                             243.7
# 1                                             270.0
# 2                                             243.5
# 3                                             270.0
# 4                                             270.0
# ...                                             ...
# 40501                                         270.0
# 40502                                         243.5
# 40503                                         243.7
# 40504                                         270.0
# 40505                                         270.0
#
#        HEAD Standby Position Y Collect Result_Fill2  \
# 0                                               270
# 1                                                50
# 2                                               270
# 3                                                50
# 4                                                50
# ...                                             ...
# 40501                                            50
# 40502                                           270
# 40503                                           270
# 40504                                            50
# 40505                                            50
#
#        HEAD Standby Position Z Collect Result_Fill2  \
# 0                                                50
# 1                                               -10
# 2                                                50
# 3                                               -10
# 4                                               -10
# ...                                             ...
# 40501                                           -10
# 40502                                            50
# 40503                                            50
# 40504                                           -10
# 40505                                           -10
#
#        Head Clean Position X Collect Result_Fill2  \
# 0                                             -10
# 1                                             119
# 2                                             -10
# 3                                             119
# 4                                             119
# ...                                           ...
# 40501                                         119
# 40502                                         -10
# 40503                                         -10
# 40504                                         119
# 40505                                         119
#
#        Head Clean Position Y Collect Result_Fill2  \
# 0                                             119
# 1                                              50
# 2                                             119
# 3                                              50
# 4                                              50
# ...                                           ...
# 40501                                          50
# 40502                                         119
# 40503                                         119
# 40504                                          50
# 40505                                          50
#
#        Head Clean Position Z Collect Result_Fill2  \
# 0                                            50.0
# 1                                            91.8
# 2                                            50.0
# 3                                            91.8
# 4                                            91.8
# ...                                           ...
# 40501                                        91.8
# 40502                                        50.0
# 40503                                        50.0
# 40504                                        91.8
# 40505                                        91.8
#
#        Head Purge Position X Collect Result_Fill2  \
# 0                                            91.8
# 1                                           270.0
# 2                                            91.8
# 3                                           270.0
# 4                                           270.0
# ...                                           ...
# 40501                                       270.0
# 40502                                        91.8
# 40503                                        91.8
# 40504                                       270.0
# 40505                                       270.0
#
#        Head Purge Position Y Collect Result_Fill2  \
# 0                                             270
# 1                                              50
# 2                                             270
# 3                                              50
# 4                                              50
# ...                                           ...
# 40501                                          50
# 40502                                         270
# 40503                                         270
# 40504                                          50
# 40505                                          50
#
#        Head Purge Position Z Collect Result_Fill2  \
# 0                                              50
# 1                                              85
# 2                                              50
# 3                                              85
# 4                                              85
# ...                                           ...
# 40501                                          85
# 40502                                          50
# 40503                                          50
# 40504                                          85
# 40505                                          85
#
#        Machine Tact time Collect Result_Fill2  PalletID Collect Result_Fill2  \
# 0                                     114.612                           19.9
# 1                                      19.600                            7.0
# 2                                     114.612                           19.8
# 3                                      19.900                           12.0
# 4                                      19.700                            8.0
# ...                                       ...                            ...
# 40501                                  19.200                            1.0
# 40502                                 114.612                           20.5
# 40503                                  85.000                           19.7
# 40504                                  20.100                           13.0
# 40505                                  19.400                            3.0
#
#        Production Qty Collect Result_Fill2  Receip No Collect Result_Fill2  \
# 0                                        7                             127
# 1                                      185                               1
# 2                                       10                              73
# 3                                      268                               1
# 4                                      121                               1
# ...                                    ...                             ...
# 40501                                  318                               1
# 40502                                   14                             197
# 40503                                    1                              27
# 40504                                  117                               1
# 40505                                  320                               1
#
#        WorkMode Collect Result_Fill2    target Model.Suffix   Workorder  \
# 0                                  1    Normal  AJX75334505  4F1XA938-1
# 1                                  0    Normal  AJX75334505  3KPM0016-2
# 2                                  1    Normal  AJX75334501  4E1X9167-1
# 3                                  0    Normal  AJX75334501  3K1X0057-1
# 4                                  0    Normal  AJX75334501  3HPM0007-1
# ...                              ...       ...          ...         ...
# 40501                              0    Normal  AJX75334501  3J1XF434-2
# 40502                              1    Normal  AJX75334501  4E1XC796-1
# 40503                              1    Normal  AJX75334501  4C1XD438-1
# 40504                              0    Normal  AJX75334501  3I1XA258-1
# 40505                              0  AbNormal  AJX75334501  3G1XA501-1
#
#          running_time  running_time_m  month  day  hour  out_of_hour
# 0     0 days 00:40:00            40.0      4   25    11            0
# 1     0 days 00:30:00            30.0      9   19    14            0
# 2     0 days 00:40:00            40.0      3    5     9            0
# 3     0 days 00:40:00            40.0      9   25    15            0
# 4     0 days 00:40:00            40.0      6   27    13            0
# ...               ...             ...    ...  ...   ...          ...
# 40501 0 days 00:40:00            40.0      9   14    15            0
# 40502 0 days 00:40:00            40.0      4   10    14            0
# 40503 0 days 00:40:00            40.0      2   22     8            0
# 40504 0 days 00:40:00            40.0      7   25    11            0
# 40505 0 days 00:30:00            30.0      5   31     1            1
#
# [40506 rows x 155 columns]

# %%
train_data = train_data.drop(columns='running_time', axis=1)

# %%
test['running_time'] = pd.to_datetime(test['Collect Date_AutoClave']) - pd.to_datetime(test['Collect Date_Dam'])
test['running_time_m'] = test['running_time'].dt.total_seconds() / 60

# %%
test['Collect Date_Dam'] = pd.to_datetime(test['Collect Date_Dam'])
test['month'] = test['Collect Date_Dam'].dt.month
test['day'] = test['Collect Date_Dam'].dt.day
test['hour'] = test['Collect Date_Dam'].dt.hour

# %%
test['out_of_hour'] = 0  # 기본값으로 0 설정
test.loc[(test['hour'] < 8) | (test['hour'] > 20), 'out_of_hour'] = 1  # 조건을 만족하는 경우 a열에 1을 할당

# %%
test = test.drop(columns='running_time', axis=1)

# %%
train_data
# Out:
#           Equipment_Dam    Collect Date_Dam  \
# 0      Dam dispenser #1 2024-04-25 11:10:00
# 1      Dam dispenser #1 2023-09-19 14:30:00
# 2      Dam dispenser #2 2024-03-05 09:30:00
# 3      Dam dispenser #2 2023-09-25 15:40:00
# 4      Dam dispenser #1 2023-06-27 13:20:00
# ...                 ...                 ...
# 40501  Dam dispenser #1 2023-09-14 15:50:00
# 40502  Dam dispenser #2 2024-04-10 14:20:00
# 40503  Dam dispenser #1 2024-02-22 08:40:00
# 40504  Dam dispenser #2 2023-07-25 11:00:00
# 40505  Dam dispenser #1 2023-05-31 01:40:00
#
#        CURE END POSITION X Collect Result_Dam  \
# 0                                       240.0
# 1                                       240.0
# 2                                      1000.0
# 3                                      1000.0
# 4                                       240.0
# ...                                       ...
# 40501                                   240.0
# 40502                                  1000.0
# 40503                                   240.0
# 40504                                  1000.0
# 40505                                   240.0
#
#        CURE END POSITION Z Collect Result_Dam  \
# 0                                         2.5
# 1                                         2.5
# 2                                        12.5
# 3                                        12.5
# 4                                         2.5
# ...                                       ...
# 40501                                     2.5
# 40502                                    12.5
# 40503                                     2.5
# 40504                                    12.5
# 40505                                     2.5
#
#        CURE END POSITION Θ Collect Result_Dam  CURE SPEED Collect Result_Dam  \
# 0                                         -90                            100
# 1                                         -90                             70
# 2                                          90                             85
# 3                                          90                             70
# 4                                         -90                             70
# ...                                       ...                            ...
# 40501                                     -90                             70
# 40502                                      90                            100
# 40503                                     -90                            100
# 40504                                      90                             70
# 40505                                     -90                             70
#
#        CURE START POSITION X Collect Result_Dam  \
# 0                                          1030
# 1                                          1030
# 2                                           280
# 3                                           280
# 4                                          1030
# ...                                         ...
# 40501                                      1030
# 40502                                       280
# 40503                                      1030
# 40504                                       280
# 40505                                      1030
#
#        CURE START POSITION Θ Collect Result_Dam  \
# 0                                           -90
# 1                                           -90
# 2                                            90
# 3                                            90
# 4                                           -90
# ...                                         ...
# 40501                                       -90
# 40502                                        90
# 40503                                       -90
# 40504                                        90
# 40505                                       -90
#
#        DISCHARGED SPEED OF RESIN Collect Result_Dam  \
# 0                                                16
# 1                                                10
# 2                                                16
# 3                                                10
# 4                                                10
# ...                                             ...
# 40501                                            10
# 40502                                            16
# 40503                                            16
# 40504                                            10
# 40505                                            10
#
#        DISCHARGED TIME OF RESIN(Stage1) Collect Result_Dam  \
# 0                                                   14.9
# 1                                                   21.3
# 2                                                   14.7
# 3                                                   21.3
# 4                                                    9.7
# ...                                                  ...
# 40501                                               17.0
# 40502                                               14.9
# 40503                                               14.2
# 40504                                                9.7
# 40505                                                9.6
#
#        DISCHARGED TIME OF RESIN(Stage2) Collect Result_Dam  \
# 0                                                    8.4
# 1                                                    4.9
# 2                                                    8.5
# 3                                                    8.4
# 4                                                    4.9
# ...                                                  ...
# 40501                                                5.0
# 40502                                                8.5
# 40503                                                8.2
# 40504                                                4.9
# 40505                                                3.9
#
#        DISCHARGED TIME OF RESIN(Stage3) Collect Result_Dam  \
# 0                                                   14.7
# 1                                                   21.3
# 2                                                   14.7
# 3                                                   21.3
# 4                                                    9.6
# ...                                                  ...
# 40501                                               17.0
# 40502                                               14.7
# 40503                                               14.3
# 40504                                                9.7
# 40505                                                9.7
#
#        Dispense Volume(Stage1) Collect Result_Dam  \
# 0                                            1.04
# 1                                            1.49
# 2                                            1.61
# 3                                            1.49
# 4                                            0.67
# ...                                           ...
# 40501                                        1.19
# 40502                                        1.04
# 40503                                        0.99
# 40504                                        0.67
# 40505                                        0.67
#
#        Dispense Volume(Stage2) Collect Result_Dam  \
# 0                                            0.58
# 1                                            0.34
# 2                                            0.93
# 3                                            0.58
# 4                                            0.34
# ...                                           ...
# 40501                                        0.35
# 40502                                        0.59
# 40503                                        0.57
# 40504                                        0.34
# 40505                                        0.27
#
#        Dispense Volume(Stage3) Collect Result_Dam  \
# 0                                            1.02
# 1                                            1.49
# 2                                            1.61
# 3                                            1.49
# 4                                            0.67
# ...                                           ...
# 40501                                        1.19
# 40502                                        1.02
# 40503                                        1.00
# 40504                                        0.67
# 40505                                        0.67
#
#       HEAD NORMAL COORDINATE X AXIS(Stage1) Collect Result_Dam  \
# 0                                                    NaN
# 1                                                  550.3
# 2                                                     OK
# 3                                                  162.4
# 4                                                    549
# ...                                                  ...
# 40501                                              550.3
# 40502                                                NaN
# 40503                                                 OK
# 40504                                              162.4
# 40505                                                549
#
#       HEAD NORMAL COORDINATE X AXIS(Stage1) Judge Value_Dam  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                     OK
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 40501                                                NaN
# 40502                                                NaN
# 40503                                                 OK
# 40504                                                NaN
# 40505                                                NaN
#
#        HEAD NORMAL COORDINATE X AXIS(Stage2) Collect Result_Dam  \
# 0                                                  550.5
# 1                                                  463.8
# 2                                                  162.4
# 3                                                  465.5
# 4                                                  462.5
# ...                                                  ...
# 40501                                              463.8
# 40502                                              163.5
# 40503                                              550.6
# 40504                                              465.1
# 40505                                              463.0
#
#        HEAD NORMAL COORDINATE X AXIS(Stage3) Collect Result_Dam  \
# 0                                                  464.3
# 1                                                  160.8
# 2                                                  465.4
# 3                                                  552.0
# 4                                                  159.5
# ...                                                  ...
# 40501                                              160.8
# 40502                                              466.2
# 40503                                              463.9
# 40504                                              551.3
# 40505                                              160.5
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage1) Collect Result_Dam  \
# 0                                                  161.4
# 1                                                  377.3
# 2                                                  551.7
# 3                                                 1271.8
# 4                                                  377.5
# ...                                                  ...
# 40501                                              377.3
# 40502                                              553.1
# 40503                                              161.5
# 40504                                             1269.0
# 40505                                              377.5
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage2) Collect Result_Dam  \
# 0                                                  384.0
# 1                                                  377.3
# 2                                                 1271.8
# 3                                                 1270.7
# 4                                                  377.0
# ...                                                  ...
# 40501                                              377.3
# 40502                                             1281.0
# 40503                                              377.6
# 40504                                             1268.4
# 40505                                              377.0
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage3) Collect Result_Dam  \
# 0                                                  383.1
# 1                                                  377.3
# 2                                                 1383.9
# 3                                                 1271.8
# 4                                                  377.5
# ...                                                  ...
# 40501                                              377.3
# 40502                                             1393.5
# 40503                                              377.1
# 40504                                             1269.0
# 40505                                              377.5
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage1) Collect Result_Dam  \
# 0                                                 384.00
# 1                                                 282.15
# 2                                                1271.80
# 3                                                 282.15
# 4                                                 284.80
# ...                                                  ...
# 40501                                             282.15
# 40502                                            1281.20
# 40503                                             378.00
# 40504                                             282.15
# 40505                                             284.80
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage2) Collect Result_Dam  \
# 0                                                 274.51
# 1                                                 282.15
# 2                                                 274.33
# 3                                                 282.15
# 4                                                 284.80
# ...                                                  ...
# 40501                                             282.15
# 40502                                             274.33
# 40503                                             274.78
# 40504                                             282.15
# 40505                                             284.80
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage3) Collect Result_Dam  \
# 0                                                 274.51
# 1                                                 282.15
# 2                                                 274.33
# 3                                                 282.15
# 4                                                 284.80
# ...                                                  ...
# 40501                                             282.15
# 40502                                             274.33
# 40503                                             274.78
# 40504                                             282.15
# 40505                                             284.80
#
#        HEAD Standby Position X Collect Result_Dam  \
# 0                                          274.51
# 1                                          257.00
# 2                                          274.33
# 3                                          257.00
# 4                                          257.00
# ...                                           ...
# 40501                                      257.00
# 40502                                      274.33
# 40503                                      274.78
# 40504                                      257.00
# 40505                                      257.00
#
#        HEAD Standby Position Y Collect Result_Dam  \
# 0                                             257
# 1                                              66
# 2                                             257
# 3                                              66
# 4                                              66
# ...                                           ...
# 40501                                          66
# 40502                                         257
# 40503                                         257
# 40504                                          66
# 40505                                          66
#
#        HEAD Standby Position Z Collect Result_Dam  \
# 0                                              66
# 1                                               0
# 2                                              66
# 3                                               0
# 4                                               0
# ...                                           ...
# 40501                                           0
# 40502                                          66
# 40503                                          66
# 40504                                           0
# 40505                                           0
#
#        Head Clean Position X Collect Result_Dam  \
# 0                                           0.0
# 1                                         127.5
# 2                                           0.0
# 3                                         127.5
# 4                                         127.5
# ...                                         ...
# 40501                                     127.5
# 40502                                       0.0
# 40503                                       0.0
# 40504                                     127.5
# 40505                                     127.5
#
#        Head Clean Position Y Collect Result_Dam  \
# 0                                         127.5
# 1                                          66.0
# 2                                         127.5
# 3                                          66.0
# 4                                          66.0
# ...                                         ...
# 40501                                      66.0
# 40502                                     127.5
# 40503                                     127.5
# 40504                                      66.0
# 40505                                      66.0
#
#        Head Clean Position Z Collect Result_Dam  \
# 0                                         66.00
# 1                                        130.85
# 2                                         66.00
# 3                                        130.85
# 4                                        133.50
# ...                                         ...
# 40501                                    130.85
# 40502                                     66.00
# 40503                                     66.00
# 40504                                    130.85
# 40505                                    133.50
#
#        Head Purge Position X Collect Result_Dam  \
# 0                                         124.0
# 1                                         257.0
# 2                                         124.0
# 3                                         257.0
# 4                                         257.0
# ...                                         ...
# 40501                                     257.0
# 40502                                     124.0
# 40503                                     124.0
# 40504                                     257.0
# 40505                                     257.0
#
#        Head Purge Position Y Collect Result_Dam  \
# 0                                           257
# 1                                            66
# 2                                           257
# 3                                            66
# 4                                            66
# ...                                         ...
# 40501                                        66
# 40502                                       257
# 40503                                       257
# 40504                                        66
# 40505                                        66
#
#        Head Purge Position Z Collect Result_Dam  \
# 0                                         66.00
# 1                                        130.85
# 2                                         66.00
# 3                                        130.85
# 4                                        133.50
# ...                                         ...
# 40501                                    130.85
# 40502                                     66.00
# 40503                                     66.00
# 40504                                    130.85
# 40505                                    133.50
#
#        Head Zero Position X Collect Result_Dam  \
# 0                                       130.85
# 1                                       505.00
# 2                                       130.85
# 3                                       505.00
# 4                                       505.00
# ...                                        ...
# 40501                                   505.00
# 40502                                   130.85
# 40503                                   130.85
# 40504                                   505.00
# 40505                                   505.00
#
#        Head Zero Position Y Collect Result_Dam  \
# 0                                        505.0
# 1                                        300.0
# 2                                        505.0
# 3                                        300.0
# 4                                        300.0
# ...                                        ...
# 40501                                    300.0
# 40502                                    505.0
# 40503                                    505.0
# 40504                                    300.0
# 40505                                    303.5
#
#        Head Zero Position Z Collect Result_Dam  \
# 0                                        300.0
# 1                                        265.0
# 2                                        300.0
# 3                                        265.0
# 4                                        265.0
# ...                                        ...
# 40501                                    265.0
# 40502                                    300.0
# 40503                                    300.0
# 40504                                    265.0
# 40505                                    265.0
#
#        Machine Tact time Collect Result_Dam  PalletID Collect Result_Dam  \
# 0                                    265.00                         58.5
# 1                                     65.10                          7.0
# 2                                    265.02                         76.9
# 3                                     70.50                         12.0
# 4                                     88.30                          8.0
# ...                                     ...                          ...
# 40501                                 56.70                          1.0
# 40502                                265.00                         78.5
# 40503                                265.02                         69.5
# 40504                                 57.70                         13.0
# 40505                                 92.10                          3.0
#
#        Production Qty Collect Result_Dam  Receip No Collect Result_Dam  \
# 0                                      7                           127
# 1                                    185                             1
# 2                                     10                            73
# 3                                    268                             1
# 4                                    121                             1
# ...                                  ...                           ...
# 40501                                318                             1
# 40502                                 14                           197
# 40503                                  1                            27
# 40504                                117                             1
# 40505                                320                             1
#
#        Stage1 Circle1 Distance Speed Collect Result_Dam  \
# 0                                                     1
# 1                                                  4000
# 2                                                     1
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                                 1
# 40503                                                 1
# 40504                                              9000
# 40505                                              9000
#
#        Stage1 Circle2 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage1 Circle3 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage1 Circle4 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage1 Line1 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage1 Line2 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage1 Line3 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage1 Line4 Distance Speed Collect Result_Dam  \
# 0                                                5600
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5600
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage2 Circle1 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  9000
# 2                                                  5800
# 3                                                  5000
# 4                                                  9000
# ...                                                 ...
# 40501                                              9000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                             12000
#
#        Stage2 Circle2 Distance Speed Collect Result_Dam  \
# 0                                                  5300
# 1                                                  9000
# 2                                                  5300
# 3                                                  5000
# 4                                                  9000
# ...                                                 ...
# 40501                                              9000
# 40502                                              5300
# 40503                                              5500
# 40504                                              9000
# 40505                                             12000
#
#        Stage2 Circle3 Distance Speed Collect Result_Dam  \
# 0                                                  5300
# 1                                                  9000
# 2                                                  5300
# 3                                                  5000
# 4                                                  9000
# ...                                                 ...
# 40501                                              9000
# 40502                                              5300
# 40503                                              5500
# 40504                                              9000
# 40505                                             12000
#
#        Stage2 Circle4 Distance Speed Collect Result_Dam  \
# 0                                                  5300
# 1                                                  9000
# 2                                                  5300
# 3                                                  5000
# 4                                                  9000
# ...                                                 ...
# 40501                                              9000
# 40502                                              5300
# 40503                                              5500
# 40504                                              9000
# 40505                                             12000
#
#        Stage2 Line1 Distance Speed Collect Result_Dam  \
# 0                                                5300
# 1                                                9000
# 2                                                5300
# 3                                                5000
# 4                                                9000
# ...                                               ...
# 40501                                            9000
# 40502                                            5300
# 40503                                            5500
# 40504                                            9000
# 40505                                           12000
#
#        Stage2 Line2 Distance Speed Collect Result_Dam  \
# 0                                                5300
# 1                                                9000
# 2                                                5300
# 3                                                5000
# 4                                                9000
# ...                                               ...
# 40501                                            9000
# 40502                                            5300
# 40503                                            5500
# 40504                                            9000
# 40505                                           12000
#
#        Stage2 Line3 Distance Speed Collect Result_Dam  \
# 0                                                5300
# 1                                                9000
# 2                                                5300
# 3                                                5000
# 4                                                9000
# ...                                               ...
# 40501                                            9000
# 40502                                            5300
# 40503                                            5500
# 40504                                            9000
# 40505                                           12000
#
#        Stage2 Line4 Distance Speed Collect Result_Dam  \
# 0                                                5300
# 1                                                9000
# 2                                                5300
# 3                                                5000
# 4                                                9000
# ...                                               ...
# 40501                                            9000
# 40502                                            5300
# 40503                                            5500
# 40504                                            9000
# 40505                                           12000
#
#        Stage3 Circle1 Distance Speed Collect Result_Dam  \
# 0                                                  5300
# 1                                                  4000
# 2                                                  5300
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5300
# 40503                                              5500
# 40504                                              9000
# 40505                                              9000
#
#        Stage3 Circle2 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage3 Circle3 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage3 Circle4 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage3 Line1 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage3 Line2 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage3 Line3 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage3 Line4 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        THICKNESS 1 Collect Result_Dam  THICKNESS 2 Collect Result_Dam  \
# 0                                5800                           0.000
# 1                                   0                           0.000
# 2                                5800                           0.012
# 3                                   0                           0.000
# 4                                   0                           0.000
# ...                               ...                             ...
# 40501                               0                           0.000
# 40502                            5800                          -0.019
# 40503                            6000                           0.000
# 40504                               0                           0.000
# 40505                               0                           0.000
#
#        THICKNESS 3 Collect Result_Dam  WorkMode Collect Result_Dam  \
# 0                               0.000                        0.000
# 1                               0.000                        7.000
# 2                              -0.022                        0.003
# 3                               0.000                        7.000
# 4                               0.000                        7.000
# ...                               ...                          ...
# 40501                           0.000                        7.000
# 40502                          -0.021                       -0.118
# 40503                           0.000                        0.000
# 40504                           0.000                        7.000
# 40505                           0.000                        7.000
#
#       Collect Date_AutoClave  1st Pressure Collect Result_AutoClave  \
# 0        2024-04-25 11:50:00                                  0.312
# 1        2023-09-19 15:00:00                                  0.311
# 2        2024-03-05 10:10:00                                  0.315
# 3        2023-09-25 16:20:00                                  0.299
# 4        2023-06-27 14:00:00                                  0.302
# ...                      ...                                    ...
# 40501    2023-09-14 16:30:00                                  0.300
# 40502    2024-04-10 15:00:00                                  0.305
# 40503    2024-02-22 09:20:00                                  0.309
# 40504    2023-07-25 11:40:00                                  0.302
# 40505    2023-05-31 02:10:00                                  0.305
#
#        1st Pressure 1st Pressure Unit Time_AutoClave  \
# 0                                                240
# 1                                                241
# 2                                                241
# 3                                                241
# 4                                                240
# ...                                              ...
# 40501                                            241
# 40502                                            240
# 40503                                            241
# 40504                                            241
# 40505                                            300
#
#        2nd Pressure Collect Result_AutoClave  \
# 0                                      0.493
# 1                                      0.311
# 2                                      0.490
# 3                                      0.300
# 4                                      0.302
# ...                                      ...
# 40501                                  0.300
# 40502                                  0.493
# 40503                                  0.490
# 40504                                  0.303
# 40505                                  0.305
#
#        2nd Pressure Unit Time_AutoClave  \
# 0                                     1
# 1                                   121
# 2                                     1
# 3                                   121
# 4                                   120
# ...                                 ...
# 40501                               121
# 40502                                 1
# 40503                                 1
# 40504                               121
# 40505                                60
#
#        3rd Pressure Collect Result_AutoClave  \
# 0                                      0.499
# 1                                      0.498
# 2                                      0.498
# 3                                      0.500
# 4                                      0.498
# ...                                      ...
# 40501                                  0.500
# 40502                                  0.498
# 40503                                  0.498
# 40504                                  0.499
# 40505                                  0.498
#
#        3rd Pressure Unit Time_AutoClave  \
# 0                                   120
# 1                                   121
# 2                                   121
# 3                                   121
# 4                                   120
# ...                                 ...
# 40501                               121
# 40502                               120
# 40503                               121
# ...
# 40505                                                NaN
#
#        HEAD NORMAL COORDINATE X AXIS(Stage2) Collect Result_Fill2  \
# 0                                                  835.5
# 1                                                  458.0
# 2                                                  305.0
# 3                                                  499.8
# 4                                                  458.0
# ...                                                  ...
# 40501                                              458.0
# 40502                                              304.8
# 40503                                              835.5
# 40504                                              499.8
# 40505                                              458.0
#
#        HEAD NORMAL COORDINATE X AXIS(Stage3) Collect Result_Fill2  \
# 0                                                  458.0
# 1                                                  156.0
# 2                                                  499.8
# 3                                                  694.0
# 4                                                  156.0
# ...                                                  ...
# 40501                                              156.0
# 40502                                              499.8
# 40503                                              458.0
# 40504                                              694.0
# 40505                                              156.0
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage1) Collect Result_Fill2  \
# 0                                                  156.0
# 1                                                  428.0
# 2                                                  694.0
# 3                                                 1324.2
# 4                                                  428.0
# ...                                                  ...
# 40501                                              428.0
# 40502                                              692.8
# 40503                                              156.0
# 40504                                             1324.2
# 40505                                              428.0
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage2) Collect Result_Fill2  \
# 0                                                  428.0
# 1                                                  427.9
# 2                                                 1324.2
# 3                                                 1324.2
# 4                                                  427.9
# ...                                                  ...
# 40501                                              427.9
# 40502                                             1324.2
# 40503                                              428.0
# 40504                                             1324.2
# 40505                                              427.9
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage3) Collect Result_Fill2  \
# 0                                                  427.9
# 1                                                  428.0
# 2                                                 1324.2
# 3                                                 1324.2
# 4                                                  428.0
# ...                                                  ...
# 40501                                              428.0
# 40502                                             1324.2
# 40503                                              427.9
# 40504                                             1324.2
# 40505                                              428.0
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage1) Collect Result_Fill2  \
# 0                                                  428.0
# 1                                                  243.7
# 2                                                 1324.2
# 3                                                  243.5
# 4                                                  243.7
# ...                                                  ...
# 40501                                              243.7
# 40502                                             1324.2
# 40503                                              428.0
# 40504                                              243.5
# 40505                                              243.7
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage2) Collect Result_Fill2  \
# 0                                                  243.7
# 1                                                  243.7
# 2                                                  243.5
# 3                                                  243.5
# 4                                                  243.7
# ...                                                  ...
# 40501                                              243.7
# 40502                                              243.5
# 40503                                              243.7
# 40504                                              243.5
# 40505                                              243.7
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage3) Collect Result_Fill2  \
# 0                                                  243.7
# 1                                                  243.7
# 2                                                  243.5
# 3                                                  243.5
# 4                                                  243.7
# ...                                                  ...
# 40501                                              243.7
# 40502                                              243.5
# 40503                                              243.7
# 40504                                              243.5
# 40505                                              243.7
#
#        HEAD Standby Position X Collect Result_Fill2  \
# 0                                             243.7
# 1                                             270.0
# 2                                             243.5
# 3                                             270.0
# 4                                             270.0
# ...                                             ...
# 40501                                         270.0
# 40502                                         243.5
# 40503                                         243.7
# 40504                                         270.0
# 40505                                         270.0
#
#        HEAD Standby Position Y Collect Result_Fill2  \
# 0                                               270
# 1                                                50
# 2                                               270
# 3                                                50
# 4                                                50
# ...                                             ...
# 40501                                            50
# 40502                                           270
# 40503                                           270
# 40504                                            50
# 40505                                            50
#
#        HEAD Standby Position Z Collect Result_Fill2  \
# 0                                                50
# 1                                               -10
# 2                                                50
# 3                                               -10
# 4                                               -10
# ...                                             ...
# 40501                                           -10
# 40502                                            50
# 40503                                            50
# 40504                                           -10
# 40505                                           -10
#
#        Head Clean Position X Collect Result_Fill2  \
# 0                                             -10
# 1                                             119
# 2                                             -10
# 3                                             119
# 4                                             119
# ...                                           ...
# 40501                                         119
# 40502                                         -10
# 40503                                         -10
# 40504                                         119
# 40505                                         119
#
#        Head Clean Position Y Collect Result_Fill2  \
# 0                                             119
# 1                                              50
# 2                                             119
# 3                                              50
# 4                                              50
# ...                                           ...
# 40501                                          50
# 40502                                         119
# 40503                                         119
# 40504                                          50
# 40505                                          50
#
#        Head Clean Position Z Collect Result_Fill2  \
# 0                                            50.0
# 1                                            91.8
# 2                                            50.0
# 3                                            91.8
# 4                                            91.8
# ...                                           ...
# 40501                                        91.8
# 40502                                        50.0
# 40503                                        50.0
# 40504                                        91.8
# 40505                                        91.8
#
#        Head Purge Position X Collect Result_Fill2  \
# 0                                            91.8
# 1                                           270.0
# 2                                            91.8
# 3                                           270.0
# 4                                           270.0
# ...                                           ...
# 40501                                       270.0
# 40502                                        91.8
# 40503                                        91.8
# 40504                                       270.0
# 40505                                       270.0
#
#        Head Purge Position Y Collect Result_Fill2  \
# 0                                             270
# 1                                              50
# 2                                             270
# 3                                              50
# 4                                              50
# ...                                           ...
# 40501                                          50
# 40502                                         270
# 40503                                         270
# 40504                                          50
# 40505                                          50
#
#        Head Purge Position Z Collect Result_Fill2  \
# 0                                              50
# 1                                              85
# 2                                              50
# 3                                              85
# 4                                              85
# ...                                           ...
# 40501                                          85
# 40502                                          50
# 40503                                          50
# 40504                                          85
# 40505                                          85
#
#        Machine Tact time Collect Result_Fill2  PalletID Collect Result_Fill2  \
# 0                                     114.612                           19.9
# 1                                      19.600                            7.0
# 2                                     114.612                           19.8
# 3                                      19.900                           12.0
# 4                                      19.700                            8.0
# ...                                       ...                            ...
# 40501                                  19.200                            1.0
# 40502                                 114.612                           20.5
# 40503                                  85.000                           19.7
# 40504                                  20.100                           13.0
# 40505                                  19.400                            3.0
#
#        Production Qty Collect Result_Fill2  Receip No Collect Result_Fill2  \
# 0                                        7                             127
# 1                                      185                               1
# 2                                       10                              73
# 3                                      268                               1
# 4                                      121                               1
# ...                                    ...                             ...
# 40501                                  318                               1
# 40502                                   14                             197
# 40503                                    1                              27
# 40504                                  117                               1
# 40505                                  320                               1
#
#        WorkMode Collect Result_Fill2    target Model.Suffix   Workorder  \
# 0                                  1    Normal  AJX75334505  4F1XA938-1
# 1                                  0    Normal  AJX75334505  3KPM0016-2
# 2                                  1    Normal  AJX75334501  4E1X9167-1
# 3                                  0    Normal  AJX75334501  3K1X0057-1
# 4                                  0    Normal  AJX75334501  3HPM0007-1
# ...                              ...       ...          ...         ...
# 40501                              0    Normal  AJX75334501  3J1XF434-2
# 40502                              1    Normal  AJX75334501  4E1XC796-1
# 40503                              1    Normal  AJX75334501  4C1XD438-1
# 40504                              0    Normal  AJX75334501  3I1XA258-1
# 40505                              0  AbNormal  AJX75334501  3G1XA501-1
#
#        running_time_m  month  day  hour  out_of_hour
# 0                40.0      4   25    11            0
# 1                30.0      9   19    14            0
# 2                40.0      3    5     9            0
# 3                40.0      9   25    15            0
# 4                40.0      6   27    13            0
# ...               ...    ...  ...   ...          ...
# 40501            40.0      9   14    15            0
# 40502            40.0      4   10    14            0
# 40503            40.0      2   22     8            0
# 40504            40.0      7   25    11            0
# 40505            30.0      5   31     1            1
#
# [40506 rows x 154 columns]

# %%
train_head=[]
# 그룹핑
for column in train_data.columns:
  if 'head' in column.lower():
    train_head.append(column)
train_head_data=train_data[train_head]

# %%
train_head_data
# Out:
#       HEAD NORMAL COORDINATE X AXIS(Stage1) Collect Result_Dam  \
# 0                                                    NaN
# 1                                                  550.3
# 2                                                     OK
# 3                                                  162.4
# 4                                                    549
# ...                                                  ...
# 40501                                              550.3
# 40502                                                NaN
# 40503                                                 OK
# 40504                                              162.4
# 40505                                                549
#
#       HEAD NORMAL COORDINATE X AXIS(Stage1) Judge Value_Dam  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                     OK
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 40501                                                NaN
# 40502                                                NaN
# 40503                                                 OK
# 40504                                                NaN
# 40505                                                NaN
#
#        HEAD NORMAL COORDINATE X AXIS(Stage2) Collect Result_Dam  \
# 0                                                  550.5
# 1                                                  463.8
# 2                                                  162.4
# 3                                                  465.5
# 4                                                  462.5
# ...                                                  ...
# 40501                                              463.8
# 40502                                              163.5
# 40503                                              550.6
# 40504                                              465.1
# 40505                                              463.0
#
#        HEAD NORMAL COORDINATE X AXIS(Stage3) Collect Result_Dam  \
# 0                                                  464.3
# 1                                                  160.8
# 2                                                  465.4
# 3                                                  552.0
# 4                                                  159.5
# ...                                                  ...
# 40501                                              160.8
# 40502                                              466.2
# 40503                                              463.9
# 40504                                              551.3
# 40505                                              160.5
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage1) Collect Result_Dam  \
# 0                                                  161.4
# 1                                                  377.3
# 2                                                  551.7
# 3                                                 1271.8
# 4                                                  377.5
# ...                                                  ...
# 40501                                              377.3
# 40502                                              553.1
# 40503                                              161.5
# 40504                                             1269.0
# 40505                                              377.5
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage2) Collect Result_Dam  \
# 0                                                  384.0
# 1                                                  377.3
# 2                                                 1271.8
# 3                                                 1270.7
# 4                                                  377.0
# ...                                                  ...
# 40501                                              377.3
# 40502                                             1281.0
# 40503                                              377.6
# 40504                                             1268.4
# 40505                                              377.0
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage3) Collect Result_Dam  \
# 0                                                  383.1
# 1                                                  377.3
# 2                                                 1383.9
# 3                                                 1271.8
# 4                                                  377.5
# ...                                                  ...
# 40501                                              377.3
# 40502                                             1393.5
# 40503                                              377.1
# 40504                                             1269.0
# 40505                                              377.5
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage1) Collect Result_Dam  \
# 0                                                 384.00
# 1                                                 282.15
# 2                                                1271.80
# 3                                                 282.15
# 4                                                 284.80
# ...                                                  ...
# 40501                                             282.15
# 40502                                            1281.20
# 40503                                             378.00
# 40504                                             282.15
# 40505                                             284.80
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage2) Collect Result_Dam  \
# 0                                                 274.51
# 1                                                 282.15
# 2                                                 274.33
# 3                                                 282.15
# 4                                                 284.80
# ...                                                  ...
# 40501                                             282.15
# 40502                                             274.33
# 40503                                             274.78
# 40504                                             282.15
# 40505                                             284.80
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage3) Collect Result_Dam  \
# 0                                                 274.51
# 1                                                 282.15
# 2                                                 274.33
# 3                                                 282.15
# 4                                                 284.80
# ...                                                  ...
# 40501                                             282.15
# 40502                                             274.33
# 40503                                             274.78
# 40504                                             282.15
# 40505                                             284.80
#
#        HEAD Standby Position X Collect Result_Dam  \
# 0                                          274.51
# 1                                          257.00
# 2                                          274.33
# 3                                          257.00
# 4                                          257.00
# ...                                           ...
# 40501                                      257.00
# 40502                                      274.33
# 40503                                      274.78
# 40504                                      257.00
# 40505                                      257.00
#
#        HEAD Standby Position Y Collect Result_Dam  \
# 0                                             257
# 1                                              66
# 2                                             257
# 3                                              66
# 4                                              66
# ...                                           ...
# 40501                                          66
# 40502                                         257
# 40503                                         257
# 40504                                          66
# 40505                                          66
#
#        HEAD Standby Position Z Collect Result_Dam  \
# 0                                              66
# 1                                               0
# 2                                              66
# 3                                               0
# 4                                               0
# ...                                           ...
# 40501                                           0
# 40502                                          66
# 40503                                          66
# 40504                                           0
# 40505                                           0
#
#        Head Clean Position X Collect Result_Dam  \
# 0                                           0.0
# 1                                         127.5
# 2                                           0.0
# 3                                         127.5
# 4                                         127.5
# ...                                         ...
# 40501                                     127.5
# 40502                                       0.0
# 40503                                       0.0
# 40504                                     127.5
# 40505                                     127.5
#
#        Head Clean Position Y Collect Result_Dam  \
# 0                                         127.5
# 1                                          66.0
# 2                                         127.5
# 3                                          66.0
# 4                                          66.0
# ...                                         ...
# 40501                                      66.0
# 40502                                     127.5
# 40503                                     127.5
# 40504                                      66.0
# 40505                                      66.0
#
#        Head Clean Position Z Collect Result_Dam  \
# 0                                         66.00
# 1                                        130.85
# 2                                         66.00
# 3                                        130.85
# 4                                        133.50
# ...                                         ...
# 40501                                    130.85
# 40502                                     66.00
# 40503                                     66.00
# 40504                                    130.85
# 40505                                    133.50
#
#        Head Purge Position X Collect Result_Dam  \
# 0                                         124.0
# 1                                         257.0
# 2                                         124.0
# 3                                         257.0
# 4                                         257.0
# ...                                         ...
# 40501                                     257.0
# 40502                                     124.0
# 40503                                     124.0
# 40504                                     257.0
# 40505                                     257.0
#
#        Head Purge Position Y Collect Result_Dam  \
# 0                                           257
# 1                                            66
# 2                                           257
# 3                                            66
# 4                                            66
# ...                                         ...
# 40501                                        66
# 40502                                       257
# 40503                                       257
# 40504                                        66
# 40505                                        66
#
#        Head Purge Position Z Collect Result_Dam  \
# 0                                         66.00
# 1                                        130.85
# 2                                         66.00
# 3                                        130.85
# 4                                        133.50
# ...                                         ...
# 40501                                    130.85
# 40502                                     66.00
# 40503                                     66.00
# 40504                                    130.85
# 40505                                    133.50
#
#        Head Zero Position X Collect Result_Dam  \
# 0                                       130.85
# 1                                       505.00
# 2                                       130.85
# 3                                       505.00
# 4                                       505.00
# ...                                        ...
# 40501                                   505.00
# 40502                                   130.85
# 40503                                   130.85
# 40504                                   505.00
# 40505                                   505.00
#
#        Head Zero Position Y Collect Result_Dam  \
# 0                                        505.0
# 1                                        300.0
# 2                                        505.0
# 3                                        300.0
# 4                                        300.0
# ...                                        ...
# 40501                                    300.0
# 40502                                    505.0
# 40503                                    505.0
# 40504                                    300.0
# 40505                                    303.5
#
#        Head Zero Position Z Collect Result_Dam  \
# 0                                        300.0
# 1                                        265.0
# 2                                        300.0
# 3                                        265.0
# 4                                        265.0
# ...                                        ...
# 40501                                    265.0
# 40502                                    300.0
# 40503                                    300.0
# 40504                                    265.0
# 40505                                    265.0
#
#       HEAD NORMAL COORDINATE X AXIS(Stage1) Collect Result_Fill1  \
# 0                                                    NaN
# 1                                                  838.4
# 2                                                     OK
# 3                                                  837.7
# 4                                                  838.4
# ...                                                  ...
# 40501                                              838.4
# 40502                                                NaN
# 40503                                                 OK
# 40504                                              837.7
# 40505                                              837.9
#
#       HEAD NORMAL COORDINATE X AXIS(Stage1) Judge Value_Fill1  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                     OK
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 40501                                                NaN
# 40502                                                NaN
# 40503                                                 OK
# 40504                                                NaN
# 40505                                                NaN
#
#        HEAD NORMAL COORDINATE X AXIS(Stage2) Collect Result_Fill1  \
# 0                                                  838.4
# 1                                                  458.5
# 2                                                  837.9
# 3                                                  458.8
# 4                                                  458.5
# ...                                                  ...
# 40501                                              458.5
# 40502                                              838.1
# 40503                                              838.4
# 40504                                              458.8
# 40505                                              460.0
#
#        HEAD NORMAL COORDINATE X AXIS(Stage3) Collect Result_Fill1  \
# 0                                                  458.7
# 1                                                  157.0
# 2                                                  458.1
# 3                                                  157.0
# 4                                                  157.0
# ...                                                  ...
# 40501                                              157.0
# 40502                                              458.7
# 40503                                              458.4
# 40504                                              157.0
# 40505                                              157.5
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage1) Collect Result_Fill1  \
# 0                                                  157.0
# 1                                                  430.5
# 2                                                  156.1
# 3                                                 1323.2
# 4                                                  430.2
# ...                                                  ...
# 40501                                              430.5
# 40502                                              156.1
# 40503                                              157.0
# 40504                                             1323.2
# 40505                                              430.2
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage2) Collect Result_Fill1  \
# 0                                                  430.0
# 1                                                  430.5
# 2                                                 1323.5
# 3                                                 1322.5
# 4                                                  430.5
# ...                                                  ...
# 40501                                              430.5
# 40502                                             1325.0
# 40503                                              430.8
# 40504                                             1323.0
# 40505                                              430.5
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage3) Collect Result_Fill1  \
# 0                                                  429.8
# 1                                                  430.8
# 2                                                 1322.5
# 3                                                 1322.8
# 4                                                  430.5
# ...                                                  ...
# 40501                                              430.8
# 40502                                             1324.0
# 40503                                              430.5
# 40504                                             1322.8
# 40505                                              430.5
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage1) Collect Result_Fill1  \
# 0                                                  430.3
# 1                                                  244.4
# 2                                                 1323.1
# 3                                                  244.3
# 4                                                  244.4
# ...                                                  ...
# 40501                                              244.4
# 40502                                             1324.3
# 40503                                              431.1
# 40504                                              244.4
# 40505                                              244.3
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage2) Collect Result_Fill1  \
# 0                                                244.520
# 1                                                244.400
# 2                                                244.415
# 3                                                244.300
# 4                                                244.400
# ...                                                  ...
# 40501                                            244.400
# 40502                                            244.535
# 40503                                            244.543
# 40504                                            244.400
# 40505                                            244.300
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage3) Collect Result_Fill1  \
# 0                                                244.520
# 1                                                244.400
# 2                                                244.415
# 3                                                244.300
# 4                                                244.400
# ...                                                  ...
# 40501                                            244.400
# 40502                                            244.535
# 40503                                            244.543
# 40504                                            244.400
# 40505                                            244.300
#
#        HEAD Standby Position X Collect Result_Fill1  \
# 0                                           244.520
# 1                                           289.000
# 2                                           244.415
# 3                                           289.000
# 4                                           289.000
# ...                                             ...
# 40501                                       289.000
# 40502                                       244.535
# 40503                                       244.543
# 40504                                       289.000
# 40505                                       289.000
#
#        HEAD Standby Position Y Collect Result_Fill1  \
# 0                                               289
# 1                                                50
# 2                                               289
# 3                                                50
# 4                                                50
# ...                                             ...
# 40501                                            50
# 40502                                           289
# 40503                                           289
# 40504                                            50
# 40505                                            50
#
#        HEAD Standby Position Z Collect Result_Fill1  \
# 0                                                50
# 1                                                 0
# 2                                                50
# 3                                                 0
# 4                                                 0
# ...                                             ...
# 40501                                             0
# 40502                                            50
# 40503                                            50
# 40504                                             0
# 40505                                             0
#
#        Head Clean Position X Collect Result_Fill1  \
# 0                                             0.0
# 1                                           123.4
# 2                                             0.0
# 3                                           123.4
# 4                                           123.4
# ...                                           ...
# 40501                                       123.4
# 40502                                         0.0
# 40503                                         0.0
# 40504                                       123.4
# 40505                                       123.4
#
#        Head Clean Position Y Collect Result_Fill1  \
# 0                                           123.4
# 1                                            50.0
# 2                                           123.4
# 3                                            50.0
# 4                                            50.0
# ...                                           ...
# 40501                                        50.0
# 40502                                       123.4
# 40503                                       123.4
# 40504                                        50.0
# 40505                                        50.0
#
#        Head Clean Position Z Collect Result_Fill1  \
# 0                                            50.0
# 1                                            92.2
# 2                                            50.0
# 3                                            92.2
# 4                                            92.2
# ...                                           ...
# 40501                                        92.2
# 40502                                        50.0
# 40503                                        50.0
# 40504                                        92.2
# 40505                                        92.2
#
#        Head Purge Position X Collect Result_Fill1  \
# 0                                            92.2
# 1                                           289.0
# 2                                            92.2
# 3                                           289.0
# 4                                           289.0
# ...                                           ...
# 40501                                       289.0
# 40502                                        92.2
# 40503                                        92.2
# 40504                                       289.0
# 40505                                       289.0
#
#        Head Purge Position Y Collect Result_Fill1  \
# 0                                             289
# 1                                              50
# 2                                             289
# 3                                              50
# 4                                              50
# ...                                           ...
# 40501                                          50
# 40502                                         289
# 40503                                         289
# 40504                                          50
# 40505                                          50
#
#        Head Purge Position Z Collect Result_Fill1  \
# 0                                              50
# 1                                             145
# 2                                              50
# 3                                             145
# 4                                              85
# ...                                           ...
# 40501                                         145
# 40502                                          50
# 40503                                          50
# 40504                                         145
# 40505                                          85
#
#       HEAD NORMAL COORDINATE X AXIS(Stage1) Collect Result_Fill2  \
# 0                                                    NaN
# 1                                                  835.5
# 2                                                     OK
# 3                                                    305
# 4                                                  835.5
# ...                                                  ...
# 40501                                              835.5
# 40502                                                NaN
# 40503                                                 OK
# 40504                                                305
# 40505                                              835.5
#
#       HEAD NORMAL COORDINATE X AXIS(Stage1) Judge Value_Fill2  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                     OK
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 40501                                                NaN
# 40502                                                NaN
# 40503                                                 OK
# 40504                                                NaN
# 40505                                                NaN
#
#        HEAD NORMAL COORDINATE X AXIS(Stage2) Collect Result_Fill2  \
# 0                                                  835.5
# 1                                                  458.0
# 2                                                  305.0
# 3                                                  499.8
# 4                                                  458.0
# ...                                                  ...
# 40501                                              458.0
# 40502                                              304.8
# 40503                                              835.5
# 40504                                              499.8
# 40505                                              458.0
#
#        HEAD NORMAL COORDINATE X AXIS(Stage3) Collect Result_Fill2  \
# 0                                                  458.0
# 1                                                  156.0
# 2                                                  499.8
# 3                                                  694.0
# 4                                                  156.0
# ...                                                  ...
# 40501                                              156.0
# 40502                                              499.8
# 40503                                              458.0
# 40504                                              694.0
# 40505                                              156.0
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage1) Collect Result_Fill2  \
# 0                                                  156.0
# 1                                                  428.0
# 2                                                  694.0
# 3                                                 1324.2
# 4                                                  428.0
# ...                                                  ...
# 40501                                              428.0
# 40502                                              692.8
# 40503                                              156.0
# 40504                                             1324.2
# 40505                                              428.0
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage2) Collect Result_Fill2  \
# 0                                                  428.0
# 1                                                  427.9
# 2                                                 1324.2
# 3                                                 1324.2
# 4                                                  427.9
# ...                                                  ...
# 40501                                              427.9
# 40502                                             1324.2
# 40503                                              428.0
# 40504                                             1324.2
# 40505                                              427.9
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage3) Collect Result_Fill2  \
# 0                                                  427.9
# 1                                                  428.0
# 2                                                 1324.2
# 3                                                 1324.2
# 4                                                  428.0
# ...                                                  ...
# 40501                                              428.0
# 40502                                             1324.2
# 40503                                              427.9
# 40504                                             1324.2
# 40505                                              428.0
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage1) Collect Result_Fill2  \
# 0                                                  428.0
# 1                                                  243.7
# 2                                                 1324.2
# 3                                                  243.5
# 4                                                  243.7
# ...                                                  ...
# 40501                                              243.7
# 40502                                             1324.2
# 40503                                              428.0
# 40504                                              243.5
# 40505                                              243.7
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage2) Collect Result_Fill2  \
# 0                                                  243.7
# 1                                                  243.7
# 2                                                  243.5
# 3                                                  243.5
# 4                                                  243.7
# ...                                                  ...
# 40501                                              243.7
# 40502                                              243.5
# 40503                                              243.7
# 40504                                              243.5
# 40505                                              243.7
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage3) Collect Result_Fill2  \
# 0                                                  243.7
# 1                                                  243.7
# 2                                                  243.5
# 3                                                  243.5
# 4                                                  243.7
# ...                                                  ...
# 40501                                              243.7
# 40502                                              243.5
# 40503                                              243.7
# 40504                                              243.5
# 40505                                              243.7
#
#        HEAD Standby Position X Collect Result_Fill2  \
# 0                                             243.7
# 1                                             270.0
# 2                                             243.5
# 3                                             270.0
# 4                                             270.0
# ...                                             ...
# 40501                                         270.0
# 40502                                         243.5
# 40503                                         243.7
# 40504                                         270.0
# 40505                                         270.0
#
#        HEAD Standby Position Y Collect Result_Fill2  \
# 0                                               270
# 1                                                50
# 2                                               270
# 3                                                50
# 4                                                50
# ...                                             ...
# 40501                                            50
# 40502                                           270
# 40503                                           270
# 40504                                            50
# 40505                                            50
#
#        HEAD Standby Position Z Collect Result_Fill2  \
# 0                                                50
# 1                                               -10
# 2                                                50
# 3                                               -10
# 4                                               -10
# ...                                             ...
# 40501                                           -10
# 40502                                            50
# 40503                                            50
# 40504                                           -10
# 40505                                           -10
#
#        Head Clean Position X Collect Result_Fill2  \
# 0                                             -10
# 1                                             119
# 2                                             -10
# 3                                             119
# 4                                             119
# ...                                           ...
# 40501                                         119
# 40502                                         -10
# 40503                                         -10
# 40504                                         119
# 40505                                         119
#
#        Head Clean Position Y Collect Result_Fill2  \
# 0                                             119
# 1                                              50
# 2                                             119
# 3                                              50
# 4                                              50
# ...                                           ...
# 40501                                          50
# 40502                                         119
# 40503                                         119
# 40504                                          50
# 40505                                          50
#
#        Head Clean Position Z Collect Result_Fill2  \
# 0                                            50.0
# 1                                            91.8
# 2                                            50.0
# 3                                            91.8
# 4                                            91.8
# ...                                           ...
# 40501                                        91.8
# 40502                                        50.0
# 40503                                        50.0
# 40504                                        91.8
# 40505                                        91.8
#
#        Head Purge Position X Collect Result_Fill2  \
# 0                                            91.8
# 1                                           270.0
# 2                                            91.8
# 3                                           270.0
# 4                                           270.0
# ...                                           ...
# 40501                                       270.0
# 40502                                        91.8
# 40503                                        91.8
# 40504                                       270.0
# 40505                                       270.0
#
#        Head Purge Position Y Collect Result_Fill2  \
# 0                                             270
# 1                                              50
# 2                                             270
# 3                                              50
# 4                                              50
# ...                                           ...
# 40501                                          50
# 40502                                         270
# 40503                                         270
# 40504                                          50
# 40505                                          50
#
#        Head Purge Position Z Collect Result_Fill2
# 0                                              50
# 1                                              85
# 2                                              50
# 3                                              85
# 4                                              85
# ...                                           ...
# 40501                                          85
# 40502                                          50
# 40503                                          50
# 40504                                          85
# 40505                                          85
#
# [40506 rows x 60 columns]

# %%
nan_data=['HEAD NORMAL COORDINATE X AXIS(Stage1) Judge Value_Dam',
'GMES_ORIGIN_INSP_JUDGE_CODE Collect Result_AutoClave',
'GMES_ORIGIN_INSP_JUDGE_CODE Judge Value_AutoClave',
'HEAD NORMAL COORDINATE X AXIS(Stage1) Judge Value_Fill1',
'HEAD NORMAL COORDINATE X AXIS(Stage1) Judge Value_Fill2',]
nanana=train_data[nan_data]

# %%
# 첫 번째 컬럼을 기준으로 나머지 컬럼들과 비교
first_col = nanana.iloc[:, 0]
comparison_results = {}

# 각 컬럼에 대해 비교 결과 저장
for col in nanana.columns[1:]:
    comparison_results[col] = first_col.equals(nanana[col])

# 결과 출력
for col, is_equal in comparison_results.items():
    if is_equal:
        train_data=train_data.drop(col, axis=1)
        test=test.drop(col,axis=1)
        print(f"컬럼 '{nan_data[0]}'와 컬럼 '{col}'는 동일합니다.")
    else:
        print(f"컬럼 '{nan_data[0]}'와 컬럼 '{col}'는 다릅니다.")
# Out:
# 컬럼 'HEAD NORMAL COORDINATE X AXIS(Stage1) Judge Value_Dam'와 컬럼 'GMES_ORIGIN_INSP_JUDGE_CODE Collect Result_AutoClave'는 동일합니다.
# 컬럼 'HEAD NORMAL COORDINATE X AXIS(Stage1) Judge Value_Dam'와 컬럼 'GMES_ORIGIN_INSP_JUDGE_CODE Judge Value_AutoClave'는 동일합니다.
# 컬럼 'HEAD NORMAL COORDINATE X AXIS(Stage1) Judge Value_Dam'와 컬럼 'HEAD NORMAL COORDINATE X AXIS(Stage1) Judge Value_Fill1'는 동일합니다.
# 컬럼 'HEAD NORMAL COORDINATE X AXIS(Stage1) Judge Value_Dam'와 컬럼 'HEAD NORMAL COORDINATE X AXIS(Stage1) Judge Value_Fill2'는 동일합니다.

# %%
train_data
# Out:
#           Equipment_Dam    Collect Date_Dam  \
# 0      Dam dispenser #1 2024-04-25 11:10:00
# 1      Dam dispenser #1 2023-09-19 14:30:00
# 2      Dam dispenser #2 2024-03-05 09:30:00
# 3      Dam dispenser #2 2023-09-25 15:40:00
# 4      Dam dispenser #1 2023-06-27 13:20:00
# ...                 ...                 ...
# 40501  Dam dispenser #1 2023-09-14 15:50:00
# 40502  Dam dispenser #2 2024-04-10 14:20:00
# 40503  Dam dispenser #1 2024-02-22 08:40:00
# 40504  Dam dispenser #2 2023-07-25 11:00:00
# 40505  Dam dispenser #1 2023-05-31 01:40:00
#
#        CURE END POSITION X Collect Result_Dam  \
# 0                                       240.0
# 1                                       240.0
# 2                                      1000.0
# 3                                      1000.0
# 4                                       240.0
# ...                                       ...
# 40501                                   240.0
# 40502                                  1000.0
# 40503                                   240.0
# 40504                                  1000.0
# 40505                                   240.0
#
#        CURE END POSITION Z Collect Result_Dam  \
# 0                                         2.5
# 1                                         2.5
# 2                                        12.5
# 3                                        12.5
# 4                                         2.5
# ...                                       ...
# 40501                                     2.5
# 40502                                    12.5
# 40503                                     2.5
# 40504                                    12.5
# 40505                                     2.5
#
#        CURE END POSITION Θ Collect Result_Dam  CURE SPEED Collect Result_Dam  \
# 0                                         -90                            100
# 1                                         -90                             70
# 2                                          90                             85
# 3                                          90                             70
# 4                                         -90                             70
# ...                                       ...                            ...
# 40501                                     -90                             70
# 40502                                      90                            100
# 40503                                     -90                            100
# 40504                                      90                             70
# 40505                                     -90                             70
#
#        CURE START POSITION X Collect Result_Dam  \
# 0                                          1030
# 1                                          1030
# 2                                           280
# 3                                           280
# 4                                          1030
# ...                                         ...
# 40501                                      1030
# 40502                                       280
# 40503                                      1030
# 40504                                       280
# 40505                                      1030
#
#        CURE START POSITION Θ Collect Result_Dam  \
# 0                                           -90
# 1                                           -90
# 2                                            90
# 3                                            90
# 4                                           -90
# ...                                         ...
# 40501                                       -90
# 40502                                        90
# 40503                                       -90
# 40504                                        90
# 40505                                       -90
#
#        DISCHARGED SPEED OF RESIN Collect Result_Dam  \
# 0                                                16
# 1                                                10
# 2                                                16
# 3                                                10
# 4                                                10
# ...                                             ...
# 40501                                            10
# 40502                                            16
# 40503                                            16
# 40504                                            10
# 40505                                            10
#
#        DISCHARGED TIME OF RESIN(Stage1) Collect Result_Dam  \
# 0                                                   14.9
# 1                                                   21.3
# 2                                                   14.7
# 3                                                   21.3
# 4                                                    9.7
# ...                                                  ...
# 40501                                               17.0
# 40502                                               14.9
# 40503                                               14.2
# 40504                                                9.7
# 40505                                                9.6
#
#        DISCHARGED TIME OF RESIN(Stage2) Collect Result_Dam  \
# 0                                                    8.4
# 1                                                    4.9
# 2                                                    8.5
# 3                                                    8.4
# 4                                                    4.9
# ...                                                  ...
# 40501                                                5.0
# 40502                                                8.5
# 40503                                                8.2
# 40504                                                4.9
# 40505                                                3.9
#
#        DISCHARGED TIME OF RESIN(Stage3) Collect Result_Dam  \
# 0                                                   14.7
# 1                                                   21.3
# 2                                                   14.7
# 3                                                   21.3
# 4                                                    9.6
# ...                                                  ...
# 40501                                               17.0
# 40502                                               14.7
# 40503                                               14.3
# 40504                                                9.7
# 40505                                                9.7
#
#        Dispense Volume(Stage1) Collect Result_Dam  \
# 0                                            1.04
# 1                                            1.49
# 2                                            1.61
# 3                                            1.49
# 4                                            0.67
# ...                                           ...
# 40501                                        1.19
# 40502                                        1.04
# 40503                                        0.99
# 40504                                        0.67
# 40505                                        0.67
#
#        Dispense Volume(Stage2) Collect Result_Dam  \
# 0                                            0.58
# 1                                            0.34
# 2                                            0.93
# 3                                            0.58
# 4                                            0.34
# ...                                           ...
# 40501                                        0.35
# 40502                                        0.59
# 40503                                        0.57
# 40504                                        0.34
# 40505                                        0.27
#
#        Dispense Volume(Stage3) Collect Result_Dam  \
# 0                                            1.02
# 1                                            1.49
# 2                                            1.61
# 3                                            1.49
# 4                                            0.67
# ...                                           ...
# 40501                                        1.19
# 40502                                        1.02
# 40503                                        1.00
# 40504                                        0.67
# 40505                                        0.67
#
#       HEAD NORMAL COORDINATE X AXIS(Stage1) Collect Result_Dam  \
# 0                                                    NaN
# 1                                                  550.3
# 2                                                     OK
# 3                                                  162.4
# 4                                                    549
# ...                                                  ...
# 40501                                              550.3
# 40502                                                NaN
# 40503                                                 OK
# 40504                                              162.4
# 40505                                                549
#
#       HEAD NORMAL COORDINATE X AXIS(Stage1) Judge Value_Dam  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                     OK
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 40501                                                NaN
# 40502                                                NaN
# 40503                                                 OK
# 40504                                                NaN
# 40505                                                NaN
#
#        HEAD NORMAL COORDINATE X AXIS(Stage2) Collect Result_Dam  \
# 0                                                  550.5
# 1                                                  463.8
# 2                                                  162.4
# 3                                                  465.5
# 4                                                  462.5
# ...                                                  ...
# 40501                                              463.8
# 40502                                              163.5
# 40503                                              550.6
# 40504                                              465.1
# 40505                                              463.0
#
#        HEAD NORMAL COORDINATE X AXIS(Stage3) Collect Result_Dam  \
# 0                                                  464.3
# 1                                                  160.8
# 2                                                  465.4
# 3                                                  552.0
# 4                                                  159.5
# ...                                                  ...
# 40501                                              160.8
# 40502                                              466.2
# 40503                                              463.9
# 40504                                              551.3
# 40505                                              160.5
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage1) Collect Result_Dam  \
# 0                                                  161.4
# 1                                                  377.3
# 2                                                  551.7
# 3                                                 1271.8
# 4                                                  377.5
# ...                                                  ...
# 40501                                              377.3
# 40502                                              553.1
# 40503                                              161.5
# 40504                                             1269.0
# 40505                                              377.5
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage2) Collect Result_Dam  \
# 0                                                  384.0
# 1                                                  377.3
# 2                                                 1271.8
# 3                                                 1270.7
# 4                                                  377.0
# ...                                                  ...
# 40501                                              377.3
# 40502                                             1281.0
# 40503                                              377.6
# 40504                                             1268.4
# 40505                                              377.0
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage3) Collect Result_Dam  \
# 0                                                  383.1
# 1                                                  377.3
# 2                                                 1383.9
# 3                                                 1271.8
# 4                                                  377.5
# ...                                                  ...
# 40501                                              377.3
# 40502                                             1393.5
# 40503                                              377.1
# 40504                                             1269.0
# 40505                                              377.5
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage1) Collect Result_Dam  \
# 0                                                 384.00
# 1                                                 282.15
# 2                                                1271.80
# 3                                                 282.15
# 4                                                 284.80
# ...                                                  ...
# 40501                                             282.15
# 40502                                            1281.20
# 40503                                             378.00
# 40504                                             282.15
# 40505                                             284.80
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage2) Collect Result_Dam  \
# 0                                                 274.51
# 1                                                 282.15
# 2                                                 274.33
# 3                                                 282.15
# 4                                                 284.80
# ...                                                  ...
# 40501                                             282.15
# 40502                                             274.33
# 40503                                             274.78
# 40504                                             282.15
# 40505                                             284.80
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage3) Collect Result_Dam  \
# 0                                                 274.51
# 1                                                 282.15
# 2                                                 274.33
# 3                                                 282.15
# 4                                                 284.80
# ...                                                  ...
# 40501                                             282.15
# 40502                                             274.33
# 40503                                             274.78
# 40504                                             282.15
# 40505                                             284.80
#
#        HEAD Standby Position X Collect Result_Dam  \
# 0                                          274.51
# 1                                          257.00
# 2                                          274.33
# 3                                          257.00
# 4                                          257.00
# ...                                           ...
# 40501                                      257.00
# 40502                                      274.33
# 40503                                      274.78
# 40504                                      257.00
# 40505                                      257.00
#
#        HEAD Standby Position Y Collect Result_Dam  \
# 0                                             257
# 1                                              66
# 2                                             257
# 3                                              66
# 4                                              66
# ...                                           ...
# 40501                                          66
# 40502                                         257
# 40503                                         257
# 40504                                          66
# 40505                                          66
#
#        HEAD Standby Position Z Collect Result_Dam  \
# 0                                              66
# 1                                               0
# 2                                              66
# 3                                               0
# 4                                               0
# ...                                           ...
# 40501                                           0
# 40502                                          66
# 40503                                          66
# 40504                                           0
# 40505                                           0
#
#        Head Clean Position X Collect Result_Dam  \
# 0                                           0.0
# 1                                         127.5
# 2                                           0.0
# 3                                         127.5
# 4                                         127.5
# ...                                         ...
# 40501                                     127.5
# 40502                                       0.0
# 40503                                       0.0
# 40504                                     127.5
# 40505                                     127.5
#
#        Head Clean Position Y Collect Result_Dam  \
# 0                                         127.5
# 1                                          66.0
# 2                                         127.5
# 3                                          66.0
# 4                                          66.0
# ...                                         ...
# 40501                                      66.0
# 40502                                     127.5
# 40503                                     127.5
# 40504                                      66.0
# 40505                                      66.0
#
#        Head Clean Position Z Collect Result_Dam  \
# 0                                         66.00
# 1                                        130.85
# 2                                         66.00
# 3                                        130.85
# 4                                        133.50
# ...                                         ...
# 40501                                    130.85
# 40502                                     66.00
# 40503                                     66.00
# 40504                                    130.85
# 40505                                    133.50
#
#        Head Purge Position X Collect Result_Dam  \
# 0                                         124.0
# 1                                         257.0
# 2                                         124.0
# 3                                         257.0
# 4                                         257.0
# ...                                         ...
# 40501                                     257.0
# 40502                                     124.0
# 40503                                     124.0
# 40504                                     257.0
# 40505                                     257.0
#
#        Head Purge Position Y Collect Result_Dam  \
# 0                                           257
# 1                                            66
# 2                                           257
# 3                                            66
# 4                                            66
# ...                                         ...
# 40501                                        66
# 40502                                       257
# 40503                                       257
# 40504                                        66
# 40505                                        66
#
#        Head Purge Position Z Collect Result_Dam  \
# 0                                         66.00
# 1                                        130.85
# 2                                         66.00
# 3                                        130.85
# 4                                        133.50
# ...                                         ...
# 40501                                    130.85
# 40502                                     66.00
# 40503                                     66.00
# 40504                                    130.85
# 40505                                    133.50
#
#        Head Zero Position X Collect Result_Dam  \
# 0                                       130.85
# 1                                       505.00
# 2                                       130.85
# 3                                       505.00
# 4                                       505.00
# ...                                        ...
# 40501                                   505.00
# 40502                                   130.85
# 40503                                   130.85
# 40504                                   505.00
# 40505                                   505.00
#
#        Head Zero Position Y Collect Result_Dam  \
# 0                                        505.0
# 1                                        300.0
# 2                                        505.0
# 3                                        300.0
# 4                                        300.0
# ...                                        ...
# 40501                                    300.0
# 40502                                    505.0
# 40503                                    505.0
# 40504                                    300.0
# 40505                                    303.5
#
#        Head Zero Position Z Collect Result_Dam  \
# 0                                        300.0
# 1                                        265.0
# 2                                        300.0
# 3                                        265.0
# 4                                        265.0
# ...                                        ...
# 40501                                    265.0
# 40502                                    300.0
# 40503                                    300.0
# 40504                                    265.0
# 40505                                    265.0
#
#        Machine Tact time Collect Result_Dam  PalletID Collect Result_Dam  \
# 0                                    265.00                         58.5
# 1                                     65.10                          7.0
# 2                                    265.02                         76.9
# 3                                     70.50                         12.0
# 4                                     88.30                          8.0
# ...                                     ...                          ...
# 40501                                 56.70                          1.0
# 40502                                265.00                         78.5
# 40503                                265.02                         69.5
# 40504                                 57.70                         13.0
# 40505                                 92.10                          3.0
#
#        Production Qty Collect Result_Dam  Receip No Collect Result_Dam  \
# 0                                      7                           127
# 1                                    185                             1
# 2                                     10                            73
# 3                                    268                             1
# 4                                    121                             1
# ...                                  ...                           ...
# 40501                                318                             1
# 40502                                 14                           197
# 40503                                  1                            27
# 40504                                117                             1
# 40505                                320                             1
#
#        Stage1 Circle1 Distance Speed Collect Result_Dam  \
# 0                                                     1
# 1                                                  4000
# 2                                                     1
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                                 1
# 40503                                                 1
# 40504                                              9000
# 40505                                              9000
#
#        Stage1 Circle2 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage1 Circle3 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage1 Circle4 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage1 Line1 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage1 Line2 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage1 Line3 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage1 Line4 Distance Speed Collect Result_Dam  \
# 0                                                5600
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5600
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage2 Circle1 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  9000
# 2                                                  5800
# 3                                                  5000
# 4                                                  9000
# ...                                                 ...
# 40501                                              9000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                             12000
#
#        Stage2 Circle2 Distance Speed Collect Result_Dam  \
# 0                                                  5300
# 1                                                  9000
# 2                                                  5300
# 3                                                  5000
# 4                                                  9000
# ...                                                 ...
# 40501                                              9000
# 40502                                              5300
# 40503                                              5500
# 40504                                              9000
# 40505                                             12000
#
#        Stage2 Circle3 Distance Speed Collect Result_Dam  \
# 0                                                  5300
# 1                                                  9000
# 2                                                  5300
# 3                                                  5000
# 4                                                  9000
# ...                                                 ...
# 40501                                              9000
# 40502                                              5300
# 40503                                              5500
# 40504                                              9000
# 40505                                             12000
#
#        Stage2 Circle4 Distance Speed Collect Result_Dam  \
# 0                                                  5300
# 1                                                  9000
# 2                                                  5300
# 3                                                  5000
# 4                                                  9000
# ...                                                 ...
# 40501                                              9000
# 40502                                              5300
# 40503                                              5500
# 40504                                              9000
# 40505                                             12000
#
#        Stage2 Line1 Distance Speed Collect Result_Dam  \
# 0                                                5300
# 1                                                9000
# 2                                                5300
# 3                                                5000
# 4                                                9000
# ...                                               ...
# 40501                                            9000
# 40502                                            5300
# 40503                                            5500
# 40504                                            9000
# 40505                                           12000
#
#        Stage2 Line2 Distance Speed Collect Result_Dam  \
# 0                                                5300
# 1                                                9000
# 2                                                5300
# 3                                                5000
# 4                                                9000
# ...                                               ...
# 40501                                            9000
# 40502                                            5300
# 40503                                            5500
# 40504                                            9000
# 40505                                           12000
#
#        Stage2 Line3 Distance Speed Collect Result_Dam  \
# 0                                                5300
# 1                                                9000
# 2                                                5300
# 3                                                5000
# 4                                                9000
# ...                                               ...
# 40501                                            9000
# 40502                                            5300
# 40503                                            5500
# 40504                                            9000
# 40505                                           12000
#
#        Stage2 Line4 Distance Speed Collect Result_Dam  \
# 0                                                5300
# 1                                                9000
# 2                                                5300
# 3                                                5000
# 4                                                9000
# ...                                               ...
# 40501                                            9000
# 40502                                            5300
# 40503                                            5500
# 40504                                            9000
# 40505                                           12000
#
#        Stage3 Circle1 Distance Speed Collect Result_Dam  \
# 0                                                  5300
# 1                                                  4000
# 2                                                  5300
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5300
# 40503                                              5500
# 40504                                              9000
# 40505                                              9000
#
#        Stage3 Circle2 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage3 Circle3 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage3 Circle4 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage3 Line1 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage3 Line2 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage3 Line3 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage3 Line4 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        THICKNESS 1 Collect Result_Dam  THICKNESS 2 Collect Result_Dam  \
# 0                                5800                           0.000
# 1                                   0                           0.000
# 2                                5800                           0.012
# 3                                   0                           0.000
# 4                                   0                           0.000
# ...                               ...                             ...
# 40501                               0                           0.000
# 40502                            5800                          -0.019
# 40503                            6000                           0.000
# 40504                               0                           0.000
# 40505                               0                           0.000
#
#        THICKNESS 3 Collect Result_Dam  WorkMode Collect Result_Dam  \
# 0                               0.000                        0.000
# 1                               0.000                        7.000
# 2                              -0.022                        0.003
# 3                               0.000                        7.000
# 4                               0.000                        7.000
# ...                               ...                          ...
# 40501                           0.000                        7.000
# 40502                          -0.021                       -0.118
# 40503                           0.000                        0.000
# 40504                           0.000                        7.000
# 40505                           0.000                        7.000
#
#       Collect Date_AutoClave  1st Pressure Collect Result_AutoClave  \
# 0        2024-04-25 11:50:00                                  0.312
# 1        2023-09-19 15:00:00                                  0.311
# 2        2024-03-05 10:10:00                                  0.315
# 3        2023-09-25 16:20:00                                  0.299
# 4        2023-06-27 14:00:00                                  0.302
# ...                      ...                                    ...
# 40501    2023-09-14 16:30:00                                  0.300
# 40502    2024-04-10 15:00:00                                  0.305
# 40503    2024-02-22 09:20:00                                  0.309
# 40504    2023-07-25 11:40:00                                  0.302
# 40505    2023-05-31 02:10:00                                  0.305
#
#        1st Pressure 1st Pressure Unit Time_AutoClave  \
# 0                                                240
# 1                                                241
# 2                                                241
# 3                                                241
# 4                                                240
# ...                                              ...
# 40501                                            241
# 40502                                            240
# 40503                                            241
# 40504                                            241
# 40505                                            300
#
#        2nd Pressure Collect Result_AutoClave  \
# 0                                      0.493
# 1                                      0.311
# 2                                      0.490
# 3                                      0.300
# 4                                      0.302
# ...                                      ...
# 40501                                  0.300
# 40502                                  0.493
# 40503                                  0.490
# 40504                                  0.303
# 40505                                  0.305
#
#        2nd Pressure Unit Time_AutoClave  \
# 0                                     1
# 1                                   121
# 2                                     1
# 3                                   121
# 4                                   120
# ...                                 ...
# 40501                               121
# 40502                                 1
# 40503                                 1
# 40504                               121
# 40505                                60
#
#        3rd Pressure Collect Result_AutoClave  \
# 0                                      0.499
# 1                                      0.498
# 2                                      0.498
# 3                                      0.500
# 4                                      0.498
# ...                                      ...
# 40501                                  0.500
# 40502                                  0.498
# 40503                                  0.498
# 40504                                  0.499
# 40505                                  0.498
#
#        3rd Pressure Unit Time_AutoClave  \
# 0                                   120
# 1                                   121
# 2                                   121
# 3                                   121
# 4                                   120
# ...                                 ...
# 40501                               121
# 40502                               120
# 40503                               121
# ...
# 40505                                              835.5
#
#        HEAD NORMAL COORDINATE X AXIS(Stage2) Collect Result_Fill2  \
# 0                                                  835.5
# 1                                                  458.0
# 2                                                  305.0
# 3                                                  499.8
# 4                                                  458.0
# ...                                                  ...
# 40501                                              458.0
# 40502                                              304.8
# 40503                                              835.5
# 40504                                              499.8
# 40505                                              458.0
#
#        HEAD NORMAL COORDINATE X AXIS(Stage3) Collect Result_Fill2  \
# 0                                                  458.0
# 1                                                  156.0
# 2                                                  499.8
# 3                                                  694.0
# 4                                                  156.0
# ...                                                  ...
# 40501                                              156.0
# 40502                                              499.8
# 40503                                              458.0
# 40504                                              694.0
# 40505                                              156.0
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage1) Collect Result_Fill2  \
# 0                                                  156.0
# 1                                                  428.0
# 2                                                  694.0
# 3                                                 1324.2
# 4                                                  428.0
# ...                                                  ...
# 40501                                              428.0
# 40502                                              692.8
# 40503                                              156.0
# 40504                                             1324.2
# 40505                                              428.0
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage2) Collect Result_Fill2  \
# 0                                                  428.0
# 1                                                  427.9
# 2                                                 1324.2
# 3                                                 1324.2
# 4                                                  427.9
# ...                                                  ...
# 40501                                              427.9
# 40502                                             1324.2
# 40503                                              428.0
# 40504                                             1324.2
# 40505                                              427.9
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage3) Collect Result_Fill2  \
# 0                                                  427.9
# 1                                                  428.0
# 2                                                 1324.2
# 3                                                 1324.2
# 4                                                  428.0
# ...                                                  ...
# 40501                                              428.0
# 40502                                             1324.2
# 40503                                              427.9
# 40504                                             1324.2
# 40505                                              428.0
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage1) Collect Result_Fill2  \
# 0                                                  428.0
# 1                                                  243.7
# 2                                                 1324.2
# 3                                                  243.5
# 4                                                  243.7
# ...                                                  ...
# 40501                                              243.7
# 40502                                             1324.2
# 40503                                              428.0
# 40504                                              243.5
# 40505                                              243.7
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage2) Collect Result_Fill2  \
# 0                                                  243.7
# 1                                                  243.7
# 2                                                  243.5
# 3                                                  243.5
# 4                                                  243.7
# ...                                                  ...
# 40501                                              243.7
# 40502                                              243.5
# 40503                                              243.7
# 40504                                              243.5
# 40505                                              243.7
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage3) Collect Result_Fill2  \
# 0                                                  243.7
# 1                                                  243.7
# 2                                                  243.5
# 3                                                  243.5
# 4                                                  243.7
# ...                                                  ...
# 40501                                              243.7
# 40502                                              243.5
# 40503                                              243.7
# 40504                                              243.5
# 40505                                              243.7
#
#        HEAD Standby Position X Collect Result_Fill2  \
# 0                                             243.7
# 1                                             270.0
# 2                                             243.5
# 3                                             270.0
# 4                                             270.0
# ...                                             ...
# 40501                                         270.0
# 40502                                         243.5
# 40503                                         243.7
# 40504                                         270.0
# 40505                                         270.0
#
#        HEAD Standby Position Y Collect Result_Fill2  \
# 0                                               270
# 1                                                50
# 2                                               270
# 3                                                50
# 4                                                50
# ...                                             ...
# 40501                                            50
# 40502                                           270
# 40503                                           270
# 40504                                            50
# 40505                                            50
#
#        HEAD Standby Position Z Collect Result_Fill2  \
# 0                                                50
# 1                                               -10
# 2                                                50
# 3                                               -10
# 4                                               -10
# ...                                             ...
# 40501                                           -10
# 40502                                            50
# 40503                                            50
# 40504                                           -10
# 40505                                           -10
#
#        Head Clean Position X Collect Result_Fill2  \
# 0                                             -10
# 1                                             119
# 2                                             -10
# 3                                             119
# 4                                             119
# ...                                           ...
# 40501                                         119
# 40502                                         -10
# 40503                                         -10
# 40504                                         119
# 40505                                         119
#
#        Head Clean Position Y Collect Result_Fill2  \
# 0                                             119
# 1                                              50
# 2                                             119
# 3                                              50
# 4                                              50
# ...                                           ...
# 40501                                          50
# 40502                                         119
# 40503                                         119
# 40504                                          50
# 40505                                          50
#
#        Head Clean Position Z Collect Result_Fill2  \
# 0                                            50.0
# 1                                            91.8
# 2                                            50.0
# 3                                            91.8
# 4                                            91.8
# ...                                           ...
# 40501                                        91.8
# 40502                                        50.0
# 40503                                        50.0
# 40504                                        91.8
# 40505                                        91.8
#
#        Head Purge Position X Collect Result_Fill2  \
# 0                                            91.8
# 1                                           270.0
# 2                                            91.8
# 3                                           270.0
# 4                                           270.0
# ...                                           ...
# 40501                                       270.0
# 40502                                        91.8
# 40503                                        91.8
# 40504                                       270.0
# 40505                                       270.0
#
#        Head Purge Position Y Collect Result_Fill2  \
# 0                                             270
# 1                                              50
# 2                                             270
# 3                                              50
# 4                                              50
# ...                                           ...
# 40501                                          50
# 40502                                         270
# 40503                                         270
# 40504                                          50
# 40505                                          50
#
#        Head Purge Position Z Collect Result_Fill2  \
# 0                                              50
# 1                                              85
# 2                                              50
# 3                                              85
# 4                                              85
# ...                                           ...
# 40501                                          85
# 40502                                          50
# 40503                                          50
# 40504                                          85
# 40505                                          85
#
#        Machine Tact time Collect Result_Fill2  PalletID Collect Result_Fill2  \
# 0                                     114.612                           19.9
# 1                                      19.600                            7.0
# 2                                     114.612                           19.8
# 3                                      19.900                           12.0
# 4                                      19.700                            8.0
# ...                                       ...                            ...
# 40501                                  19.200                            1.0
# 40502                                 114.612                           20.5
# 40503                                  85.000                           19.7
# 40504                                  20.100                           13.0
# 40505                                  19.400                            3.0
#
#        Production Qty Collect Result_Fill2  Receip No Collect Result_Fill2  \
# 0                                        7                             127
# 1                                      185                               1
# 2                                       10                              73
# 3                                      268                               1
# 4                                      121                               1
# ...                                    ...                             ...
# 40501                                  318                               1
# 40502                                   14                             197
# 40503                                    1                              27
# 40504                                  117                               1
# 40505                                  320                               1
#
#        WorkMode Collect Result_Fill2    target Model.Suffix   Workorder  \
# 0                                  1    Normal  AJX75334505  4F1XA938-1
# 1                                  0    Normal  AJX75334505  3KPM0016-2
# 2                                  1    Normal  AJX75334501  4E1X9167-1
# 3                                  0    Normal  AJX75334501  3K1X0057-1
# 4                                  0    Normal  AJX75334501  3HPM0007-1
# ...                              ...       ...          ...         ...
# 40501                              0    Normal  AJX75334501  3J1XF434-2
# 40502                              1    Normal  AJX75334501  4E1XC796-1
# 40503                              1    Normal  AJX75334501  4C1XD438-1
# 40504                              0    Normal  AJX75334501  3I1XA258-1
# 40505                              0  AbNormal  AJX75334501  3G1XA501-1
#
#        running_time_m  month  day  hour  out_of_hour
# 0                40.0      4   25    11            0
# 1                30.0      9   19    14            0
# 2                40.0      3    5     9            0
# 3                40.0      9   25    15            0
# 4                40.0      6   27    13            0
# ...               ...    ...  ...   ...          ...
# 40501            40.0      9   14    15            0
# 40502            40.0      4   10    14            0
# 40503            40.0      2   22     8            0
# 40504            40.0      7   25    11            0
# 40505            30.0      5   31     1            1
#
# [40506 rows x 150 columns]

# %%
train_data['HEAD NORMAL COORDINATE X AXIS(Stage1) Judge Value_Dam'] = train_data['HEAD NORMAL COORDINATE X AXIS(Stage1) Judge Value_Dam'].combine_first(
    train_data['HEAD NORMAL COORDINATE X AXIS(Stage1) Collect Result_Dam'].apply(lambda x: 'nan' if pd.isna(x) else np.nan)
)
# 'Collect Result_Dam' 값이 숫자인 경우 'Judge Value_Dam'를 'NG'로 채우기
train_data.loc[
    (pd.to_numeric(train_data['HEAD NORMAL COORDINATE X AXIS(Stage1) Collect Result_Dam'], errors='coerce').notna()) &
    (~train_data['HEAD NORMAL COORDINATE X AXIS(Stage1) Judge Value_Dam'].isin(['OK', 'NaN'])),
    'HEAD NORMAL COORDINATE X AXIS(Stage1) Judge Value_Dam'
] = 'NG'


test['HEAD NORMAL COORDINATE X AXIS(Stage1) Judge Value_Dam'] = test['HEAD NORMAL COORDINATE X AXIS(Stage1) Judge Value_Dam'].combine_first(
    test['HEAD NORMAL COORDINATE X AXIS(Stage1) Collect Result_Dam'].apply(lambda x: 'nan' if pd.isna(x) else np.nan)
)
# 'Collect Result_Dam' 값이 숫자인 경우 'Judge Value_Dam'를 'NG'로 채우기
test.loc[
    (pd.to_numeric(test['HEAD NORMAL COORDINATE X AXIS(Stage1) Collect Result_Dam'], errors='coerce').notna()) &
    (~test['HEAD NORMAL COORDINATE X AXIS(Stage1) Judge Value_Dam'].isin(['OK', 'NaN'])),
    'HEAD NORMAL COORDINATE X AXIS(Stage1) Judge Value_Dam'
] = 'NG'

# %%
train_data
# Out:
#           Equipment_Dam    Collect Date_Dam  \
# 0      Dam dispenser #1 2024-04-25 11:10:00
# 1      Dam dispenser #1 2023-09-19 14:30:00
# 2      Dam dispenser #2 2024-03-05 09:30:00
# 3      Dam dispenser #2 2023-09-25 15:40:00
# 4      Dam dispenser #1 2023-06-27 13:20:00
# ...                 ...                 ...
# 40501  Dam dispenser #1 2023-09-14 15:50:00
# 40502  Dam dispenser #2 2024-04-10 14:20:00
# 40503  Dam dispenser #1 2024-02-22 08:40:00
# 40504  Dam dispenser #2 2023-07-25 11:00:00
# 40505  Dam dispenser #1 2023-05-31 01:40:00
#
#        CURE END POSITION X Collect Result_Dam  \
# 0                                       240.0
# 1                                       240.0
# 2                                      1000.0
# 3                                      1000.0
# 4                                       240.0
# ...                                       ...
# 40501                                   240.0
# 40502                                  1000.0
# 40503                                   240.0
# 40504                                  1000.0
# 40505                                   240.0
#
#        CURE END POSITION Z Collect Result_Dam  \
# 0                                         2.5
# 1                                         2.5
# 2                                        12.5
# 3                                        12.5
# 4                                         2.5
# ...                                       ...
# 40501                                     2.5
# 40502                                    12.5
# 40503                                     2.5
# 40504                                    12.5
# 40505                                     2.5
#
#        CURE END POSITION Θ Collect Result_Dam  CURE SPEED Collect Result_Dam  \
# 0                                         -90                            100
# 1                                         -90                             70
# 2                                          90                             85
# 3                                          90                             70
# 4                                         -90                             70
# ...                                       ...                            ...
# 40501                                     -90                             70
# 40502                                      90                            100
# 40503                                     -90                            100
# 40504                                      90                             70
# 40505                                     -90                             70
#
#        CURE START POSITION X Collect Result_Dam  \
# 0                                          1030
# 1                                          1030
# 2                                           280
# 3                                           280
# 4                                          1030
# ...                                         ...
# 40501                                      1030
# 40502                                       280
# 40503                                      1030
# 40504                                       280
# 40505                                      1030
#
#        CURE START POSITION Θ Collect Result_Dam  \
# 0                                           -90
# 1                                           -90
# 2                                            90
# 3                                            90
# 4                                           -90
# ...                                         ...
# 40501                                       -90
# 40502                                        90
# 40503                                       -90
# 40504                                        90
# 40505                                       -90
#
#        DISCHARGED SPEED OF RESIN Collect Result_Dam  \
# 0                                                16
# 1                                                10
# 2                                                16
# 3                                                10
# 4                                                10
# ...                                             ...
# 40501                                            10
# 40502                                            16
# 40503                                            16
# 40504                                            10
# 40505                                            10
#
#        DISCHARGED TIME OF RESIN(Stage1) Collect Result_Dam  \
# 0                                                   14.9
# 1                                                   21.3
# 2                                                   14.7
# 3                                                   21.3
# 4                                                    9.7
# ...                                                  ...
# 40501                                               17.0
# 40502                                               14.9
# 40503                                               14.2
# 40504                                                9.7
# 40505                                                9.6
#
#        DISCHARGED TIME OF RESIN(Stage2) Collect Result_Dam  \
# 0                                                    8.4
# 1                                                    4.9
# 2                                                    8.5
# 3                                                    8.4
# 4                                                    4.9
# ...                                                  ...
# 40501                                                5.0
# 40502                                                8.5
# 40503                                                8.2
# 40504                                                4.9
# 40505                                                3.9
#
#        DISCHARGED TIME OF RESIN(Stage3) Collect Result_Dam  \
# 0                                                   14.7
# 1                                                   21.3
# 2                                                   14.7
# 3                                                   21.3
# 4                                                    9.6
# ...                                                  ...
# 40501                                               17.0
# 40502                                               14.7
# 40503                                               14.3
# 40504                                                9.7
# 40505                                                9.7
#
#        Dispense Volume(Stage1) Collect Result_Dam  \
# 0                                            1.04
# 1                                            1.49
# 2                                            1.61
# 3                                            1.49
# 4                                            0.67
# ...                                           ...
# 40501                                        1.19
# 40502                                        1.04
# 40503                                        0.99
# 40504                                        0.67
# 40505                                        0.67
#
#        Dispense Volume(Stage2) Collect Result_Dam  \
# 0                                            0.58
# 1                                            0.34
# 2                                            0.93
# 3                                            0.58
# 4                                            0.34
# ...                                           ...
# 40501                                        0.35
# 40502                                        0.59
# 40503                                        0.57
# 40504                                        0.34
# 40505                                        0.27
#
#        Dispense Volume(Stage3) Collect Result_Dam  \
# 0                                            1.02
# 1                                            1.49
# 2                                            1.61
# 3                                            1.49
# 4                                            0.67
# ...                                           ...
# 40501                                        1.19
# 40502                                        1.02
# 40503                                        1.00
# 40504                                        0.67
# 40505                                        0.67
#
#       HEAD NORMAL COORDINATE X AXIS(Stage1) Collect Result_Dam  \
# 0                                                    NaN
# 1                                                  550.3
# 2                                                     OK
# 3                                                  162.4
# 4                                                    549
# ...                                                  ...
# 40501                                              550.3
# 40502                                                NaN
# 40503                                                 OK
# 40504                                              162.4
# 40505                                                549
#
#       HEAD NORMAL COORDINATE X AXIS(Stage1) Judge Value_Dam  \
# 0                                                    nan
# 1                                                     NG
# 2                                                     OK
# 3                                                     NG
# 4                                                     NG
# ...                                                  ...
# 40501                                                 NG
# 40502                                                nan
# 40503                                                 OK
# 40504                                                 NG
# 40505                                                 NG
#
#        HEAD NORMAL COORDINATE X AXIS(Stage2) Collect Result_Dam  \
# 0                                                  550.5
# 1                                                  463.8
# 2                                                  162.4
# 3                                                  465.5
# 4                                                  462.5
# ...                                                  ...
# 40501                                              463.8
# 40502                                              163.5
# 40503                                              550.6
# 40504                                              465.1
# 40505                                              463.0
#
#        HEAD NORMAL COORDINATE X AXIS(Stage3) Collect Result_Dam  \
# 0                                                  464.3
# 1                                                  160.8
# 2                                                  465.4
# 3                                                  552.0
# 4                                                  159.5
# ...                                                  ...
# 40501                                              160.8
# 40502                                              466.2
# 40503                                              463.9
# 40504                                              551.3
# 40505                                              160.5
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage1) Collect Result_Dam  \
# 0                                                  161.4
# 1                                                  377.3
# 2                                                  551.7
# 3                                                 1271.8
# 4                                                  377.5
# ...                                                  ...
# 40501                                              377.3
# 40502                                              553.1
# 40503                                              161.5
# 40504                                             1269.0
# 40505                                              377.5
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage2) Collect Result_Dam  \
# 0                                                  384.0
# 1                                                  377.3
# 2                                                 1271.8
# 3                                                 1270.7
# 4                                                  377.0
# ...                                                  ...
# 40501                                              377.3
# 40502                                             1281.0
# 40503                                              377.6
# 40504                                             1268.4
# 40505                                              377.0
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage3) Collect Result_Dam  \
# 0                                                  383.1
# 1                                                  377.3
# 2                                                 1383.9
# 3                                                 1271.8
# 4                                                  377.5
# ...                                                  ...
# 40501                                              377.3
# 40502                                             1393.5
# 40503                                              377.1
# 40504                                             1269.0
# 40505                                              377.5
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage1) Collect Result_Dam  \
# 0                                                 384.00
# 1                                                 282.15
# 2                                                1271.80
# 3                                                 282.15
# 4                                                 284.80
# ...                                                  ...
# 40501                                             282.15
# 40502                                            1281.20
# 40503                                             378.00
# 40504                                             282.15
# 40505                                             284.80
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage2) Collect Result_Dam  \
# 0                                                 274.51
# 1                                                 282.15
# 2                                                 274.33
# 3                                                 282.15
# 4                                                 284.80
# ...                                                  ...
# 40501                                             282.15
# 40502                                             274.33
# 40503                                             274.78
# 40504                                             282.15
# 40505                                             284.80
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage3) Collect Result_Dam  \
# 0                                                 274.51
# 1                                                 282.15
# 2                                                 274.33
# 3                                                 282.15
# 4                                                 284.80
# ...                                                  ...
# 40501                                             282.15
# 40502                                             274.33
# 40503                                             274.78
# 40504                                             282.15
# 40505                                             284.80
#
#        HEAD Standby Position X Collect Result_Dam  \
# 0                                          274.51
# 1                                          257.00
# 2                                          274.33
# 3                                          257.00
# 4                                          257.00
# ...                                           ...
# 40501                                      257.00
# 40502                                      274.33
# 40503                                      274.78
# 40504                                      257.00
# 40505                                      257.00
#
#        HEAD Standby Position Y Collect Result_Dam  \
# 0                                             257
# 1                                              66
# 2                                             257
# 3                                              66
# 4                                              66
# ...                                           ...
# 40501                                          66
# 40502                                         257
# 40503                                         257
# 40504                                          66
# 40505                                          66
#
#        HEAD Standby Position Z Collect Result_Dam  \
# 0                                              66
# 1                                               0
# 2                                              66
# 3                                               0
# 4                                               0
# ...                                           ...
# 40501                                           0
# 40502                                          66
# 40503                                          66
# 40504                                           0
# 40505                                           0
#
#        Head Clean Position X Collect Result_Dam  \
# 0                                           0.0
# 1                                         127.5
# 2                                           0.0
# 3                                         127.5
# 4                                         127.5
# ...                                         ...
# 40501                                     127.5
# 40502                                       0.0
# 40503                                       0.0
# 40504                                     127.5
# 40505                                     127.5
#
#        Head Clean Position Y Collect Result_Dam  \
# 0                                         127.5
# 1                                          66.0
# 2                                         127.5
# 3                                          66.0
# 4                                          66.0
# ...                                         ...
# 40501                                      66.0
# 40502                                     127.5
# 40503                                     127.5
# 40504                                      66.0
# 40505                                      66.0
#
#        Head Clean Position Z Collect Result_Dam  \
# 0                                         66.00
# 1                                        130.85
# 2                                         66.00
# 3                                        130.85
# 4                                        133.50
# ...                                         ...
# 40501                                    130.85
# 40502                                     66.00
# 40503                                     66.00
# 40504                                    130.85
# 40505                                    133.50
#
#        Head Purge Position X Collect Result_Dam  \
# 0                                         124.0
# 1                                         257.0
# 2                                         124.0
# 3                                         257.0
# 4                                         257.0
# ...                                         ...
# 40501                                     257.0
# 40502                                     124.0
# 40503                                     124.0
# 40504                                     257.0
# 40505                                     257.0
#
#        Head Purge Position Y Collect Result_Dam  \
# 0                                           257
# 1                                            66
# 2                                           257
# 3                                            66
# 4                                            66
# ...                                         ...
# 40501                                        66
# 40502                                       257
# 40503                                       257
# 40504                                        66
# 40505                                        66
#
#        Head Purge Position Z Collect Result_Dam  \
# 0                                         66.00
# 1                                        130.85
# 2                                         66.00
# 3                                        130.85
# 4                                        133.50
# ...                                         ...
# 40501                                    130.85
# 40502                                     66.00
# 40503                                     66.00
# 40504                                    130.85
# 40505                                    133.50
#
#        Head Zero Position X Collect Result_Dam  \
# 0                                       130.85
# 1                                       505.00
# 2                                       130.85
# 3                                       505.00
# 4                                       505.00
# ...                                        ...
# 40501                                   505.00
# 40502                                   130.85
# 40503                                   130.85
# 40504                                   505.00
# 40505                                   505.00
#
#        Head Zero Position Y Collect Result_Dam  \
# 0                                        505.0
# 1                                        300.0
# 2                                        505.0
# 3                                        300.0
# 4                                        300.0
# ...                                        ...
# 40501                                    300.0
# 40502                                    505.0
# 40503                                    505.0
# 40504                                    300.0
# 40505                                    303.5
#
#        Head Zero Position Z Collect Result_Dam  \
# 0                                        300.0
# 1                                        265.0
# 2                                        300.0
# 3                                        265.0
# 4                                        265.0
# ...                                        ...
# 40501                                    265.0
# 40502                                    300.0
# 40503                                    300.0
# 40504                                    265.0
# 40505                                    265.0
#
#        Machine Tact time Collect Result_Dam  PalletID Collect Result_Dam  \
# 0                                    265.00                         58.5
# 1                                     65.10                          7.0
# 2                                    265.02                         76.9
# 3                                     70.50                         12.0
# 4                                     88.30                          8.0
# ...                                     ...                          ...
# 40501                                 56.70                          1.0
# 40502                                265.00                         78.5
# 40503                                265.02                         69.5
# 40504                                 57.70                         13.0
# 40505                                 92.10                          3.0
#
#        Production Qty Collect Result_Dam  Receip No Collect Result_Dam  \
# 0                                      7                           127
# 1                                    185                             1
# 2                                     10                            73
# 3                                    268                             1
# 4                                    121                             1
# ...                                  ...                           ...
# 40501                                318                             1
# 40502                                 14                           197
# 40503                                  1                            27
# 40504                                117                             1
# 40505                                320                             1
#
#        Stage1 Circle1 Distance Speed Collect Result_Dam  \
# 0                                                     1
# 1                                                  4000
# 2                                                     1
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                                 1
# 40503                                                 1
# 40504                                              9000
# 40505                                              9000
#
#        Stage1 Circle2 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage1 Circle3 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage1 Circle4 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage1 Line1 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage1 Line2 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage1 Line3 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage1 Line4 Distance Speed Collect Result_Dam  \
# 0                                                5600
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5600
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage2 Circle1 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  9000
# 2                                                  5800
# 3                                                  5000
# 4                                                  9000
# ...                                                 ...
# 40501                                              9000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                             12000
#
#        Stage2 Circle2 Distance Speed Collect Result_Dam  \
# 0                                                  5300
# 1                                                  9000
# 2                                                  5300
# 3                                                  5000
# 4                                                  9000
# ...                                                 ...
# 40501                                              9000
# 40502                                              5300
# 40503                                              5500
# 40504                                              9000
# 40505                                             12000
#
#        Stage2 Circle3 Distance Speed Collect Result_Dam  \
# 0                                                  5300
# 1                                                  9000
# 2                                                  5300
# 3                                                  5000
# 4                                                  9000
# ...                                                 ...
# 40501                                              9000
# 40502                                              5300
# 40503                                              5500
# 40504                                              9000
# 40505                                             12000
#
#        Stage2 Circle4 Distance Speed Collect Result_Dam  \
# 0                                                  5300
# 1                                                  9000
# 2                                                  5300
# 3                                                  5000
# 4                                                  9000
# ...                                                 ...
# 40501                                              9000
# 40502                                              5300
# 40503                                              5500
# 40504                                              9000
# 40505                                             12000
#
#        Stage2 Line1 Distance Speed Collect Result_Dam  \
# 0                                                5300
# 1                                                9000
# 2                                                5300
# 3                                                5000
# 4                                                9000
# ...                                               ...
# 40501                                            9000
# 40502                                            5300
# 40503                                            5500
# 40504                                            9000
# 40505                                           12000
#
#        Stage2 Line2 Distance Speed Collect Result_Dam  \
# 0                                                5300
# 1                                                9000
# 2                                                5300
# 3                                                5000
# 4                                                9000
# ...                                               ...
# 40501                                            9000
# 40502                                            5300
# 40503                                            5500
# 40504                                            9000
# 40505                                           12000
#
#        Stage2 Line3 Distance Speed Collect Result_Dam  \
# 0                                                5300
# 1                                                9000
# 2                                                5300
# 3                                                5000
# 4                                                9000
# ...                                               ...
# 40501                                            9000
# 40502                                            5300
# 40503                                            5500
# 40504                                            9000
# 40505                                           12000
#
#        Stage2 Line4 Distance Speed Collect Result_Dam  \
# 0                                                5300
# 1                                                9000
# 2                                                5300
# 3                                                5000
# 4                                                9000
# ...                                               ...
# 40501                                            9000
# 40502                                            5300
# 40503                                            5500
# 40504                                            9000
# 40505                                           12000
#
#        Stage3 Circle1 Distance Speed Collect Result_Dam  \
# 0                                                  5300
# 1                                                  4000
# 2                                                  5300
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5300
# 40503                                              5500
# 40504                                              9000
# 40505                                              9000
#
#        Stage3 Circle2 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage3 Circle3 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage3 Circle4 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage3 Line1 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage3 Line2 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage3 Line3 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage3 Line4 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        THICKNESS 1 Collect Result_Dam  THICKNESS 2 Collect Result_Dam  \
# 0                                5800                           0.000
# 1                                   0                           0.000
# 2                                5800                           0.012
# 3                                   0                           0.000
# 4                                   0                           0.000
# ...                               ...                             ...
# 40501                               0                           0.000
# 40502                            5800                          -0.019
# 40503                            6000                           0.000
# 40504                               0                           0.000
# 40505                               0                           0.000
#
#        THICKNESS 3 Collect Result_Dam  WorkMode Collect Result_Dam  \
# 0                               0.000                        0.000
# 1                               0.000                        7.000
# 2                              -0.022                        0.003
# 3                               0.000                        7.000
# 4                               0.000                        7.000
# ...                               ...                          ...
# 40501                           0.000                        7.000
# 40502                          -0.021                       -0.118
# 40503                           0.000                        0.000
# 40504                           0.000                        7.000
# 40505                           0.000                        7.000
#
#       Collect Date_AutoClave  1st Pressure Collect Result_AutoClave  \
# 0        2024-04-25 11:50:00                                  0.312
# 1        2023-09-19 15:00:00                                  0.311
# 2        2024-03-05 10:10:00                                  0.315
# 3        2023-09-25 16:20:00                                  0.299
# 4        2023-06-27 14:00:00                                  0.302
# ...                      ...                                    ...
# 40501    2023-09-14 16:30:00                                  0.300
# 40502    2024-04-10 15:00:00                                  0.305
# 40503    2024-02-22 09:20:00                                  0.309
# 40504    2023-07-25 11:40:00                                  0.302
# 40505    2023-05-31 02:10:00                                  0.305
#
#        1st Pressure 1st Pressure Unit Time_AutoClave  \
# 0                                                240
# 1                                                241
# 2                                                241
# 3                                                241
# 4                                                240
# ...                                              ...
# 40501                                            241
# 40502                                            240
# 40503                                            241
# 40504                                            241
# 40505                                            300
#
#        2nd Pressure Collect Result_AutoClave  \
# 0                                      0.493
# 1                                      0.311
# 2                                      0.490
# 3                                      0.300
# 4                                      0.302
# ...                                      ...
# 40501                                  0.300
# 40502                                  0.493
# 40503                                  0.490
# 40504                                  0.303
# 40505                                  0.305
#
#        2nd Pressure Unit Time_AutoClave  \
# 0                                     1
# 1                                   121
# 2                                     1
# 3                                   121
# 4                                   120
# ...                                 ...
# 40501                               121
# 40502                                 1
# 40503                                 1
# 40504                               121
# 40505                                60
#
#        3rd Pressure Collect Result_AutoClave  \
# 0                                      0.499
# 1                                      0.498
# 2                                      0.498
# 3                                      0.500
# 4                                      0.498
# ...                                      ...
# 40501                                  0.500
# 40502                                  0.498
# 40503                                  0.498
# 40504                                  0.499
# 40505                                  0.498
#
#        3rd Pressure Unit Time_AutoClave  \
# 0                                   120
# 1                                   121
# 2                                   121
# 3                                   121
# 4                                   120
# ...                                 ...
# 40501                               121
# 40502                               120
# 40503                               121
# ...
# 40505                                              835.5
#
#        HEAD NORMAL COORDINATE X AXIS(Stage2) Collect Result_Fill2  \
# 0                                                  835.5
# 1                                                  458.0
# 2                                                  305.0
# 3                                                  499.8
# 4                                                  458.0
# ...                                                  ...
# 40501                                              458.0
# 40502                                              304.8
# 40503                                              835.5
# 40504                                              499.8
# 40505                                              458.0
#
#        HEAD NORMAL COORDINATE X AXIS(Stage3) Collect Result_Fill2  \
# 0                                                  458.0
# 1                                                  156.0
# 2                                                  499.8
# 3                                                  694.0
# 4                                                  156.0
# ...                                                  ...
# 40501                                              156.0
# 40502                                              499.8
# 40503                                              458.0
# 40504                                              694.0
# 40505                                              156.0
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage1) Collect Result_Fill2  \
# 0                                                  156.0
# 1                                                  428.0
# 2                                                  694.0
# 3                                                 1324.2
# 4                                                  428.0
# ...                                                  ...
# 40501                                              428.0
# 40502                                              692.8
# 40503                                              156.0
# 40504                                             1324.2
# 40505                                              428.0
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage2) Collect Result_Fill2  \
# 0                                                  428.0
# 1                                                  427.9
# 2                                                 1324.2
# 3                                                 1324.2
# 4                                                  427.9
# ...                                                  ...
# 40501                                              427.9
# 40502                                             1324.2
# 40503                                              428.0
# 40504                                             1324.2
# 40505                                              427.9
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage3) Collect Result_Fill2  \
# 0                                                  427.9
# 1                                                  428.0
# 2                                                 1324.2
# 3                                                 1324.2
# 4                                                  428.0
# ...                                                  ...
# 40501                                              428.0
# 40502                                             1324.2
# 40503                                              427.9
# 40504                                             1324.2
# 40505                                              428.0
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage1) Collect Result_Fill2  \
# 0                                                  428.0
# 1                                                  243.7
# 2                                                 1324.2
# 3                                                  243.5
# 4                                                  243.7
# ...                                                  ...
# 40501                                              243.7
# 40502                                             1324.2
# 40503                                              428.0
# 40504                                              243.5
# 40505                                              243.7
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage2) Collect Result_Fill2  \
# 0                                                  243.7
# 1                                                  243.7
# 2                                                  243.5
# 3                                                  243.5
# 4                                                  243.7
# ...                                                  ...
# 40501                                              243.7
# 40502                                              243.5
# 40503                                              243.7
# 40504                                              243.5
# 40505                                              243.7
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage3) Collect Result_Fill2  \
# 0                                                  243.7
# 1                                                  243.7
# 2                                                  243.5
# 3                                                  243.5
# 4                                                  243.7
# ...                                                  ...
# 40501                                              243.7
# 40502                                              243.5
# 40503                                              243.7
# 40504                                              243.5
# 40505                                              243.7
#
#        HEAD Standby Position X Collect Result_Fill2  \
# 0                                             243.7
# 1                                             270.0
# 2                                             243.5
# 3                                             270.0
# 4                                             270.0
# ...                                             ...
# 40501                                         270.0
# 40502                                         243.5
# 40503                                         243.7
# 40504                                         270.0
# 40505                                         270.0
#
#        HEAD Standby Position Y Collect Result_Fill2  \
# 0                                               270
# 1                                                50
# 2                                               270
# 3                                                50
# 4                                                50
# ...                                             ...
# 40501                                            50
# 40502                                           270
# 40503                                           270
# 40504                                            50
# 40505                                            50
#
#        HEAD Standby Position Z Collect Result_Fill2  \
# 0                                                50
# 1                                               -10
# 2                                                50
# 3                                               -10
# 4                                               -10
# ...                                             ...
# 40501                                           -10
# 40502                                            50
# 40503                                            50
# 40504                                           -10
# 40505                                           -10
#
#        Head Clean Position X Collect Result_Fill2  \
# 0                                             -10
# 1                                             119
# 2                                             -10
# 3                                             119
# 4                                             119
# ...                                           ...
# 40501                                         119
# 40502                                         -10
# 40503                                         -10
# 40504                                         119
# 40505                                         119
#
#        Head Clean Position Y Collect Result_Fill2  \
# 0                                             119
# 1                                              50
# 2                                             119
# 3                                              50
# 4                                              50
# ...                                           ...
# 40501                                          50
# 40502                                         119
# 40503                                         119
# 40504                                          50
# 40505                                          50
#
#        Head Clean Position Z Collect Result_Fill2  \
# 0                                            50.0
# 1                                            91.8
# 2                                            50.0
# 3                                            91.8
# 4                                            91.8
# ...                                           ...
# 40501                                        91.8
# 40502                                        50.0
# 40503                                        50.0
# 40504                                        91.8
# 40505                                        91.8
#
#        Head Purge Position X Collect Result_Fill2  \
# 0                                            91.8
# 1                                           270.0
# 2                                            91.8
# 3                                           270.0
# 4                                           270.0
# ...                                           ...
# 40501                                       270.0
# 40502                                        91.8
# 40503                                        91.8
# 40504                                       270.0
# 40505                                       270.0
#
#        Head Purge Position Y Collect Result_Fill2  \
# 0                                             270
# 1                                              50
# 2                                             270
# 3                                              50
# 4                                              50
# ...                                           ...
# 40501                                          50
# 40502                                         270
# 40503                                         270
# 40504                                          50
# 40505                                          50
#
#        Head Purge Position Z Collect Result_Fill2  \
# 0                                              50
# 1                                              85
# 2                                              50
# 3                                              85
# 4                                              85
# ...                                           ...
# 40501                                          85
# 40502                                          50
# 40503                                          50
# 40504                                          85
# 40505                                          85
#
#        Machine Tact time Collect Result_Fill2  PalletID Collect Result_Fill2  \
# 0                                     114.612                           19.9
# 1                                      19.600                            7.0
# 2                                     114.612                           19.8
# 3                                      19.900                           12.0
# 4                                      19.700                            8.0
# ...                                       ...                            ...
# 40501                                  19.200                            1.0
# 40502                                 114.612                           20.5
# 40503                                  85.000                           19.7
# 40504                                  20.100                           13.0
# 40505                                  19.400                            3.0
#
#        Production Qty Collect Result_Fill2  Receip No Collect Result_Fill2  \
# 0                                        7                             127
# 1                                      185                               1
# 2                                       10                              73
# 3                                      268                               1
# 4                                      121                               1
# ...                                    ...                             ...
# 40501                                  318                               1
# 40502                                   14                             197
# 40503                                    1                              27
# 40504                                  117                               1
# 40505                                  320                               1
#
#        WorkMode Collect Result_Fill2    target Model.Suffix   Workorder  \
# 0                                  1    Normal  AJX75334505  4F1XA938-1
# 1                                  0    Normal  AJX75334505  3KPM0016-2
# 2                                  1    Normal  AJX75334501  4E1X9167-1
# 3                                  0    Normal  AJX75334501  3K1X0057-1
# 4                                  0    Normal  AJX75334501  3HPM0007-1
# ...                              ...       ...          ...         ...
# 40501                              0    Normal  AJX75334501  3J1XF434-2
# 40502                              1    Normal  AJX75334501  4E1XC796-1
# 40503                              1    Normal  AJX75334501  4C1XD438-1
# 40504                              0    Normal  AJX75334501  3I1XA258-1
# 40505                              0  AbNormal  AJX75334501  3G1XA501-1
#
#        running_time_m  month  day  hour  out_of_hour
# 0                40.0      4   25    11            0
# 1                30.0      9   19    14            0
# 2                40.0      3    5     9            0
# 3                40.0      9   25    15            0
# 4                40.0      6   27    13            0
# ...               ...    ...  ...   ...          ...
# 40501            40.0      9   14    15            0
# 40502            40.0      4   10    14            0
# 40503            40.0      2   22     8            0
# 40504            40.0      7   25    11            0
# 40505            30.0      5   31     1            1
#
# [40506 rows x 150 columns]

# %%
train_data.info(200)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40506 entries, 0 to 40505
# Data columns (total 150 columns):
#  #    Column                                                      Dtype
# ---   ------                                                      -----
#  0    Equipment_Dam                                               object
#  1    Collect Date_Dam                                            datetime64[ns]
#  2    CURE END POSITION X Collect Result_Dam                      float64
#  3    CURE END POSITION Z Collect Result_Dam                      float64
#  4    CURE END POSITION Θ Collect Result_Dam                      int64
#  5    CURE SPEED Collect Result_Dam                               int64
#  6    CURE START POSITION X Collect Result_Dam                    int64
#  7    CURE START POSITION Θ Collect Result_Dam                    int64
#  8    DISCHARGED SPEED OF RESIN Collect Result_Dam                int64
#  9    DISCHARGED TIME OF RESIN(Stage1) Collect Result_Dam         float64
#  10   DISCHARGED TIME OF RESIN(Stage2) Collect Result_Dam         float64
#  11   DISCHARGED TIME OF RESIN(Stage3) Collect Result_Dam         float64
#  12   Dispense Volume(Stage1) Collect Result_Dam                  float64
#  13   Dispense Volume(Stage2) Collect Result_Dam                  float64
#  14   Dispense Volume(Stage3) Collect Result_Dam                  float64
#  15   HEAD NORMAL COORDINATE X AXIS(Stage1) Collect Result_Dam    object
#  16   HEAD NORMAL COORDINATE X AXIS(Stage1) Judge Value_Dam       object
#  17   HEAD NORMAL COORDINATE X AXIS(Stage2) Collect Result_Dam    float64
#  18   HEAD NORMAL COORDINATE X AXIS(Stage3) Collect Result_Dam    float64
#  19   HEAD NORMAL COORDINATE Y AXIS(Stage1) Collect Result_Dam    float64
#  20   HEAD NORMAL COORDINATE Y AXIS(Stage2) Collect Result_Dam    float64
#  21   HEAD NORMAL COORDINATE Y AXIS(Stage3) Collect Result_Dam    float64
#  22   HEAD NORMAL COORDINATE Z AXIS(Stage1) Collect Result_Dam    float64
#  23   HEAD NORMAL COORDINATE Z AXIS(Stage2) Collect Result_Dam    float64
#  24   HEAD NORMAL COORDINATE Z AXIS(Stage3) Collect Result_Dam    float64
#  25   HEAD Standby Position X Collect Result_Dam                  float64
#  26   HEAD Standby Position Y Collect Result_Dam                  int64
#  27   HEAD Standby Position Z Collect Result_Dam                  int64
#  28   Head Clean Position X Collect Result_Dam                    float64
#  29   Head Clean Position Y Collect Result_Dam                    float64
#  30   Head Clean Position Z Collect Result_Dam                    float64
#  31   Head Purge Position X Collect Result_Dam                    float64
#  32   Head Purge Position Y Collect Result_Dam                    int64
#  33   Head Purge Position Z Collect Result_Dam                    float64
#  34   Head Zero Position X Collect Result_Dam                     float64
#  35   Head Zero Position Y Collect Result_Dam                     float64
#  36   Head Zero Position Z Collect Result_Dam                     float64
#  37   Machine Tact time Collect Result_Dam                        float64
#  38   PalletID Collect Result_Dam                                 float64
#  39   Production Qty Collect Result_Dam                           int64
#  40   Receip No Collect Result_Dam                                int64
#  41   Stage1 Circle1 Distance Speed Collect Result_Dam            int64
#  42   Stage1 Circle2 Distance Speed Collect Result_Dam            int64
#  43   Stage1 Circle3 Distance Speed Collect Result_Dam            int64
#  44   Stage1 Circle4 Distance Speed Collect Result_Dam            int64
#  45   Stage1 Line1 Distance Speed Collect Result_Dam              int64
#  46   Stage1 Line2 Distance Speed Collect Result_Dam              int64
#  47   Stage1 Line3 Distance Speed Collect Result_Dam              int64
#  48   Stage1 Line4 Distance Speed Collect Result_Dam              int64
#  49   Stage2 Circle1 Distance Speed Collect Result_Dam            int64
#  50   Stage2 Circle2 Distance Speed Collect Result_Dam            int64
#  51   Stage2 Circle3 Distance Speed Collect Result_Dam            int64
#  52   Stage2 Circle4 Distance Speed Collect Result_Dam            int64
#  53   Stage2 Line1 Distance Speed Collect Result_Dam              int64
#  54   Stage2 Line2 Distance Speed Collect Result_Dam              int64
#  55   Stage2 Line3 Distance Speed Collect Result_Dam              int64
#  56   Stage2 Line4 Distance Speed Collect Result_Dam              int64
#  57   Stage3 Circle1 Distance Speed Collect Result_Dam            int64
#  58   Stage3 Circle2 Distance Speed Collect Result_Dam            int64
#  59   Stage3 Circle3 Distance Speed Collect Result_Dam            int64
#  60   Stage3 Circle4 Distance Speed Collect Result_Dam            int64
#  61   Stage3 Line1 Distance Speed Collect Result_Dam              int64
#  62   Stage3 Line2 Distance Speed Collect Result_Dam              int64
#  63   Stage3 Line3 Distance Speed Collect Result_Dam              int64
#  64   Stage3 Line4 Distance Speed Collect Result_Dam              int64
#  65   THICKNESS 1 Collect Result_Dam                              int64
#  66   THICKNESS 2 Collect Result_Dam                              float64
#  67   THICKNESS 3 Collect Result_Dam                              float64
#  68   WorkMode Collect Result_Dam                                 float64
#  69   Collect Date_AutoClave                                      object
#  70   1st Pressure Collect Result_AutoClave                       float64
#  71   1st Pressure 1st Pressure Unit Time_AutoClave               int64
#  72   2nd Pressure Collect Result_AutoClave                       float64
#  73   2nd Pressure Unit Time_AutoClave                            int64
#  74   3rd Pressure Collect Result_AutoClave                       float64
#  75   3rd Pressure Unit Time_AutoClave                            int64
#  76   Chamber Temp. Collect Result_AutoClave                      int64
#  77   Chamber Temp. Unit Time_AutoClave                           int64
#  78   Chamber Temp. Judge Value_AutoClave                         object
#  79   Equipment_Fill1                                             object
#  80   Collect Date_Fill1                                          object
#  81   DISCHARGED SPEED OF RESIN Collect Result_Fill1              float64
#  82   DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill1       float64
#  83   DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill1       float64
#  84   DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill1       float64
#  85   Dispense Volume(Stage1) Collect Result_Fill1                float64
#  86   Dispense Volume(Stage2) Collect Result_Fill1                float64
#  87   Dispense Volume(Stage3) Collect Result_Fill1                float64
#  88   HEAD NORMAL COORDINATE X AXIS(Stage1) Collect Result_Fill1  object
#  89   HEAD NORMAL COORDINATE X AXIS(Stage2) Collect Result_Fill1  float64
#  90   HEAD NORMAL COORDINATE X AXIS(Stage3) Collect Result_Fill1  float64
#  91   HEAD NORMAL COORDINATE Y AXIS(Stage1) Collect Result_Fill1  float64
#  92   HEAD NORMAL COORDINATE Y AXIS(Stage2) Collect Result_Fill1  float64
#  93   HEAD NORMAL COORDINATE Y AXIS(Stage3) Collect Result_Fill1  float64
#  94   HEAD NORMAL COORDINATE Z AXIS(Stage1) Collect Result_Fill1  float64
#  95   HEAD NORMAL COORDINATE Z AXIS(Stage2) Collect Result_Fill1  float64
#  96   HEAD NORMAL COORDINATE Z AXIS(Stage3) Collect Result_Fill1  float64
#  97   HEAD Standby Position X Collect Result_Fill1                float64
#  98   HEAD Standby Position Y Collect Result_Fill1                int64
#  99   HEAD Standby Position Z Collect Result_Fill1                int64
#  100  Head Clean Position X Collect Result_Fill1                  float64
#  101  Head Clean Position Y Collect Result_Fill1                  float64
#  102  Head Clean Position Z Collect Result_Fill1                  float64
#  103  Head Purge Position X Collect Result_Fill1                  float64
#  104  Head Purge Position Y Collect Result_Fill1                  int64
#  105  Head Purge Position Z Collect Result_Fill1                  int64
#  106  Machine Tact time Collect Result_Fill1                      float64
#  107  PalletID Collect Result_Fill1                               float64
#  108  Production Qty Collect Result_Fill1                         int64
#  109  Receip No Collect Result_Fill1                              int64
#  110  WorkMode Collect Result_Fill1                               int64
#  111  Equipment_Fill2                                             object
#  112  Collect Date_Fill2                                          object
#  113  CURE END POSITION X Collect Result_Fill2                    int64
#  114  CURE END POSITION Z Collect Result_Fill2                    int64
#  115  CURE SPEED Collect Result_Fill2                             int64
#  116  CURE STANDBY POSITION Z Collect Result_Fill2                int64
#  117  CURE START POSITION X Collect Result_Fill2                  int64
#  118  CURE START POSITION Z Collect Result_Fill2                  int64
#  119  HEAD NORMAL COORDINATE X AXIS(Stage1) Collect Result_Fill2  object
#  120  HEAD NORMAL COORDINATE X AXIS(Stage2) Collect Result_Fill2  float64
#  121  HEAD NORMAL COORDINATE X AXIS(Stage3) Collect Result_Fill2  float64
#  122  HEAD NORMAL COORDINATE Y AXIS(Stage1) Collect Result_Fill2  float64
#  123  HEAD NORMAL COORDINATE Y AXIS(Stage2) Collect Result_Fill2  float64
#  124  HEAD NORMAL COORDINATE Y AXIS(Stage3) Collect Result_Fill2  float64
#  125  HEAD NORMAL COORDINATE Z AXIS(Stage1) Collect Result_Fill2  float64
#  126  HEAD NORMAL COORDINATE Z AXIS(Stage2) Collect Result_Fill2  float64
#  127  HEAD NORMAL COORDINATE Z AXIS(Stage3) Collect Result_Fill2  float64
#  128  HEAD Standby Position X Collect Result_Fill2                float64
#  129  HEAD Standby Position Y Collect Result_Fill2                int64
#  130  HEAD Standby Position Z Collect Result_Fill2                int64
#  131  Head Clean Position X Collect Result_Fill2                  int64
#  132  Head Clean Position Y Collect Result_Fill2                  int64
#  133  Head Clean Position Z Collect Result_Fill2                  float64
#  134  Head Purge Position X Collect Result_Fill2                  float64
#  135  Head Purge Position Y Collect Result_Fill2                  int64
#  136  Head Purge Position Z Collect Result_Fill2                  int64
#  137  Machine Tact time Collect Result_Fill2                      float64
#  138  PalletID Collect Result_Fill2                               float64
#  139  Production Qty Collect Result_Fill2                         int64
#  140  Receip No Collect Result_Fill2                              int64
#  141  WorkMode Collect Result_Fill2                               int64
#  142  target                                                      object
#  143  Model.Suffix                                                object
#  144  Workorder                                                   object
#  145  running_time_m                                              float64
#  146  month                                                       int32
#  147  day                                                         int32
#  148  hour                                                        int32
#  149  out_of_hour                                                 int64
# dtypes: datetime64[ns](1), float64(69), int32(3), int64(63), object(14)
# memory usage: 45.9+ MB

# %%
# 'OK' 값을 NaN으로 변환하고 결측치 처리할 열 리스트
columns_to_replace = [
    'HEAD NORMAL COORDINATE X AXIS(Stage1) Collect Result_Dam',
    'HEAD NORMAL COORDINATE X AXIS(Stage1) Collect Result_Fill1',
    'HEAD NORMAL COORDINATE X AXIS(Stage1) Collect Result_Fill2'
]
# 결측치를 처리할 열 리스트
columns_to_fill = [
    'HEAD NORMAL COORDINATE X AXIS(Stage1) Collect Result_Dam',
    'HEAD NORMAL COORDINATE X AXIS(Stage2) Collect Result_Dam',
    'HEAD NORMAL COORDINATE X AXIS(Stage3) Collect Result_Dam',
    'HEAD NORMAL COORDINATE Y AXIS(Stage1) Collect Result_Dam',
    'HEAD NORMAL COORDINATE Y AXIS(Stage2) Collect Result_Dam',
    'HEAD NORMAL COORDINATE Y AXIS(Stage3) Collect Result_Dam',
    'HEAD NORMAL COORDINATE Z AXIS(Stage1) Collect Result_Dam',
    'HEAD NORMAL COORDINATE Z AXIS(Stage2) Collect Result_Dam',
    'HEAD NORMAL COORDINATE X AXIS(Stage1) Collect Result_Fill1',
    'HEAD NORMAL COORDINATE X AXIS(Stage1) Collect Result_Fill2'
]

# %%
def preprocess_coordinates(df, columns_to_replace, columns_to_fill):
    def replace_value(row, column, possible_values, mapping, stage2_col, stage3_col):
        # Stage2와 Stage3의 값 처리
        stage2_value = row[stage2_col]
        stage2_value = int(str(round(stage2_value,1))[:1])
        stage3_value = round(row[stage3_col])
        stage3_value = int(str(stage3_value)[:1])

        # 선택 가능한 값
        remaining_value = [val for val in possible_values if val not in [stage2_value, stage3_value]]
        if len(remaining_value) == 1:
            replacement_value = mapping[remaining_value[0]]
            return replacement_value
        else:
            return row[column]
    def get_mapping(val):
        val = int(val) // 100
        if val in [3, 5, 6]:  # 논리 연산자 사용
            return  [3, 5, 6], {3: 305.0, 5: 499.8, 6: 694.0}
        else:
            return [1, 4, 8],{1: 156.0, 4: 458.0, 8: 835.8}

    # 1. 특정 값('OK')을 NaN으로 변환
    for column in columns_to_replace:
        df[column].replace('OK', np.nan, inplace=True)
    # 2. 숫자로 변환할 수 없는 데이터를 NaN으로 변환
    for column in columns_to_replace:
        df[column] = pd.to_numeric(df[column], errors='coerce')

    # 3. 결측치를 처리하기 위한 최빈값 계산 및 채우기
    for column in columns_to_fill:
        if 'Dam' in column:
            possible_values = [1, 4, 5]
            stage2_col = 'HEAD NORMAL COORDINATE X AXIS(Stage2) Collect Result_Dam'
            stage3_col = 'HEAD NORMAL COORDINATE X AXIS(Stage3) Collect Result_Dam'
            mapping = {1: 161.0, 4: 464.0, 5: 550.4}
            mask = df[column].isna()
            df.loc[mask, column] = df[mask].apply(
                lambda row: replace_value(row, column, possible_values, mapping, stage2_col, stage3_col),
                axis=1
            )
        if 'Fill1' in column:
            possible_values = [1, 4, 8]
            stage2_col = 'HEAD NORMAL COORDINATE X AXIS(Stage2) Collect Result_Fill1'
            stage3_col = 'HEAD NORMAL COORDINATE X AXIS(Stage3) Collect Result_Fill1'
            mapping = {1: 157.0, 4: 458.5, 8: 838.4}
            mask = df[column].isna()
            df.loc[mask, column] = df[mask].apply(
                lambda row: replace_value(row, column, possible_values, mapping, stage2_col, stage3_col),
                axis=1
            )

        if 'Fill2' in column:
            stage2_col = 'HEAD NORMAL COORDINATE X AXIS(Stage2) Collect Result_Fill2'
            stage3_col = 'HEAD NORMAL COORDINATE X AXIS(Stage3) Collect Result_Fill2'

            mask = df[column].isna()
            df.loc[mask, column] = df[mask].apply(lambda row: replace_value(row, column, *get_mapping(round(row[stage2_col])), stage2_col, stage3_col),axis=1)

    return df

# %%
# 결측치 함수
train_data = preprocess_coordinates(train_data, columns_to_replace, columns_to_fill)
test=preprocess_coordinates(test, columns_to_replace, columns_to_fill)

# %%
train_data.loc[train_data["HEAD NORMAL COORDINATE X AXIS(Stage2) Collect Result_Fill1"] == 681.2, 'HEAD NORMAL COORDINATE X AXIS(Stage1) Collect Result_Fill1'] = 838.0
train_data.loc[train_data["HEAD NORMAL COORDINATE X AXIS(Stage2) Collect Result_Fill1"] == 681.2, 'HEAD NORMAL COORDINATE X AXIS(Stage3) Collect Result_Fill1'] = 157.0
train_data.loc[train_data["HEAD NORMAL COORDINATE X AXIS(Stage2) Collect Result_Fill1"] == 681.2, 'HEAD NORMAL COORDINATE X AXIS(Stage2) Collect Result_Fill1'] = 458.5

test.loc[test["HEAD NORMAL COORDINATE X AXIS(Stage2) Collect Result_Fill1"] == 681.2, 'HEAD NORMAL COORDINATE X AXIS(Stage1) Collect Result_Fill1'] = 838.0
test.loc[test["HEAD NORMAL COORDINATE X AXIS(Stage2) Collect Result_Fill1"] == 681.2, 'HEAD NORMAL COORDINATE X AXIS(Stage3) Collect Result_Fill1'] = 157.0
test.loc[test["HEAD NORMAL COORDINATE X AXIS(Stage2) Collect Result_Fill1"] == 681.2, 'HEAD NORMAL COORDINATE X AXIS(Stage2) Collect Result_Fill1'] = 458.5

# %%
x = train_data.drop('target', axis=1)
y = train_data['target']

# %%
train_head=[]
# 그룹핑
for column in train_data.columns:
  if 'head' in column.lower():
    train_head.append(column)
train_head_data=train_data[train_head]

# %%
train_head_data
# Out:
#        HEAD NORMAL COORDINATE X AXIS(Stage1) Collect Result_Dam  \
# 0                                                  161.0
# 1                                                  550.3
# 2                                                  550.4
# 3                                                  162.4
# 4                                                  549.0
# ...                                                  ...
# 40501                                              550.3
# 40502                                              550.4
# 40503                                              161.0
# 40504                                              162.4
# 40505                                              549.0
#
#       HEAD NORMAL COORDINATE X AXIS(Stage1) Judge Value_Dam  \
# 0                                                    nan
# 1                                                     NG
# 2                                                     OK
# 3                                                     NG
# 4                                                     NG
# ...                                                  ...
# 40501                                                 NG
# 40502                                                nan
# 40503                                                 OK
# 40504                                                 NG
# 40505                                                 NG
#
#        HEAD NORMAL COORDINATE X AXIS(Stage2) Collect Result_Dam  \
# 0                                                  550.5
# 1                                                  463.8
# 2                                                  162.4
# 3                                                  465.5
# 4                                                  462.5
# ...                                                  ...
# 40501                                              463.8
# 40502                                              163.5
# 40503                                              550.6
# 40504                                              465.1
# 40505                                              463.0
#
#        HEAD NORMAL COORDINATE X AXIS(Stage3) Collect Result_Dam  \
# 0                                                  464.3
# 1                                                  160.8
# 2                                                  465.4
# 3                                                  552.0
# 4                                                  159.5
# ...                                                  ...
# 40501                                              160.8
# 40502                                              466.2
# 40503                                              463.9
# 40504                                              551.3
# 40505                                              160.5
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage1) Collect Result_Dam  \
# 0                                                  161.4
# 1                                                  377.3
# 2                                                  551.7
# 3                                                 1271.8
# 4                                                  377.5
# ...                                                  ...
# 40501                                              377.3
# 40502                                              553.1
# 40503                                              161.5
# 40504                                             1269.0
# 40505                                              377.5
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage2) Collect Result_Dam  \
# 0                                                  384.0
# 1                                                  377.3
# 2                                                 1271.8
# 3                                                 1270.7
# 4                                                  377.0
# ...                                                  ...
# 40501                                              377.3
# 40502                                             1281.0
# 40503                                              377.6
# 40504                                             1268.4
# 40505                                              377.0
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage3) Collect Result_Dam  \
# 0                                                  383.1
# 1                                                  377.3
# 2                                                 1383.9
# 3                                                 1271.8
# 4                                                  377.5
# ...                                                  ...
# 40501                                              377.3
# 40502                                             1393.5
# 40503                                              377.1
# 40504                                             1269.0
# 40505                                              377.5
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage1) Collect Result_Dam  \
# 0                                                 384.00
# 1                                                 282.15
# 2                                                1271.80
# 3                                                 282.15
# 4                                                 284.80
# ...                                                  ...
# 40501                                             282.15
# 40502                                            1281.20
# 40503                                             378.00
# 40504                                             282.15
# 40505                                             284.80
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage2) Collect Result_Dam  \
# 0                                                 274.51
# 1                                                 282.15
# 2                                                 274.33
# 3                                                 282.15
# 4                                                 284.80
# ...                                                  ...
# 40501                                             282.15
# 40502                                             274.33
# 40503                                             274.78
# 40504                                             282.15
# 40505                                             284.80
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage3) Collect Result_Dam  \
# 0                                                 274.51
# 1                                                 282.15
# 2                                                 274.33
# 3                                                 282.15
# 4                                                 284.80
# ...                                                  ...
# 40501                                             282.15
# 40502                                             274.33
# 40503                                             274.78
# 40504                                             282.15
# 40505                                             284.80
#
#        HEAD Standby Position X Collect Result_Dam  \
# 0                                          274.51
# 1                                          257.00
# 2                                          274.33
# 3                                          257.00
# 4                                          257.00
# ...                                           ...
# 40501                                      257.00
# 40502                                      274.33
# 40503                                      274.78
# 40504                                      257.00
# 40505                                      257.00
#
#        HEAD Standby Position Y Collect Result_Dam  \
# 0                                             257
# 1                                              66
# 2                                             257
# 3                                              66
# 4                                              66
# ...                                           ...
# 40501                                          66
# 40502                                         257
# 40503                                         257
# 40504                                          66
# 40505                                          66
#
#        HEAD Standby Position Z Collect Result_Dam  \
# 0                                              66
# 1                                               0
# 2                                              66
# 3                                               0
# 4                                               0
# ...                                           ...
# 40501                                           0
# 40502                                          66
# 40503                                          66
# 40504                                           0
# 40505                                           0
#
#        Head Clean Position X Collect Result_Dam  \
# 0                                           0.0
# 1                                         127.5
# 2                                           0.0
# 3                                         127.5
# 4                                         127.5
# ...                                         ...
# 40501                                     127.5
# 40502                                       0.0
# 40503                                       0.0
# 40504                                     127.5
# 40505                                     127.5
#
#        Head Clean Position Y Collect Result_Dam  \
# 0                                         127.5
# 1                                          66.0
# 2                                         127.5
# 3                                          66.0
# 4                                          66.0
# ...                                         ...
# 40501                                      66.0
# 40502                                     127.5
# 40503                                     127.5
# 40504                                      66.0
# 40505                                      66.0
#
#        Head Clean Position Z Collect Result_Dam  \
# 0                                         66.00
# 1                                        130.85
# 2                                         66.00
# 3                                        130.85
# 4                                        133.50
# ...                                         ...
# 40501                                    130.85
# 40502                                     66.00
# 40503                                     66.00
# 40504                                    130.85
# 40505                                    133.50
#
#        Head Purge Position X Collect Result_Dam  \
# 0                                         124.0
# 1                                         257.0
# 2                                         124.0
# 3                                         257.0
# 4                                         257.0
# ...                                         ...
# 40501                                     257.0
# 40502                                     124.0
# 40503                                     124.0
# 40504                                     257.0
# 40505                                     257.0
#
#        Head Purge Position Y Collect Result_Dam  \
# 0                                           257
# 1                                            66
# 2                                           257
# 3                                            66
# 4                                            66
# ...                                         ...
# 40501                                        66
# 40502                                       257
# 40503                                       257
# 40504                                        66
# 40505                                        66
#
#        Head Purge Position Z Collect Result_Dam  \
# 0                                         66.00
# 1                                        130.85
# 2                                         66.00
# 3                                        130.85
# 4                                        133.50
# ...                                         ...
# 40501                                    130.85
# 40502                                     66.00
# 40503                                     66.00
# 40504                                    130.85
# 40505                                    133.50
#
#        Head Zero Position X Collect Result_Dam  \
# 0                                       130.85
# 1                                       505.00
# 2                                       130.85
# 3                                       505.00
# 4                                       505.00
# ...                                        ...
# 40501                                   505.00
# 40502                                   130.85
# 40503                                   130.85
# 40504                                   505.00
# 40505                                   505.00
#
#        Head Zero Position Y Collect Result_Dam  \
# 0                                        505.0
# 1                                        300.0
# 2                                        505.0
# 3                                        300.0
# 4                                        300.0
# ...                                        ...
# 40501                                    300.0
# 40502                                    505.0
# 40503                                    505.0
# 40504                                    300.0
# 40505                                    303.5
#
#        Head Zero Position Z Collect Result_Dam  \
# 0                                        300.0
# 1                                        265.0
# 2                                        300.0
# 3                                        265.0
# 4                                        265.0
# ...                                        ...
# 40501                                    265.0
# 40502                                    300.0
# 40503                                    300.0
# 40504                                    265.0
# 40505                                    265.0
#
#        HEAD NORMAL COORDINATE X AXIS(Stage1) Collect Result_Fill1  \
# 0                                                  157.0
# 1                                                  838.4
# 2                                                  157.0
# 3                                                  837.7
# 4                                                  838.4
# ...                                                  ...
# 40501                                              838.4
# 40502                                              157.0
# 40503                                              157.0
# 40504                                              837.7
# 40505                                              837.9
#
#        HEAD NORMAL COORDINATE X AXIS(Stage2) Collect Result_Fill1  \
# 0                                                  838.4
# 1                                                  458.5
# 2                                                  837.9
# 3                                                  458.8
# 4                                                  458.5
# ...                                                  ...
# 40501                                              458.5
# 40502                                              838.1
# 40503                                              838.4
# 40504                                              458.8
# 40505                                              460.0
#
#        HEAD NORMAL COORDINATE X AXIS(Stage3) Collect Result_Fill1  \
# 0                                                  458.7
# 1                                                  157.0
# 2                                                  458.1
# 3                                                  157.0
# 4                                                  157.0
# ...                                                  ...
# 40501                                              157.0
# 40502                                              458.7
# 40503                                              458.4
# 40504                                              157.0
# 40505                                              157.5
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage1) Collect Result_Fill1  \
# 0                                                  157.0
# 1                                                  430.5
# 2                                                  156.1
# 3                                                 1323.2
# 4                                                  430.2
# ...                                                  ...
# 40501                                              430.5
# 40502                                              156.1
# 40503                                              157.0
# 40504                                             1323.2
# 40505                                              430.2
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage2) Collect Result_Fill1  \
# 0                                                  430.0
# 1                                                  430.5
# 2                                                 1323.5
# 3                                                 1322.5
# 4                                                  430.5
# ...                                                  ...
# 40501                                              430.5
# 40502                                             1325.0
# 40503                                              430.8
# 40504                                             1323.0
# 40505                                              430.5
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage3) Collect Result_Fill1  \
# 0                                                  429.8
# 1                                                  430.8
# 2                                                 1322.5
# 3                                                 1322.8
# 4                                                  430.5
# ...                                                  ...
# 40501                                              430.8
# 40502                                             1324.0
# 40503                                              430.5
# 40504                                             1322.8
# 40505                                              430.5
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage1) Collect Result_Fill1  \
# 0                                                  430.3
# 1                                                  244.4
# 2                                                 1323.1
# 3                                                  244.3
# 4                                                  244.4
# ...                                                  ...
# 40501                                              244.4
# 40502                                             1324.3
# 40503                                              431.1
# 40504                                              244.4
# 40505                                              244.3
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage2) Collect Result_Fill1  \
# 0                                                244.520
# 1                                                244.400
# 2                                                244.415
# 3                                                244.300
# 4                                                244.400
# ...                                                  ...
# 40501                                            244.400
# 40502                                            244.535
# 40503                                            244.543
# 40504                                            244.400
# 40505                                            244.300
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage3) Collect Result_Fill1  \
# 0                                                244.520
# 1                                                244.400
# 2                                                244.415
# 3                                                244.300
# 4                                                244.400
# ...                                                  ...
# 40501                                            244.400
# 40502                                            244.535
# 40503                                            244.543
# 40504                                            244.400
# 40505                                            244.300
#
#        HEAD Standby Position X Collect Result_Fill1  \
# 0                                           244.520
# 1                                           289.000
# 2                                           244.415
# 3                                           289.000
# 4                                           289.000
# ...                                             ...
# 40501                                       289.000
# 40502                                       244.535
# 40503                                       244.543
# 40504                                       289.000
# 40505                                       289.000
#
#        HEAD Standby Position Y Collect Result_Fill1  \
# 0                                               289
# 1                                                50
# 2                                               289
# 3                                                50
# 4                                                50
# ...                                             ...
# 40501                                            50
# 40502                                           289
# 40503                                           289
# 40504                                            50
# 40505                                            50
#
#        HEAD Standby Position Z Collect Result_Fill1  \
# 0                                                50
# 1                                                 0
# 2                                                50
# 3                                                 0
# 4                                                 0
# ...                                             ...
# 40501                                             0
# 40502                                            50
# 40503                                            50
# 40504                                             0
# 40505                                             0
#
#        Head Clean Position X Collect Result_Fill1  \
# 0                                             0.0
# 1                                           123.4
# 2                                             0.0
# 3                                           123.4
# 4                                           123.4
# ...                                           ...
# 40501                                       123.4
# 40502                                         0.0
# 40503                                         0.0
# 40504                                       123.4
# 40505                                       123.4
#
#        Head Clean Position Y Collect Result_Fill1  \
# 0                                           123.4
# 1                                            50.0
# 2                                           123.4
# 3                                            50.0
# 4                                            50.0
# ...                                           ...
# 40501                                        50.0
# 40502                                       123.4
# 40503                                       123.4
# 40504                                        50.0
# 40505                                        50.0
#
#        Head Clean Position Z Collect Result_Fill1  \
# 0                                            50.0
# 1                                            92.2
# 2                                            50.0
# 3                                            92.2
# 4                                            92.2
# ...                                           ...
# 40501                                        92.2
# 40502                                        50.0
# 40503                                        50.0
# 40504                                        92.2
# 40505                                        92.2
#
#        Head Purge Position X Collect Result_Fill1  \
# 0                                            92.2
# 1                                           289.0
# 2                                            92.2
# 3                                           289.0
# 4                                           289.0
# ...                                           ...
# 40501                                       289.0
# 40502                                        92.2
# 40503                                        92.2
# 40504                                       289.0
# 40505                                       289.0
#
#        Head Purge Position Y Collect Result_Fill1  \
# 0                                             289
# 1                                              50
# 2                                             289
# 3                                              50
# 4                                              50
# ...                                           ...
# 40501                                          50
# 40502                                         289
# 40503                                         289
# 40504                                          50
# 40505                                          50
#
#        Head Purge Position Z Collect Result_Fill1  \
# 0                                              50
# 1                                             145
# 2                                              50
# 3                                             145
# 4                                              85
# ...                                           ...
# 40501                                         145
# 40502                                          50
# 40503                                          50
# 40504                                         145
# 40505                                          85
#
#        HEAD NORMAL COORDINATE X AXIS(Stage1) Collect Result_Fill2  \
# 0                                                  156.0
# 1                                                  835.5
# 2                                                  694.0
# 3                                                  305.0
# 4                                                  835.5
# ...                                                  ...
# 40501                                              835.5
# 40502                                              694.0
# 40503                                              156.0
# 40504                                              305.0
# 40505                                              835.5
#
#        HEAD NORMAL COORDINATE X AXIS(Stage2) Collect Result_Fill2  \
# 0                                                  835.5
# 1                                                  458.0
# 2                                                  305.0
# 3                                                  499.8
# 4                                                  458.0
# ...                                                  ...
# 40501                                              458.0
# 40502                                              304.8
# 40503                                              835.5
# 40504                                              499.8
# 40505                                              458.0
#
#        HEAD NORMAL COORDINATE X AXIS(Stage3) Collect Result_Fill2  \
# 0                                                  458.0
# 1                                                  156.0
# 2                                                  499.8
# 3                                                  694.0
# 4                                                  156.0
# ...                                                  ...
# 40501                                              156.0
# 40502                                              499.8
# 40503                                              458.0
# 40504                                              694.0
# 40505                                              156.0
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage1) Collect Result_Fill2  \
# 0                                                  156.0
# 1                                                  428.0
# 2                                                  694.0
# 3                                                 1324.2
# 4                                                  428.0
# ...                                                  ...
# 40501                                              428.0
# 40502                                              692.8
# 40503                                              156.0
# 40504                                             1324.2
# 40505                                              428.0
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage2) Collect Result_Fill2  \
# 0                                                  428.0
# 1                                                  427.9
# 2                                                 1324.2
# 3                                                 1324.2
# 4                                                  427.9
# ...                                                  ...
# 40501                                              427.9
# 40502                                             1324.2
# 40503                                              428.0
# 40504                                             1324.2
# 40505                                              427.9
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage3) Collect Result_Fill2  \
# 0                                                  427.9
# 1                                                  428.0
# 2                                                 1324.2
# 3                                                 1324.2
# 4                                                  428.0
# ...                                                  ...
# 40501                                              428.0
# 40502                                             1324.2
# 40503                                              427.9
# 40504                                             1324.2
# 40505                                              428.0
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage1) Collect Result_Fill2  \
# 0                                                  428.0
# 1                                                  243.7
# 2                                                 1324.2
# 3                                                  243.5
# 4                                                  243.7
# ...                                                  ...
# 40501                                              243.7
# 40502                                             1324.2
# 40503                                              428.0
# 40504                                              243.5
# 40505                                              243.7
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage2) Collect Result_Fill2  \
# 0                                                  243.7
# 1                                                  243.7
# 2                                                  243.5
# 3                                                  243.5
# 4                                                  243.7
# ...                                                  ...
# 40501                                              243.7
# 40502                                              243.5
# 40503                                              243.7
# 40504                                              243.5
# 40505                                              243.7
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage3) Collect Result_Fill2  \
# 0                                                  243.7
# 1                                                  243.7
# 2                                                  243.5
# 3                                                  243.5
# 4                                                  243.7
# ...                                                  ...
# 40501                                              243.7
# 40502                                              243.5
# 40503                                              243.7
# 40504                                              243.5
# 40505                                              243.7
#
#        HEAD Standby Position X Collect Result_Fill2  \
# 0                                             243.7
# 1                                             270.0
# 2                                             243.5
# 3                                             270.0
# 4                                             270.0
# ...                                             ...
# 40501                                         270.0
# 40502                                         243.5
# 40503                                         243.7
# 40504                                         270.0
# 40505                                         270.0
#
#        HEAD Standby Position Y Collect Result_Fill2  \
# 0                                               270
# 1                                                50
# 2                                               270
# 3                                                50
# 4                                                50
# ...                                             ...
# 40501                                            50
# 40502                                           270
# 40503                                           270
# 40504                                            50
# 40505                                            50
#
#        HEAD Standby Position Z Collect Result_Fill2  \
# 0                                                50
# 1                                               -10
# 2                                                50
# 3                                               -10
# 4                                               -10
# ...                                             ...
# 40501                                           -10
# 40502                                            50
# 40503                                            50
# 40504                                           -10
# 40505                                           -10
#
#        Head Clean Position X Collect Result_Fill2  \
# 0                                             -10
# 1                                             119
# 2                                             -10
# 3                                             119
# 4                                             119
# ...                                           ...
# 40501                                         119
# 40502                                         -10
# 40503                                         -10
# 40504                                         119
# 40505                                         119
#
#        Head Clean Position Y Collect Result_Fill2  \
# 0                                             119
# 1                                              50
# 2                                             119
# 3                                              50
# 4                                              50
# ...                                           ...
# 40501                                          50
# 40502                                         119
# 40503                                         119
# 40504                                          50
# 40505                                          50
#
#        Head Clean Position Z Collect Result_Fill2  \
# 0                                            50.0
# 1                                            91.8
# 2                                            50.0
# 3                                            91.8
# 4                                            91.8
# ...                                           ...
# 40501                                        91.8
# 40502                                        50.0
# 40503                                        50.0
# 40504                                        91.8
# 40505                                        91.8
#
#        Head Purge Position X Collect Result_Fill2  \
# 0                                            91.8
# 1                                           270.0
# 2                                            91.8
# 3                                           270.0
# 4                                           270.0
# ...                                           ...
# 40501                                       270.0
# 40502                                        91.8
# 40503                                        91.8
# 40504                                       270.0
# 40505                                       270.0
#
#        Head Purge Position Y Collect Result_Fill2  \
# 0                                             270
# 1                                              50
# 2                                             270
# 3                                              50
# 4                                              50
# ...                                           ...
# 40501                                          50
# 40502                                         270
# 40503                                         270
# 40504                                          50
# 40505                                          50
#
#        Head Purge Position Z Collect Result_Fill2
# 0                                              50
# 1                                              85
# 2                                              50
# 3                                              85
# 4                                              85
# ...                                           ...
# 40501                                          85
# 40502                                          50
# 40503                                          50
# 40504                                          85
# 40505                                          85
#
# [40506 rows x 58 columns]

# %%
pos_col = train_head_data.columns.copy()

grouped_columns = {}
grouped_columns['Dam'] = {}
grouped_columns['Fill1'] = {}
grouped_columns['Fill2'] = {}

# 그룹핑
for column in pos_col:
  if 'judge' not in column.lower():
    parts = column.split('_')
    if len(parts) == 2:
        coord_info, process_type = parts
        axis = 'X' if ' X ' in coord_info else 'Y' if ' Y ' in coord_info else 'Z' if ' Z ' in coord_info else 'Θ' if ' Θ ' in coord_info else 'Unknown'
        # axis가 존재하지 않으면 새로 생성
        if axis not in grouped_columns[process_type]:
            grouped_columns[process_type][axis] = []
        grouped_columns[process_type][axis].append(column)

# 딕셔너리의 각 프로세스와 축에 대해 새로운 컬럼 생성
for process_type, axes in grouped_columns.items():
    for axis, columns in axes.items():
        # 각 축에 대한 컬럼을 tuple로 묶어 새로운 컬럼을 생성
        new_column_name = f'{process_type} {axis}'  # ex: 'Dam X', 'Fill1 X'
        train_data[new_column_name] = list(zip(*[train_data[col] for col in columns]))
        train_data[new_column_name] = train_data[new_column_name].astype(str)
        test[new_column_name] = list(zip(*[test[col] for col in columns]))
        test[new_column_name] = test[new_column_name].astype(str)

# %%
train_data
# Out:
#           Equipment_Dam    Collect Date_Dam  \
# 0      Dam dispenser #1 2024-04-25 11:10:00
# 1      Dam dispenser #1 2023-09-19 14:30:00
# 2      Dam dispenser #2 2024-03-05 09:30:00
# 3      Dam dispenser #2 2023-09-25 15:40:00
# 4      Dam dispenser #1 2023-06-27 13:20:00
# ...                 ...                 ...
# 40501  Dam dispenser #1 2023-09-14 15:50:00
# 40502  Dam dispenser #2 2024-04-10 14:20:00
# 40503  Dam dispenser #1 2024-02-22 08:40:00
# 40504  Dam dispenser #2 2023-07-25 11:00:00
# 40505  Dam dispenser #1 2023-05-31 01:40:00
#
#        CURE END POSITION X Collect Result_Dam  \
# 0                                       240.0
# 1                                       240.0
# 2                                      1000.0
# 3                                      1000.0
# 4                                       240.0
# ...                                       ...
# 40501                                   240.0
# 40502                                  1000.0
# 40503                                   240.0
# 40504                                  1000.0
# 40505                                   240.0
#
#        CURE END POSITION Z Collect Result_Dam  \
# 0                                         2.5
# 1                                         2.5
# 2                                        12.5
# 3                                        12.5
# 4                                         2.5
# ...                                       ...
# 40501                                     2.5
# 40502                                    12.5
# 40503                                     2.5
# 40504                                    12.5
# 40505                                     2.5
#
#        CURE END POSITION Θ Collect Result_Dam  CURE SPEED Collect Result_Dam  \
# 0                                         -90                            100
# 1                                         -90                             70
# 2                                          90                             85
# 3                                          90                             70
# 4                                         -90                             70
# ...                                       ...                            ...
# 40501                                     -90                             70
# 40502                                      90                            100
# 40503                                     -90                            100
# 40504                                      90                             70
# 40505                                     -90                             70
#
#        CURE START POSITION X Collect Result_Dam  \
# 0                                          1030
# 1                                          1030
# 2                                           280
# 3                                           280
# 4                                          1030
# ...                                         ...
# 40501                                      1030
# 40502                                       280
# 40503                                      1030
# 40504                                       280
# 40505                                      1030
#
#        CURE START POSITION Θ Collect Result_Dam  \
# 0                                           -90
# 1                                           -90
# 2                                            90
# 3                                            90
# 4                                           -90
# ...                                         ...
# 40501                                       -90
# 40502                                        90
# 40503                                       -90
# 40504                                        90
# 40505                                       -90
#
#        DISCHARGED SPEED OF RESIN Collect Result_Dam  \
# 0                                                16
# 1                                                10
# 2                                                16
# 3                                                10
# 4                                                10
# ...                                             ...
# 40501                                            10
# 40502                                            16
# 40503                                            16
# 40504                                            10
# 40505                                            10
#
#        DISCHARGED TIME OF RESIN(Stage1) Collect Result_Dam  \
# 0                                                   14.9
# 1                                                   21.3
# 2                                                   14.7
# 3                                                   21.3
# 4                                                    9.7
# ...                                                  ...
# 40501                                               17.0
# 40502                                               14.9
# 40503                                               14.2
# 40504                                                9.7
# 40505                                                9.6
#
#        DISCHARGED TIME OF RESIN(Stage2) Collect Result_Dam  \
# 0                                                    8.4
# 1                                                    4.9
# 2                                                    8.5
# 3                                                    8.4
# 4                                                    4.9
# ...                                                  ...
# 40501                                                5.0
# 40502                                                8.5
# 40503                                                8.2
# 40504                                                4.9
# 40505                                                3.9
#
#        DISCHARGED TIME OF RESIN(Stage3) Collect Result_Dam  \
# 0                                                   14.7
# 1                                                   21.3
# 2                                                   14.7
# 3                                                   21.3
# 4                                                    9.6
# ...                                                  ...
# 40501                                               17.0
# 40502                                               14.7
# 40503                                               14.3
# 40504                                                9.7
# 40505                                                9.7
#
#        Dispense Volume(Stage1) Collect Result_Dam  \
# 0                                            1.04
# 1                                            1.49
# 2                                            1.61
# 3                                            1.49
# 4                                            0.67
# ...                                           ...
# 40501                                        1.19
# 40502                                        1.04
# 40503                                        0.99
# 40504                                        0.67
# 40505                                        0.67
#
#        Dispense Volume(Stage2) Collect Result_Dam  \
# 0                                            0.58
# 1                                            0.34
# 2                                            0.93
# 3                                            0.58
# 4                                            0.34
# ...                                           ...
# 40501                                        0.35
# 40502                                        0.59
# 40503                                        0.57
# 40504                                        0.34
# 40505                                        0.27
#
#        Dispense Volume(Stage3) Collect Result_Dam  \
# 0                                            1.02
# 1                                            1.49
# 2                                            1.61
# 3                                            1.49
# 4                                            0.67
# ...                                           ...
# 40501                                        1.19
# 40502                                        1.02
# 40503                                        1.00
# 40504                                        0.67
# 40505                                        0.67
#
#        HEAD NORMAL COORDINATE X AXIS(Stage1) Collect Result_Dam  \
# 0                                                  161.0
# 1                                                  550.3
# 2                                                  550.4
# 3                                                  162.4
# 4                                                  549.0
# ...                                                  ...
# 40501                                              550.3
# 40502                                              550.4
# 40503                                              161.0
# 40504                                              162.4
# 40505                                              549.0
#
#       HEAD NORMAL COORDINATE X AXIS(Stage1) Judge Value_Dam  \
# 0                                                    nan
# 1                                                     NG
# 2                                                     OK
# 3                                                     NG
# 4                                                     NG
# ...                                                  ...
# 40501                                                 NG
# 40502                                                nan
# 40503                                                 OK
# 40504                                                 NG
# 40505                                                 NG
#
#        HEAD NORMAL COORDINATE X AXIS(Stage2) Collect Result_Dam  \
# 0                                                  550.5
# 1                                                  463.8
# 2                                                  162.4
# 3                                                  465.5
# 4                                                  462.5
# ...                                                  ...
# 40501                                              463.8
# 40502                                              163.5
# 40503                                              550.6
# 40504                                              465.1
# 40505                                              463.0
#
#        HEAD NORMAL COORDINATE X AXIS(Stage3) Collect Result_Dam  \
# 0                                                  464.3
# 1                                                  160.8
# 2                                                  465.4
# 3                                                  552.0
# 4                                                  159.5
# ...                                                  ...
# 40501                                              160.8
# 40502                                              466.2
# 40503                                              463.9
# 40504                                              551.3
# 40505                                              160.5
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage1) Collect Result_Dam  \
# 0                                                  161.4
# 1                                                  377.3
# 2                                                  551.7
# 3                                                 1271.8
# 4                                                  377.5
# ...                                                  ...
# 40501                                              377.3
# 40502                                              553.1
# 40503                                              161.5
# 40504                                             1269.0
# 40505                                              377.5
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage2) Collect Result_Dam  \
# 0                                                  384.0
# 1                                                  377.3
# 2                                                 1271.8
# 3                                                 1270.7
# 4                                                  377.0
# ...                                                  ...
# 40501                                              377.3
# 40502                                             1281.0
# 40503                                              377.6
# 40504                                             1268.4
# 40505                                              377.0
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage3) Collect Result_Dam  \
# 0                                                  383.1
# 1                                                  377.3
# 2                                                 1383.9
# 3                                                 1271.8
# 4                                                  377.5
# ...                                                  ...
# 40501                                              377.3
# 40502                                             1393.5
# 40503                                              377.1
# 40504                                             1269.0
# 40505                                              377.5
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage1) Collect Result_Dam  \
# 0                                                 384.00
# 1                                                 282.15
# 2                                                1271.80
# 3                                                 282.15
# 4                                                 284.80
# ...                                                  ...
# 40501                                             282.15
# 40502                                            1281.20
# 40503                                             378.00
# 40504                                             282.15
# 40505                                             284.80
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage2) Collect Result_Dam  \
# 0                                                 274.51
# 1                                                 282.15
# 2                                                 274.33
# 3                                                 282.15
# 4                                                 284.80
# ...                                                  ...
# 40501                                             282.15
# 40502                                             274.33
# 40503                                             274.78
# 40504                                             282.15
# 40505                                             284.80
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage3) Collect Result_Dam  \
# 0                                                 274.51
# 1                                                 282.15
# 2                                                 274.33
# 3                                                 282.15
# 4                                                 284.80
# ...                                                  ...
# 40501                                             282.15
# 40502                                             274.33
# 40503                                             274.78
# 40504                                             282.15
# 40505                                             284.80
#
#        HEAD Standby Position X Collect Result_Dam  \
# 0                                          274.51
# 1                                          257.00
# 2                                          274.33
# 3                                          257.00
# 4                                          257.00
# ...                                           ...
# 40501                                      257.00
# 40502                                      274.33
# 40503                                      274.78
# 40504                                      257.00
# 40505                                      257.00
#
#        HEAD Standby Position Y Collect Result_Dam  \
# 0                                             257
# 1                                              66
# 2                                             257
# 3                                              66
# 4                                              66
# ...                                           ...
# 40501                                          66
# 40502                                         257
# 40503                                         257
# 40504                                          66
# 40505                                          66
#
#        HEAD Standby Position Z Collect Result_Dam  \
# 0                                              66
# 1                                               0
# 2                                              66
# 3                                               0
# 4                                               0
# ...                                           ...
# 40501                                           0
# 40502                                          66
# 40503                                          66
# 40504                                           0
# 40505                                           0
#
#        Head Clean Position X Collect Result_Dam  \
# 0                                           0.0
# 1                                         127.5
# 2                                           0.0
# 3                                         127.5
# 4                                         127.5
# ...                                         ...
# 40501                                     127.5
# 40502                                       0.0
# 40503                                       0.0
# 40504                                     127.5
# 40505                                     127.5
#
#        Head Clean Position Y Collect Result_Dam  \
# 0                                         127.5
# 1                                          66.0
# 2                                         127.5
# 3                                          66.0
# 4                                          66.0
# ...                                         ...
# 40501                                      66.0
# 40502                                     127.5
# 40503                                     127.5
# 40504                                      66.0
# 40505                                      66.0
#
#        Head Clean Position Z Collect Result_Dam  \
# 0                                         66.00
# 1                                        130.85
# 2                                         66.00
# 3                                        130.85
# 4                                        133.50
# ...                                         ...
# 40501                                    130.85
# 40502                                     66.00
# 40503                                     66.00
# 40504                                    130.85
# 40505                                    133.50
#
#        Head Purge Position X Collect Result_Dam  \
# 0                                         124.0
# 1                                         257.0
# 2                                         124.0
# 3                                         257.0
# 4                                         257.0
# ...                                         ...
# 40501                                     257.0
# 40502                                     124.0
# 40503                                     124.0
# 40504                                     257.0
# 40505                                     257.0
#
#        Head Purge Position Y Collect Result_Dam  \
# 0                                           257
# 1                                            66
# 2                                           257
# 3                                            66
# 4                                            66
# ...                                         ...
# 40501                                        66
# 40502                                       257
# 40503                                       257
# 40504                                        66
# 40505                                        66
#
#        Head Purge Position Z Collect Result_Dam  \
# 0                                         66.00
# 1                                        130.85
# 2                                         66.00
# 3                                        130.85
# 4                                        133.50
# ...                                         ...
# 40501                                    130.85
# 40502                                     66.00
# 40503                                     66.00
# 40504                                    130.85
# 40505                                    133.50
#
#        Head Zero Position X Collect Result_Dam  \
# 0                                       130.85
# 1                                       505.00
# 2                                       130.85
# 3                                       505.00
# 4                                       505.00
# ...                                        ...
# 40501                                   505.00
# 40502                                   130.85
# 40503                                   130.85
# 40504                                   505.00
# 40505                                   505.00
#
#        Head Zero Position Y Collect Result_Dam  \
# 0                                        505.0
# 1                                        300.0
# 2                                        505.0
# 3                                        300.0
# 4                                        300.0
# ...                                        ...
# 40501                                    300.0
# 40502                                    505.0
# 40503                                    505.0
# 40504                                    300.0
# 40505                                    303.5
#
#        Head Zero Position Z Collect Result_Dam  \
# 0                                        300.0
# 1                                        265.0
# 2                                        300.0
# 3                                        265.0
# 4                                        265.0
# ...                                        ...
# 40501                                    265.0
# 40502                                    300.0
# 40503                                    300.0
# 40504                                    265.0
# 40505                                    265.0
#
#        Machine Tact time Collect Result_Dam  PalletID Collect Result_Dam  \
# 0                                    265.00                         58.5
# 1                                     65.10                          7.0
# 2                                    265.02                         76.9
# 3                                     70.50                         12.0
# 4                                     88.30                          8.0
# ...                                     ...                          ...
# 40501                                 56.70                          1.0
# 40502                                265.00                         78.5
# 40503                                265.02                         69.5
# 40504                                 57.70                         13.0
# 40505                                 92.10                          3.0
#
#        Production Qty Collect Result_Dam  Receip No Collect Result_Dam  \
# 0                                      7                           127
# 1                                    185                             1
# 2                                     10                            73
# 3                                    268                             1
# 4                                    121                             1
# ...                                  ...                           ...
# 40501                                318                             1
# 40502                                 14                           197
# 40503                                  1                            27
# 40504                                117                             1
# 40505                                320                             1
#
#        Stage1 Circle1 Distance Speed Collect Result_Dam  \
# 0                                                     1
# 1                                                  4000
# 2                                                     1
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                                 1
# 40503                                                 1
# 40504                                              9000
# 40505                                              9000
#
#        Stage1 Circle2 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage1 Circle3 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage1 Circle4 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage1 Line1 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage1 Line2 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage1 Line3 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage1 Line4 Distance Speed Collect Result_Dam  \
# 0                                                5600
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5600
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage2 Circle1 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  9000
# 2                                                  5800
# 3                                                  5000
# 4                                                  9000
# ...                                                 ...
# 40501                                              9000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                             12000
#
#        Stage2 Circle2 Distance Speed Collect Result_Dam  \
# 0                                                  5300
# 1                                                  9000
# 2                                                  5300
# 3                                                  5000
# 4                                                  9000
# ...                                                 ...
# 40501                                              9000
# 40502                                              5300
# 40503                                              5500
# 40504                                              9000
# 40505                                             12000
#
#        Stage2 Circle3 Distance Speed Collect Result_Dam  \
# 0                                                  5300
# 1                                                  9000
# 2                                                  5300
# 3                                                  5000
# 4                                                  9000
# ...                                                 ...
# 40501                                              9000
# 40502                                              5300
# 40503                                              5500
# 40504                                              9000
# 40505                                             12000
#
#        Stage2 Circle4 Distance Speed Collect Result_Dam  \
# 0                                                  5300
# 1                                                  9000
# 2                                                  5300
# 3                                                  5000
# 4                                                  9000
# ...                                                 ...
# 40501                                              9000
# 40502                                              5300
# 40503                                              5500
# 40504                                              9000
# 40505                                             12000
#
#        Stage2 Line1 Distance Speed Collect Result_Dam  \
# 0                                                5300
# 1                                                9000
# 2                                                5300
# 3                                                5000
# 4                                                9000
# ...                                               ...
# 40501                                            9000
# 40502                                            5300
# 40503                                            5500
# 40504                                            9000
# 40505                                           12000
#
#        Stage2 Line2 Distance Speed Collect Result_Dam  \
# 0                                                5300
# 1                                                9000
# 2                                                5300
# 3                                                5000
# 4                                                9000
# ...                                               ...
# 40501                                            9000
# 40502                                            5300
# 40503                                            5500
# 40504                                            9000
# 40505                                           12000
#
#        Stage2 Line3 Distance Speed Collect Result_Dam  \
# 0                                                5300
# 1                                                9000
# 2                                                5300
# 3                                                5000
# 4                                                9000
# ...                                               ...
# 40501                                            9000
# 40502                                            5300
# 40503                                            5500
# 40504                                            9000
# 40505                                           12000
#
#        Stage2 Line4 Distance Speed Collect Result_Dam  \
# 0                                                5300
# 1                                                9000
# 2                                                5300
# 3                                                5000
# 4                                                9000
# ...                                               ...
# 40501                                            9000
# 40502                                            5300
# 40503                                            5500
# 40504                                            9000
# 40505                                           12000
#
#        Stage3 Circle1 Distance Speed Collect Result_Dam  \
# 0                                                  5300
# 1                                                  4000
# 2                                                  5300
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5300
# 40503                                              5500
# 40504                                              9000
# 40505                                              9000
#
#        Stage3 Circle2 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage3 Circle3 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage3 Circle4 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage3 Line1 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage3 Line2 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage3 Line3 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage3 Line4 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        THICKNESS 1 Collect Result_Dam  THICKNESS 2 Collect Result_Dam  \
# 0                                5800                           0.000
# 1                                   0                           0.000
# 2                                5800                           0.012
# 3                                   0                           0.000
# 4                                   0                           0.000
# ...                               ...                             ...
# 40501                               0                           0.000
# 40502                            5800                          -0.019
# 40503                            6000                           0.000
# 40504                               0                           0.000
# 40505                               0                           0.000
#
#        THICKNESS 3 Collect Result_Dam  WorkMode Collect Result_Dam  \
# 0                               0.000                        0.000
# 1                               0.000                        7.000
# 2                              -0.022                        0.003
# 3                               0.000                        7.000
# 4                               0.000                        7.000
# ...                               ...                          ...
# 40501                           0.000                        7.000
# 40502                          -0.021                       -0.118
# 40503                           0.000                        0.000
# 40504                           0.000                        7.000
# 40505                           0.000                        7.000
#
#       Collect Date_AutoClave  1st Pressure Collect Result_AutoClave  \
# 0        2024-04-25 11:50:00                                  0.312
# 1        2023-09-19 15:00:00                                  0.311
# 2        2024-03-05 10:10:00                                  0.315
# 3        2023-09-25 16:20:00                                  0.299
# 4        2023-06-27 14:00:00                                  0.302
# ...                      ...                                    ...
# 40501    2023-09-14 16:30:00                                  0.300
# 40502    2024-04-10 15:00:00                                  0.305
# 40503    2024-02-22 09:20:00                                  0.309
# 40504    2023-07-25 11:40:00                                  0.302
# 40505    2023-05-31 02:10:00                                  0.305
#
#        1st Pressure 1st Pressure Unit Time_AutoClave  \
# 0                                                240
# 1                                                241
# 2                                                241
# 3                                                241
# 4                                                240
# ...                                              ...
# 40501                                            241
# 40502                                            240
# 40503                                            241
# 40504                                            241
# 40505                                            300
#
#        2nd Pressure Collect Result_AutoClave  \
# 0                                      0.493
# 1                                      0.311
# 2                                      0.490
# 3                                      0.300
# 4                                      0.302
# ...                                      ...
# 40501                                  0.300
# 40502                                  0.493
# 40503                                  0.490
# 40504                                  0.303
# 40505                                  0.305
#
#        2nd Pressure Unit Time_AutoClave  \
# 0                                     1
# 1                                   121
# 2                                     1
# 3                                   121
# 4                                   120
# ...                                 ...
# 40501                               121
# 40502                                 1
# 40503                                 1
# 40504                               121
# 40505                                60
#
#        3rd Pressure Collect Result_AutoClave  \
# 0                                      0.499
# 1                                      0.498
# 2                                      0.498
# 3                                      0.500
# 4                                      0.498
# ...                                      ...
# 40501                                  0.500
# 40502                                  0.498
# 40503                                  0.498
# 40504                                  0.499
# 40505                                  0.498
#
#        3rd Pressure Unit Time_AutoClave  \
# 0                                   120
# 1                                   121
# 2                                   121
# 3                                   121
# 4                                   120
# ...                                 ...
# 40501                               121
# 40502                               120
# ...
# 40505                                              243.7
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage3) Collect Result_Fill2  \
# 0                                                  243.7
# 1                                                  243.7
# 2                                                  243.5
# 3                                                  243.5
# 4                                                  243.7
# ...                                                  ...
# 40501                                              243.7
# 40502                                              243.5
# 40503                                              243.7
# 40504                                              243.5
# 40505                                              243.7
#
#        HEAD Standby Position X Collect Result_Fill2  \
# 0                                             243.7
# 1                                             270.0
# 2                                             243.5
# 3                                             270.0
# 4                                             270.0
# ...                                             ...
# 40501                                         270.0
# 40502                                         243.5
# 40503                                         243.7
# 40504                                         270.0
# 40505                                         270.0
#
#        HEAD Standby Position Y Collect Result_Fill2  \
# 0                                               270
# 1                                                50
# 2                                               270
# 3                                                50
# 4                                                50
# ...                                             ...
# 40501                                            50
# 40502                                           270
# 40503                                           270
# 40504                                            50
# 40505                                            50
#
#        HEAD Standby Position Z Collect Result_Fill2  \
# 0                                                50
# 1                                               -10
# 2                                                50
# 3                                               -10
# 4                                               -10
# ...                                             ...
# 40501                                           -10
# 40502                                            50
# 40503                                            50
# 40504                                           -10
# 40505                                           -10
#
#        Head Clean Position X Collect Result_Fill2  \
# 0                                             -10
# 1                                             119
# 2                                             -10
# 3                                             119
# 4                                             119
# ...                                           ...
# 40501                                         119
# 40502                                         -10
# 40503                                         -10
# 40504                                         119
# 40505                                         119
#
#        Head Clean Position Y Collect Result_Fill2  \
# 0                                             119
# 1                                              50
# 2                                             119
# 3                                              50
# 4                                              50
# ...                                           ...
# 40501                                          50
# 40502                                         119
# 40503                                         119
# 40504                                          50
# 40505                                          50
#
#        Head Clean Position Z Collect Result_Fill2  \
# 0                                            50.0
# 1                                            91.8
# 2                                            50.0
# 3                                            91.8
# 4                                            91.8
# ...                                           ...
# 40501                                        91.8
# 40502                                        50.0
# 40503                                        50.0
# 40504                                        91.8
# 40505                                        91.8
#
#        Head Purge Position X Collect Result_Fill2  \
# 0                                            91.8
# 1                                           270.0
# 2                                            91.8
# 3                                           270.0
# 4                                           270.0
# ...                                           ...
# 40501                                       270.0
# 40502                                        91.8
# 40503                                        91.8
# 40504                                       270.0
# 40505                                       270.0
#
#        Head Purge Position Y Collect Result_Fill2  \
# 0                                             270
# 1                                              50
# 2                                             270
# 3                                              50
# 4                                              50
# ...                                           ...
# 40501                                          50
# 40502                                         270
# 40503                                         270
# 40504                                          50
# 40505                                          50
#
#        Head Purge Position Z Collect Result_Fill2  \
# 0                                              50
# 1                                              85
# 2                                              50
# 3                                              85
# 4                                              85
# ...                                           ...
# 40501                                          85
# 40502                                          50
# 40503                                          50
# 40504                                          85
# 40505                                          85
#
#        Machine Tact time Collect Result_Fill2  PalletID Collect Result_Fill2  \
# 0                                     114.612                           19.9
# 1                                      19.600                            7.0
# 2                                     114.612                           19.8
# 3                                      19.900                           12.0
# 4                                      19.700                            8.0
# ...                                       ...                            ...
# 40501                                  19.200                            1.0
# 40502                                 114.612                           20.5
# 40503                                  85.000                           19.7
# 40504                                  20.100                           13.0
# 40505                                  19.400                            3.0
#
#        Production Qty Collect Result_Fill2  Receip No Collect Result_Fill2  \
# 0                                        7                             127
# 1                                      185                               1
# 2                                       10                              73
# 3                                      268                               1
# 4                                      121                               1
# ...                                    ...                             ...
# 40501                                  318                               1
# 40502                                   14                             197
# 40503                                    1                              27
# 40504                                  117                               1
# 40505                                  320                               1
#
#        WorkMode Collect Result_Fill2    target Model.Suffix   Workorder  \
# 0                                  1    Normal  AJX75334505  4F1XA938-1
# 1                                  0    Normal  AJX75334505  3KPM0016-2
# 2                                  1    Normal  AJX75334501  4E1X9167-1
# 3                                  0    Normal  AJX75334501  3K1X0057-1
# 4                                  0    Normal  AJX75334501  3HPM0007-1
# ...                              ...       ...          ...         ...
# 40501                              0    Normal  AJX75334501  3J1XF434-2
# 40502                              1    Normal  AJX75334501  4E1XC796-1
# 40503                              1    Normal  AJX75334501  4C1XD438-1
# 40504                              0    Normal  AJX75334501  3I1XA258-1
# 40505                              0  AbNormal  AJX75334501  3G1XA501-1
#
#        running_time_m  month  day  hour  out_of_hour  \
# 0                40.0      4   25    11            0
# 1                30.0      9   19    14            0
# 2                40.0      3    5     9            0
# 3                40.0      9   25    15            0
# 4                40.0      6   27    13            0
# ...               ...    ...  ...   ...          ...
# 40501            40.0      9   14    15            0
# 40502            40.0      4   10    14            0
# 40503            40.0      2   22     8            0
# 40504            40.0      7   25    11            0
# 40505            30.0      5   31     1            1
#
#                                                    Dam X  \
# 0      (161.0, 550.5, 464.3, 274.51, 0.0, 124.0, 130.85)
# 1      (550.3, 463.8, 160.8, 257.0, 127.5, 257.0, 505.0)
# 2      (550.4, 162.4, 465.4, 274.33, 0.0, 124.0, 130.85)
# 3      (162.4, 465.5, 552.0, 257.0, 127.5, 257.0, 505.0)
# 4      (549.0, 462.5, 159.5, 257.0, 127.5, 257.0, 505.0)
# ...                                                  ...
# 40501  (550.3, 463.8, 160.8, 257.0, 127.5, 257.0, 505.0)
# 40502  (550.4, 163.5, 466.2, 274.33, 0.0, 124.0, 130.85)
# 40503  (161.0, 550.6, 463.9, 274.78, 0.0, 124.0, 130.85)
# 40504  (162.4, 465.1, 551.3, 257.0, 127.5, 257.0, 505.0)
# 40505  (549.0, 463.0, 160.5, 257.0, 127.5, 257.0, 505.0)
#
#                                                  Dam Y  \
# 0        (161.4, 384.0, 383.1, 257, 127.5, 257, 505.0)
# 1           (377.3, 377.3, 377.3, 66, 66.0, 66, 300.0)
# 2      (551.7, 1271.8, 1383.9, 257, 127.5, 257, 505.0)
# 3        (1271.8, 1270.7, 1271.8, 66, 66.0, 66, 300.0)
# 4           (377.5, 377.0, 377.5, 66, 66.0, 66, 300.0)
# ...                                                ...
# 40501       (377.3, 377.3, 377.3, 66, 66.0, 66, 300.0)
# 40502  (553.1, 1281.0, 1393.5, 257, 127.5, 257, 505.0)
# 40503    (161.5, 377.6, 377.1, 257, 127.5, 257, 505.0)
# 40504    (1269.0, 1268.4, 1269.0, 66, 66.0, 66, 300.0)
# 40505       (377.5, 377.0, 377.5, 66, 66.0, 66, 303.5)
#
#                                                    Dam Z  \
# 0         (384.0, 274.51, 274.51, 66, 66.0, 66.0, 300.0)
# 1      (282.15, 282.15, 282.15, 0, 130.85, 130.85, 26...
# 2        (1271.8, 274.33, 274.33, 66, 66.0, 66.0, 300.0)
# 3      (282.15, 282.15, 282.15, 0, 130.85, 130.85, 26...
# 4          (284.8, 284.8, 284.8, 0, 133.5, 133.5, 265.0)
# ...                                                  ...
# 40501  (282.15, 282.15, 282.15, 0, 130.85, 130.85, 26...
# 40502    (1281.2, 274.33, 274.33, 66, 66.0, 66.0, 300.0)
# 40503     (378.0, 274.78, 274.78, 66, 66.0, 66.0, 300.0)
# 40504  (282.15, 282.15, 282.15, 0, 130.85, 130.85, 26...
# 40505      (284.8, 284.8, 284.8, 0, 133.5, 133.5, 265.0)
#
#                                           Fill1 X  \
# 0        (157.0, 838.4, 458.7, 244.52, 0.0, 92.2)
# 1      (838.4, 458.5, 157.0, 289.0, 123.4, 289.0)
# 2       (157.0, 837.9, 458.1, 244.415, 0.0, 92.2)
# 3      (837.7, 458.8, 157.0, 289.0, 123.4, 289.0)
# 4      (838.4, 458.5, 157.0, 289.0, 123.4, 289.0)
# ...                                           ...
# 40501  (838.4, 458.5, 157.0, 289.0, 123.4, 289.0)
# 40502   (157.0, 838.1, 458.7, 244.535, 0.0, 92.2)
# 40503   (157.0, 838.4, 458.4, 244.543, 0.0, 92.2)
# 40504  (837.7, 458.8, 157.0, 289.0, 123.4, 289.0)
# 40505  (837.9, 460.0, 157.5, 289.0, 123.4, 289.0)
#
#                                         Fill1 Y  \
# 0        (157.0, 430.0, 429.8, 289, 123.4, 289)
# 1           (430.5, 430.5, 430.8, 50, 50.0, 50)
# 2      (156.1, 1323.5, 1322.5, 289, 123.4, 289)
# 3        (1323.2, 1322.5, 1322.8, 50, 50.0, 50)
# 4           (430.2, 430.5, 430.5, 50, 50.0, 50)
# ...                                         ...
# 40501       (430.5, 430.5, 430.8, 50, 50.0, 50)
# 40502  (156.1, 1325.0, 1324.0, 289, 123.4, 289)
# 40503    (157.0, 430.8, 430.5, 289, 123.4, 289)
# 40504    (1323.2, 1323.0, 1322.8, 50, 50.0, 50)
# 40505       (430.2, 430.5, 430.5, 50, 50.0, 50)
#
#                                         Fill1 Z  \
# 0         (430.3, 244.52, 244.52, 50, 50.0, 50)
# 1           (244.4, 244.4, 244.4, 0, 92.2, 145)
# 2      (1323.1, 244.415, 244.415, 50, 50.0, 50)
# 3           (244.3, 244.3, 244.3, 0, 92.2, 145)
# 4            (244.4, 244.4, 244.4, 0, 92.2, 85)
# ...                                         ...
# 40501       (244.4, 244.4, 244.4, 0, 92.2, 145)
# 40502  (1324.3, 244.535, 244.535, 50, 50.0, 50)
# 40503   (431.1, 244.543, 244.543, 50, 50.0, 50)
# 40504       (244.4, 244.4, 244.4, 0, 92.2, 145)
# 40505        (244.3, 244.3, 244.3, 0, 92.2, 85)
#
#                                         Fill2 X  \
# 0       (156.0, 835.5, 458.0, 243.7, -10, 91.8)
# 1      (835.5, 458.0, 156.0, 270.0, 119, 270.0)
# 2       (694.0, 305.0, 499.8, 243.5, -10, 91.8)
# 3      (305.0, 499.8, 694.0, 270.0, 119, 270.0)
# 4      (835.5, 458.0, 156.0, 270.0, 119, 270.0)
# ...                                         ...
# 40501  (835.5, 458.0, 156.0, 270.0, 119, 270.0)
# 40502   (694.0, 304.8, 499.8, 243.5, -10, 91.8)
# 40503   (156.0, 835.5, 458.0, 243.7, -10, 91.8)
# 40504  (305.0, 499.8, 694.0, 270.0, 119, 270.0)
# 40505  (835.5, 458.0, 156.0, 270.0, 119, 270.0)
#
#                                       Fill2 Y  \
# 0        (156.0, 428.0, 427.9, 270, 119, 270)
# 1           (428.0, 427.9, 428.0, 50, 50, 50)
# 2      (694.0, 1324.2, 1324.2, 270, 119, 270)
# 3        (1324.2, 1324.2, 1324.2, 50, 50, 50)
# 4           (428.0, 427.9, 428.0, 50, 50, 50)
# ...                                       ...
# 40501       (428.0, 427.9, 428.0, 50, 50, 50)
# 40502  (692.8, 1324.2, 1324.2, 270, 119, 270)
# 40503    (156.0, 428.0, 427.9, 270, 119, 270)
# 40504    (1324.2, 1324.2, 1324.2, 50, 50, 50)
# 40505       (428.0, 427.9, 428.0, 50, 50, 50)
#
#                                     Fill2 Z
# 0       (428.0, 243.7, 243.7, 50, 50.0, 50)
# 1      (243.7, 243.7, 243.7, -10, 91.8, 85)
# 2      (1324.2, 243.5, 243.5, 50, 50.0, 50)
# 3      (243.5, 243.5, 243.5, -10, 91.8, 85)
# 4      (243.7, 243.7, 243.7, -10, 91.8, 85)
# ...                                     ...
# 40501  (243.7, 243.7, 243.7, -10, 91.8, 85)
# 40502  (1324.2, 243.5, 243.5, 50, 50.0, 50)
# 40503   (428.0, 243.7, 243.7, 50, 50.0, 50)
# 40504  (243.5, 243.5, 243.5, -10, 91.8, 85)
# 40505  (243.7, 243.7, 243.7, -10, 91.8, 85)
#
# [40506 rows x 159 columns]

# %%
cleanpurge_col_set = [['Head Clean Position X Collect Result_Fill1',
'Head Purge Position X Collect Result_Fill1'],
                 ['Head Clean Position Y Collect Result_Fill1',
'Head Purge Position Y Collect Result_Fill1'],
                 ['Head Clean Position Z Collect Result_Fill1',
'Head Purge Position Z Collect Result_Fill1'],
                 
                 ['Head Clean Position X Collect Result_Dam',
'Head Purge Position X Collect Result_Dam'],
                 ['Head Clean Position Y Collect Result_Dam',
'Head Purge Position Y Collect Result_Dam'],
                 ['Head Clean Position Z Collect Result_Dam',
'Head Purge Position Z Collect Result_Dam']]

new_col = []
for col_set in cleanpurge_col_set:
  colname = col_set[0].replace('Clean', 'Clean&Purge')
  new_col.append(colname)
  train_data[colname] = list(train_data[col_set].itertuples(index=False, name=None))
  train_data[colname] = train_data[colname].astype(str)
  test[colname] = list(test[col_set].itertuples(index=False, name=None))
  test[colname] = test[colname].astype(str)

# %%
train_data
# Out:
#           Equipment_Dam    Collect Date_Dam  \
# 0      Dam dispenser #1 2024-04-25 11:10:00
# 1      Dam dispenser #1 2023-09-19 14:30:00
# 2      Dam dispenser #2 2024-03-05 09:30:00
# 3      Dam dispenser #2 2023-09-25 15:40:00
# 4      Dam dispenser #1 2023-06-27 13:20:00
# ...                 ...                 ...
# 40501  Dam dispenser #1 2023-09-14 15:50:00
# 40502  Dam dispenser #2 2024-04-10 14:20:00
# 40503  Dam dispenser #1 2024-02-22 08:40:00
# 40504  Dam dispenser #2 2023-07-25 11:00:00
# 40505  Dam dispenser #1 2023-05-31 01:40:00
#
#        CURE END POSITION X Collect Result_Dam  \
# 0                                       240.0
# 1                                       240.0
# 2                                      1000.0
# 3                                      1000.0
# 4                                       240.0
# ...                                       ...
# 40501                                   240.0
# 40502                                  1000.0
# 40503                                   240.0
# 40504                                  1000.0
# 40505                                   240.0
#
#        CURE END POSITION Z Collect Result_Dam  \
# 0                                         2.5
# 1                                         2.5
# 2                                        12.5
# 3                                        12.5
# 4                                         2.5
# ...                                       ...
# 40501                                     2.5
# 40502                                    12.5
# 40503                                     2.5
# 40504                                    12.5
# 40505                                     2.5
#
#        CURE END POSITION Θ Collect Result_Dam  CURE SPEED Collect Result_Dam  \
# 0                                         -90                            100
# 1                                         -90                             70
# 2                                          90                             85
# 3                                          90                             70
# 4                                         -90                             70
# ...                                       ...                            ...
# 40501                                     -90                             70
# 40502                                      90                            100
# 40503                                     -90                            100
# 40504                                      90                             70
# 40505                                     -90                             70
#
#        CURE START POSITION X Collect Result_Dam  \
# 0                                          1030
# 1                                          1030
# 2                                           280
# 3                                           280
# 4                                          1030
# ...                                         ...
# 40501                                      1030
# 40502                                       280
# 40503                                      1030
# 40504                                       280
# 40505                                      1030
#
#        CURE START POSITION Θ Collect Result_Dam  \
# 0                                           -90
# 1                                           -90
# 2                                            90
# 3                                            90
# 4                                           -90
# ...                                         ...
# 40501                                       -90
# 40502                                        90
# 40503                                       -90
# 40504                                        90
# 40505                                       -90
#
#        DISCHARGED SPEED OF RESIN Collect Result_Dam  \
# 0                                                16
# 1                                                10
# 2                                                16
# 3                                                10
# 4                                                10
# ...                                             ...
# 40501                                            10
# 40502                                            16
# 40503                                            16
# 40504                                            10
# 40505                                            10
#
#        DISCHARGED TIME OF RESIN(Stage1) Collect Result_Dam  \
# 0                                                   14.9
# 1                                                   21.3
# 2                                                   14.7
# 3                                                   21.3
# 4                                                    9.7
# ...                                                  ...
# 40501                                               17.0
# 40502                                               14.9
# 40503                                               14.2
# 40504                                                9.7
# 40505                                                9.6
#
#        DISCHARGED TIME OF RESIN(Stage2) Collect Result_Dam  \
# 0                                                    8.4
# 1                                                    4.9
# 2                                                    8.5
# 3                                                    8.4
# 4                                                    4.9
# ...                                                  ...
# 40501                                                5.0
# 40502                                                8.5
# 40503                                                8.2
# 40504                                                4.9
# 40505                                                3.9
#
#        DISCHARGED TIME OF RESIN(Stage3) Collect Result_Dam  \
# 0                                                   14.7
# 1                                                   21.3
# 2                                                   14.7
# 3                                                   21.3
# 4                                                    9.6
# ...                                                  ...
# 40501                                               17.0
# 40502                                               14.7
# 40503                                               14.3
# 40504                                                9.7
# 40505                                                9.7
#
#        Dispense Volume(Stage1) Collect Result_Dam  \
# 0                                            1.04
# 1                                            1.49
# 2                                            1.61
# 3                                            1.49
# 4                                            0.67
# ...                                           ...
# 40501                                        1.19
# 40502                                        1.04
# 40503                                        0.99
# 40504                                        0.67
# 40505                                        0.67
#
#        Dispense Volume(Stage2) Collect Result_Dam  \
# 0                                            0.58
# 1                                            0.34
# 2                                            0.93
# 3                                            0.58
# 4                                            0.34
# ...                                           ...
# 40501                                        0.35
# 40502                                        0.59
# 40503                                        0.57
# 40504                                        0.34
# 40505                                        0.27
#
#        Dispense Volume(Stage3) Collect Result_Dam  \
# 0                                            1.02
# 1                                            1.49
# 2                                            1.61
# 3                                            1.49
# 4                                            0.67
# ...                                           ...
# 40501                                        1.19
# 40502                                        1.02
# 40503                                        1.00
# 40504                                        0.67
# 40505                                        0.67
#
#        HEAD NORMAL COORDINATE X AXIS(Stage1) Collect Result_Dam  \
# 0                                                  161.0
# 1                                                  550.3
# 2                                                  550.4
# 3                                                  162.4
# 4                                                  549.0
# ...                                                  ...
# 40501                                              550.3
# 40502                                              550.4
# 40503                                              161.0
# 40504                                              162.4
# 40505                                              549.0
#
#       HEAD NORMAL COORDINATE X AXIS(Stage1) Judge Value_Dam  \
# 0                                                    nan
# 1                                                     NG
# 2                                                     OK
# 3                                                     NG
# 4                                                     NG
# ...                                                  ...
# 40501                                                 NG
# 40502                                                nan
# 40503                                                 OK
# 40504                                                 NG
# 40505                                                 NG
#
#        HEAD NORMAL COORDINATE X AXIS(Stage2) Collect Result_Dam  \
# 0                                                  550.5
# 1                                                  463.8
# 2                                                  162.4
# 3                                                  465.5
# 4                                                  462.5
# ...                                                  ...
# 40501                                              463.8
# 40502                                              163.5
# 40503                                              550.6
# 40504                                              465.1
# 40505                                              463.0
#
#        HEAD NORMAL COORDINATE X AXIS(Stage3) Collect Result_Dam  \
# 0                                                  464.3
# 1                                                  160.8
# 2                                                  465.4
# 3                                                  552.0
# 4                                                  159.5
# ...                                                  ...
# 40501                                              160.8
# 40502                                              466.2
# 40503                                              463.9
# 40504                                              551.3
# 40505                                              160.5
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage1) Collect Result_Dam  \
# 0                                                  161.4
# 1                                                  377.3
# 2                                                  551.7
# 3                                                 1271.8
# 4                                                  377.5
# ...                                                  ...
# 40501                                              377.3
# 40502                                              553.1
# 40503                                              161.5
# 40504                                             1269.0
# 40505                                              377.5
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage2) Collect Result_Dam  \
# 0                                                  384.0
# 1                                                  377.3
# 2                                                 1271.8
# 3                                                 1270.7
# 4                                                  377.0
# ...                                                  ...
# 40501                                              377.3
# 40502                                             1281.0
# 40503                                              377.6
# 40504                                             1268.4
# 40505                                              377.0
#
#        HEAD NORMAL COORDINATE Y AXIS(Stage3) Collect Result_Dam  \
# 0                                                  383.1
# 1                                                  377.3
# 2                                                 1383.9
# 3                                                 1271.8
# 4                                                  377.5
# ...                                                  ...
# 40501                                              377.3
# 40502                                             1393.5
# 40503                                              377.1
# 40504                                             1269.0
# 40505                                              377.5
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage1) Collect Result_Dam  \
# 0                                                 384.00
# 1                                                 282.15
# 2                                                1271.80
# 3                                                 282.15
# 4                                                 284.80
# ...                                                  ...
# 40501                                             282.15
# 40502                                            1281.20
# 40503                                             378.00
# 40504                                             282.15
# 40505                                             284.80
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage2) Collect Result_Dam  \
# 0                                                 274.51
# 1                                                 282.15
# 2                                                 274.33
# 3                                                 282.15
# 4                                                 284.80
# ...                                                  ...
# 40501                                             282.15
# 40502                                             274.33
# 40503                                             274.78
# 40504                                             282.15
# 40505                                             284.80
#
#        HEAD NORMAL COORDINATE Z AXIS(Stage3) Collect Result_Dam  \
# 0                                                 274.51
# 1                                                 282.15
# 2                                                 274.33
# 3                                                 282.15
# 4                                                 284.80
# ...                                                  ...
# 40501                                             282.15
# 40502                                             274.33
# 40503                                             274.78
# 40504                                             282.15
# 40505                                             284.80
#
#        HEAD Standby Position X Collect Result_Dam  \
# 0                                          274.51
# 1                                          257.00
# 2                                          274.33
# 3                                          257.00
# 4                                          257.00
# ...                                           ...
# 40501                                      257.00
# 40502                                      274.33
# 40503                                      274.78
# 40504                                      257.00
# 40505                                      257.00
#
#        HEAD Standby Position Y Collect Result_Dam  \
# 0                                             257
# 1                                              66
# 2                                             257
# 3                                              66
# 4                                              66
# ...                                           ...
# 40501                                          66
# 40502                                         257
# 40503                                         257
# 40504                                          66
# 40505                                          66
#
#        HEAD Standby Position Z Collect Result_Dam  \
# 0                                              66
# 1                                               0
# 2                                              66
# 3                                               0
# 4                                               0
# ...                                           ...
# 40501                                           0
# 40502                                          66
# 40503                                          66
# 40504                                           0
# 40505                                           0
#
#        Head Clean Position X Collect Result_Dam  \
# 0                                           0.0
# 1                                         127.5
# 2                                           0.0
# 3                                         127.5
# 4                                         127.5
# ...                                         ...
# 40501                                     127.5
# 40502                                       0.0
# 40503                                       0.0
# 40504                                     127.5
# 40505                                     127.5
#
#        Head Clean Position Y Collect Result_Dam  \
# 0                                         127.5
# 1                                          66.0
# 2                                         127.5
# 3                                          66.0
# 4                                          66.0
# ...                                         ...
# 40501                                      66.0
# 40502                                     127.5
# 40503                                     127.5
# 40504                                      66.0
# 40505                                      66.0
#
#        Head Clean Position Z Collect Result_Dam  \
# 0                                         66.00
# 1                                        130.85
# 2                                         66.00
# 3                                        130.85
# 4                                        133.50
# ...                                         ...
# 40501                                    130.85
# 40502                                     66.00
# 40503                                     66.00
# 40504                                    130.85
# 40505                                    133.50
#
#        Head Purge Position X Collect Result_Dam  \
# 0                                         124.0
# 1                                         257.0
# 2                                         124.0
# 3                                         257.0
# 4                                         257.0
# ...                                         ...
# 40501                                     257.0
# 40502                                     124.0
# 40503                                     124.0
# 40504                                     257.0
# 40505                                     257.0
#
#        Head Purge Position Y Collect Result_Dam  \
# 0                                           257
# 1                                            66
# 2                                           257
# 3                                            66
# 4                                            66
# ...                                         ...
# 40501                                        66
# 40502                                       257
# 40503                                       257
# 40504                                        66
# 40505                                        66
#
#        Head Purge Position Z Collect Result_Dam  \
# 0                                         66.00
# 1                                        130.85
# 2                                         66.00
# 3                                        130.85
# 4                                        133.50
# ...                                         ...
# 40501                                    130.85
# 40502                                     66.00
# 40503                                     66.00
# 40504                                    130.85
# 40505                                    133.50
#
#        Head Zero Position X Collect Result_Dam  \
# 0                                       130.85
# 1                                       505.00
# 2                                       130.85
# 3                                       505.00
# 4                                       505.00
# ...                                        ...
# 40501                                   505.00
# 40502                                   130.85
# 40503                                   130.85
# 40504                                   505.00
# 40505                                   505.00
#
#        Head Zero Position Y Collect Result_Dam  \
# 0                                        505.0
# 1                                        300.0
# 2                                        505.0
# 3                                        300.0
# 4                                        300.0
# ...                                        ...
# 40501                                    300.0
# 40502                                    505.0
# 40503                                    505.0
# 40504                                    300.0
# 40505                                    303.5
#
#        Head Zero Position Z Collect Result_Dam  \
# 0                                        300.0
# 1                                        265.0
# 2                                        300.0
# 3                                        265.0
# 4                                        265.0
# ...                                        ...
# 40501                                    265.0
# 40502                                    300.0
# 40503                                    300.0
# 40504                                    265.0
# 40505                                    265.0
#
#        Machine Tact time Collect Result_Dam  PalletID Collect Result_Dam  \
# 0                                    265.00                         58.5
# 1                                     65.10                          7.0
# 2                                    265.02                         76.9
# 3                                     70.50                         12.0
# 4                                     88.30                          8.0
# ...                                     ...                          ...
# 40501                                 56.70                          1.0
# 40502                                265.00                         78.5
# 40503                                265.02                         69.5
# 40504                                 57.70                         13.0
# 40505                                 92.10                          3.0
#
#        Production Qty Collect Result_Dam  Receip No Collect Result_Dam  \
# 0                                      7                           127
# 1                                    185                             1
# 2                                     10                            73
# 3                                    268                             1
# 4                                    121                             1
# ...                                  ...                           ...
# 40501                                318                             1
# 40502                                 14                           197
# 40503                                  1                            27
# 40504                                117                             1
# 40505                                320                             1
#
#        Stage1 Circle1 Distance Speed Collect Result_Dam  \
# 0                                                     1
# 1                                                  4000
# 2                                                     1
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                                 1
# 40503                                                 1
# 40504                                              9000
# 40505                                              9000
#
#        Stage1 Circle2 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage1 Circle3 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage1 Circle4 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage1 Line1 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage1 Line2 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage1 Line3 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage1 Line4 Distance Speed Collect Result_Dam  \
# 0                                                5600
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5600
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage2 Circle1 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  9000
# 2                                                  5800
# 3                                                  5000
# 4                                                  9000
# ...                                                 ...
# 40501                                              9000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                             12000
#
#        Stage2 Circle2 Distance Speed Collect Result_Dam  \
# 0                                                  5300
# 1                                                  9000
# 2                                                  5300
# 3                                                  5000
# 4                                                  9000
# ...                                                 ...
# 40501                                              9000
# 40502                                              5300
# 40503                                              5500
# 40504                                              9000
# 40505                                             12000
#
#        Stage2 Circle3 Distance Speed Collect Result_Dam  \
# 0                                                  5300
# 1                                                  9000
# 2                                                  5300
# 3                                                  5000
# 4                                                  9000
# ...                                                 ...
# 40501                                              9000
# 40502                                              5300
# 40503                                              5500
# 40504                                              9000
# 40505                                             12000
#
#        Stage2 Circle4 Distance Speed Collect Result_Dam  \
# 0                                                  5300
# 1                                                  9000
# 2                                                  5300
# 3                                                  5000
# 4                                                  9000
# ...                                                 ...
# 40501                                              9000
# 40502                                              5300
# 40503                                              5500
# 40504                                              9000
# 40505                                             12000
#
#        Stage2 Line1 Distance Speed Collect Result_Dam  \
# 0                                                5300
# 1                                                9000
# 2                                                5300
# 3                                                5000
# 4                                                9000
# ...                                               ...
# 40501                                            9000
# 40502                                            5300
# 40503                                            5500
# 40504                                            9000
# 40505                                           12000
#
#        Stage2 Line2 Distance Speed Collect Result_Dam  \
# 0                                                5300
# 1                                                9000
# 2                                                5300
# 3                                                5000
# 4                                                9000
# ...                                               ...
# 40501                                            9000
# 40502                                            5300
# 40503                                            5500
# 40504                                            9000
# 40505                                           12000
#
#        Stage2 Line3 Distance Speed Collect Result_Dam  \
# 0                                                5300
# 1                                                9000
# 2                                                5300
# 3                                                5000
# 4                                                9000
# ...                                               ...
# 40501                                            9000
# 40502                                            5300
# 40503                                            5500
# 40504                                            9000
# 40505                                           12000
#
#        Stage2 Line4 Distance Speed Collect Result_Dam  \
# 0                                                5300
# 1                                                9000
# 2                                                5300
# 3                                                5000
# 4                                                9000
# ...                                               ...
# 40501                                            9000
# 40502                                            5300
# 40503                                            5500
# 40504                                            9000
# 40505                                           12000
#
#        Stage3 Circle1 Distance Speed Collect Result_Dam  \
# 0                                                  5300
# 1                                                  4000
# 2                                                  5300
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5300
# 40503                                              5500
# 40504                                              9000
# 40505                                              9000
#
#        Stage3 Circle2 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage3 Circle3 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage3 Circle4 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage3 Line1 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage3 Line2 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage3 Line3 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage3 Line4 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        THICKNESS 1 Collect Result_Dam  THICKNESS 2 Collect Result_Dam  \
# 0                                5800                           0.000
# 1                                   0                           0.000
# 2                                5800                           0.012
# 3                                   0                           0.000
# 4                                   0                           0.000
# ...                               ...                             ...
# 40501                               0                           0.000
# 40502                            5800                          -0.019
# 40503                            6000                           0.000
# 40504                               0                           0.000
# 40505                               0                           0.000
#
#        THICKNESS 3 Collect Result_Dam  WorkMode Collect Result_Dam  \
# 0                               0.000                        0.000
# 1                               0.000                        7.000
# 2                              -0.022                        0.003
# 3                               0.000                        7.000
# 4                               0.000                        7.000
# ...                               ...                          ...
# 40501                           0.000                        7.000
# 40502                          -0.021                       -0.118
# 40503                           0.000                        0.000
# 40504                           0.000                        7.000
# 40505                           0.000                        7.000
#
#       Collect Date_AutoClave  1st Pressure Collect Result_AutoClave  \
# 0        2024-04-25 11:50:00                                  0.312
# 1        2023-09-19 15:00:00                                  0.311
# 2        2024-03-05 10:10:00                                  0.315
# 3        2023-09-25 16:20:00                                  0.299
# 4        2023-06-27 14:00:00                                  0.302
# ...                      ...                                    ...
# 40501    2023-09-14 16:30:00                                  0.300
# 40502    2024-04-10 15:00:00                                  0.305
# 40503    2024-02-22 09:20:00                                  0.309
# 40504    2023-07-25 11:40:00                                  0.302
# 40505    2023-05-31 02:10:00                                  0.305
#
#        1st Pressure 1st Pressure Unit Time_AutoClave  \
# 0                                                240
# 1                                                241
# 2                                                241
# 3                                                241
# 4                                                240
# ...                                              ...
# 40501                                            241
# 40502                                            240
# 40503                                            241
# 40504                                            241
# 40505                                            300
#
#        2nd Pressure Collect Result_AutoClave  \
# 0                                      0.493
# 1                                      0.311
# 2                                      0.490
# 3                                      0.300
# 4                                      0.302
# ...                                      ...
# 40501                                  0.300
# 40502                                  0.493
# 40503                                  0.490
# 40504                                  0.303
# 40505                                  0.305
#
#        2nd Pressure Unit Time_AutoClave  \
# 0                                     1
# 1                                   121
# 2                                     1
# 3                                   121
# 4                                   120
# ...                                 ...
# 40501                               121
# 40502                                 1
# 40503                                 1
# 40504                               121
# 40505                                60
#
#        3rd Pressure Collect Result_AutoClave  \
# 0                                      0.499
# 1                                      0.498
# 2                                      0.498
# 3                                      0.500
# 4                                      0.498
# ...                                      ...
# 40501                                  0.500
# 40502                                  0.498
# 40503                                  0.498
# 40504                                  0.499
# 40505                                  0.498
#
#        3rd Pressure Unit Time_AutoClave  \
# 0                                   120
# 1                                   121
# 2                                   121
# 3                                   121
# 4                                   120
# ...                                 ...
# 40501                               121
# 40502                               120
# ...
# 40505                                          50
#
#        Head Clean Position Z Collect Result_Fill2  \
# 0                                            50.0
# 1                                            91.8
# 2                                            50.0
# 3                                            91.8
# 4                                            91.8
# ...                                           ...
# 40501                                        91.8
# 40502                                        50.0
# 40503                                        50.0
# 40504                                        91.8
# 40505                                        91.8
#
#        Head Purge Position X Collect Result_Fill2  \
# 0                                            91.8
# 1                                           270.0
# 2                                            91.8
# 3                                           270.0
# 4                                           270.0
# ...                                           ...
# 40501                                       270.0
# 40502                                        91.8
# 40503                                        91.8
# 40504                                       270.0
# 40505                                       270.0
#
#        Head Purge Position Y Collect Result_Fill2  \
# 0                                             270
# 1                                              50
# 2                                             270
# 3                                              50
# 4                                              50
# ...                                           ...
# 40501                                          50
# 40502                                         270
# 40503                                         270
# 40504                                          50
# 40505                                          50
#
#        Head Purge Position Z Collect Result_Fill2  \
# 0                                              50
# 1                                              85
# 2                                              50
# 3                                              85
# 4                                              85
# ...                                           ...
# 40501                                          85
# 40502                                          50
# 40503                                          50
# 40504                                          85
# 40505                                          85
#
#        Machine Tact time Collect Result_Fill2  PalletID Collect Result_Fill2  \
# 0                                     114.612                           19.9
# 1                                      19.600                            7.0
# 2                                     114.612                           19.8
# 3                                      19.900                           12.0
# 4                                      19.700                            8.0
# ...                                       ...                            ...
# 40501                                  19.200                            1.0
# 40502                                 114.612                           20.5
# 40503                                  85.000                           19.7
# 40504                                  20.100                           13.0
# 40505                                  19.400                            3.0
#
#        Production Qty Collect Result_Fill2  Receip No Collect Result_Fill2  \
# 0                                        7                             127
# 1                                      185                               1
# 2                                       10                              73
# 3                                      268                               1
# 4                                      121                               1
# ...                                    ...                             ...
# 40501                                  318                               1
# 40502                                   14                             197
# 40503                                    1                              27
# 40504                                  117                               1
# 40505                                  320                               1
#
#        WorkMode Collect Result_Fill2    target Model.Suffix   Workorder  \
# 0                                  1    Normal  AJX75334505  4F1XA938-1
# 1                                  0    Normal  AJX75334505  3KPM0016-2
# 2                                  1    Normal  AJX75334501  4E1X9167-1
# 3                                  0    Normal  AJX75334501  3K1X0057-1
# 4                                  0    Normal  AJX75334501  3HPM0007-1
# ...                              ...       ...          ...         ...
# 40501                              0    Normal  AJX75334501  3J1XF434-2
# 40502                              1    Normal  AJX75334501  4E1XC796-1
# 40503                              1    Normal  AJX75334501  4C1XD438-1
# 40504                              0    Normal  AJX75334501  3I1XA258-1
# 40505                              0  AbNormal  AJX75334501  3G1XA501-1
#
#        running_time_m  month  day  hour  out_of_hour  \
# 0                40.0      4   25    11            0
# 1                30.0      9   19    14            0
# 2                40.0      3    5     9            0
# 3                40.0      9   25    15            0
# 4                40.0      6   27    13            0
# ...               ...    ...  ...   ...          ...
# 40501            40.0      9   14    15            0
# 40502            40.0      4   10    14            0
# 40503            40.0      2   22     8            0
# 40504            40.0      7   25    11            0
# 40505            30.0      5   31     1            1
#
#                                                    Dam X  \
# 0      (161.0, 550.5, 464.3, 274.51, 0.0, 124.0, 130.85)
# 1      (550.3, 463.8, 160.8, 257.0, 127.5, 257.0, 505.0)
# 2      (550.4, 162.4, 465.4, 274.33, 0.0, 124.0, 130.85)
# 3      (162.4, 465.5, 552.0, 257.0, 127.5, 257.0, 505.0)
# 4      (549.0, 462.5, 159.5, 257.0, 127.5, 257.0, 505.0)
# ...                                                  ...
# 40501  (550.3, 463.8, 160.8, 257.0, 127.5, 257.0, 505.0)
# 40502  (550.4, 163.5, 466.2, 274.33, 0.0, 124.0, 130.85)
# 40503  (161.0, 550.6, 463.9, 274.78, 0.0, 124.0, 130.85)
# 40504  (162.4, 465.1, 551.3, 257.0, 127.5, 257.0, 505.0)
# 40505  (549.0, 463.0, 160.5, 257.0, 127.5, 257.0, 505.0)
#
#                                                  Dam Y  \
# 0        (161.4, 384.0, 383.1, 257, 127.5, 257, 505.0)
# 1           (377.3, 377.3, 377.3, 66, 66.0, 66, 300.0)
# 2      (551.7, 1271.8, 1383.9, 257, 127.5, 257, 505.0)
# 3        (1271.8, 1270.7, 1271.8, 66, 66.0, 66, 300.0)
# 4           (377.5, 377.0, 377.5, 66, 66.0, 66, 300.0)
# ...                                                ...
# 40501       (377.3, 377.3, 377.3, 66, 66.0, 66, 300.0)
# 40502  (553.1, 1281.0, 1393.5, 257, 127.5, 257, 505.0)
# 40503    (161.5, 377.6, 377.1, 257, 127.5, 257, 505.0)
# 40504    (1269.0, 1268.4, 1269.0, 66, 66.0, 66, 300.0)
# 40505       (377.5, 377.0, 377.5, 66, 66.0, 66, 303.5)
#
#                                                    Dam Z  \
# 0         (384.0, 274.51, 274.51, 66, 66.0, 66.0, 300.0)
# 1      (282.15, 282.15, 282.15, 0, 130.85, 130.85, 26...
# 2        (1271.8, 274.33, 274.33, 66, 66.0, 66.0, 300.0)
# 3      (282.15, 282.15, 282.15, 0, 130.85, 130.85, 26...
# 4          (284.8, 284.8, 284.8, 0, 133.5, 133.5, 265.0)
# ...                                                  ...
# 40501  (282.15, 282.15, 282.15, 0, 130.85, 130.85, 26...
# 40502    (1281.2, 274.33, 274.33, 66, 66.0, 66.0, 300.0)
# 40503     (378.0, 274.78, 274.78, 66, 66.0, 66.0, 300.0)
# 40504  (282.15, 282.15, 282.15, 0, 130.85, 130.85, 26...
# 40505      (284.8, 284.8, 284.8, 0, 133.5, 133.5, 265.0)
#
#                                           Fill1 X  \
# 0        (157.0, 838.4, 458.7, 244.52, 0.0, 92.2)
# 1      (838.4, 458.5, 157.0, 289.0, 123.4, 289.0)
# 2       (157.0, 837.9, 458.1, 244.415, 0.0, 92.2)
# 3      (837.7, 458.8, 157.0, 289.0, 123.4, 289.0)
# 4      (838.4, 458.5, 157.0, 289.0, 123.4, 289.0)
# ...                                           ...
# 40501  (838.4, 458.5, 157.0, 289.0, 123.4, 289.0)
# 40502   (157.0, 838.1, 458.7, 244.535, 0.0, 92.2)
# 40503   (157.0, 838.4, 458.4, 244.543, 0.0, 92.2)
# 40504  (837.7, 458.8, 157.0, 289.0, 123.4, 289.0)
# 40505  (837.9, 460.0, 157.5, 289.0, 123.4, 289.0)
#
#                                         Fill1 Y  \
# 0        (157.0, 430.0, 429.8, 289, 123.4, 289)
# 1           (430.5, 430.5, 430.8, 50, 50.0, 50)
# 2      (156.1, 1323.5, 1322.5, 289, 123.4, 289)
# 3        (1323.2, 1322.5, 1322.8, 50, 50.0, 50)
# 4           (430.2, 430.5, 430.5, 50, 50.0, 50)
# ...                                         ...
# 40501       (430.5, 430.5, 430.8, 50, 50.0, 50)
# 40502  (156.1, 1325.0, 1324.0, 289, 123.4, 289)
# 40503    (157.0, 430.8, 430.5, 289, 123.4, 289)
# 40504    (1323.2, 1323.0, 1322.8, 50, 50.0, 50)
# 40505       (430.2, 430.5, 430.5, 50, 50.0, 50)
#
#                                         Fill1 Z  \
# 0         (430.3, 244.52, 244.52, 50, 50.0, 50)
# 1           (244.4, 244.4, 244.4, 0, 92.2, 145)
# 2      (1323.1, 244.415, 244.415, 50, 50.0, 50)
# 3           (244.3, 244.3, 244.3, 0, 92.2, 145)
# 4            (244.4, 244.4, 244.4, 0, 92.2, 85)
# ...                                         ...
# 40501       (244.4, 244.4, 244.4, 0, 92.2, 145)
# 40502  (1324.3, 244.535, 244.535, 50, 50.0, 50)
# 40503   (431.1, 244.543, 244.543, 50, 50.0, 50)
# 40504       (244.4, 244.4, 244.4, 0, 92.2, 145)
# 40505        (244.3, 244.3, 244.3, 0, 92.2, 85)
#
#                                         Fill2 X  \
# 0       (156.0, 835.5, 458.0, 243.7, -10, 91.8)
# 1      (835.5, 458.0, 156.0, 270.0, 119, 270.0)
# 2       (694.0, 305.0, 499.8, 243.5, -10, 91.8)
# 3      (305.0, 499.8, 694.0, 270.0, 119, 270.0)
# 4      (835.5, 458.0, 156.0, 270.0, 119, 270.0)
# ...                                         ...
# 40501  (835.5, 458.0, 156.0, 270.0, 119, 270.0)
# 40502   (694.0, 304.8, 499.8, 243.5, -10, 91.8)
# 40503   (156.0, 835.5, 458.0, 243.7, -10, 91.8)
# 40504  (305.0, 499.8, 694.0, 270.0, 119, 270.0)
# 40505  (835.5, 458.0, 156.0, 270.0, 119, 270.0)
#
#                                       Fill2 Y  \
# 0        (156.0, 428.0, 427.9, 270, 119, 270)
# 1           (428.0, 427.9, 428.0, 50, 50, 50)
# 2      (694.0, 1324.2, 1324.2, 270, 119, 270)
# 3        (1324.2, 1324.2, 1324.2, 50, 50, 50)
# 4           (428.0, 427.9, 428.0, 50, 50, 50)
# ...                                       ...
# 40501       (428.0, 427.9, 428.0, 50, 50, 50)
# 40502  (692.8, 1324.2, 1324.2, 270, 119, 270)
# 40503    (156.0, 428.0, 427.9, 270, 119, 270)
# 40504    (1324.2, 1324.2, 1324.2, 50, 50, 50)
# 40505       (428.0, 427.9, 428.0, 50, 50, 50)
#
#                                     Fill2 Z  \
# 0       (428.0, 243.7, 243.7, 50, 50.0, 50)
# 1      (243.7, 243.7, 243.7, -10, 91.8, 85)
# 2      (1324.2, 243.5, 243.5, 50, 50.0, 50)
# 3      (243.5, 243.5, 243.5, -10, 91.8, 85)
# 4      (243.7, 243.7, 243.7, -10, 91.8, 85)
# ...                                     ...
# 40501  (243.7, 243.7, 243.7, -10, 91.8, 85)
# 40502  (1324.2, 243.5, 243.5, 50, 50.0, 50)
# 40503   (428.0, 243.7, 243.7, 50, 50.0, 50)
# 40504  (243.5, 243.5, 243.5, -10, 91.8, 85)
# 40505  (243.7, 243.7, 243.7, -10, 91.8, 85)
#
#       Head Clean&Purge Position X Collect Result_Fill1  \
# 0                                          (0.0, 92.2)
# 1                                       (123.4, 289.0)
# 2                                          (0.0, 92.2)
# 3                                       (123.4, 289.0)
# 4                                       (123.4, 289.0)
# ...                                                ...
# 40501                                   (123.4, 289.0)
# 40502                                      (0.0, 92.2)
# 40503                                      (0.0, 92.2)
# 40504                                   (123.4, 289.0)
# 40505                                   (123.4, 289.0)
#
#       Head Clean&Purge Position Y Collect Result_Fill1  \
# 0                                         (123.4, 289)
# 1                                           (50.0, 50)
# 2                                         (123.4, 289)
# 3                                           (50.0, 50)
# 4                                           (50.0, 50)
# ...                                                ...
# 40501                                       (50.0, 50)
# 40502                                     (123.4, 289)
# 40503                                     (123.4, 289)
# 40504                                       (50.0, 50)
# 40505                                       (50.0, 50)
#
#       Head Clean&Purge Position Z Collect Result_Fill1  \
# 0                                           (50.0, 50)
# 1                                          (92.2, 145)
# 2                                           (50.0, 50)
# 3                                          (92.2, 145)
# 4                                           (92.2, 85)
# ...                                                ...
# 40501                                      (92.2, 145)
# 40502                                       (50.0, 50)
# 40503                                       (50.0, 50)
# 40504                                      (92.2, 145)
# 40505                                       (92.2, 85)
#
#       Head Clean&Purge Position X Collect Result_Dam  \
# 0                                       (0.0, 124.0)
# 1                                     (127.5, 257.0)
# 2                                       (0.0, 124.0)
# 3                                     (127.5, 257.0)
# 4                                     (127.5, 257.0)
# ...                                              ...
# 40501                                 (127.5, 257.0)
# 40502                                   (0.0, 124.0)
# 40503                                   (0.0, 124.0)
# 40504                                 (127.5, 257.0)
# 40505                                 (127.5, 257.0)
#
#       Head Clean&Purge Position Y Collect Result_Dam  \
# 0                                       (127.5, 257)
# 1                                         (66.0, 66)
# 2                                       (127.5, 257)
# 3                                         (66.0, 66)
# 4                                         (66.0, 66)
# ...                                              ...
# 40501                                     (66.0, 66)
# 40502                                   (127.5, 257)
# 40503                                   (127.5, 257)
# 40504                                     (66.0, 66)
# 40505                                     (66.0, 66)
#
#       Head Clean&Purge Position Z Collect Result_Dam
# 0                                       (66.0, 66.0)
# 1                                   (130.85, 130.85)
# 2                                       (66.0, 66.0)
# 3                                   (130.85, 130.85)
# 4                                     (133.5, 133.5)
# ...                                              ...
# 40501                               (130.85, 130.85)
# 40502                                   (66.0, 66.0)
# 40503                                   (66.0, 66.0)
# 40504                               (130.85, 130.85)
# 40505                                 (133.5, 133.5)
#
# [40506 rows x 165 columns]

# %%
cure_col_set = [ ['CURE START POSITION X Collect Result_Dam',
                  'CURE END POSITION X Collect Result_Dam'],
                 ['CURE START POSITION Θ Collect Result_Dam',
                  'CURE END POSITION Θ Collect Result_Dam'],
                 [ 'CURE START POSITION X Collect Result_Fill2',
                   'CURE END POSITION X Collect Result_Fill2'],
                 [ 'CURE START POSITION Z Collect Result_Fill2',
                   'CURE END POSITION Z Collect Result_Fill2']]



new_col = []
for col_set in cure_col_set:
  colname = col_set[0].replace('START', '')
  new_col.append(colname)
  train_data[colname] = list(train_data[col_set].itertuples(index=False, name=None))
  train_data[colname] = train_data[colname].astype(str)
  test[colname] = list(test[col_set].itertuples(index=False, name=None))
  test[colname] = test[colname].astype(str)

# %%
stage_col_set = [['HEAD NORMAL COORDINATE X AXIS(Stage1) Collect Result_Dam',
                  'HEAD NORMAL COORDINATE X AXIS(Stage2) Collect Result_Dam',
                  'HEAD NORMAL COORDINATE X AXIS(Stage3) Collect Result_Dam'],
                 ['HEAD NORMAL COORDINATE Y AXIS(Stage1) Collect Result_Dam',
                  'HEAD NORMAL COORDINATE Y AXIS(Stage2) Collect Result_Dam',
                  'HEAD NORMAL COORDINATE Y AXIS(Stage3) Collect Result_Dam'],
                 ['HEAD NORMAL COORDINATE Z AXIS(Stage1) Collect Result_Dam',
                  'HEAD NORMAL COORDINATE Z AXIS(Stage2) Collect Result_Dam',
                  'HEAD NORMAL COORDINATE Z AXIS(Stage3) Collect Result_Dam'],
                 ['HEAD NORMAL COORDINATE X AXIS(Stage1) Collect Result_Fill1',
                  'HEAD NORMAL COORDINATE X AXIS(Stage2) Collect Result_Fill1',
                  'HEAD NORMAL COORDINATE X AXIS(Stage3) Collect Result_Fill1'],
                 ['HEAD NORMAL COORDINATE Y AXIS(Stage1) Collect Result_Fill1',
                  'HEAD NORMAL COORDINATE Y AXIS(Stage2) Collect Result_Fill1',
                  'HEAD NORMAL COORDINATE Y AXIS(Stage3) Collect Result_Fill1'],
                 ['HEAD NORMAL COORDINATE Z AXIS(Stage1) Collect Result_Fill1',
                  'HEAD NORMAL COORDINATE Z AXIS(Stage2) Collect Result_Fill1',
                  'HEAD NORMAL COORDINATE Z AXIS(Stage3) Collect Result_Fill1'],
                 ['HEAD NORMAL COORDINATE X AXIS(Stage1) Collect Result_Fill2',
                  'HEAD NORMAL COORDINATE X AXIS(Stage2) Collect Result_Fill2',
                  'HEAD NORMAL COORDINATE X AXIS(Stage3) Collect Result_Fill2'],
                 ['HEAD NORMAL COORDINATE Y AXIS(Stage1) Collect Result_Fill2',
                  'HEAD NORMAL COORDINATE Y AXIS(Stage2) Collect Result_Fill2',
                  'HEAD NORMAL COORDINATE Y AXIS(Stage3) Collect Result_Fill2'],
                 ['HEAD NORMAL COORDINATE Z AXIS(Stage1) Collect Result_Fill2',
                  'HEAD NORMAL COORDINATE Z AXIS(Stage2) Collect Result_Fill2',
                  'HEAD NORMAL COORDINATE Z AXIS(Stage3) Collect Result_Fill2']]
new_col = []
for col_set in stage_col_set:
  colname = col_set[0].replace('1)', ')')
  new_col.append(colname)
  train_data[colname] = list(train_data[col_set].itertuples(index=False, name=None))
  train_data[colname] = train_data[colname].astype(str)
  test[colname] = list(test[col_set].itertuples(index=False, name=None))
  test[colname] = test[colname].astype(str)

# %%
import re
coordinate_groups = {}

head_dam_XYZ_col = []
head_fill1_XYZ_col = []
head_fill2_XYZ_col = []

cure_XYZ_col = []

# filtered_columns = [col for col in column_names if 'CURE' not in col]




for col in pos_col:
    # 정규 표현식을 사용하여 X, Y, Z 부분을 찾고, 공통 이름을 추출
    match = re.match(r'(.*?)(\bX\b|\bY\b|\bZ\b)(.*)', col)
    if match:
        base_name = match.group(1).strip() + ' ' + match.group(3).strip()
        if base_name not in coordinate_groups:
            coordinate_groups[base_name] = {}
        coordinate_groups[base_name][match.group(2)] = col

# 각 그룹에 대해 가능한 X, Y, Z 좌표를 묶어서 새로운 컬럼 추가
for base_name, coords in coordinate_groups.items():
    # 기존 컬럼 중 존재하는 X, Y, Z 값을 가져와서 묶기
    grouped_columns_train = []
    grouped_columns_test = []
    for coord in ['X', 'Y', 'Z']:
        if coord in coords:
            grouped_columns_train.append(train_data[coords[coord]])
            grouped_columns_test.append(test[coords[coord]])
        else:
            grouped_columns_train.append([None] * len(train_data))  # 해당 컬럼이 없으면 None으로 채움
            grouped_columns_test.append([None] * len(test))
    # 새로운 (X, Y, Z) 튜플 컬럼 생성
    train_data[f'{base_name} XYZ'] = [str(tup) for tup in list(zip(*grouped_columns_train))] 
    test[f'{base_name} XYZ'] = [str(tup) for tup in list(zip(*grouped_columns_test))]
    if 'head' in base_name.lower():
        if 'dam' in base_name.lower():
            head_dam_XYZ_col.append(f'{base_name} XYZ')
        if 'fill1' in base_name.lower():
            head_fill1_XYZ_col.append(f'{base_name} XYZ')
        if 'fill2' in base_name.lower():
            head_fill2_XYZ_col.append(f'{base_name} XYZ')
    
            
    # else:
    #     cure_XYZ_col.append(f'{base_name} XYZ')
    
    # 기존의 X, Y, Z 컬럼 제거
    train_data.drop(columns=list(coords.values()), inplace=True)
    test.drop(columns=list(coords.values()), inplace=True)

# %%
train_data
# Out:
#           Equipment_Dam    Collect Date_Dam  \
# 0      Dam dispenser #1 2024-04-25 11:10:00
# 1      Dam dispenser #1 2023-09-19 14:30:00
# 2      Dam dispenser #2 2024-03-05 09:30:00
# 3      Dam dispenser #2 2023-09-25 15:40:00
# 4      Dam dispenser #1 2023-06-27 13:20:00
# ...                 ...                 ...
# 40501  Dam dispenser #1 2023-09-14 15:50:00
# 40502  Dam dispenser #2 2024-04-10 14:20:00
# 40503  Dam dispenser #1 2024-02-22 08:40:00
# 40504  Dam dispenser #2 2023-07-25 11:00:00
# 40505  Dam dispenser #1 2023-05-31 01:40:00
#
#        CURE END POSITION X Collect Result_Dam  \
# 0                                       240.0
# 1                                       240.0
# 2                                      1000.0
# 3                                      1000.0
# 4                                       240.0
# ...                                       ...
# 40501                                   240.0
# 40502                                  1000.0
# 40503                                   240.0
# 40504                                  1000.0
# 40505                                   240.0
#
#        CURE END POSITION Z Collect Result_Dam  \
# 0                                         2.5
# 1                                         2.5
# 2                                        12.5
# 3                                        12.5
# 4                                         2.5
# ...                                       ...
# 40501                                     2.5
# 40502                                    12.5
# 40503                                     2.5
# 40504                                    12.5
# 40505                                     2.5
#
#        CURE END POSITION Θ Collect Result_Dam  CURE SPEED Collect Result_Dam  \
# 0                                         -90                            100
# 1                                         -90                             70
# 2                                          90                             85
# 3                                          90                             70
# 4                                         -90                             70
# ...                                       ...                            ...
# 40501                                     -90                             70
# 40502                                      90                            100
# 40503                                     -90                            100
# 40504                                      90                             70
# 40505                                     -90                             70
#
#        CURE START POSITION X Collect Result_Dam  \
# 0                                          1030
# 1                                          1030
# 2                                           280
# 3                                           280
# 4                                          1030
# ...                                         ...
# 40501                                      1030
# 40502                                       280
# 40503                                      1030
# 40504                                       280
# 40505                                      1030
#
#        CURE START POSITION Θ Collect Result_Dam  \
# 0                                           -90
# 1                                           -90
# 2                                            90
# 3                                            90
# 4                                           -90
# ...                                         ...
# 40501                                       -90
# 40502                                        90
# 40503                                       -90
# 40504                                        90
# 40505                                       -90
#
#        DISCHARGED SPEED OF RESIN Collect Result_Dam  \
# 0                                                16
# 1                                                10
# 2                                                16
# 3                                                10
# 4                                                10
# ...                                             ...
# 40501                                            10
# 40502                                            16
# 40503                                            16
# 40504                                            10
# 40505                                            10
#
#        DISCHARGED TIME OF RESIN(Stage1) Collect Result_Dam  \
# 0                                                   14.9
# 1                                                   21.3
# 2                                                   14.7
# 3                                                   21.3
# 4                                                    9.7
# ...                                                  ...
# 40501                                               17.0
# 40502                                               14.9
# 40503                                               14.2
# 40504                                                9.7
# 40505                                                9.6
#
#        DISCHARGED TIME OF RESIN(Stage2) Collect Result_Dam  \
# 0                                                    8.4
# 1                                                    4.9
# 2                                                    8.5
# 3                                                    8.4
# 4                                                    4.9
# ...                                                  ...
# 40501                                                5.0
# 40502                                                8.5
# 40503                                                8.2
# 40504                                                4.9
# 40505                                                3.9
#
#        DISCHARGED TIME OF RESIN(Stage3) Collect Result_Dam  \
# 0                                                   14.7
# 1                                                   21.3
# 2                                                   14.7
# 3                                                   21.3
# 4                                                    9.6
# ...                                                  ...
# 40501                                               17.0
# 40502                                               14.7
# 40503                                               14.3
# 40504                                                9.7
# 40505                                                9.7
#
#        Dispense Volume(Stage1) Collect Result_Dam  \
# 0                                            1.04
# 1                                            1.49
# 2                                            1.61
# 3                                            1.49
# 4                                            0.67
# ...                                           ...
# 40501                                        1.19
# 40502                                        1.04
# 40503                                        0.99
# 40504                                        0.67
# 40505                                        0.67
#
#        Dispense Volume(Stage2) Collect Result_Dam  \
# 0                                            0.58
# 1                                            0.34
# 2                                            0.93
# 3                                            0.58
# 4                                            0.34
# ...                                           ...
# 40501                                        0.35
# 40502                                        0.59
# 40503                                        0.57
# 40504                                        0.34
# 40505                                        0.27
#
#        Dispense Volume(Stage3) Collect Result_Dam  \
# 0                                            1.02
# 1                                            1.49
# 2                                            1.61
# 3                                            1.49
# 4                                            0.67
# ...                                           ...
# 40501                                        1.19
# 40502                                        1.02
# 40503                                        1.00
# 40504                                        0.67
# 40505                                        0.67
#
#        Machine Tact time Collect Result_Dam  PalletID Collect Result_Dam  \
# 0                                    265.00                         58.5
# 1                                     65.10                          7.0
# 2                                    265.02                         76.9
# 3                                     70.50                         12.0
# 4                                     88.30                          8.0
# ...                                     ...                          ...
# 40501                                 56.70                          1.0
# 40502                                265.00                         78.5
# 40503                                265.02                         69.5
# 40504                                 57.70                         13.0
# 40505                                 92.10                          3.0
#
#        Production Qty Collect Result_Dam  Receip No Collect Result_Dam  \
# 0                                      7                           127
# 1                                    185                             1
# 2                                     10                            73
# 3                                    268                             1
# 4                                    121                             1
# ...                                  ...                           ...
# 40501                                318                             1
# 40502                                 14                           197
# 40503                                  1                            27
# 40504                                117                             1
# 40505                                320                             1
#
#        Stage1 Circle1 Distance Speed Collect Result_Dam  \
# 0                                                     1
# 1                                                  4000
# 2                                                     1
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                                 1
# 40503                                                 1
# 40504                                              9000
# 40505                                              9000
#
#        Stage1 Circle2 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage1 Circle3 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage1 Circle4 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage1 Line1 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage1 Line2 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage1 Line3 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage1 Line4 Distance Speed Collect Result_Dam  \
# 0                                                5600
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5600
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage2 Circle1 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  9000
# 2                                                  5800
# 3                                                  5000
# 4                                                  9000
# ...                                                 ...
# 40501                                              9000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                             12000
#
#        Stage2 Circle2 Distance Speed Collect Result_Dam  \
# 0                                                  5300
# 1                                                  9000
# 2                                                  5300
# 3                                                  5000
# 4                                                  9000
# ...                                                 ...
# 40501                                              9000
# 40502                                              5300
# 40503                                              5500
# 40504                                              9000
# 40505                                             12000
#
#        Stage2 Circle3 Distance Speed Collect Result_Dam  \
# 0                                                  5300
# 1                                                  9000
# 2                                                  5300
# 3                                                  5000
# 4                                                  9000
# ...                                                 ...
# 40501                                              9000
# 40502                                              5300
# 40503                                              5500
# 40504                                              9000
# 40505                                             12000
#
#        Stage2 Circle4 Distance Speed Collect Result_Dam  \
# 0                                                  5300
# 1                                                  9000
# 2                                                  5300
# 3                                                  5000
# 4                                                  9000
# ...                                                 ...
# 40501                                              9000
# 40502                                              5300
# 40503                                              5500
# 40504                                              9000
# 40505                                             12000
#
#        Stage2 Line1 Distance Speed Collect Result_Dam  \
# 0                                                5300
# 1                                                9000
# 2                                                5300
# 3                                                5000
# 4                                                9000
# ...                                               ...
# 40501                                            9000
# 40502                                            5300
# 40503                                            5500
# 40504                                            9000
# 40505                                           12000
#
#        Stage2 Line2 Distance Speed Collect Result_Dam  \
# 0                                                5300
# 1                                                9000
# 2                                                5300
# 3                                                5000
# 4                                                9000
# ...                                               ...
# 40501                                            9000
# 40502                                            5300
# 40503                                            5500
# 40504                                            9000
# 40505                                           12000
#
#        Stage2 Line3 Distance Speed Collect Result_Dam  \
# 0                                                5300
# 1                                                9000
# 2                                                5300
# 3                                                5000
# 4                                                9000
# ...                                               ...
# 40501                                            9000
# 40502                                            5300
# 40503                                            5500
# 40504                                            9000
# 40505                                           12000
#
#        Stage2 Line4 Distance Speed Collect Result_Dam  \
# 0                                                5300
# 1                                                9000
# 2                                                5300
# 3                                                5000
# 4                                                9000
# ...                                               ...
# 40501                                            9000
# 40502                                            5300
# 40503                                            5500
# 40504                                            9000
# 40505                                           12000
#
#        Stage3 Circle1 Distance Speed Collect Result_Dam  \
# 0                                                  5300
# 1                                                  4000
# 2                                                  5300
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5300
# 40503                                              5500
# 40504                                              9000
# 40505                                              9000
#
#        Stage3 Circle2 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage3 Circle3 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage3 Circle4 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage3 Line1 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage3 Line2 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage3 Line3 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage3 Line4 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        THICKNESS 1 Collect Result_Dam  THICKNESS 2 Collect Result_Dam  \
# 0                                5800                           0.000
# 1                                   0                           0.000
# 2                                5800                           0.012
# 3                                   0                           0.000
# 4                                   0                           0.000
# ...                               ...                             ...
# 40501                               0                           0.000
# 40502                            5800                          -0.019
# 40503                            6000                           0.000
# 40504                               0                           0.000
# 40505                               0                           0.000
#
#        THICKNESS 3 Collect Result_Dam  WorkMode Collect Result_Dam  \
# 0                               0.000                        0.000
# 1                               0.000                        7.000
# 2                              -0.022                        0.003
# 3                               0.000                        7.000
# 4                               0.000                        7.000
# ...                               ...                          ...
# 40501                           0.000                        7.000
# 40502                          -0.021                       -0.118
# 40503                           0.000                        0.000
# 40504                           0.000                        7.000
# 40505                           0.000                        7.000
#
#       Collect Date_AutoClave  1st Pressure Collect Result_AutoClave  \
# 0        2024-04-25 11:50:00                                  0.312
# 1        2023-09-19 15:00:00                                  0.311
# 2        2024-03-05 10:10:00                                  0.315
# 3        2023-09-25 16:20:00                                  0.299
# 4        2023-06-27 14:00:00                                  0.302
# ...                      ...                                    ...
# 40501    2023-09-14 16:30:00                                  0.300
# 40502    2024-04-10 15:00:00                                  0.305
# 40503    2024-02-22 09:20:00                                  0.309
# 40504    2023-07-25 11:40:00                                  0.302
# 40505    2023-05-31 02:10:00                                  0.305
#
#        1st Pressure 1st Pressure Unit Time_AutoClave  \
# 0                                                240
# 1                                                241
# 2                                                241
# 3                                                241
# 4                                                240
# ...                                              ...
# 40501                                            241
# 40502                                            240
# 40503                                            241
# 40504                                            241
# 40505                                            300
#
#        2nd Pressure Collect Result_AutoClave  \
# 0                                      0.493
# 1                                      0.311
# 2                                      0.490
# 3                                      0.300
# 4                                      0.302
# ...                                      ...
# 40501                                  0.300
# 40502                                  0.493
# 40503                                  0.490
# 40504                                  0.303
# 40505                                  0.305
#
#        2nd Pressure Unit Time_AutoClave  \
# 0                                     1
# 1                                   121
# 2                                     1
# 3                                   121
# 4                                   120
# ...                                 ...
# 40501                               121
# 40502                                 1
# 40503                                 1
# 40504                               121
# 40505                                60
#
#        3rd Pressure Collect Result_AutoClave  \
# 0                                      0.499
# 1                                      0.498
# 2                                      0.498
# 3                                      0.500
# 4                                      0.498
# ...                                      ...
# 40501                                  0.500
# 40502                                  0.498
# 40503                                  0.498
# 40504                                  0.499
# 40505                                  0.498
#
#        3rd Pressure Unit Time_AutoClave  \
# 0                                   120
# 1                                   121
# 2                                   121
# 3                                   121
# 4                                   120
# ...                                 ...
# 40501                               121
# 40502                               120
# 40503                               121
# 40504                               121
# 40505                               120
#
#        Chamber Temp. Collect Result_AutoClave  \
# 0                                          54
# 1                                          54
# 2                                          56
# 3                                          54
# 4                                          47
# ...                                       ...
# 40501                                      54
# 40502                                      49
# 40503                                      48
# 40504                                      54
# 40505                                      47
#
#        Chamber Temp. Unit Time_AutoClave Chamber Temp. Judge Value_AutoClave  \
# 0                                    361                                  OK
# 1                                    483                                  OK
# 2                                    363                                  OK
# 3                                    483                                  OK
# 4                                    480                                  NG
# ...                                  ...                                 ...
# 40501                                483                                  OK
# 40502                                361                                  NG
# 40503                                363                                  NG
# 40504                                483                                  OK
# 40505                                480                                  NG
#
#           Equipment_Fill1   Collect Date_Fill1  \
# 0      Fill1 dispenser #1  2024-04-25 11:20:00
# 1      Fill1 dispenser #1  2023-09-19 14:30:00
# 2      Fill1 dispenser #2  2024-03-05 09:30:00
# 3      Fill1 dispenser #2  2023-09-25 15:40:00
# 4      Fill1 dispenser #1  2023-06-27 13:20:00
# ...                   ...                  ...
# 40501  Fill1 dispenser #1  2023-09-14 15:50:00
# 40502  Fill1 dispenser #2  2024-04-10 14:20:00
# 40503  Fill1 dispenser #1  2024-02-22 08:50:00
# 40504  Fill1 dispenser #2  2023-07-25 11:00:00
# 40505  Fill1 dispenser #1  2023-05-31 01:40:00
#
#        DISCHARGED SPEED OF RESIN Collect Result_Fill1  \
# 0                                                10.6
# 1                                                10.6
# 2                                                10.6
# 3                                                10.6
# 4                                                10.6
# ...                                               ...
# 40501                                            10.6
# 40502                                            10.6
# 40503                                            10.6
# 40504                                            10.6
# 40505                                            10.9
#
#        DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill1  \
# 0                                                   12.7
# 1                                                   13.5
# 2                                                   13.5
# 3                                                   13.5
# 4                                                   13.5
# ...                                                  ...
# 40501                                               13.5
# 40502                                               13.5
# 40503                                               12.9
# 40504                                               13.5
# 40505                                               13.4
#
#        DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill1  \
# 0                                                    3.6
# 1                                                    3.6
# 2                                                    3.5
# 3                                                    3.6
# 4                                                    3.6
# ...                                                  ...
# 40501                                                3.6
# 40502                                                3.6
# 40503                                                3.6
# 40504                                                3.6
# 40505                                                5.0
#
#        DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill1  \
# 0                                                   12.6
# 1                                                   13.5
# 2                                                   13.4
# 3                                                   13.5
# 4                                                   13.5
# ...                                                  ...
# 40501                                               13.5
# 40502                                               13.5
# 40503                                               12.9
# 40504                                               13.4
# 40505                                               13.4
#
#        Dispense Volume(Stage1) Collect Result_Fill1  \
# 0                                             12.06
# 1                                             12.82
# 2                                             12.82
# 3                                             12.82
# 4                                             12.82
# ...                                             ...
# 40501                                         12.82
# 40502                                         12.82
# 40503                                         12.25
# 40504                                         12.82
# 40505                                         12.73
#
#        Dispense Volume(Stage2) Collect Result_Fill1  \
# 0                                              3.42
# 1                                              3.42
# 2                                              3.32
# 3                                              3.42
# 4                                              3.42
# ...                                             ...
# 40501                                          3.42
# 40502                                          3.42
# 40503                                          3.42
# 40504                                          3.42
# 40505                                          4.75
#
#        Dispense Volume(Stage3) Collect Result_Fill1  \
# 0                                             11.97
# 1                                             12.82
# 2                                             12.73
# 3                                             12.82
# 4                                             12.82
# ...                                             ...
# 40501                                         12.82
# 40502                                         12.82
# 40503                                         12.25
# 40504                                         12.73
# 40505                                         12.73
#
#        Machine Tact time Collect Result_Fill1  PalletID Collect Result_Fill1  \
# 0                                       128.0                           55.7
# 1                                        56.5                            7.0
# 2                                       128.0                           58.7
# 3                                        57.7                           12.0
# 4                                        89.9                            8.0
# ...                                       ...                            ...
# 40501                                    51.8                            1.0
# 40502                                   128.0                           58.7
# 40503                                   128.0                           56.2
# 40504                                    57.4                           13.0
# 40505                                    91.5                            3.0
#
#        Production Qty Collect Result_Fill1  Receip No Collect Result_Fill1  \
# 0                                        7                             127
# 1                                      185                               1
# 2                                       10                              73
# 3                                      268                               1
# 4                                      121                               1
# ...                                    ...                             ...
# 40501                                  318                               1
# 40502                                   14                             197
# 40503                                    1                              27
# 40504                                  117                               1
# 40505                                  320                               1
#
#        WorkMode Collect Result_Fill1     Equipment_Fill2   Collect Date_Fill2  \
# 0                                  1  Fill2 dispenser #1  2024-04-25 11:20:00
# 1                                  7  Fill2 dispenser #1  2023-09-19 14:30:00
# 2                                  1  Fill2 dispenser #2  2024-03-05 09:30:00
# 3                                  7  Fill2 dispenser #2  2023-09-25 15:40:00
# 4                                  7  Fill2 dispenser #1  2023-06-27 13:20:00
# ...                              ...                 ...                  ...
# 40501                              7  Fill2 dispenser #1  2023-09-14 15:50:00
# 40502                              1  Fill2 dispenser #2  2024-04-10 14:20:00
# 40503                              1  Fill2 dispenser #1  2024-02-22 08:50:00
# 40504                              7  Fill2 dispenser #2  2023-07-25 11:00:00
# 40505                              7  Fill2 dispenser #1  2023-05-31 01:40:00
#
#        CURE END POSITION X Collect Result_Fill2  \
# 0                                           240
# 1                                           240
# 2                                           240
# 3                                           240
# 4                                           240
# ...                                         ...
# 40501                                       240
# 40502                                       240
# 40503                                       240
# 40504                                       240
# 40505                                       240
#
#        CURE END POSITION Z Collect Result_Fill2  \
# 0                                            33
# 1                                            33
# 2                                            33
# 3                                            33
# 4                                            32
# ...                                         ...
# 40501                                        33
# 40502                                        33
# 40503                                        33
# 40504                                        33
# 40505                                        32
#
#        CURE SPEED Collect Result_Fill2  \
# 0                                   48
# 1                                   50
# 2                                   50
# 3                                   50
# 4                                   50
# ...                                ...
# 40501                               50
# 40502                               48
# 40503                               50
# 40504                               50
# 40505                               50
#
#        CURE STANDBY POSITION Z Collect Result_Fill2  \
# 0                                                33
# 1                                                33
# 2                                                33
# 3                                                33
# 4                                                33
# ...                                             ...
# 40501                                            33
# 40502                                            33
# 40503                                            33
# 40504                                            33
# 40505                                            32
#
#        CURE START POSITION X Collect Result_Fill2  \
# 0                                            1020
# 1                                            1020
# 2                                            1020
# 3                                            1020
# 4                                            1020
# ...                                           ...
# 40501                                        1020
# 40502                                        1020
# 40503                                        1020
# 40504                                        1020
# 40505                                        1020
#
#        CURE START POSITION Z Collect Result_Fill2  \
# 0                                              33
# 1                                              33
# 2                                              33
# 3                                              33
# 4                                              33
# ...                                           ...
# 40501                                          33
# 40502                                          33
# 40503                                          33
# 40504                                          33
# 40505                                          32
#
#        Machine Tact time Collect Result_Fill2  PalletID Collect Result_Fill2  \
# 0                                     114.612                           19.9
# 1                                      19.600                            7.0
# 2                                     114.612                           19.8
# 3                                      19.900                           12.0
# 4                                      19.700                            8.0
# ...                                       ...                            ...
# 40501                                  19.200                            1.0
# 40502                                 114.612                           20.5
# 40503                                  85.000                           19.7
# 40504                                  20.100                           13.0
# 40505                                  19.400                            3.0
#
#        Production Qty Collect Result_Fill2  Receip No Collect Result_Fill2  \
# 0                                        7                             127
# 1                                      185                               1
# 2                                       10                              73
# 3                                      268                               1
# 4                                      121                               1
# ...                                    ...                             ...
# 40501                                  318                               1
# ...
# ...                                                  ...
# 40501                              (428.0, 427.9, 428.0)
# 40502                            (692.8, 1324.2, 1324.2)
# 40503                              (156.0, 428.0, 427.9)
# 40504                           (1324.2, 1324.2, 1324.2)
# 40505                              (428.0, 427.9, 428.0)
#
#       HEAD NORMAL COORDINATE Z AXIS(Stage) Collect Result_Fill2  \
# 0                                  (428.0, 243.7, 243.7)
# 1                                  (243.7, 243.7, 243.7)
# 2                                 (1324.2, 243.5, 243.5)
# 3                                  (243.5, 243.5, 243.5)
# 4                                  (243.7, 243.7, 243.7)
# ...                                                  ...
# 40501                              (243.7, 243.7, 243.7)
# 40502                             (1324.2, 243.5, 243.5)
# 40503                              (428.0, 243.7, 243.7)
# 40504                              (243.5, 243.5, 243.5)
# 40505                              (243.7, 243.7, 243.7)
#
#       HEAD NORMAL COORDINATE AXIS(Stage1) Collect Result_Dam XYZ  \
# 0                                  (161.0, 161.4, 384.0)
# 1                                 (550.3, 377.3, 282.15)
# 2                                 (550.4, 551.7, 1271.8)
# 3                                (162.4, 1271.8, 282.15)
# 4                                  (549.0, 377.5, 284.8)
# ...                                                  ...
# 40501                             (550.3, 377.3, 282.15)
# 40502                             (550.4, 553.1, 1281.2)
# 40503                              (161.0, 161.5, 378.0)
# 40504                            (162.4, 1269.0, 282.15)
# 40505                              (549.0, 377.5, 284.8)
#
#       HEAD NORMAL COORDINATE AXIS(Stage1) Judge Value_Dam XYZ  \
# 0                                    ('nan', None, None)
# 1                                     ('NG', None, None)
# 2                                     ('OK', None, None)
# 3                                     ('NG', None, None)
# 4                                     ('NG', None, None)
# ...                                                  ...
# 40501                                 ('NG', None, None)
# 40502                                ('nan', None, None)
# 40503                                 ('OK', None, None)
# 40504                                 ('NG', None, None)
# 40505                                 ('NG', None, None)
#
#       HEAD NORMAL COORDINATE AXIS(Stage2) Collect Result_Dam XYZ  \
# 0                                 (550.5, 384.0, 274.51)
# 1                                 (463.8, 377.3, 282.15)
# 2                                (162.4, 1271.8, 274.33)
# 3                                (465.5, 1270.7, 282.15)
# 4                                  (462.5, 377.0, 284.8)
# ...                                                  ...
# 40501                             (463.8, 377.3, 282.15)
# 40502                            (163.5, 1281.0, 274.33)
# 40503                             (550.6, 377.6, 274.78)
# 40504                            (465.1, 1268.4, 282.15)
# 40505                              (463.0, 377.0, 284.8)
#
#       HEAD NORMAL COORDINATE AXIS(Stage3) Collect Result_Dam XYZ  \
# 0                                 (464.3, 383.1, 274.51)
# 1                                 (160.8, 377.3, 282.15)
# 2                                (465.4, 1383.9, 274.33)
# 3                                (552.0, 1271.8, 282.15)
# 4                                  (159.5, 377.5, 284.8)
# ...                                                  ...
# 40501                             (160.8, 377.3, 282.15)
# 40502                            (466.2, 1393.5, 274.33)
# 40503                             (463.9, 377.1, 274.78)
# 40504                            (551.3, 1269.0, 282.15)
# 40505                              (160.5, 377.5, 284.8)
#
#       HEAD Standby Position Collect Result_Dam XYZ  \
# 0                                (274.51, 257, 66)
# 1                                   (257.0, 66, 0)
# 2                                (274.33, 257, 66)
# 3                                   (257.0, 66, 0)
# 4                                   (257.0, 66, 0)
# ...                                            ...
# 40501                               (257.0, 66, 0)
# 40502                            (274.33, 257, 66)
# 40503                            (274.78, 257, 66)
# 40504                               (257.0, 66, 0)
# 40505                               (257.0, 66, 0)
#
#       Head Clean Position Collect Result_Dam XYZ  \
# 0                             (0.0, 127.5, 66.0)
# 1                          (127.5, 66.0, 130.85)
# 2                             (0.0, 127.5, 66.0)
# 3                          (127.5, 66.0, 130.85)
# 4                           (127.5, 66.0, 133.5)
# ...                                          ...
# 40501                      (127.5, 66.0, 130.85)
# 40502                         (0.0, 127.5, 66.0)
# 40503                         (0.0, 127.5, 66.0)
# 40504                      (127.5, 66.0, 130.85)
# 40505                       (127.5, 66.0, 133.5)
#
#       Head Purge Position Collect Result_Dam XYZ  \
# 0                             (124.0, 257, 66.0)
# 1                            (257.0, 66, 130.85)
# 2                             (124.0, 257, 66.0)
# 3                            (257.0, 66, 130.85)
# 4                             (257.0, 66, 133.5)
# ...                                          ...
# 40501                        (257.0, 66, 130.85)
# 40502                         (124.0, 257, 66.0)
# 40503                         (124.0, 257, 66.0)
# 40504                        (257.0, 66, 130.85)
# 40505                         (257.0, 66, 133.5)
#
#       Head Zero Position Collect Result_Dam XYZ  \
# 0                        (130.85, 505.0, 300.0)
# 1                         (505.0, 300.0, 265.0)
# 2                        (130.85, 505.0, 300.0)
# 3                         (505.0, 300.0, 265.0)
# 4                         (505.0, 300.0, 265.0)
# ...                                         ...
# 40501                     (505.0, 300.0, 265.0)
# 40502                    (130.85, 505.0, 300.0)
# 40503                    (130.85, 505.0, 300.0)
# 40504                     (505.0, 300.0, 265.0)
# 40505                     (505.0, 303.5, 265.0)
#
#       HEAD NORMAL COORDINATE AXIS(Stage1) Collect Result_Fill1 XYZ  \
# 0                                  (157.0, 157.0, 430.3)
# 1                                  (838.4, 430.5, 244.4)
# 2                                 (157.0, 156.1, 1323.1)
# 3                                 (837.7, 1323.2, 244.3)
# 4                                  (838.4, 430.2, 244.4)
# ...                                                  ...
# 40501                              (838.4, 430.5, 244.4)
# 40502                             (157.0, 156.1, 1324.3)
# 40503                              (157.0, 157.0, 431.1)
# 40504                             (837.7, 1323.2, 244.4)
# 40505                              (837.9, 430.2, 244.3)
#
#       HEAD NORMAL COORDINATE AXIS(Stage2) Collect Result_Fill1 XYZ  \
# 0                                 (838.4, 430.0, 244.52)
# 1                                  (458.5, 430.5, 244.4)
# 2                               (837.9, 1323.5, 244.415)
# 3                                 (458.8, 1322.5, 244.3)
# 4                                  (458.5, 430.5, 244.4)
# ...                                                  ...
# 40501                              (458.5, 430.5, 244.4)
# 40502                           (838.1, 1325.0, 244.535)
# 40503                            (838.4, 430.8, 244.543)
# 40504                             (458.8, 1323.0, 244.4)
# 40505                              (460.0, 430.5, 244.3)
#
#       HEAD NORMAL COORDINATE AXIS(Stage3) Collect Result_Fill1 XYZ  \
# 0                                 (458.7, 429.8, 244.52)
# 1                                  (157.0, 430.8, 244.4)
# 2                               (458.1, 1322.5, 244.415)
# 3                                 (157.0, 1322.8, 244.3)
# 4                                  (157.0, 430.5, 244.4)
# ...                                                  ...
# 40501                              (157.0, 430.8, 244.4)
# 40502                           (458.7, 1324.0, 244.535)
# 40503                            (458.4, 430.5, 244.543)
# 40504                             (157.0, 1322.8, 244.4)
# 40505                              (157.5, 430.5, 244.3)
#
#       HEAD Standby Position Collect Result_Fill1 XYZ  \
# 0                                  (244.52, 289, 50)
# 1                                     (289.0, 50, 0)
# 2                                 (244.415, 289, 50)
# 3                                     (289.0, 50, 0)
# 4                                     (289.0, 50, 0)
# ...                                              ...
# 40501                                 (289.0, 50, 0)
# 40502                             (244.535, 289, 50)
# 40503                             (244.543, 289, 50)
# 40504                                 (289.0, 50, 0)
# 40505                                 (289.0, 50, 0)
#
#       Head Clean Position Collect Result_Fill1 XYZ  \
# 0                               (0.0, 123.4, 50.0)
# 1                              (123.4, 50.0, 92.2)
# 2                               (0.0, 123.4, 50.0)
# 3                              (123.4, 50.0, 92.2)
# 4                              (123.4, 50.0, 92.2)
# ...                                            ...
# 40501                          (123.4, 50.0, 92.2)
# 40502                           (0.0, 123.4, 50.0)
# 40503                           (0.0, 123.4, 50.0)
# 40504                          (123.4, 50.0, 92.2)
# 40505                          (123.4, 50.0, 92.2)
#
#       Head Purge Position Collect Result_Fill1 XYZ  \
# 0                                  (92.2, 289, 50)
# 1                                 (289.0, 50, 145)
# 2                                  (92.2, 289, 50)
# 3                                 (289.0, 50, 145)
# 4                                  (289.0, 50, 85)
# ...                                            ...
# 40501                             (289.0, 50, 145)
# 40502                              (92.2, 289, 50)
# 40503                              (92.2, 289, 50)
# 40504                             (289.0, 50, 145)
# 40505                              (289.0, 50, 85)
#
#       HEAD NORMAL COORDINATE AXIS(Stage1) Collect Result_Fill2 XYZ  \
# 0                                  (156.0, 156.0, 428.0)
# 1                                  (835.5, 428.0, 243.7)
# 2                                 (694.0, 694.0, 1324.2)
# 3                                 (305.0, 1324.2, 243.5)
# 4                                  (835.5, 428.0, 243.7)
# ...                                                  ...
# 40501                              (835.5, 428.0, 243.7)
# 40502                             (694.0, 692.8, 1324.2)
# 40503                              (156.0, 156.0, 428.0)
# 40504                             (305.0, 1324.2, 243.5)
# 40505                              (835.5, 428.0, 243.7)
#
#       HEAD NORMAL COORDINATE AXIS(Stage2) Collect Result_Fill2 XYZ  \
# 0                                  (835.5, 428.0, 243.7)
# 1                                  (458.0, 427.9, 243.7)
# 2                                 (305.0, 1324.2, 243.5)
# 3                                 (499.8, 1324.2, 243.5)
# 4                                  (458.0, 427.9, 243.7)
# ...                                                  ...
# 40501                              (458.0, 427.9, 243.7)
# 40502                             (304.8, 1324.2, 243.5)
# 40503                              (835.5, 428.0, 243.7)
# 40504                             (499.8, 1324.2, 243.5)
# 40505                              (458.0, 427.9, 243.7)
#
#       HEAD NORMAL COORDINATE AXIS(Stage3) Collect Result_Fill2 XYZ  \
# 0                                  (458.0, 427.9, 243.7)
# 1                                  (156.0, 428.0, 243.7)
# 2                                 (499.8, 1324.2, 243.5)
# 3                                 (694.0, 1324.2, 243.5)
# 4                                  (156.0, 428.0, 243.7)
# ...                                                  ...
# 40501                              (156.0, 428.0, 243.7)
# 40502                             (499.8, 1324.2, 243.5)
# 40503                              (458.0, 427.9, 243.7)
# 40504                             (694.0, 1324.2, 243.5)
# 40505                              (156.0, 428.0, 243.7)
#
#       HEAD Standby Position Collect Result_Fill2 XYZ  \
# 0                                   (243.7, 270, 50)
# 1                                   (270.0, 50, -10)
# 2                                   (243.5, 270, 50)
# 3                                   (270.0, 50, -10)
# 4                                   (270.0, 50, -10)
# ...                                              ...
# 40501                               (270.0, 50, -10)
# 40502                               (243.5, 270, 50)
# 40503                               (243.7, 270, 50)
# 40504                               (270.0, 50, -10)
# 40505                               (270.0, 50, -10)
#
#       Head Clean Position Collect Result_Fill2 XYZ  \
# 0                                 (-10, 119, 50.0)
# 1                                  (119, 50, 91.8)
# 2                                 (-10, 119, 50.0)
# 3                                  (119, 50, 91.8)
# 4                                  (119, 50, 91.8)
# ...                                            ...
# 40501                              (119, 50, 91.8)
# 40502                             (-10, 119, 50.0)
# 40503                             (-10, 119, 50.0)
# 40504                              (119, 50, 91.8)
# 40505                              (119, 50, 91.8)
#
#       Head Purge Position Collect Result_Fill2 XYZ
# 0                                  (91.8, 270, 50)
# 1                                  (270.0, 50, 85)
# 2                                  (91.8, 270, 50)
# 3                                  (270.0, 50, 85)
# 4                                  (270.0, 50, 85)
# ...                                            ...
# 40501                              (270.0, 50, 85)
# 40502                              (91.8, 270, 50)
# 40503                              (91.8, 270, 50)
# 40504                              (270.0, 50, 85)
# 40505                              (270.0, 50, 85)
#
# [40506 rows x 140 columns]

# %%
head_dam_XYZ_col
# Out:
# ['HEAD NORMAL COORDINATE AXIS(Stage1) Collect Result_Dam XYZ',
#  'HEAD NORMAL COORDINATE AXIS(Stage1) Judge Value_Dam XYZ',
#  'HEAD NORMAL COORDINATE AXIS(Stage2) Collect Result_Dam XYZ',
#  'HEAD NORMAL COORDINATE AXIS(Stage3) Collect Result_Dam XYZ',
#  'HEAD Standby Position Collect Result_Dam XYZ',
#  'Head Clean Position Collect Result_Dam XYZ',
#  'Head Purge Position Collect Result_Dam XYZ',
#  'Head Zero Position Collect Result_Dam XYZ']

# %%
del head_dam_XYZ_col[1]  #Judge 제외
del head_dam_XYZ_col[-1] # Zero 제외
 

head_XYZ_col = head_dam_XYZ_col + head_fill1_XYZ_col + head_fill2_XYZ_col 

head_dam_XYZ_col = [head_dam_XYZ_col[3]] + head_dam_XYZ_col[:3] + head_dam_XYZ_col[4:]
head_fill1_XYZ_col = [head_fill1_XYZ_col[3]] + head_fill1_XYZ_col[:3] + head_fill1_XYZ_col[4:]
head_fill2_XYZ_col = [head_fill2_XYZ_col[3]] + head_fill2_XYZ_col[:3] + head_fill2_XYZ_col[4:]

# %%
head_dam_XYZ_col
# Out:
# ['HEAD Standby Position Collect Result_Dam XYZ',
#  'HEAD NORMAL COORDINATE AXIS(Stage1) Collect Result_Dam XYZ',
#  'HEAD NORMAL COORDINATE AXIS(Stage2) Collect Result_Dam XYZ',
#  'HEAD NORMAL COORDINATE AXIS(Stage3) Collect Result_Dam XYZ',
#  'Head Clean Position Collect Result_Dam XYZ',
#  'Head Purge Position Collect Result_Dam XYZ']

# %%
from sklearn.preprocessing import LabelEncoder

# 1. 라벨 인코딩 적용
label_encoders = {}
for col in head_dam_XYZ_col:
    le = LabelEncoder()
    train_data[col] = le.fit_transform(train_data[col])
    for label in list(test[col].unique()): #train에 없는 test값 처리
        if label not in list(le.classes_):
            le.classes_ = np.append(le.classes_,label)
    test[col] = le.transform(test[col])
    label_encoders[col] = le
    train_data[col] = train_data[col].astype(str) # 범주 변수 처리
    test[col] = test[col].astype(str) # 범주 변수 처리
    
# 2. 전체 상호작용항 생성 및 라벨 인코딩
interaction_col_name = 'head_interactionDam'  # 향후에 head_interaction dam/fill1/fill2로 분리해 볼 필요 있음

train_data[interaction_col_name] = train_data[head_dam_XYZ_col].astype(str).agg('_'.join, axis=1)
test[interaction_col_name] = test[head_dam_XYZ_col].astype(str).agg('_'.join, axis=1)

# %%
from sklearn.preprocessing import LabelEncoder

# 1. 라벨 인코딩 적용
label_encoders = {}
for col in head_fill1_XYZ_col:
    le = LabelEncoder()
    train_data[col] = le.fit_transform(train_data[col])
    for label in list(test[col].unique()): #train에 없는 test값 처리
        if label not in list(le.classes_):
            le.classes_ = np.append(le.classes_,label)
    test[col] = le.transform(test[col])
    label_encoders[col] = le
    train_data[col] = train_data[col].astype(str) # 범주 변수 처리
    test[col] = test[col].astype(str) # 범주 변수 처리
    
# 2. 전체 상호작용항 생성 및 라벨 인코딩
interaction_col_name = 'head_interactionFill1'  # 향후에 head_interaction dam/fill1/fill2로 분리해 볼 필요 있음

train_data[interaction_col_name] = train_data[head_fill1_XYZ_col].astype(str).agg('_'.join, axis=1)
test[interaction_col_name] = test[head_fill1_XYZ_col].astype(str).agg('_'.join, axis=1)

# %%
from sklearn.preprocessing import LabelEncoder

# 1. 라벨 인코딩 적용
label_encoders = {}
for col in head_fill2_XYZ_col:
    le = LabelEncoder()
    train_data[col] = le.fit_transform(train_data[col])
    for label in list(test[col].unique()): #train에 없는 test값 처리
        if label not in list(le.classes_):
            le.classes_ = np.append(le.classes_,label)
    test[col] = le.transform(test[col])
    label_encoders[col] = le
    train_data[col] = train_data[col].astype(str) # 범주 변수 처리
    test[col] = test[col].astype(str) # 범주 변수 처리
    
# 2. 전체 상호작용항 생성 및 라벨 인코딩
interaction_col_name = 'head_interactionFill2'  # 향후에 head_interaction dam/fill1/fill2로 분리해 볼 필요 있음

train_data[interaction_col_name] = train_data[head_fill2_XYZ_col].astype(str).agg('_'.join, axis=1)
test[interaction_col_name] = test[head_fill2_XYZ_col].astype(str).agg('_'.join, axis=1)

# %%
from sklearn.preprocessing import LabelEncoder

# # 1. 라벨 인코딩 적용
# label_encoders = {}
# for col in head_XYZ_col:
#     le = LabelEncoder()
#     train_data[col] = le.fit_transform(train_data[col])
#     for label in list(test[col].unique()): #train에 없는 test값 처리
#         if label not in list(le.classes_):
#             le.classes_ = np.append(le.classes_,label)
#     test[col] = le.transform(test[col])
#     label_encoders[col] = le
#     train_data[col] = train_data[col].astype(str) # 범주 변수 처리
#     test[col] = test[col].astype(str) # 범주 변수 처리
    
# # 2. 전체 상호작용항 생성 및 라벨 인코딩
# interaction_col_name = 'head_interaction'  # 향후에 head_interaction dam/fill1/fill2로 분리해 볼 필요 있음

# train_data[interaction_col_name] = train_data[head_XYZ_col].astype(str).agg('_'.join, axis=1)
# test[interaction_col_name] = test[head_XYZ_col].astype(str).agg('_'.join, axis=1)

# 2. 순차적 상호작용

train_data['stage123_dam'] = train_data[head_dam_XYZ_col].iloc[:,1] + '_' + train_data[head_dam_XYZ_col].iloc[:,2] + '_' + train_data[head_dam_XYZ_col].iloc[:,3]
train_data['clean_purge_dam'] = train_data[head_dam_XYZ_col].iloc[:,4] + '_' + train_data[head_dam_XYZ_col].iloc[:,4] 

train_data['stage123_fill1'] = train_data[head_fill1_XYZ_col].iloc[:,1] + '_' + train_data[head_fill1_XYZ_col].iloc[:,2] + '_' + train_data[head_fill1_XYZ_col].iloc[:,3]
train_data['clean_purge_fill1'] = train_data[head_fill1_XYZ_col].iloc[:,4] + '_' + train_data[head_fill1_XYZ_col].iloc[:,5] 

train_data['stage123_fill2'] = train_data[head_fill2_XYZ_col].iloc[:,1] + '_' + train_data[head_fill2_XYZ_col].iloc[:,2] + '_' + train_data[head_fill2_XYZ_col].iloc[:,3]
train_data['clean_purge_fill2'] = train_data[head_fill2_XYZ_col].iloc[:,4] + '_' + train_data[head_fill2_XYZ_col].iloc[:,5] 

####################################################################################################################3

test['stage123_dam'] = test[head_dam_XYZ_col].iloc[:,1] + '_' + test[head_dam_XYZ_col].iloc[:,2] + '_' + test[head_dam_XYZ_col].iloc[:,3]
test['clean_purge_dam'] = test[head_dam_XYZ_col].iloc[:,4] + '_' + test[head_dam_XYZ_col].iloc[:,4] 
test['stage123_fill1'] = test[head_fill1_XYZ_col].iloc[:,1] + '_' + test[head_fill1_XYZ_col].iloc[:,2] + '_' + test[head_fill1_XYZ_col].iloc[:,3]
test['clean_purge_fill1'] = test[head_fill1_XYZ_col].iloc[:,4] + '_' + test[head_fill1_XYZ_col].iloc[:,5] 

test['stage123_fill2'] = test[head_fill2_XYZ_col].iloc[:,1] + '_' + test[head_fill2_XYZ_col].iloc[:,2] + '_' + test[head_fill2_XYZ_col].iloc[:,3]
test['clean_purge_fill2'] = test[head_fill2_XYZ_col].iloc[:,4] + '_' + test[head_fill2_XYZ_col].iloc[:,5] 


# 4. 상호작용항에 라벨 인코딩 적용
ordered_interaction_col_name = train_data.columns[train_data.columns.str.contains('dam|fill1|fill2')]

for i in ordered_interaction_col_name:

    interaction_le = LabelEncoder()
    train_data[i] = interaction_le.fit_transform(train_data[i])
    for label in list(test[i].unique()): #train에 없는 test값 처리
        if label not in list(interaction_le.classes_):
            interaction_le.classes_ = np.append(interaction_le.classes_,label)
    test[i] = interaction_le.transform(test[i])
    train_data[i] = train_data[i].astype("object") # 범주 변수 처리
    test[i] = test[i].astype("object") # 범주 변수 처리

# %%
train_data.drop(columns=head_XYZ_col, inplace=True)
test.drop(columns=head_XYZ_col, inplace=True)

# %%
# train_data['MEAN DISCHARGED TIME OF RESIN_Dam']=train_data[['DISCHARGED TIME OF RESIN(Stage1) Collect Result_Dam',
#        'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Dam',
#        'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Dam']].mean(axis=1)
# train_data['STD DISCHARGED TIME OF RESIN_Dam']=train_data[['DISCHARGED TIME OF RESIN(Stage1) Collect Result_Dam',
#        'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Dam',
#        'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Dam']].std(axis=1)
# train_data['SUM DISCHARGED TIME OF RESIN_Dam']=train_data[['DISCHARGED TIME OF RESIN(Stage1) Collect Result_Dam',
#        'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Dam',
#        'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Dam']].sum(axis=1)

# train_data['MEAN Dispense Volume_Dam']=train_data[['Dispense Volume(Stage1) Collect Result_Dam',
#        'Dispense Volume(Stage2) Collect Result_Dam',
#        'Dispense Volume(Stage3) Collect Result_Dam']].mean(axis=1)
# train_data['STD Dispense Volume_Dam']=train_data[['Dispense Volume(Stage1) Collect Result_Dam',
#        'Dispense Volume(Stage2) Collect Result_Dam',
#        'Dispense Volume(Stage3) Collect Result_Dam']].std(axis=1)
# train_data['SUM Dispense Volume_Dam']=train_data[['Dispense Volume(Stage1) Collect Result_Dam',
#        'Dispense Volume(Stage2) Collect Result_Dam',
#        'Dispense Volume(Stage3) Collect Result_Dam']].sum(axis=1)

# #비율 - 같은 용량이 나오는 데에 걸리는 시간
# train_data['DIV Dispense Volume(Stage1)_Dam']=train_data['DISCHARGED TIME OF RESIN(Stage1) Collect Result_Dam']/train_data['Dispense Volume(Stage1) Collect Result_Dam']
# train_data['DIV Dispense Volume(Stage2)_Dam']=train_data['DISCHARGED TIME OF RESIN(Stage2) Collect Result_Dam']/train_data['Dispense Volume(Stage2) Collect Result_Dam']
# train_data['DIV Dispense Volume(Stage3)_Dam']=train_data['DISCHARGED TIME OF RESIN(Stage3) Collect Result_Dam']/train_data['Dispense Volume(Stage3) Collect Result_Dam']

# #Fill1
# #합계/평균/최대/최소/표준편차/분산/비율

# train_data['MEAN DISCHARGED TIME OF RESIN_Fill1']=train_data[['DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill1',
#        'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill1',
#        'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill1']].mean(axis=1)
# train_data['STD DISCHARGED TIME OF RESIN_Fill1']=train_data[['DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill1',
#        'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill1',
#        'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill1']].std(axis=1)
# train_data['SUM DISCHARGED TIME OF RESIN_Fill1']=train_data[['DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill1',
#        'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill1',
#        'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill1']].sum(axis=1)

# train_data['MEAN Dispense Volume_Fill1']=train_data[['Dispense Volume(Stage1) Collect Result_Fill1',
#        'Dispense Volume(Stage2) Collect Result_Fill1',
#        'Dispense Volume(Stage3) Collect Result_Fill1']].mean(axis=1)
# train_data['STD Dispense Volume_Fill1']=train_data[['Dispense Volume(Stage1) Collect Result_Fill1',
#        'Dispense Volume(Stage2) Collect Result_Fill1',
#        'Dispense Volume(Stage3) Collect Result_Fill1']].std(axis=1)
# train_data['SUM Dispense Volume_Fill1']=train_data[['Dispense Volume(Stage1) Collect Result_Fill1',
#        'Dispense Volume(Stage2) Collect Result_Fill1',
#        'Dispense Volume(Stage3) Collect Result_Fill1']].sum(axis=1)

# #비율 - 같은 용량이 나오는 데에 걸리는 시간
# # train_data['DIV Dispense Volume(Stage1)_Fill1']=train_data['DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill1']/train_data['Dispense Volume(Stage1) Collect Result_Fill1']
# # train_data['DIV Dispense Volume(Stage2)_Fill1']=train_data['DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill1']/train_data['Dispense Volume(Stage2) Collect Result_Fill1']
# # train_data['DIV Dispense Volume(Stage3)_Fill1']=train_data['DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill1']/train_data['Dispense Volume(Stage3) Collect Result_Fill1']

# #Thickness(변화가 있는지도 비율로 보면 좋을듯)

# train_data['SUM THICKNESS_Dam']=train_data[['THICKNESS 1 Collect Result_Dam', 'THICKNESS 2 Collect Result_Dam','THICKNESS 3 Collect Result_Dam']].sum(axis=1)
# train_data['MEAN THICKNESS_Dam']=train_data[['THICKNESS 1 Collect Result_Dam', 'THICKNESS 2 Collect Result_Dam','THICKNESS 3 Collect Result_Dam']].mean(axis=1)
# train_data['STD THICKNESS_Dam']=train_data[['THICKNESS 1 Collect Result_Dam', 'THICKNESS 2 Collect Result_Dam','THICKNESS 3 Collect Result_Dam']].std(axis=1)

# train_data['DIV1 THICKNESS_Dam']=train_data['THICKNESS 2 Collect Result_Dam']/train_data['THICKNESS 1 Collect Result_Dam']
# train_data['DIV2 THICKNESS_Dam']=train_data['THICKNESS 3 Collect Result_Dam']/train_data['THICKNESS 2 Collect Result_Dam']

# #1st/2nd/3rd - 'THICKNESS 1 Collect Result_Dam', 'THICKNESS 2 Collect Result_Dam''THICKNESS 3 Collect Result_Dam'
# train_data['SUM Pressure_AutoClave']=train_data[['1st Pressure Collect Result_AutoClave', '2nd Pressure Collect Result_AutoClave', '3rd Pressure Collect Result_AutoClave']].sum(axis=1)
# train_data['MEAN Pressure_AutoClave']=train_data[['1st Pressure Collect Result_AutoClave', '2nd Pressure Collect Result_AutoClave', '3rd Pressure Collect Result_AutoClave']].mean(axis=1)
# train_data['STD Pressure_AutoClave']=train_data[['1st Pressure Collect Result_AutoClave', '2nd Pressure Collect Result_AutoClave', '3rd Pressure Collect Result_AutoClave']].std(axis=1)

# train_data['DIV1 Pressure_AutoClave']=train_data['2nd Pressure Collect Result_AutoClave']/train_data['1st Pressure Collect Result_AutoClave']
# train_data['DIV2 Pressure_AutoClave']=train_data['3rd Pressure Collect Result_AutoClave']/train_data['2nd Pressure Collect Result_AutoClave']

# %%
# test['MEAN DISCHARGED TIME OF RESIN_Dam']=test[['DISCHARGED TIME OF RESIN(Stage1) Collect Result_Dam',
#        'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Dam',
#        'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Dam']].mean(axis=1)
# test['STD DISCHARGED TIME OF RESIN_Dam']=test[['DISCHARGED TIME OF RESIN(Stage1) Collect Result_Dam',
#        'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Dam',
#        'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Dam']].std(axis=1)
# test['SUM DISCHARGED TIME OF RESIN_Dam']=test[['DISCHARGED TIME OF RESIN(Stage1) Collect Result_Dam',
#        'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Dam',
#        'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Dam']].sum(axis=1)

# test['MEAN Dispense Volume_Dam']=test[['Dispense Volume(Stage1) Collect Result_Dam',
#        'Dispense Volume(Stage2) Collect Result_Dam',
#        'Dispense Volume(Stage3) Collect Result_Dam']].mean(axis=1)
# test['STD Dispense Volume_Dam']=test[['Dispense Volume(Stage1) Collect Result_Dam',
#        'Dispense Volume(Stage2) Collect Result_Dam',
#        'Dispense Volume(Stage3) Collect Result_Dam']].std(axis=1)
# test['SUM Dispense Volume_Dam']=test[['Dispense Volume(Stage1) Collect Result_Dam',
#        'Dispense Volume(Stage2) Collect Result_Dam',
#        'Dispense Volume(Stage3) Collect Result_Dam']].sum(axis=1)

# #비율 - 같은 용량이 나오는 데에 걸리는 시간
# test['DIV Dispense Volume(Stage1)_Dam']=test['DISCHARGED TIME OF RESIN(Stage1) Collect Result_Dam']/test['Dispense Volume(Stage1) Collect Result_Dam']
# test['DIV Dispense Volume(Stage2)_Dam']=test['DISCHARGED TIME OF RESIN(Stage2) Collect Result_Dam']/test['Dispense Volume(Stage2) Collect Result_Dam']
# test['DIV Dispense Volume(Stage3)_Dam']=test['DISCHARGED TIME OF RESIN(Stage3) Collect Result_Dam']/test['Dispense Volume(Stage3) Collect Result_Dam']

# #Fill1
# #합계/평균/최대/최소/표준편차/분산/비율

# test['MEAN DISCHARGED TIME OF RESIN_Fill1']=test[['DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill1',
#        'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill1',
#        'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill1']].mean(axis=1)
# test['STD DISCHARGED TIME OF RESIN_Fill1']=test[['DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill1',
#        'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill1',
#        'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill1']].std(axis=1)
# test['SUM DISCHARGED TIME OF RESIN_Fill1']=test[['DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill1',
#        'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill1',
#        'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill1']].sum(axis=1)

# test['MEAN Dispense Volume_Fill1']=test[['Dispense Volume(Stage1) Collect Result_Fill1',
#        'Dispense Volume(Stage2) Collect Result_Fill1',
#        'Dispense Volume(Stage3) Collect Result_Fill1']].mean(axis=1)
# test['STD Dispense Volume_Fill1']=test[['Dispense Volume(Stage1) Collect Result_Fill1',
#        'Dispense Volume(Stage2) Collect Result_Fill1',
#        'Dispense Volume(Stage3) Collect Result_Fill1']].std(axis=1)
# test['SUM Dispense Volume_Fill1']=test[['Dispense Volume(Stage1) Collect Result_Fill1',
#        'Dispense Volume(Stage2) Collect Result_Fill1',
#        'Dispense Volume(Stage3) Collect Result_Fill1']].sum(axis=1)

# #비율 - 같은 용량이 나오는 데에 걸리는 시간
# # test['DIV Dispense Volume(Stage1)_Fill1']=test['DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill1']/test['Dispense Volume(Stage1) Collect Result_Fill1']
# # test['DIV Dispense Volume(Stage2)_Fill1']=test['DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill1']/test['Dispense Volume(Stage2) Collect Result_Fill1']
# # test['DIV Dispense Volume(Stage3)_Fill1']=test['DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill1']/test['Dispense Volume(Stage3) Collect Result_Fill1']

# #Thickness(변화가 있는지도 비율로 보면 좋을듯)

# test['SUM THICKNESS_Dam']=test[['THICKNESS 1 Collect Result_Dam', 'THICKNESS 2 Collect Result_Dam','THICKNESS 3 Collect Result_Dam']].sum(axis=1)
# test['MEAN THICKNESS_Dam']=test[['THICKNESS 1 Collect Result_Dam', 'THICKNESS 2 Collect Result_Dam','THICKNESS 3 Collect Result_Dam']].mean(axis=1)
# test['STD THICKNESS_Dam']=test[['THICKNESS 1 Collect Result_Dam', 'THICKNESS 2 Collect Result_Dam','THICKNESS 3 Collect Result_Dam']].std(axis=1)

# test['DIV1 THICKNESS_Dam']=test['THICKNESS 2 Collect Result_Dam']/test['THICKNESS 1 Collect Result_Dam']
# test['DIV2 THICKNESS_Dam']=test['THICKNESS 3 Collect Result_Dam']/test['THICKNESS 2 Collect Result_Dam']

# #1st/2nd/3rd - 'THICKNESS 1 Collect Result_Dam', 'THICKNESS 2 Collect Result_Dam''THICKNESS 3 Collect Result_Dam'
# test['SUM Pressure_AutoClave']=test[['1st Pressure Collect Result_AutoClave', '2nd Pressure Collect Result_AutoClave', '3rd Pressure Collect Result_AutoClave']].sum(axis=1)
# test['MEAN Pressure_AutoClave']=test[['1st Pressure Collect Result_AutoClave', '2nd Pressure Collect Result_AutoClave', '3rd Pressure Collect Result_AutoClave']].mean(axis=1)
# test['STD Pressure_AutoClave']=test[['1st Pressure Collect Result_AutoClave', '2nd Pressure Collect Result_AutoClave', '3rd Pressure Collect Result_AutoClave']].std(axis=1)

# test['DIV1 Pressure_AutoClave']=test['2nd Pressure Collect Result_AutoClave']/test['1st Pressure Collect Result_AutoClave']
# test['DIV2 Pressure_AutoClave']=test['3rd Pressure Collect Result_AutoClave']/test['2nd Pressure Collect Result_AutoClave']

# %%
train_data['DIV Dispense Volume(Stage2)_Dam']=train_data['DISCHARGED TIME OF RESIN(Stage2) Collect Result_Dam']/train_data['Dispense Volume(Stage2) Collect Result_Dam']
train_data['DIV Dispense Volume(Stage3)_Dam']=train_data['DISCHARGED TIME OF RESIN(Stage3) Collect Result_Dam']/train_data['Dispense Volume(Stage3) Collect Result_Dam']

train_data['STD Dispense Volume_Fill1']=train_data[['Dispense Volume(Stage1) Collect Result_Fill1',
       'Dispense Volume(Stage2) Collect Result_Fill1',
       'Dispense Volume(Stage3) Collect Result_Fill1']].std(axis=1)

# %%
test['DIV Dispense Volume(Stage2)_Dam']=test['DISCHARGED TIME OF RESIN(Stage2) Collect Result_Dam']/test['Dispense Volume(Stage2) Collect Result_Dam']
test['DIV Dispense Volume(Stage3)_Dam']=test['DISCHARGED TIME OF RESIN(Stage3) Collect Result_Dam']/test['Dispense Volume(Stage3) Collect Result_Dam']

test['STD Dispense Volume_Fill1']=test[['Dispense Volume(Stage1) Collect Result_Fill1',
       'Dispense Volume(Stage2) Collect Result_Fill1',
       'Dispense Volume(Stage3) Collect Result_Fill1']].std(axis=1)

# %%
#  'STD DISCHARGED TIME OF RESIN_Dam',
#  'STD Dispense Volume_Dam',
#  'DIV Dispense Volume(Stage1)_Dam',
#  'DIV Dispense Volume(Stage2)_Dam',
#  'DIV Dispense Volume(Stage3)_Dam',
#  'STD DISCHARGED TIME OF RESIN_Fill1',
#  'STD Dispense Volume_Fill1',
#  'DIV2 THICKNESS_Dam',
#  'STD Pressure_AutoClave',
#  'DIV1 Pressure_AutoClave',
#  'DIV2 Pressure_AutoClave'
    
    
    
    
# #      'MEAN Dispense Volume_Dam',
# #        'SUM Dispense Volume_Dam', 'DIV Dispense Volume(Stage2)_Dam',
# #        'DIV Dispense Volume(Stage3)_Dam', 'SUM DISCHARGED TIME OF RESIN_Fill1',
# #        'MEAN Dispense Volume_Fill1', 'STD Dispense Volume_Fill1',
# #        'DIV1 THICKNESS_Dam', 'DIV2 THICKNESS_Dam', 'SUM Pressure_AutoClave',
# #        'MEAN Pressure_AutoClave', 'DIV1 Pressure_AutoClave',
# #        'DIV2 Pressure_AutoClave'


#  'DIV Dispense Volume(Stage2)_Dam',
#  'DIV Dispense Volume(Stage3)_Dam',
#  'STD Dispense Volume_Fill1'

# %%
#        'DIV1 THICKNESS_Dam', 'DIV2 THICKNESS_Dam', 'SUM Pressure_AutoClave',
#        'MEAN Pressure_AutoClave', 'DIV1 Pressure_AutoClave',
#        'DIV2 Pressure_AutoClave'

# %%
train_data['Mismatch_Dam_Fill1'] = (train_data['Production Qty Collect Result_Fill1'] != train_data['Production Qty Collect Result_Dam']).astype(object)
train_data['Mismatch_Dam_Fill2'] = (train_data['Production Qty Collect Result_Fill2'] != train_data['Production Qty Collect Result_Dam']).astype(object)
train_data['Mismatch_Fill1_Fill2'] = (train_data['Production Qty Collect Result_Fill1'] != train_data['Production Qty Collect Result_Fill2']).astype(object)

test['Mismatch_Dam_Fill1'] = (test['Production Qty Collect Result_Fill1'] != test['Production Qty Collect Result_Dam']).astype(object)
test['Mismatch_Dam_Fill2'] = (test['Production Qty Collect Result_Fill2'] != test['Production Qty Collect Result_Dam']).astype(object)
test['Mismatch_Fill1_Fill2'] = (test['Production Qty Collect Result_Fill1'] != test['Production Qty Collect Result_Fill2']).astype(object)

# %%
train_data['Mismatch_Receip_Dam_Fill1'] = (train_data['Receip No Collect Result_Fill1'] != train_data['Receip No Collect Result_Dam']).astype(object)
train_data['Mismatch_Receip_Dam_Fill2'] = (train_data['Receip No Collect Result_Fill2'] != train_data['Receip No Collect Result_Dam']).astype(object)
train_data['Mismatch_Receip_Fill1_Fill2'] = (train_data['Receip No Collect Result_Fill1'] != train_data['Receip No Collect Result_Fill2']).astype(object)

test['Mismatch_Receip_Dam_Fill1'] = (test['Receip No Collect Result_Fill1'] != test['Receip No Collect Result_Dam']).astype(object)
test['Mismatch_Receip_Dam_Fill2'] = (test['Receip No Collect Result_Fill2'] != test['Receip No Collect Result_Dam']).astype(object)
test['Mismatch_Receip_Fill1_Fill2'] = (test['Receip No Collect Result_Fill1'] != test['Receip No Collect Result_Fill2']).astype(object)

# %%
train_data['Mismatch_equipment_Dam_Fill1'] = (train_data['Equipment_Fill1'] != train_data['Equipment_Dam']).astype(object)
train_data['Mismatch_equipment_Dam_Fill2'] = (train_data['Equipment_Fill2'] != train_data['Equipment_Dam']).astype(object)
train_data['Mismatch_equipment_Fill1_Fill2'] = (train_data['Equipment_Fill1'] != train_data['Equipment_Fill2']).astype(object)

test['Mismatch_equipment_Dam_Fill1'] = (test['Equipment_Fill1'] != test['Equipment_Dam']).astype(object)
test['Mismatch_equipment_Dam_Fill2'] = (test['Equipment_Fill2'] != test['Equipment_Dam']).astype(object)
test['Mismatch_equipment_Fill1_Fill2'] = (test['Equipment_Fill1'] != test['Equipment_Fill2']).astype(object)

# %%
cols=['Stage1 Circle1 Distance Speed Collect Result_Dam',
 'Stage1 Circle2 Distance Speed Collect Result_Dam',
 'Stage1 Line1 Distance Speed Collect Result_Dam',
 'Stage1 Line2 Distance Speed Collect Result_Dam',
 'Stage1 Line4 Distance Speed Collect Result_Dam',
 'Stage2 Circle1 Distance Speed Collect Result_Dam',
 'Stage2 Circle2 Distance Speed Collect Result_Dam',
 'Stage2 Line2 Distance Speed Collect Result_Dam',
 'Stage2 Line3 Distance Speed Collect Result_Dam',
 'Stage2 Line4 Distance Speed Collect Result_Dam',
 'Stage3 Circle2 Distance Speed Collect Result_Dam',
 'Stage3 Line2 Distance Speed Collect Result_Dam',
 'Stage3 Line4 Distance Speed Collect Result_Dam',]

# %%
train_data[cols]
# Out:
#        Stage1 Circle1 Distance Speed Collect Result_Dam  \
# 0                                                     1
# 1                                                  4000
# 2                                                     1
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                                 1
# 40503                                                 1
# 40504                                              9000
# 40505                                              9000
#
#        Stage1 Circle2 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage1 Line1 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage1 Line2 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage1 Line4 Distance Speed Collect Result_Dam  \
# 0                                                5600
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5600
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage2 Circle1 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  9000
# 2                                                  5800
# 3                                                  5000
# 4                                                  9000
# ...                                                 ...
# 40501                                              9000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                             12000
#
#        Stage2 Circle2 Distance Speed Collect Result_Dam  \
# 0                                                  5300
# 1                                                  9000
# 2                                                  5300
# 3                                                  5000
# 4                                                  9000
# ...                                                 ...
# 40501                                              9000
# 40502                                              5300
# 40503                                              5500
# 40504                                              9000
# 40505                                             12000
#
#        Stage2 Line2 Distance Speed Collect Result_Dam  \
# 0                                                5300
# 1                                                9000
# 2                                                5300
# 3                                                5000
# 4                                                9000
# ...                                               ...
# 40501                                            9000
# 40502                                            5300
# 40503                                            5500
# 40504                                            9000
# 40505                                           12000
#
#        Stage2 Line3 Distance Speed Collect Result_Dam  \
# 0                                                5300
# 1                                                9000
# 2                                                5300
# 3                                                5000
# 4                                                9000
# ...                                               ...
# 40501                                            9000
# 40502                                            5300
# 40503                                            5500
# 40504                                            9000
# 40505                                           12000
#
#        Stage2 Line4 Distance Speed Collect Result_Dam  \
# 0                                                5300
# 1                                                9000
# 2                                                5300
# 3                                                5000
# 4                                                9000
# ...                                               ...
# 40501                                            9000
# 40502                                            5300
# 40503                                            5500
# 40504                                            9000
# 40505                                           12000
#
#        Stage3 Circle2 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage3 Line2 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage3 Line4 Distance Speed Collect Result_Dam
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
# [40506 rows x 13 columns]

# %%
train_data
# Out:
#           Equipment_Dam    Collect Date_Dam  \
# 0      Dam dispenser #1 2024-04-25 11:10:00
# 1      Dam dispenser #1 2023-09-19 14:30:00
# 2      Dam dispenser #2 2024-03-05 09:30:00
# 3      Dam dispenser #2 2023-09-25 15:40:00
# 4      Dam dispenser #1 2023-06-27 13:20:00
# ...                 ...                 ...
# 40501  Dam dispenser #1 2023-09-14 15:50:00
# 40502  Dam dispenser #2 2024-04-10 14:20:00
# 40503  Dam dispenser #1 2024-02-22 08:40:00
# 40504  Dam dispenser #2 2023-07-25 11:00:00
# 40505  Dam dispenser #1 2023-05-31 01:40:00
#
#        CURE END POSITION X Collect Result_Dam  \
# 0                                       240.0
# 1                                       240.0
# 2                                      1000.0
# 3                                      1000.0
# 4                                       240.0
# ...                                       ...
# 40501                                   240.0
# 40502                                  1000.0
# 40503                                   240.0
# 40504                                  1000.0
# 40505                                   240.0
#
#        CURE END POSITION Z Collect Result_Dam  \
# 0                                         2.5
# 1                                         2.5
# 2                                        12.5
# 3                                        12.5
# 4                                         2.5
# ...                                       ...
# 40501                                     2.5
# 40502                                    12.5
# 40503                                     2.5
# 40504                                    12.5
# 40505                                     2.5
#
#        CURE END POSITION Θ Collect Result_Dam  CURE SPEED Collect Result_Dam  \
# 0                                         -90                            100
# 1                                         -90                             70
# 2                                          90                             85
# 3                                          90                             70
# 4                                         -90                             70
# ...                                       ...                            ...
# 40501                                     -90                             70
# 40502                                      90                            100
# 40503                                     -90                            100
# 40504                                      90                             70
# 40505                                     -90                             70
#
#        CURE START POSITION X Collect Result_Dam  \
# 0                                          1030
# 1                                          1030
# 2                                           280
# 3                                           280
# 4                                          1030
# ...                                         ...
# 40501                                      1030
# 40502                                       280
# 40503                                      1030
# 40504                                       280
# 40505                                      1030
#
#        CURE START POSITION Θ Collect Result_Dam  \
# 0                                           -90
# 1                                           -90
# 2                                            90
# 3                                            90
# 4                                           -90
# ...                                         ...
# 40501                                       -90
# 40502                                        90
# 40503                                       -90
# 40504                                        90
# 40505                                       -90
#
#        DISCHARGED SPEED OF RESIN Collect Result_Dam  \
# 0                                                16
# 1                                                10
# 2                                                16
# 3                                                10
# 4                                                10
# ...                                             ...
# 40501                                            10
# 40502                                            16
# 40503                                            16
# 40504                                            10
# 40505                                            10
#
#        DISCHARGED TIME OF RESIN(Stage1) Collect Result_Dam  \
# 0                                                   14.9
# 1                                                   21.3
# 2                                                   14.7
# 3                                                   21.3
# 4                                                    9.7
# ...                                                  ...
# 40501                                               17.0
# 40502                                               14.9
# 40503                                               14.2
# 40504                                                9.7
# 40505                                                9.6
#
#        DISCHARGED TIME OF RESIN(Stage2) Collect Result_Dam  \
# 0                                                    8.4
# 1                                                    4.9
# 2                                                    8.5
# 3                                                    8.4
# 4                                                    4.9
# ...                                                  ...
# 40501                                                5.0
# 40502                                                8.5
# 40503                                                8.2
# 40504                                                4.9
# 40505                                                3.9
#
#        DISCHARGED TIME OF RESIN(Stage3) Collect Result_Dam  \
# 0                                                   14.7
# 1                                                   21.3
# 2                                                   14.7
# 3                                                   21.3
# 4                                                    9.6
# ...                                                  ...
# 40501                                               17.0
# 40502                                               14.7
# 40503                                               14.3
# 40504                                                9.7
# 40505                                                9.7
#
#        Dispense Volume(Stage1) Collect Result_Dam  \
# 0                                            1.04
# 1                                            1.49
# 2                                            1.61
# 3                                            1.49
# 4                                            0.67
# ...                                           ...
# 40501                                        1.19
# 40502                                        1.04
# 40503                                        0.99
# 40504                                        0.67
# 40505                                        0.67
#
#        Dispense Volume(Stage2) Collect Result_Dam  \
# 0                                            0.58
# 1                                            0.34
# 2                                            0.93
# 3                                            0.58
# 4                                            0.34
# ...                                           ...
# 40501                                        0.35
# 40502                                        0.59
# 40503                                        0.57
# 40504                                        0.34
# 40505                                        0.27
#
#        Dispense Volume(Stage3) Collect Result_Dam  \
# 0                                            1.02
# 1                                            1.49
# 2                                            1.61
# 3                                            1.49
# 4                                            0.67
# ...                                           ...
# 40501                                        1.19
# 40502                                        1.02
# 40503                                        1.00
# 40504                                        0.67
# 40505                                        0.67
#
#        Machine Tact time Collect Result_Dam  PalletID Collect Result_Dam  \
# 0                                    265.00                         58.5
# 1                                     65.10                          7.0
# 2                                    265.02                         76.9
# 3                                     70.50                         12.0
# 4                                     88.30                          8.0
# ...                                     ...                          ...
# 40501                                 56.70                          1.0
# 40502                                265.00                         78.5
# 40503                                265.02                         69.5
# 40504                                 57.70                         13.0
# 40505                                 92.10                          3.0
#
#        Production Qty Collect Result_Dam  Receip No Collect Result_Dam  \
# 0                                      7                           127
# 1                                    185                             1
# 2                                     10                            73
# 3                                    268                             1
# 4                                    121                             1
# ...                                  ...                           ...
# 40501                                318                             1
# 40502                                 14                           197
# 40503                                  1                            27
# 40504                                117                             1
# 40505                                320                             1
#
#        Stage1 Circle1 Distance Speed Collect Result_Dam  \
# 0                                                     1
# 1                                                  4000
# 2                                                     1
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                                 1
# 40503                                                 1
# 40504                                              9000
# 40505                                              9000
#
#        Stage1 Circle2 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage1 Circle3 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage1 Circle4 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage1 Line1 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage1 Line2 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage1 Line3 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage1 Line4 Distance Speed Collect Result_Dam  \
# 0                                                5600
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5600
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage2 Circle1 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  9000
# 2                                                  5800
# 3                                                  5000
# 4                                                  9000
# ...                                                 ...
# 40501                                              9000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                             12000
#
#        Stage2 Circle2 Distance Speed Collect Result_Dam  \
# 0                                                  5300
# 1                                                  9000
# 2                                                  5300
# 3                                                  5000
# 4                                                  9000
# ...                                                 ...
# 40501                                              9000
# 40502                                              5300
# 40503                                              5500
# 40504                                              9000
# 40505                                             12000
#
#        Stage2 Circle3 Distance Speed Collect Result_Dam  \
# 0                                                  5300
# 1                                                  9000
# 2                                                  5300
# 3                                                  5000
# 4                                                  9000
# ...                                                 ...
# 40501                                              9000
# 40502                                              5300
# 40503                                              5500
# 40504                                              9000
# 40505                                             12000
#
#        Stage2 Circle4 Distance Speed Collect Result_Dam  \
# 0                                                  5300
# 1                                                  9000
# 2                                                  5300
# 3                                                  5000
# 4                                                  9000
# ...                                                 ...
# 40501                                              9000
# 40502                                              5300
# 40503                                              5500
# 40504                                              9000
# 40505                                             12000
#
#        Stage2 Line1 Distance Speed Collect Result_Dam  \
# 0                                                5300
# 1                                                9000
# 2                                                5300
# 3                                                5000
# 4                                                9000
# ...                                               ...
# 40501                                            9000
# 40502                                            5300
# 40503                                            5500
# 40504                                            9000
# 40505                                           12000
#
#        Stage2 Line2 Distance Speed Collect Result_Dam  \
# 0                                                5300
# 1                                                9000
# 2                                                5300
# 3                                                5000
# 4                                                9000
# ...                                               ...
# 40501                                            9000
# 40502                                            5300
# 40503                                            5500
# 40504                                            9000
# 40505                                           12000
#
#        Stage2 Line3 Distance Speed Collect Result_Dam  \
# 0                                                5300
# 1                                                9000
# 2                                                5300
# 3                                                5000
# 4                                                9000
# ...                                               ...
# 40501                                            9000
# 40502                                            5300
# 40503                                            5500
# 40504                                            9000
# 40505                                           12000
#
#        Stage2 Line4 Distance Speed Collect Result_Dam  \
# 0                                                5300
# 1                                                9000
# 2                                                5300
# 3                                                5000
# 4                                                9000
# ...                                               ...
# 40501                                            9000
# 40502                                            5300
# 40503                                            5500
# 40504                                            9000
# 40505                                           12000
#
#        Stage3 Circle1 Distance Speed Collect Result_Dam  \
# 0                                                  5300
# 1                                                  4000
# 2                                                  5300
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5300
# 40503                                              5500
# 40504                                              9000
# 40505                                              9000
#
#        Stage3 Circle2 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage3 Circle3 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage3 Circle4 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage3 Line1 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage3 Line2 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage3 Line3 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage3 Line4 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        THICKNESS 1 Collect Result_Dam  THICKNESS 2 Collect Result_Dam  \
# 0                                5800                           0.000
# 1                                   0                           0.000
# 2                                5800                           0.012
# 3                                   0                           0.000
# 4                                   0                           0.000
# ...                               ...                             ...
# 40501                               0                           0.000
# 40502                            5800                          -0.019
# 40503                            6000                           0.000
# 40504                               0                           0.000
# 40505                               0                           0.000
#
#        THICKNESS 3 Collect Result_Dam  WorkMode Collect Result_Dam  \
# 0                               0.000                        0.000
# 1                               0.000                        7.000
# 2                              -0.022                        0.003
# 3                               0.000                        7.000
# 4                               0.000                        7.000
# ...                               ...                          ...
# 40501                           0.000                        7.000
# 40502                          -0.021                       -0.118
# 40503                           0.000                        0.000
# 40504                           0.000                        7.000
# 40505                           0.000                        7.000
#
#       Collect Date_AutoClave  1st Pressure Collect Result_AutoClave  \
# 0        2024-04-25 11:50:00                                  0.312
# 1        2023-09-19 15:00:00                                  0.311
# 2        2024-03-05 10:10:00                                  0.315
# 3        2023-09-25 16:20:00                                  0.299
# 4        2023-06-27 14:00:00                                  0.302
# ...                      ...                                    ...
# 40501    2023-09-14 16:30:00                                  0.300
# 40502    2024-04-10 15:00:00                                  0.305
# 40503    2024-02-22 09:20:00                                  0.309
# 40504    2023-07-25 11:40:00                                  0.302
# 40505    2023-05-31 02:10:00                                  0.305
#
#        1st Pressure 1st Pressure Unit Time_AutoClave  \
# 0                                                240
# 1                                                241
# 2                                                241
# 3                                                241
# 4                                                240
# ...                                              ...
# 40501                                            241
# 40502                                            240
# 40503                                            241
# 40504                                            241
# 40505                                            300
#
#        2nd Pressure Collect Result_AutoClave  \
# 0                                      0.493
# 1                                      0.311
# 2                                      0.490
# 3                                      0.300
# 4                                      0.302
# ...                                      ...
# 40501                                  0.300
# 40502                                  0.493
# 40503                                  0.490
# 40504                                  0.303
# 40505                                  0.305
#
#        2nd Pressure Unit Time_AutoClave  \
# 0                                     1
# 1                                   121
# 2                                     1
# 3                                   121
# 4                                   120
# ...                                 ...
# 40501                               121
# 40502                                 1
# 40503                                 1
# 40504                               121
# 40505                                60
#
#        3rd Pressure Collect Result_AutoClave  \
# 0                                      0.499
# 1                                      0.498
# 2                                      0.498
# 3                                      0.500
# 4                                      0.498
# ...                                      ...
# 40501                                  0.500
# 40502                                  0.498
# 40503                                  0.498
# 40504                                  0.499
# 40505                                  0.498
#
#        3rd Pressure Unit Time_AutoClave  \
# 0                                   120
# 1                                   121
# 2                                   121
# 3                                   121
# 4                                   120
# ...                                 ...
# 40501                               121
# 40502                               120
# 40503                               121
# 40504                               121
# 40505                               120
#
#        Chamber Temp. Collect Result_AutoClave  \
# 0                                          54
# 1                                          54
# 2                                          56
# 3                                          54
# 4                                          47
# ...                                       ...
# 40501                                      54
# 40502                                      49
# 40503                                      48
# 40504                                      54
# 40505                                      47
#
#        Chamber Temp. Unit Time_AutoClave Chamber Temp. Judge Value_AutoClave  \
# 0                                    361                                  OK
# 1                                    483                                  OK
# 2                                    363                                  OK
# 3                                    483                                  OK
# 4                                    480                                  NG
# ...                                  ...                                 ...
# 40501                                483                                  OK
# 40502                                361                                  NG
# 40503                                363                                  NG
# 40504                                483                                  OK
# 40505                                480                                  NG
#
#           Equipment_Fill1   Collect Date_Fill1  \
# 0      Fill1 dispenser #1  2024-04-25 11:20:00
# 1      Fill1 dispenser #1  2023-09-19 14:30:00
# 2      Fill1 dispenser #2  2024-03-05 09:30:00
# 3      Fill1 dispenser #2  2023-09-25 15:40:00
# 4      Fill1 dispenser #1  2023-06-27 13:20:00
# ...                   ...                  ...
# 40501  Fill1 dispenser #1  2023-09-14 15:50:00
# 40502  Fill1 dispenser #2  2024-04-10 14:20:00
# 40503  Fill1 dispenser #1  2024-02-22 08:50:00
# 40504  Fill1 dispenser #2  2023-07-25 11:00:00
# 40505  Fill1 dispenser #1  2023-05-31 01:40:00
#
#        DISCHARGED SPEED OF RESIN Collect Result_Fill1  \
# 0                                                10.6
# 1                                                10.6
# 2                                                10.6
# 3                                                10.6
# 4                                                10.6
# ...                                               ...
# 40501                                            10.6
# 40502                                            10.6
# 40503                                            10.6
# 40504                                            10.6
# 40505                                            10.9
#
#        DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill1  \
# 0                                                   12.7
# 1                                                   13.5
# 2                                                   13.5
# 3                                                   13.5
# 4                                                   13.5
# ...                                                  ...
# 40501                                               13.5
# 40502                                               13.5
# 40503                                               12.9
# 40504                                               13.5
# 40505                                               13.4
#
#        DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill1  \
# 0                                                    3.6
# 1                                                    3.6
# 2                                                    3.5
# 3                                                    3.6
# 4                                                    3.6
# ...                                                  ...
# 40501                                                3.6
# 40502                                                3.6
# 40503                                                3.6
# 40504                                                3.6
# 40505                                                5.0
#
#        DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill1  \
# 0                                                   12.6
# 1                                                   13.5
# 2                                                   13.4
# 3                                                   13.5
# 4                                                   13.5
# ...                                                  ...
# 40501                                               13.5
# 40502                                               13.5
# 40503                                               12.9
# 40504                                               13.4
# 40505                                               13.4
#
#        Dispense Volume(Stage1) Collect Result_Fill1  \
# 0                                             12.06
# 1                                             12.82
# 2                                             12.82
# 3                                             12.82
# 4                                             12.82
# ...                                             ...
# 40501                                         12.82
# 40502                                         12.82
# 40503                                         12.25
# 40504                                         12.82
# 40505                                         12.73
#
#        Dispense Volume(Stage2) Collect Result_Fill1  \
# 0                                              3.42
# 1                                              3.42
# 2                                              3.32
# 3                                              3.42
# 4                                              3.42
# ...                                             ...
# 40501                                          3.42
# 40502                                          3.42
# 40503                                          3.42
# 40504                                          3.42
# 40505                                          4.75
#
#        Dispense Volume(Stage3) Collect Result_Fill1  \
# 0                                             11.97
# 1                                             12.82
# 2                                             12.73
# 3                                             12.82
# 4                                             12.82
# ...                                             ...
# 40501                                         12.82
# 40502                                         12.82
# 40503                                         12.25
# 40504                                         12.73
# 40505                                         12.73
#
#        Machine Tact time Collect Result_Fill1  PalletID Collect Result_Fill1  \
# 0                                       128.0                           55.7
# 1                                        56.5                            7.0
# 2                                       128.0                           58.7
# 3                                        57.7                           12.0
# 4                                        89.9                            8.0
# ...                                       ...                            ...
# 40501                                    51.8                            1.0
# 40502                                   128.0                           58.7
# 40503                                   128.0                           56.2
# 40504                                    57.4                           13.0
# 40505                                    91.5                            3.0
#
#        Production Qty Collect Result_Fill1  Receip No Collect Result_Fill1  \
# 0                                        7                             127
# 1                                      185                               1
# 2                                       10                              73
# 3                                      268                               1
# 4                                      121                               1
# ...                                    ...                             ...
# 40501                                  318                               1
# 40502                                   14                             197
# 40503                                    1                              27
# 40504                                  117                               1
# 40505                                  320                               1
#
#        WorkMode Collect Result_Fill1     Equipment_Fill2   Collect Date_Fill2  \
# 0                                  1  Fill2 dispenser #1  2024-04-25 11:20:00
# 1                                  7  Fill2 dispenser #1  2023-09-19 14:30:00
# 2                                  1  Fill2 dispenser #2  2024-03-05 09:30:00
# 3                                  7  Fill2 dispenser #2  2023-09-25 15:40:00
# 4                                  7  Fill2 dispenser #1  2023-06-27 13:20:00
# ...                              ...                 ...                  ...
# 40501                              7  Fill2 dispenser #1  2023-09-14 15:50:00
# 40502                              1  Fill2 dispenser #2  2024-04-10 14:20:00
# 40503                              1  Fill2 dispenser #1  2024-02-22 08:50:00
# 40504                              7  Fill2 dispenser #2  2023-07-25 11:00:00
# 40505                              7  Fill2 dispenser #1  2023-05-31 01:40:00
#
#        CURE END POSITION X Collect Result_Fill2  \
# 0                                           240
# 1                                           240
# 2                                           240
# 3                                           240
# 4                                           240
# ...                                         ...
# 40501                                       240
# 40502                                       240
# 40503                                       240
# 40504                                       240
# 40505                                       240
#
#        CURE END POSITION Z Collect Result_Fill2  \
# 0                                            33
# 1                                            33
# 2                                            33
# 3                                            33
# 4                                            32
# ...                                         ...
# 40501                                        33
# 40502                                        33
# 40503                                        33
# 40504                                        33
# 40505                                        32
#
#        CURE SPEED Collect Result_Fill2  \
# 0                                   48
# 1                                   50
# 2                                   50
# 3                                   50
# 4                                   50
# ...                                ...
# 40501                               50
# 40502                               48
# 40503                               50
# 40504                               50
# 40505                               50
#
#        CURE STANDBY POSITION Z Collect Result_Fill2  \
# 0                                                33
# 1                                                33
# 2                                                33
# 3                                                33
# 4                                                33
# ...                                             ...
# 40501                                            33
# 40502                                            33
# 40503                                            33
# 40504                                            33
# 40505                                            32
#
#        CURE START POSITION X Collect Result_Fill2  \
# 0                                            1020
# 1                                            1020
# 2                                            1020
# 3                                            1020
# 4                                            1020
# ...                                           ...
# 40501                                        1020
# 40502                                        1020
# 40503                                        1020
# 40504                                        1020
# 40505                                        1020
#
#        CURE START POSITION Z Collect Result_Fill2  \
# 0                                              33
# 1                                              33
# 2                                              33
# 3                                              33
# 4                                              33
# ...                                           ...
# 40501                                          33
# 40502                                          33
# 40503                                          33
# 40504                                          33
# 40505                                          32
#
#        Machine Tact time Collect Result_Fill2  PalletID Collect Result_Fill2  \
# 0                                     114.612                           19.9
# 1                                      19.600                            7.0
# 2                                     114.612                           19.8
# 3                                      19.900                           12.0
# 4                                      19.700                            8.0
# ...                                       ...                            ...
# 40501                                  19.200                            1.0
# 40502                                 114.612                           20.5
# 40503                                  85.000                           19.7
# 40504                                  20.100                           13.0
# 40505                                  19.400                            3.0
#
#        Production Qty Collect Result_Fill2  Receip No Collect Result_Fill2  \
# 0                                        7                             127
# 1                                      185                               1
# 2                                       10                              73
# 3                                      268                               1
# 4                                      121                               1
# ...                                    ...                             ...
# 40501                                  318                               1
# ...
# 40502                           (1020, 240)
# 40503                           (1020, 240)
# 40504                           (1020, 240)
# 40505                           (1020, 240)
#
#       CURE  POSITION Z Collect Result_Fill2  \
# 0                                  (33, 33)
# 1                                  (33, 33)
# 2                                  (33, 33)
# 3                                  (33, 33)
# 4                                  (33, 32)
# ...                                     ...
# 40501                              (33, 33)
# 40502                              (33, 33)
# 40503                              (33, 33)
# 40504                              (33, 33)
# 40505                              (32, 32)
#
#       HEAD NORMAL COORDINATE X AXIS(Stage) Collect Result_Dam  \
# 0                                  (161.0, 550.5, 464.3)
# 1                                  (550.3, 463.8, 160.8)
# 2                                  (550.4, 162.4, 465.4)
# 3                                  (162.4, 465.5, 552.0)
# 4                                  (549.0, 462.5, 159.5)
# ...                                                  ...
# 40501                              (550.3, 463.8, 160.8)
# 40502                              (550.4, 163.5, 466.2)
# 40503                              (161.0, 550.6, 463.9)
# 40504                              (162.4, 465.1, 551.3)
# 40505                              (549.0, 463.0, 160.5)
#
#       HEAD NORMAL COORDINATE Y AXIS(Stage) Collect Result_Dam  \
# 0                                  (161.4, 384.0, 383.1)
# 1                                  (377.3, 377.3, 377.3)
# 2                                (551.7, 1271.8, 1383.9)
# 3                               (1271.8, 1270.7, 1271.8)
# 4                                  (377.5, 377.0, 377.5)
# ...                                                  ...
# 40501                              (377.3, 377.3, 377.3)
# 40502                            (553.1, 1281.0, 1393.5)
# 40503                              (161.5, 377.6, 377.1)
# 40504                           (1269.0, 1268.4, 1269.0)
# 40505                              (377.5, 377.0, 377.5)
#
#       HEAD NORMAL COORDINATE Z AXIS(Stage) Collect Result_Dam  \
# 0                                (384.0, 274.51, 274.51)
# 1                               (282.15, 282.15, 282.15)
# 2                               (1271.8, 274.33, 274.33)
# 3                               (282.15, 282.15, 282.15)
# 4                                  (284.8, 284.8, 284.8)
# ...                                                  ...
# 40501                           (282.15, 282.15, 282.15)
# 40502                           (1281.2, 274.33, 274.33)
# 40503                            (378.0, 274.78, 274.78)
# 40504                           (282.15, 282.15, 282.15)
# 40505                              (284.8, 284.8, 284.8)
#
#       HEAD NORMAL COORDINATE X AXIS(Stage) Collect Result_Fill1  \
# 0                                  (157.0, 838.4, 458.7)
# 1                                  (838.4, 458.5, 157.0)
# 2                                  (157.0, 837.9, 458.1)
# 3                                  (837.7, 458.8, 157.0)
# 4                                  (838.4, 458.5, 157.0)
# ...                                                  ...
# 40501                              (838.4, 458.5, 157.0)
# 40502                              (157.0, 838.1, 458.7)
# 40503                              (157.0, 838.4, 458.4)
# 40504                              (837.7, 458.8, 157.0)
# 40505                              (837.9, 460.0, 157.5)
#
#       HEAD NORMAL COORDINATE Y AXIS(Stage) Collect Result_Fill1  \
# 0                                  (157.0, 430.0, 429.8)
# 1                                  (430.5, 430.5, 430.8)
# 2                                (156.1, 1323.5, 1322.5)
# 3                               (1323.2, 1322.5, 1322.8)
# 4                                  (430.2, 430.5, 430.5)
# ...                                                  ...
# 40501                              (430.5, 430.5, 430.8)
# 40502                            (156.1, 1325.0, 1324.0)
# 40503                              (157.0, 430.8, 430.5)
# 40504                           (1323.2, 1323.0, 1322.8)
# 40505                              (430.2, 430.5, 430.5)
#
#       HEAD NORMAL COORDINATE Z AXIS(Stage) Collect Result_Fill1  \
# 0                                (430.3, 244.52, 244.52)
# 1                                  (244.4, 244.4, 244.4)
# 2                             (1323.1, 244.415, 244.415)
# 3                                  (244.3, 244.3, 244.3)
# 4                                  (244.4, 244.4, 244.4)
# ...                                                  ...
# 40501                              (244.4, 244.4, 244.4)
# 40502                         (1324.3, 244.535, 244.535)
# 40503                          (431.1, 244.543, 244.543)
# 40504                              (244.4, 244.4, 244.4)
# 40505                              (244.3, 244.3, 244.3)
#
#       HEAD NORMAL COORDINATE X AXIS(Stage) Collect Result_Fill2  \
# 0                                  (156.0, 835.5, 458.0)
# 1                                  (835.5, 458.0, 156.0)
# 2                                  (694.0, 305.0, 499.8)
# 3                                  (305.0, 499.8, 694.0)
# 4                                  (835.5, 458.0, 156.0)
# ...                                                  ...
# 40501                              (835.5, 458.0, 156.0)
# 40502                              (694.0, 304.8, 499.8)
# 40503                              (156.0, 835.5, 458.0)
# 40504                              (305.0, 499.8, 694.0)
# 40505                              (835.5, 458.0, 156.0)
#
#       HEAD NORMAL COORDINATE Y AXIS(Stage) Collect Result_Fill2  \
# 0                                  (156.0, 428.0, 427.9)
# 1                                  (428.0, 427.9, 428.0)
# 2                                (694.0, 1324.2, 1324.2)
# 3                               (1324.2, 1324.2, 1324.2)
# 4                                  (428.0, 427.9, 428.0)
# ...                                                  ...
# 40501                              (428.0, 427.9, 428.0)
# 40502                            (692.8, 1324.2, 1324.2)
# 40503                              (156.0, 428.0, 427.9)
# 40504                           (1324.2, 1324.2, 1324.2)
# 40505                              (428.0, 427.9, 428.0)
#
#       HEAD NORMAL COORDINATE Z AXIS(Stage) Collect Result_Fill2  \
# 0                                  (428.0, 243.7, 243.7)
# 1                                  (243.7, 243.7, 243.7)
# 2                                 (1324.2, 243.5, 243.5)
# 3                                  (243.5, 243.5, 243.5)
# 4                                  (243.7, 243.7, 243.7)
# ...                                                  ...
# 40501                              (243.7, 243.7, 243.7)
# 40502                             (1324.2, 243.5, 243.5)
# 40503                              (428.0, 243.7, 243.7)
# 40504                              (243.5, 243.5, 243.5)
# 40505                              (243.7, 243.7, 243.7)
#
#       HEAD NORMAL COORDINATE AXIS(Stage1) Judge Value_Dam XYZ  \
# 0                                    ('nan', None, None)
# 1                                     ('NG', None, None)
# 2                                     ('OK', None, None)
# 3                                     ('NG', None, None)
# 4                                     ('NG', None, None)
# ...                                                  ...
# 40501                                 ('NG', None, None)
# 40502                                ('nan', None, None)
# 40503                                 ('OK', None, None)
# 40504                                 ('NG', None, None)
# 40505                                 ('NG', None, None)
#
#       Head Zero Position Collect Result_Dam XYZ head_interactionDam  \
# 0                        (130.85, 505.0, 300.0)       6_6_59_25_0_1
# 1                         (505.0, 300.0, 265.0)       0_28_40_5_2_4
# 2                        (130.85, 505.0, 300.0)       4_31_7_40_0_1
# 3                         (505.0, 300.0, 265.0)      0_22_48_73_2_4
# 4                         (505.0, 300.0, 265.0)       0_24_35_0_3_5
# ...                                         ...                 ...
# 40501                     (505.0, 300.0, 265.0)       0_28_40_5_2_4
# 40502                    (130.85, 505.0, 300.0)      4_45_21_51_0_1
# 40503                    (130.85, 505.0, 300.0)       7_7_63_19_0_1
# 40504                     (505.0, 300.0, 265.0)      0_18_42_70_2_4
# 40505                     (505.0, 303.5, 265.0)       0_24_38_4_3_5
#
#       head_interactionFill1 head_interactionFill2 stage123_dam  \
# 0           11_14_47_52_0_2           1_0_4_1_0_1           85
# 1             17_28_4_8_1_0           2_4_2_0_1_0           34
# 2             5_0_31_25_0_2           0_3_1_2_0_1           44
# 3            17_20_11_1_1_0           2_1_3_3_1_0           23
# 4             17_26_4_6_1_1           2_4_2_0_1_0           26
# ...                     ...                   ...          ...
# 40501         17_28_4_8_1_0           2_4_2_0_1_0           34
# 40502        12_2_42_50_0_2           0_2_0_2_0_1           66
# 40503       13_17_54_40_0_2           1_0_4_1_0_1           89
# 40504        17_21_14_2_1_0           2_1_3_3_1_0           15
# 40505        17_22_21_9_1_1           2_4_2_0_1_0           30
#
#       clean_purge_dam stage123_fill1 clean_purge_fill1 stage123_fill2  \
# 0                   0             12                 0              0
# 1                   2             57                 1              4
# 2                   0              0                 0              3
# 3                   2             34                 1              1
# 4                   3             53                 2              4
# ...               ...            ...               ...            ...
# 40501               2             57                 1              4
# 40502               0             60                 0              2
# 40503               0             24                 0              0
# 40504               2             35                 1              1
# 40505               3             40                 2              4
#
#       clean_purge_fill2  DIV Dispense Volume(Stage2)_Dam  \
# 0                     0                        14.482759
# 1                     1                        14.411765
# 2                     0                         9.139785
# 3                     1                        14.482759
# 4                     1                        14.411765
# ...                 ...                              ...
# 40501                 1                        14.285714
# 40502                 0                        14.406780
# 40503                 0                        14.385965
# 40504                 1                        14.411765
# 40505                 1                        14.444444
#
#        DIV Dispense Volume(Stage3)_Dam  STD Dispense Volume_Fill1  \
# 0                            14.411765                   4.962530
# 1                            14.295302                   5.427093
# 2                             9.130435                   5.459032
# 3                            14.295302                   5.427093
# 4                            14.328358                   5.427093
# ...                                ...                        ...
# 40501                        14.285714                   5.427093
# 40502                        14.411765                   5.427093
# 40503                        14.300000                   5.098003
# 40504                        14.477612                   5.401299
# 40505                        14.477612                   4.607255
#
#       Mismatch_Dam_Fill1 Mismatch_Dam_Fill2 Mismatch_Fill1_Fill2  \
# 0                  False              False                False
# 1                  False              False                False
# 2                  False              False                False
# 3                  False              False                False
# 4                  False              False                False
# ...                  ...                ...                  ...
# 40501              False              False                False
# 40502              False              False                False
# 40503              False              False                False
# 40504              False              False                False
# 40505              False              False                False
#
#       Mismatch_Receip_Dam_Fill1 Mismatch_Receip_Dam_Fill2  \
# 0                         False                     False
# 1                         False                     False
# 2                         False                     False
# 3                         False                     False
# 4                         False                     False
# ...                         ...                       ...
# 40501                     False                     False
# 40502                     False                     False
# 40503                     False                     False
# 40504                     False                     False
# 40505                     False                     False
#
#       Mismatch_Receip_Fill1_Fill2 Mismatch_equipment_Dam_Fill1  \
# 0                           False                         True
# 1                           False                         True
# 2                           False                         True
# 3                           False                         True
# 4                           False                         True
# ...                           ...                          ...
# 40501                       False                         True
# 40502                       False                         True
# 40503                       False                         True
# 40504                       False                         True
# 40505                       False                         True
#
#       Mismatch_equipment_Dam_Fill2 Mismatch_equipment_Fill1_Fill2
# 0                             True                           True
# 1                             True                           True
# 2                             True                           True
# 3                             True                           True
# 4                             True                           True
# ...                            ...                            ...
# 40501                         True                           True
# 40502                         True                           True
# 40503                         True                           True
# 40504                         True                           True
# 40505                         True                           True
#
# [40506 rows x 143 columns]

# %%
drop_col=['Equipment_Dam','Equipment_Fill1','Equipment_Fill2',
          'Receip No Collect Result_Dam','Receip No Collect Result_Fill1','Receip No Collect Result_Fill2',
         'Production Qty Collect Result_Dam','Production Qty Collect Result_Fill1','Production Qty Collect Result_Fill2',
         ]
train=train_data.drop(columns=drop_col)
test=test.drop(columns=drop_col)

# %%
# 먼저 각 컬럼을 datetime 형식으로 변환합니다.
train['Collect Date_Dam'] = pd.to_datetime(train['Collect Date_Dam'])
train['Collect Date_AutoClave'] = pd.to_datetime(train['Collect Date_AutoClave'])

# AutoClave에서 Dam을 뺀 시간을 계산하여 새로운 컬럼에 저장합니다.
train['Time_Difference_AutoClave_Dam'] = train['Collect Date_AutoClave'] - train['Collect Date_Dam']
train['Time_Difference_AutoClave_Dam'] = train['Time_Difference_AutoClave_Dam'].apply(lambda x: str(x).replace("0 days ", ""))
train['Time_Difference_AutoClave_Dam'] = train['Time_Difference_AutoClave_Dam'].astype("object")


# 결과 확인
print(train[['Collect Date_AutoClave', 'Collect Date_Dam', 'Time_Difference_AutoClave_Dam']].head())
# Out:
#   Collect Date_AutoClave    Collect Date_Dam Time_Difference_AutoClave_Dam
# 0    2024-04-25 11:50:00 2024-04-25 11:10:00                      00:40:00
# 1    2023-09-19 15:00:00 2023-09-19 14:30:00                      00:30:00
# 2    2024-03-05 10:10:00 2024-03-05 09:30:00                      00:40:00
# 3    2023-09-25 16:20:00 2023-09-25 15:40:00                      00:40:00
# 4    2023-06-27 14:00:00 2023-06-27 13:20:00                      00:40:00

# %%
# 먼저 각 컬럼을 datetime 형식으로 변환합니다.
test['Collect Date_Dam'] = pd.to_datetime(test['Collect Date_Dam'])
test['Collect Date_AutoClave'] = pd.to_datetime(test['Collect Date_AutoClave'])

# AutoClave에서 Dam을 뺀 시간을 계산하여 새로운 컬럼에 저장합니다.
test['Time_Difference_AutoClave_Dam'] = test['Collect Date_AutoClave'] - test['Collect Date_Dam']

test['Time_Difference_AutoClave_Dam'] = test['Time_Difference_AutoClave_Dam'].apply(lambda x: str(x).replace("0 days ", ""))
test['Time_Difference_AutoClave_Dam'] = test['Time_Difference_AutoClave_Dam'].astype("object")
# 결과 확인
print(test[['Collect Date_AutoClave', 'Collect Date_Dam', 'Time_Difference_AutoClave_Dam']].head())
# Out:
#   Collect Date_AutoClave    Collect Date_Dam Time_Difference_AutoClave_Dam
# 0    2023-09-15 14:00:00 2023-09-15 13:20:00                      00:40:00
# 1    2024-02-06 17:30:00 2024-02-06 16:50:00                      00:40:00
# 2    2023-07-14 12:10:00 2023-07-14 11:30:00                      00:40:00
# 3    2023-11-03 08:30:00 2023-11-03 08:00:00                      00:30:00
# 4    2023-12-23 14:40:00 2023-12-23 14:00:00                      00:40:00

# %%
train=train.drop(columns=['Collect Date_Dam', 'Collect Date_AutoClave', 'Collect Date_Fill1', 'Collect Date_Fill2'])
test=test.drop(columns=['Collect Date_Dam', 'Collect Date_AutoClave', 'Collect Date_Fill1', 'Collect Date_Fill2'])

# %%
# time=train[['Collect Date_Dam', 'Collect Date_AutoClave', 'Collect Date_Fill1', 'Collect Date_Fill2']]
# time.loc[ train['Collect Date_Fill1']!= train['Collect Date_Fill2']]

# %%
# time['Collect Date_AutoClave']-time['Collect Date_Dam']

# %%
# # 먼저 각 컬럼을 datetime 형식으로 변환합니다.
# time['Collect Date_Dam'] = pd.to_datetime(time['Collect Date_Dam'])
# time['Collect Date_AutoClave'] = pd.to_datetime(time['Collect Date_AutoClave'])

# # AutoClave에서 Dam을 뺀 시간을 계산하여 새로운 컬럼에 저장합니다.
# time['Time_Difference_AutoClave_Dam'] = time['Collect Date_AutoClave'] - time['Collect Date_Dam']

# # 결과 확인
# print(time[['Collect Date_AutoClave', 'Collect Date_Dam', 'Time_Difference_AutoClave_Dam']].head())

# %%
# time

# %%
# # 먼저 각 컬럼을 datetime 형식으로 변환합니다.
# train_data['Collect Date_Dam'] = pd.to_datetime(train_data['Collect Date_Dam'])
# train_data['Collect Date_AutoClave'] = pd.to_datetime(train_data['Collect Date_AutoClave'])

# # AutoClave에서 Dam을 뺀 시간을 계산하여 새로운 컬럼에 저장합니다.
# train_data['Time_Difference_AutoClave_Dam'] = train_data['Collect Date_AutoClave'] - train_data['Collect Date_Dam']

# # 결과 확인
# print(train_data[['Collect Date_AutoClave', 'Collect Date_Dam', 'Time_Difference_AutoClave_Dam']].head())

# %%
# 각 컬럼의 NA 개수 계산
na_counts = train_data.isna().sum()

# NA 개수가 0보다 큰 컬럼 목록 필터링
columns_with_na = na_counts[na_counts > 0].index.tolist()

# 결과 출력
print("NA 개수가 0보다 큰 컬럼들:")
columns_with_na
# Out:
# NA 개수가 0보다 큰 컬럼들:
# []

# %%
# 각 컬럼의 NA 개수 계산
na_counts = test.isna().sum()

# NA 개수가 0보다 큰 컬럼 목록 필터링
columns_with_na = na_counts[na_counts > 0].index.tolist()

# 결과 출력
print("NA 개수가 0보다 큰 컬럼들:")
columns_with_na
# Out:
# NA 개수가 0보다 큰 컬럼들:
# ['target']

# %%
train.info(200)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40506 entries, 0 to 40505
# Data columns (total 131 columns):
#  #    Column                                                     Dtype
# ---   ------                                                     -----
#  0    CURE END POSITION X Collect Result_Dam                     float64
#  1    CURE END POSITION Z Collect Result_Dam                     float64
#  2    CURE END POSITION Θ Collect Result_Dam                     int64
#  3    CURE SPEED Collect Result_Dam                              int64
#  4    CURE START POSITION X Collect Result_Dam                   int64
#  5    CURE START POSITION Θ Collect Result_Dam                   int64
#  6    DISCHARGED SPEED OF RESIN Collect Result_Dam               int64
#  7    DISCHARGED TIME OF RESIN(Stage1) Collect Result_Dam        float64
#  8    DISCHARGED TIME OF RESIN(Stage2) Collect Result_Dam        float64
#  9    DISCHARGED TIME OF RESIN(Stage3) Collect Result_Dam        float64
#  10   Dispense Volume(Stage1) Collect Result_Dam                 float64
#  11   Dispense Volume(Stage2) Collect Result_Dam                 float64
#  12   Dispense Volume(Stage3) Collect Result_Dam                 float64
#  13   Machine Tact time Collect Result_Dam                       float64
#  14   PalletID Collect Result_Dam                                float64
#  15   Stage1 Circle1 Distance Speed Collect Result_Dam           int64
#  16   Stage1 Circle2 Distance Speed Collect Result_Dam           int64
#  17   Stage1 Circle3 Distance Speed Collect Result_Dam           int64
#  18   Stage1 Circle4 Distance Speed Collect Result_Dam           int64
#  19   Stage1 Line1 Distance Speed Collect Result_Dam             int64
#  20   Stage1 Line2 Distance Speed Collect Result_Dam             int64
#  21   Stage1 Line3 Distance Speed Collect Result_Dam             int64
#  22   Stage1 Line4 Distance Speed Collect Result_Dam             int64
#  23   Stage2 Circle1 Distance Speed Collect Result_Dam           int64
#  24   Stage2 Circle2 Distance Speed Collect Result_Dam           int64
#  25   Stage2 Circle3 Distance Speed Collect Result_Dam           int64
#  26   Stage2 Circle4 Distance Speed Collect Result_Dam           int64
#  27   Stage2 Line1 Distance Speed Collect Result_Dam             int64
#  28   Stage2 Line2 Distance Speed Collect Result_Dam             int64
#  29   Stage2 Line3 Distance Speed Collect Result_Dam             int64
#  30   Stage2 Line4 Distance Speed Collect Result_Dam             int64
#  31   Stage3 Circle1 Distance Speed Collect Result_Dam           int64
#  32   Stage3 Circle2 Distance Speed Collect Result_Dam           int64
#  33   Stage3 Circle3 Distance Speed Collect Result_Dam           int64
#  34   Stage3 Circle4 Distance Speed Collect Result_Dam           int64
#  35   Stage3 Line1 Distance Speed Collect Result_Dam             int64
#  36   Stage3 Line2 Distance Speed Collect Result_Dam             int64
#  37   Stage3 Line3 Distance Speed Collect Result_Dam             int64
#  38   Stage3 Line4 Distance Speed Collect Result_Dam             int64
#  39   THICKNESS 1 Collect Result_Dam                             int64
#  40   THICKNESS 2 Collect Result_Dam                             float64
#  41   THICKNESS 3 Collect Result_Dam                             float64
#  42   WorkMode Collect Result_Dam                                float64
#  43   1st Pressure Collect Result_AutoClave                      float64
#  44   1st Pressure 1st Pressure Unit Time_AutoClave              int64
#  45   2nd Pressure Collect Result_AutoClave                      float64
#  46   2nd Pressure Unit Time_AutoClave                           int64
#  47   3rd Pressure Collect Result_AutoClave                      float64
#  48   3rd Pressure Unit Time_AutoClave                           int64
#  49   Chamber Temp. Collect Result_AutoClave                     int64
#  50   Chamber Temp. Unit Time_AutoClave                          int64
#  51   Chamber Temp. Judge Value_AutoClave                        object
#  52   DISCHARGED SPEED OF RESIN Collect Result_Fill1             float64
#  53   DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill1      float64
#  54   DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill1      float64
#  55   DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill1      float64
#  56   Dispense Volume(Stage1) Collect Result_Fill1               float64
#  57   Dispense Volume(Stage2) Collect Result_Fill1               float64
#  58   Dispense Volume(Stage3) Collect Result_Fill1               float64
#  59   Machine Tact time Collect Result_Fill1                     float64
#  60   PalletID Collect Result_Fill1                              float64
#  61   WorkMode Collect Result_Fill1                              int64
#  62   CURE END POSITION X Collect Result_Fill2                   int64
#  63   CURE END POSITION Z Collect Result_Fill2                   int64
#  64   CURE SPEED Collect Result_Fill2                            int64
#  65   CURE STANDBY POSITION Z Collect Result_Fill2               int64
#  66   CURE START POSITION X Collect Result_Fill2                 int64
#  67   CURE START POSITION Z Collect Result_Fill2                 int64
#  68   Machine Tact time Collect Result_Fill2                     float64
#  69   PalletID Collect Result_Fill2                              float64
#  70   WorkMode Collect Result_Fill2                              int64
#  71   target                                                     object
#  72   Model.Suffix                                               object
#  73   Workorder                                                  object
#  74   running_time_m                                             float64
#  75   month                                                      int32
#  76   day                                                        int32
#  77   hour                                                       int32
#  78   out_of_hour                                                int64
#  79   Dam X                                                      object
#  80   Dam Y                                                      object
#  81   Dam Z                                                      object
#  82   Fill1 X                                                    object
#  83   Fill1 Y                                                    object
#  84   Fill1 Z                                                    object
#  85   Fill2 X                                                    object
#  86   Fill2 Y                                                    object
#  87   Fill2 Z                                                    object
#  88   Head Clean&Purge Position X Collect Result_Fill1           object
#  89   Head Clean&Purge Position Y Collect Result_Fill1           object
#  90   Head Clean&Purge Position Z Collect Result_Fill1           object
#  91   Head Clean&Purge Position X Collect Result_Dam             object
#  92   Head Clean&Purge Position Y Collect Result_Dam             object
#  93   Head Clean&Purge Position Z Collect Result_Dam             object
#  94   CURE  POSITION X Collect Result_Dam                        object
#  95   CURE  POSITION Θ Collect Result_Dam                        object
#  96   CURE  POSITION X Collect Result_Fill2                      object
#  97   CURE  POSITION Z Collect Result_Fill2                      object
#  98   HEAD NORMAL COORDINATE X AXIS(Stage) Collect Result_Dam    object
#  99   HEAD NORMAL COORDINATE Y AXIS(Stage) Collect Result_Dam    object
#  100  HEAD NORMAL COORDINATE Z AXIS(Stage) Collect Result_Dam    object
#  101  HEAD NORMAL COORDINATE X AXIS(Stage) Collect Result_Fill1  object
#  102  HEAD NORMAL COORDINATE Y AXIS(Stage) Collect Result_Fill1  object
#  103  HEAD NORMAL COORDINATE Z AXIS(Stage) Collect Result_Fill1  object
#  104  HEAD NORMAL COORDINATE X AXIS(Stage) Collect Result_Fill2  object
#  105  HEAD NORMAL COORDINATE Y AXIS(Stage) Collect Result_Fill2  object
#  106  HEAD NORMAL COORDINATE Z AXIS(Stage) Collect Result_Fill2  object
#  107  HEAD NORMAL COORDINATE AXIS(Stage1) Judge Value_Dam XYZ    object
#  108  Head Zero Position Collect Result_Dam XYZ                  object
#  109  head_interactionDam                                        object
#  110  head_interactionFill1                                      object
#  111  head_interactionFill2                                      object
#  112  stage123_dam                                               object
#  113  clean_purge_dam                                            object
#  114  stage123_fill1                                             object
#  115  clean_purge_fill1                                          object
#  116  stage123_fill2                                             object
#  117  clean_purge_fill2                                          object
#  118  DIV Dispense Volume(Stage2)_Dam                            float64
#  119  DIV Dispense Volume(Stage3)_Dam                            float64
#  120  STD Dispense Volume_Fill1                                  float64
#  121  Mismatch_Dam_Fill1                                         object
#  122  Mismatch_Dam_Fill2                                         object
#  123  Mismatch_Fill1_Fill2                                       object
#  124  Mismatch_Receip_Dam_Fill1                                  object
#  125  Mismatch_Receip_Dam_Fill2                                  object
#  126  Mismatch_Receip_Fill1_Fill2                                object
#  127  Mismatch_equipment_Dam_Fill1                               object
#  128  Mismatch_equipment_Dam_Fill2                               object
#  129  Mismatch_equipment_Fill1_Fill2                             object
#  130  Time_Difference_AutoClave_Dam                              object
# dtypes: float64(31), int32(3), int64(44), object(53)
# memory usage: 40.0+ MB

# %%
# train['Workorder1'] = train['Workorder'].str[:3]
# train['Workorder3']=train['Workorder'].apply(lambda x:x[5:8]).astype(int)

# test['Workorder1'] = test['Workorder'].str[:3]
# test['Workorder3']=test['Workorder'].apply(lambda x:x[5:8]).astype(int)

# train=train.drop(columns=['Workorder','Model.Suffix'])
# test=test.drop(columns=['Workorder','Model.Suffix'])

# %%
data_type = train.dtypes.reset_index()
data_type.columns = ['col', 'type']
cat_features = list(data_type[data_type['type']=='object']['col'])
num_features = list(data_type[data_type['type']!='object']['col'])
data_type['unique'] = data_type['col'].apply(lambda x : train[x].nunique())
data_type['nullcount'] = data_type['col'].apply(lambda x : train[x].isnull().sum())
print('범주형 변수 수 : ' ,len(cat_features))
print('숫자형 변수 수 : ' ,len(num_features))
# Out:
# 범주형 변수 수 :  53
# 숫자형 변수 수 :  78

# %%
train_num = train.loc[:,num_features]
original_cols = train_num.columns
rank = np.linalg.matrix_rank(train_num.values)
independent_cols = []
for i in range(len(original_cols)):
    sub_matrix = train_num[original_cols[:i+1]].values
    if np.linalg.matrix_rank(sub_matrix) > len(independent_cols):
        independent_cols.append(original_cols[i])
train = train.loc[:,cat_features + independent_cols]
test = test.loc[:,cat_features + independent_cols]

# %%
data_type = train.dtypes.reset_index()
data_type.columns = ['col', 'type']
cat_features = list(data_type[data_type['type']=='object']['col'])
num_features = list(data_type[data_type['type']!='object']['col'])
data_type['unique'] = data_type['col'].apply(lambda x : train[x].nunique())
data_type['nullcount'] = data_type['col'].apply(lambda x : train[x].isnull().sum())
print('범주형 변수 수 : ' ,len(cat_features))
print('숫자형 변수 수 : ' ,len(num_features))
# Out:
# 범주형 변수 수 :  53
# 숫자형 변수 수 :  61

# %%
num_features

# ['CURE END POSITION X Collect Result_Dam',
#  'CURE END POSITION Z Collect Result_Dam',
#  'CURE SPEED Collect Result_Dam',
#  'DISCHARGED SPEED OF RESIN Collect Result_Dam',
#  'DISCHARGED TIME OF RESIN(Stage1) Collect Result_Dam',
#  'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Dam',
#  'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Dam',
#  'Dispense Volume(Stage1) Collect Result_Dam',
#  'Dispense Volume(Stage2) Collect Result_Dam',
#  'Dispense Volume(Stage3) Collect Result_Dam',
#  'Machine Tact time Collect Result_Dam',
#  'PalletID Collect Result_Dam',
#  'Stage1 Circle1 Distance Speed Collect Result_Dam',
#  'Stage1 Circle2 Distance Speed Collect Result_Dam',
#  'Stage1 Line1 Distance Speed Collect Result_Dam',
#  'Stage1 Line2 Distance Speed Collect Result_Dam',
#  'Stage1 Line4 Distance Speed Collect Result_Dam',
#  'Stage2 Circle1 Distance Speed Collect Result_Dam',
#  'Stage2 Circle2 Distance Speed Collect Result_Dam',
#  'Stage2 Line2 Distance Speed Collect Result_Dam',
#  'Stage2 Line3 Distance Speed Collect Result_Dam',
#  'Stage2 Line4 Distance Speed Collect Result_Dam',
#  'Stage3 Circle2 Distance Speed Collect Result_Dam',
#  'Stage3 Line2 Distance Speed Collect Result_Dam',
#  'Stage3 Line4 Distance Speed Collect Result_Dam',
#  'THICKNESS 1 Collect Result_Dam',
#  'THICKNESS 2 Collect Result_Dam',
#  'THICKNESS 3 Collect Result_Dam',
#  'WorkMode Collect Result_Dam',
#  '1st Pressure Collect Result_AutoClave',
#  '1st Pressure 1st Pressure Unit Time_AutoClave',
#  '2nd Pressure Collect Result_AutoClave',
#  '2nd Pressure Unit Time_AutoClave',
#  '3rd Pressure Collect Result_AutoClave',
#  '3rd Pressure Unit Time_AutoClave',
#  'Chamber Temp. Collect Result_AutoClave',
#  'DISCHARGED SPEED OF RESIN Collect Result_Fill1',
#  'DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill1',
#  'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill1',
#  'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill1',
#  'Dispense Volume(Stage1) Collect Result_Fill1',
#  'Dispense Volume(Stage2) Collect Result_Fill1',
#  'Dispense Volume(Stage3) Collect Result_Fill1',
#  'Machine Tact time Collect Result_Fill1',
#  'PalletID Collect Result_Fill1',
#  'WorkMode Collect Result_Fill1',
#  'CURE END POSITION X Collect Result_Fill2',
#  'CURE END POSITION Z Collect Result_Fill2',
#  'CURE SPEED Collect Result_Fill2',
#  'CURE STANDBY POSITION Z Collect Result_Fill2',
#  'Machine Tact time Collect Result_Fill2',
#  'PalletID Collect Result_Fill2',
#  'WorkMode Collect Result_Fill2',
#  'DIV Dispense Volume(Stage2)_Dam',
#  'DIV Dispense Volume(Stage3)_Dam',
#  'STD Dispense Volume_Fill1']
# Out:
# ['CURE END POSITION X Collect Result_Dam',
#  'CURE END POSITION Z Collect Result_Dam',
#  'CURE SPEED Collect Result_Dam',
#  'DISCHARGED SPEED OF RESIN Collect Result_Dam',
#  'DISCHARGED TIME OF RESIN(Stage1) Collect Result_Dam',
#  'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Dam',
#  'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Dam',
#  'Dispense Volume(Stage1) Collect Result_Dam',
#  'Dispense Volume(Stage2) Collect Result_Dam',
#  'Dispense Volume(Stage3) Collect Result_Dam',
#  'Machine Tact time Collect Result_Dam',
#  'PalletID Collect Result_Dam',
#  'Stage1 Circle1 Distance Speed Collect Result_Dam',
#  'Stage1 Circle2 Distance Speed Collect Result_Dam',
#  'Stage1 Line1 Distance Speed Collect Result_Dam',
#  'Stage1 Line2 Distance Speed Collect Result_Dam',
#  'Stage1 Line4 Distance Speed Collect Result_Dam',
#  'Stage2 Circle1 Distance Speed Collect Result_Dam',
#  'Stage2 Circle2 Distance Speed Collect Result_Dam',
#  'Stage2 Line2 Distance Speed Collect Result_Dam',
#  'Stage2 Line3 Distance Speed Collect Result_Dam',
#  'Stage2 Line4 Distance Speed Collect Result_Dam',
#  'Stage3 Circle2 Distance Speed Collect Result_Dam',
#  'Stage3 Line2 Distance Speed Collect Result_Dam',
#  'Stage3 Line4 Distance Speed Collect Result_Dam',
#  'THICKNESS 1 Collect Result_Dam',
#  'THICKNESS 2 Collect Result_Dam',
#  'THICKNESS 3 Collect Result_Dam',
#  'WorkMode Collect Result_Dam',
#  '1st Pressure Collect Result_AutoClave',
#  '1st Pressure 1st Pressure Unit Time_AutoClave',
#  '2nd Pressure Collect Result_AutoClave',
#  '2nd Pressure Unit Time_AutoClave',
#  '3rd Pressure Collect Result_AutoClave',
#  '3rd Pressure Unit Time_AutoClave',
#  'Chamber Temp. Collect Result_AutoClave',
#  'DISCHARGED SPEED OF RESIN Collect Result_Fill1',
#  'DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill1',
#  'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill1',
#  'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill1',
#  'Dispense Volume(Stage1) Collect Result_Fill1',
#  'Dispense Volume(Stage2) Collect Result_Fill1',
#  'Dispense Volume(Stage3) Collect Result_Fill1',
#  'Machine Tact time Collect Result_Fill1',
#  'PalletID Collect Result_Fill1',
#  'WorkMode Collect Result_Fill1',
#  'CURE END POSITION X Collect Result_Fill2',
#  'CURE END POSITION Z Collect Result_Fill2',
#  'CURE SPEED Collect Result_Fill2',
#  'CURE STANDBY POSITION Z Collect Result_Fill2',
#  'Machine Tact time Collect Result_Fill2',
#  'PalletID Collect Result_Fill2',
#  'WorkMode Collect Result_Fill2',
#  'running_time_m',
#  'month',
#  'day',
#  'hour',
#  'out_of_hour',
#  'DIV Dispense Volume(Stage2)_Dam',
#  'DIV Dispense Volume(Stage3)_Dam',
#  'STD Dispense Volume_Fill1']

# %%
# 'MEAN Dispense Volume_Dam',
#        'SUM Dispense Volume_Dam', 'DIV Dispense Volume(Stage2)_Dam',
#        'DIV Dispense Volume(Stage3)_Dam', 'SUM DISCHARGED TIME OF RESIN_Fill1',
#        'MEAN Dispense Volume_Fill1', 'STD Dispense Volume_Fill1',
#        'DIV1 THICKNESS_Dam', 'DIV2 THICKNESS_Dam', 'SUM Pressure_AutoClave',
#        'MEAN Pressure_AutoClave', 'DIV1 Pressure_AutoClave',
#        'DIV2 Pressure_AutoClave'

# %%
for col in ['target']:
    le = LabelEncoder()
    le = le.fit(train[col])
    train[col] = le.transform(train[col])
    for label in list(test[col].unique()): #train에 없는 test값 처리
        if label not in list(le.classes_):
            le.classes_ = np.append(le.classes_,label)
    test[col] = le.transform(test[col])
cat_features.remove('target')

# %%
target = train['target']
train = train.drop('target', axis=1)

# %%
for col in cat_features:
  train[col] = train[col].astype("category")
  test[col] = test[col].astype("category")

# %%
train['target'] = target.apply(lambda x : 1 if x==0 else 0)

# %%
tuning_train, tuning_valid = train_test_split(train, test_size=0.2, random_state=0, stratify=train['target'])
# 적합에 필요한 데이터 분리
x_train = tuning_train.drop('target', axis=1)
y_train = tuning_train['target']
# 검증에 필요한 데이터 분리
x_valid = tuning_valid.drop('target', axis=1)
y_valid = tuning_valid['target']
# set seed
SEED = 0
# class weight
class_weights = compute_class_weight(classes=np.array([0,1]), y=tuning_train['target'], class_weight='balanced')
class_weights = {i: weight for i, weight in enumerate(class_weights)}
class_weights
# Out:
# {0: 0.5307954396540427, 1: 8.61808510638298}

# %%
train
# Out:
#       Chamber Temp. Judge Value_AutoClave Model.Suffix   Workorder  \
# 0                                      OK  AJX75334505  4F1XA938-1
# 1                                      OK  AJX75334505  3KPM0016-2
# 2                                      OK  AJX75334501  4E1X9167-1
# 3                                      OK  AJX75334501  3K1X0057-1
# 4                                      NG  AJX75334501  3HPM0007-1
# ...                                   ...          ...         ...
# 40501                                  OK  AJX75334501  3J1XF434-2
# 40502                                  NG  AJX75334501  4E1XC796-1
# 40503                                  NG  AJX75334501  4C1XD438-1
# 40504                                  OK  AJX75334501  3I1XA258-1
# 40505                                  NG  AJX75334501  3G1XA501-1
#
#                                                    Dam X  \
# 0      (161.0, 550.5, 464.3, 274.51, 0.0, 124.0, 130.85)
# 1      (550.3, 463.8, 160.8, 257.0, 127.5, 257.0, 505.0)
# 2      (550.4, 162.4, 465.4, 274.33, 0.0, 124.0, 130.85)
# 3      (162.4, 465.5, 552.0, 257.0, 127.5, 257.0, 505.0)
# 4      (549.0, 462.5, 159.5, 257.0, 127.5, 257.0, 505.0)
# ...                                                  ...
# 40501  (550.3, 463.8, 160.8, 257.0, 127.5, 257.0, 505.0)
# 40502  (550.4, 163.5, 466.2, 274.33, 0.0, 124.0, 130.85)
# 40503  (161.0, 550.6, 463.9, 274.78, 0.0, 124.0, 130.85)
# 40504  (162.4, 465.1, 551.3, 257.0, 127.5, 257.0, 505.0)
# 40505  (549.0, 463.0, 160.5, 257.0, 127.5, 257.0, 505.0)
#
#                                                  Dam Y  \
# 0        (161.4, 384.0, 383.1, 257, 127.5, 257, 505.0)
# 1           (377.3, 377.3, 377.3, 66, 66.0, 66, 300.0)
# 2      (551.7, 1271.8, 1383.9, 257, 127.5, 257, 505.0)
# 3        (1271.8, 1270.7, 1271.8, 66, 66.0, 66, 300.0)
# 4           (377.5, 377.0, 377.5, 66, 66.0, 66, 300.0)
# ...                                                ...
# 40501       (377.3, 377.3, 377.3, 66, 66.0, 66, 300.0)
# 40502  (553.1, 1281.0, 1393.5, 257, 127.5, 257, 505.0)
# 40503    (161.5, 377.6, 377.1, 257, 127.5, 257, 505.0)
# 40504    (1269.0, 1268.4, 1269.0, 66, 66.0, 66, 300.0)
# 40505       (377.5, 377.0, 377.5, 66, 66.0, 66, 303.5)
#
#                                                    Dam Z  \
# 0         (384.0, 274.51, 274.51, 66, 66.0, 66.0, 300.0)
# 1      (282.15, 282.15, 282.15, 0, 130.85, 130.85, 26...
# 2        (1271.8, 274.33, 274.33, 66, 66.0, 66.0, 300.0)
# 3      (282.15, 282.15, 282.15, 0, 130.85, 130.85, 26...
# 4          (284.8, 284.8, 284.8, 0, 133.5, 133.5, 265.0)
# ...                                                  ...
# 40501  (282.15, 282.15, 282.15, 0, 130.85, 130.85, 26...
# 40502    (1281.2, 274.33, 274.33, 66, 66.0, 66.0, 300.0)
# 40503     (378.0, 274.78, 274.78, 66, 66.0, 66.0, 300.0)
# 40504  (282.15, 282.15, 282.15, 0, 130.85, 130.85, 26...
# 40505      (284.8, 284.8, 284.8, 0, 133.5, 133.5, 265.0)
#
#                                           Fill1 X  \
# 0        (157.0, 838.4, 458.7, 244.52, 0.0, 92.2)
# 1      (838.4, 458.5, 157.0, 289.0, 123.4, 289.0)
# 2       (157.0, 837.9, 458.1, 244.415, 0.0, 92.2)
# 3      (837.7, 458.8, 157.0, 289.0, 123.4, 289.0)
# 4      (838.4, 458.5, 157.0, 289.0, 123.4, 289.0)
# ...                                           ...
# 40501  (838.4, 458.5, 157.0, 289.0, 123.4, 289.0)
# 40502   (157.0, 838.1, 458.7, 244.535, 0.0, 92.2)
# 40503   (157.0, 838.4, 458.4, 244.543, 0.0, 92.2)
# 40504  (837.7, 458.8, 157.0, 289.0, 123.4, 289.0)
# 40505  (837.9, 460.0, 157.5, 289.0, 123.4, 289.0)
#
#                                         Fill1 Y  \
# 0        (157.0, 430.0, 429.8, 289, 123.4, 289)
# 1           (430.5, 430.5, 430.8, 50, 50.0, 50)
# 2      (156.1, 1323.5, 1322.5, 289, 123.4, 289)
# 3        (1323.2, 1322.5, 1322.8, 50, 50.0, 50)
# 4           (430.2, 430.5, 430.5, 50, 50.0, 50)
# ...                                         ...
# 40501       (430.5, 430.5, 430.8, 50, 50.0, 50)
# 40502  (156.1, 1325.0, 1324.0, 289, 123.4, 289)
# 40503    (157.0, 430.8, 430.5, 289, 123.4, 289)
# 40504    (1323.2, 1323.0, 1322.8, 50, 50.0, 50)
# 40505       (430.2, 430.5, 430.5, 50, 50.0, 50)
#
#                                         Fill1 Z  \
# 0         (430.3, 244.52, 244.52, 50, 50.0, 50)
# 1           (244.4, 244.4, 244.4, 0, 92.2, 145)
# 2      (1323.1, 244.415, 244.415, 50, 50.0, 50)
# 3           (244.3, 244.3, 244.3, 0, 92.2, 145)
# 4            (244.4, 244.4, 244.4, 0, 92.2, 85)
# ...                                         ...
# 40501       (244.4, 244.4, 244.4, 0, 92.2, 145)
# 40502  (1324.3, 244.535, 244.535, 50, 50.0, 50)
# 40503   (431.1, 244.543, 244.543, 50, 50.0, 50)
# 40504       (244.4, 244.4, 244.4, 0, 92.2, 145)
# 40505        (244.3, 244.3, 244.3, 0, 92.2, 85)
#
#                                         Fill2 X  \
# 0       (156.0, 835.5, 458.0, 243.7, -10, 91.8)
# 1      (835.5, 458.0, 156.0, 270.0, 119, 270.0)
# 2       (694.0, 305.0, 499.8, 243.5, -10, 91.8)
# 3      (305.0, 499.8, 694.0, 270.0, 119, 270.0)
# 4      (835.5, 458.0, 156.0, 270.0, 119, 270.0)
# ...                                         ...
# 40501  (835.5, 458.0, 156.0, 270.0, 119, 270.0)
# 40502   (694.0, 304.8, 499.8, 243.5, -10, 91.8)
# 40503   (156.0, 835.5, 458.0, 243.7, -10, 91.8)
# 40504  (305.0, 499.8, 694.0, 270.0, 119, 270.0)
# 40505  (835.5, 458.0, 156.0, 270.0, 119, 270.0)
#
#                                       Fill2 Y  \
# 0        (156.0, 428.0, 427.9, 270, 119, 270)
# 1           (428.0, 427.9, 428.0, 50, 50, 50)
# 2      (694.0, 1324.2, 1324.2, 270, 119, 270)
# 3        (1324.2, 1324.2, 1324.2, 50, 50, 50)
# 4           (428.0, 427.9, 428.0, 50, 50, 50)
# ...                                       ...
# 40501       (428.0, 427.9, 428.0, 50, 50, 50)
# 40502  (692.8, 1324.2, 1324.2, 270, 119, 270)
# 40503    (156.0, 428.0, 427.9, 270, 119, 270)
# 40504    (1324.2, 1324.2, 1324.2, 50, 50, 50)
# 40505       (428.0, 427.9, 428.0, 50, 50, 50)
#
#                                     Fill2 Z  \
# 0       (428.0, 243.7, 243.7, 50, 50.0, 50)
# 1      (243.7, 243.7, 243.7, -10, 91.8, 85)
# 2      (1324.2, 243.5, 243.5, 50, 50.0, 50)
# 3      (243.5, 243.5, 243.5, -10, 91.8, 85)
# 4      (243.7, 243.7, 243.7, -10, 91.8, 85)
# ...                                     ...
# 40501  (243.7, 243.7, 243.7, -10, 91.8, 85)
# 40502  (1324.2, 243.5, 243.5, 50, 50.0, 50)
# 40503   (428.0, 243.7, 243.7, 50, 50.0, 50)
# 40504  (243.5, 243.5, 243.5, -10, 91.8, 85)
# 40505  (243.7, 243.7, 243.7, -10, 91.8, 85)
#
#       Head Clean&Purge Position X Collect Result_Fill1  \
# 0                                          (0.0, 92.2)
# 1                                       (123.4, 289.0)
# 2                                          (0.0, 92.2)
# 3                                       (123.4, 289.0)
# 4                                       (123.4, 289.0)
# ...                                                ...
# 40501                                   (123.4, 289.0)
# 40502                                      (0.0, 92.2)
# 40503                                      (0.0, 92.2)
# 40504                                   (123.4, 289.0)
# 40505                                   (123.4, 289.0)
#
#       Head Clean&Purge Position Y Collect Result_Fill1  \
# 0                                         (123.4, 289)
# 1                                           (50.0, 50)
# 2                                         (123.4, 289)
# 3                                           (50.0, 50)
# 4                                           (50.0, 50)
# ...                                                ...
# 40501                                       (50.0, 50)
# 40502                                     (123.4, 289)
# 40503                                     (123.4, 289)
# 40504                                       (50.0, 50)
# 40505                                       (50.0, 50)
#
#       Head Clean&Purge Position Z Collect Result_Fill1  \
# 0                                           (50.0, 50)
# 1                                          (92.2, 145)
# 2                                           (50.0, 50)
# 3                                          (92.2, 145)
# 4                                           (92.2, 85)
# ...                                                ...
# 40501                                      (92.2, 145)
# 40502                                       (50.0, 50)
# 40503                                       (50.0, 50)
# 40504                                      (92.2, 145)
# 40505                                       (92.2, 85)
#
#       Head Clean&Purge Position X Collect Result_Dam  \
# 0                                       (0.0, 124.0)
# 1                                     (127.5, 257.0)
# 2                                       (0.0, 124.0)
# 3                                     (127.5, 257.0)
# 4                                     (127.5, 257.0)
# ...                                              ...
# 40501                                 (127.5, 257.0)
# 40502                                   (0.0, 124.0)
# 40503                                   (0.0, 124.0)
# 40504                                 (127.5, 257.0)
# 40505                                 (127.5, 257.0)
#
#       Head Clean&Purge Position Y Collect Result_Dam  \
# 0                                       (127.5, 257)
# 1                                         (66.0, 66)
# 2                                       (127.5, 257)
# 3                                         (66.0, 66)
# 4                                         (66.0, 66)
# ...                                              ...
# 40501                                     (66.0, 66)
# 40502                                   (127.5, 257)
# 40503                                   (127.5, 257)
# 40504                                     (66.0, 66)
# 40505                                     (66.0, 66)
#
#       Head Clean&Purge Position Z Collect Result_Dam  \
# 0                                       (66.0, 66.0)
# 1                                   (130.85, 130.85)
# 2                                       (66.0, 66.0)
# 3                                   (130.85, 130.85)
# 4                                     (133.5, 133.5)
# ...                                              ...
# 40501                               (130.85, 130.85)
# 40502                                   (66.0, 66.0)
# 40503                                   (66.0, 66.0)
# 40504                               (130.85, 130.85)
# 40505                                 (133.5, 133.5)
#
#       CURE  POSITION X Collect Result_Dam CURE  POSITION Θ Collect Result_Dam  \
# 0                           (1030, 240.0)                          (-90, -90)
# 1                           (1030, 240.0)                          (-90, -90)
# 2                           (280, 1000.0)                            (90, 90)
# 3                           (280, 1000.0)                            (90, 90)
# 4                           (1030, 240.0)                          (-90, -90)
# ...                                   ...                                 ...
# 40501                       (1030, 240.0)                          (-90, -90)
# 40502                       (280, 1000.0)                            (90, 90)
# 40503                       (1030, 240.0)                          (-90, -90)
# 40504                       (280, 1000.0)                            (90, 90)
# 40505                       (1030, 240.0)                          (-90, -90)
#
#       CURE  POSITION X Collect Result_Fill2  \
# 0                               (1020, 240)
# 1                               (1020, 240)
# 2                               (1020, 240)
# 3                               (1020, 240)
# 4                               (1020, 240)
# ...                                     ...
# 40501                           (1020, 240)
# 40502                           (1020, 240)
# 40503                           (1020, 240)
# 40504                           (1020, 240)
# 40505                           (1020, 240)
#
#       CURE  POSITION Z Collect Result_Fill2  \
# 0                                  (33, 33)
# 1                                  (33, 33)
# 2                                  (33, 33)
# 3                                  (33, 33)
# 4                                  (33, 32)
# ...                                     ...
# 40501                              (33, 33)
# 40502                              (33, 33)
# 40503                              (33, 33)
# 40504                              (33, 33)
# 40505                              (32, 32)
#
#       HEAD NORMAL COORDINATE X AXIS(Stage) Collect Result_Dam  \
# 0                                  (161.0, 550.5, 464.3)
# 1                                  (550.3, 463.8, 160.8)
# 2                                  (550.4, 162.4, 465.4)
# 3                                  (162.4, 465.5, 552.0)
# 4                                  (549.0, 462.5, 159.5)
# ...                                                  ...
# 40501                              (550.3, 463.8, 160.8)
# 40502                              (550.4, 163.5, 466.2)
# 40503                              (161.0, 550.6, 463.9)
# 40504                              (162.4, 465.1, 551.3)
# 40505                              (549.0, 463.0, 160.5)
#
#       HEAD NORMAL COORDINATE Y AXIS(Stage) Collect Result_Dam  \
# 0                                  (161.4, 384.0, 383.1)
# 1                                  (377.3, 377.3, 377.3)
# 2                                (551.7, 1271.8, 1383.9)
# 3                               (1271.8, 1270.7, 1271.8)
# 4                                  (377.5, 377.0, 377.5)
# ...                                                  ...
# 40501                              (377.3, 377.3, 377.3)
# 40502                            (553.1, 1281.0, 1393.5)
# 40503                              (161.5, 377.6, 377.1)
# 40504                           (1269.0, 1268.4, 1269.0)
# 40505                              (377.5, 377.0, 377.5)
#
#       HEAD NORMAL COORDINATE Z AXIS(Stage) Collect Result_Dam  \
# 0                                (384.0, 274.51, 274.51)
# 1                               (282.15, 282.15, 282.15)
# 2                               (1271.8, 274.33, 274.33)
# 3                               (282.15, 282.15, 282.15)
# 4                                  (284.8, 284.8, 284.8)
# ...                                                  ...
# 40501                           (282.15, 282.15, 282.15)
# 40502                           (1281.2, 274.33, 274.33)
# 40503                            (378.0, 274.78, 274.78)
# 40504                           (282.15, 282.15, 282.15)
# 40505                              (284.8, 284.8, 284.8)
#
#       HEAD NORMAL COORDINATE X AXIS(Stage) Collect Result_Fill1  \
# 0                                  (157.0, 838.4, 458.7)
# 1                                  (838.4, 458.5, 157.0)
# 2                                  (157.0, 837.9, 458.1)
# 3                                  (837.7, 458.8, 157.0)
# 4                                  (838.4, 458.5, 157.0)
# ...                                                  ...
# 40501                              (838.4, 458.5, 157.0)
# 40502                              (157.0, 838.1, 458.7)
# 40503                              (157.0, 838.4, 458.4)
# 40504                              (837.7, 458.8, 157.0)
# 40505                              (837.9, 460.0, 157.5)
#
#       HEAD NORMAL COORDINATE Y AXIS(Stage) Collect Result_Fill1  \
# 0                                  (157.0, 430.0, 429.8)
# 1                                  (430.5, 430.5, 430.8)
# 2                                (156.1, 1323.5, 1322.5)
# 3                               (1323.2, 1322.5, 1322.8)
# 4                                  (430.2, 430.5, 430.5)
# ...                                                  ...
# 40501                              (430.5, 430.5, 430.8)
# 40502                            (156.1, 1325.0, 1324.0)
# 40503                              (157.0, 430.8, 430.5)
# 40504                           (1323.2, 1323.0, 1322.8)
# 40505                              (430.2, 430.5, 430.5)
#
#       HEAD NORMAL COORDINATE Z AXIS(Stage) Collect Result_Fill1  \
# 0                                (430.3, 244.52, 244.52)
# 1                                  (244.4, 244.4, 244.4)
# 2                             (1323.1, 244.415, 244.415)
# 3                                  (244.3, 244.3, 244.3)
# 4                                  (244.4, 244.4, 244.4)
# ...                                                  ...
# 40501                              (244.4, 244.4, 244.4)
# 40502                         (1324.3, 244.535, 244.535)
# 40503                          (431.1, 244.543, 244.543)
# 40504                              (244.4, 244.4, 244.4)
# 40505                              (244.3, 244.3, 244.3)
#
#       HEAD NORMAL COORDINATE X AXIS(Stage) Collect Result_Fill2  \
# 0                                  (156.0, 835.5, 458.0)
# 1                                  (835.5, 458.0, 156.0)
# 2                                  (694.0, 305.0, 499.8)
# 3                                  (305.0, 499.8, 694.0)
# 4                                  (835.5, 458.0, 156.0)
# ...                                                  ...
# 40501                              (835.5, 458.0, 156.0)
# 40502                              (694.0, 304.8, 499.8)
# 40503                              (156.0, 835.5, 458.0)
# 40504                              (305.0, 499.8, 694.0)
# 40505                              (835.5, 458.0, 156.0)
#
#       HEAD NORMAL COORDINATE Y AXIS(Stage) Collect Result_Fill2  \
# 0                                  (156.0, 428.0, 427.9)
# 1                                  (428.0, 427.9, 428.0)
# 2                                (694.0, 1324.2, 1324.2)
# 3                               (1324.2, 1324.2, 1324.2)
# 4                                  (428.0, 427.9, 428.0)
# ...                                                  ...
# 40501                              (428.0, 427.9, 428.0)
# 40502                            (692.8, 1324.2, 1324.2)
# 40503                              (156.0, 428.0, 427.9)
# 40504                           (1324.2, 1324.2, 1324.2)
# 40505                              (428.0, 427.9, 428.0)
#
#       HEAD NORMAL COORDINATE Z AXIS(Stage) Collect Result_Fill2  \
# 0                                  (428.0, 243.7, 243.7)
# 1                                  (243.7, 243.7, 243.7)
# 2                                 (1324.2, 243.5, 243.5)
# 3                                  (243.5, 243.5, 243.5)
# 4                                  (243.7, 243.7, 243.7)
# ...                                                  ...
# 40501                              (243.7, 243.7, 243.7)
# 40502                             (1324.2, 243.5, 243.5)
# 40503                              (428.0, 243.7, 243.7)
# 40504                              (243.5, 243.5, 243.5)
# 40505                              (243.7, 243.7, 243.7)
#
#       HEAD NORMAL COORDINATE AXIS(Stage1) Judge Value_Dam XYZ  \
# 0                                    ('nan', None, None)
# 1                                     ('NG', None, None)
# 2                                     ('OK', None, None)
# 3                                     ('NG', None, None)
# 4                                     ('NG', None, None)
# ...                                                  ...
# 40501                                 ('NG', None, None)
# 40502                                ('nan', None, None)
# 40503                                 ('OK', None, None)
# 40504                                 ('NG', None, None)
# 40505                                 ('NG', None, None)
#
#       Head Zero Position Collect Result_Dam XYZ head_interactionDam  \
# 0                        (130.85, 505.0, 300.0)       6_6_59_25_0_1
# 1                         (505.0, 300.0, 265.0)       0_28_40_5_2_4
# 2                        (130.85, 505.0, 300.0)       4_31_7_40_0_1
# 3                         (505.0, 300.0, 265.0)      0_22_48_73_2_4
# 4                         (505.0, 300.0, 265.0)       0_24_35_0_3_5
# ...                                         ...                 ...
# 40501                     (505.0, 300.0, 265.0)       0_28_40_5_2_4
# 40502                    (130.85, 505.0, 300.0)      4_45_21_51_0_1
# 40503                    (130.85, 505.0, 300.0)       7_7_63_19_0_1
# 40504                     (505.0, 300.0, 265.0)      0_18_42_70_2_4
# 40505                     (505.0, 303.5, 265.0)       0_24_38_4_3_5
#
#       head_interactionFill1 head_interactionFill2 stage123_dam  \
# 0           11_14_47_52_0_2           1_0_4_1_0_1           85
# 1             17_28_4_8_1_0           2_4_2_0_1_0           34
# 2             5_0_31_25_0_2           0_3_1_2_0_1           44
# 3            17_20_11_1_1_0           2_1_3_3_1_0           23
# 4             17_26_4_6_1_1           2_4_2_0_1_0           26
# ...                     ...                   ...          ...
# 40501         17_28_4_8_1_0           2_4_2_0_1_0           34
# 40502        12_2_42_50_0_2           0_2_0_2_0_1           66
# 40503       13_17_54_40_0_2           1_0_4_1_0_1           89
# 40504        17_21_14_2_1_0           2_1_3_3_1_0           15
# 40505        17_22_21_9_1_1           2_4_2_0_1_0           30
#
#       clean_purge_dam stage123_fill1 clean_purge_fill1 stage123_fill2  \
# 0                   0             12                 0              0
# 1                   2             57                 1              4
# 2                   0              0                 0              3
# 3                   2             34                 1              1
# 4                   3             53                 2              4
# ...               ...            ...               ...            ...
# 40501               2             57                 1              4
# 40502               0             60                 0              2
# 40503               0             24                 0              0
# 40504               2             35                 1              1
# 40505               3             40                 2              4
#
#       clean_purge_fill2 Mismatch_Dam_Fill1 Mismatch_Dam_Fill2  \
# 0                     0              False              False
# 1                     1              False              False
# 2                     0              False              False
# 3                     1              False              False
# 4                     1              False              False
# ...                 ...                ...                ...
# 40501                 1              False              False
# 40502                 0              False              False
# 40503                 0              False              False
# 40504                 1              False              False
# 40505                 1              False              False
#
#       Mismatch_Fill1_Fill2 Mismatch_Receip_Dam_Fill1  \
# 0                    False                     False
# 1                    False                     False
# 2                    False                     False
# 3                    False                     False
# 4                    False                     False
# ...                    ...                       ...
# 40501                False                     False
# 40502                False                     False
# 40503                False                     False
# 40504                False                     False
# 40505                False                     False
#
#       Mismatch_Receip_Dam_Fill2 Mismatch_Receip_Fill1_Fill2  \
# 0                         False                       False
# 1                         False                       False
# 2                         False                       False
# 3                         False                       False
# 4                         False                       False
# ...                         ...                         ...
# 40501                     False                       False
# 40502                     False                       False
# 40503                     False                       False
# 40504                     False                       False
# 40505                     False                       False
#
#       Mismatch_equipment_Dam_Fill1 Mismatch_equipment_Dam_Fill2  \
# 0                             True                         True
# 1                             True                         True
# 2                             True                         True
# 3                             True                         True
# 4                             True                         True
# ...                            ...                          ...
# 40501                         True                         True
# 40502                         True                         True
# 40503                         True                         True
# 40504                         True                         True
# 40505                         True                         True
#
#       Mismatch_equipment_Fill1_Fill2 Time_Difference_AutoClave_Dam  \
# 0                               True                      00:40:00
# 1                               True                      00:30:00
# 2                               True                      00:40:00
# 3                               True                      00:40:00
# 4                               True                      00:40:00
# ...                              ...                           ...
# 40501                           True                      00:40:00
# 40502                           True                      00:40:00
# 40503                           True                      00:40:00
# 40504                           True                      00:40:00
# 40505                           True                      00:30:00
#
#        CURE END POSITION X Collect Result_Dam  \
# 0                                       240.0
# 1                                       240.0
# 2                                      1000.0
# 3                                      1000.0
# 4                                       240.0
# ...                                       ...
# 40501                                   240.0
# 40502                                  1000.0
# 40503                                   240.0
# 40504                                  1000.0
# 40505                                   240.0
#
#        CURE END POSITION Z Collect Result_Dam  CURE SPEED Collect Result_Dam  \
# 0                                         2.5                            100
# 1                                         2.5                             70
# 2                                        12.5                             85
# 3                                        12.5                             70
# 4                                         2.5                             70
# ...                                       ...                            ...
# 40501                                     2.5                             70
# 40502                                    12.5                            100
# 40503                                     2.5                            100
# 40504                                    12.5                             70
# 40505                                     2.5                             70
#
#        DISCHARGED SPEED OF RESIN Collect Result_Dam  \
# 0                                                16
# 1                                                10
# 2                                                16
# 3                                                10
# 4                                                10
# ...                                             ...
# 40501                                            10
# 40502                                            16
# 40503                                            16
# 40504                                            10
# 40505                                            10
#
#        DISCHARGED TIME OF RESIN(Stage1) Collect Result_Dam  \
# 0                                                   14.9
# 1                                                   21.3
# 2                                                   14.7
# 3                                                   21.3
# 4                                                    9.7
# ...                                                  ...
# 40501                                               17.0
# 40502                                               14.9
# 40503                                               14.2
# 40504                                                9.7
# 40505                                                9.6
#
#        DISCHARGED TIME OF RESIN(Stage2) Collect Result_Dam  \
# 0                                                    8.4
# 1                                                    4.9
# 2                                                    8.5
# 3                                                    8.4
# 4                                                    4.9
# ...                                                  ...
# 40501                                                5.0
# 40502                                                8.5
# 40503                                                8.2
# 40504                                                4.9
# 40505                                                3.9
#
#        DISCHARGED TIME OF RESIN(Stage3) Collect Result_Dam  \
# 0                                                   14.7
# 1                                                   21.3
# 2                                                   14.7
# 3                                                   21.3
# 4                                                    9.6
# ...                                                  ...
# 40501                                               17.0
# 40502                                               14.7
# 40503                                               14.3
# 40504                                                9.7
# 40505                                                9.7
#
#        Dispense Volume(Stage1) Collect Result_Dam  \
# 0                                            1.04
# 1                                            1.49
# 2                                            1.61
# 3                                            1.49
# 4                                            0.67
# ...                                           ...
# 40501                                        1.19
# 40502                                        1.04
# 40503                                        0.99
# 40504                                        0.67
# 40505                                        0.67
#
#        Dispense Volume(Stage2) Collect Result_Dam  \
# 0                                            0.58
# 1                                            0.34
# 2                                            0.93
# 3                                            0.58
# 4                                            0.34
# ...                                           ...
# 40501                                        0.35
# 40502                                        0.59
# 40503                                        0.57
# 40504                                        0.34
# 40505                                        0.27
#
#        Dispense Volume(Stage3) Collect Result_Dam  \
# 0                                            1.02
# 1                                            1.49
# 2                                            1.61
# 3                                            1.49
# 4                                            0.67
# ...                                           ...
# 40501                                        1.19
# 40502                                        1.02
# 40503                                        1.00
# 40504                                        0.67
# 40505                                        0.67
#
#        Machine Tact time Collect Result_Dam  PalletID Collect Result_Dam  \
# 0                                    265.00                         58.5
# 1                                     65.10                          7.0
# 2                                    265.02                         76.9
# 3                                     70.50                         12.0
# 4                                     88.30                          8.0
# ...                                     ...                          ...
# 40501                                 56.70                          1.0
# 40502                                265.00                         78.5
# 40503                                265.02                         69.5
# 40504                                 57.70                         13.0
# 40505                                 92.10                          3.0
#
#        Stage1 Circle1 Distance Speed Collect Result_Dam  \
# 0                                                     1
# 1                                                  4000
# 2                                                     1
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                                 1
# 40503                                                 1
# 40504                                              9000
# 40505                                              9000
#
#        Stage1 Circle2 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage1 Line1 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage1 Line2 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage1 Line4 Distance Speed Collect Result_Dam  \
# 0                                                5600
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5600
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage2 Circle1 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  9000
# 2                                                  5800
# 3                                                  5000
# 4                                                  9000
# ...                                                 ...
# 40501                                              9000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                             12000
#
#        Stage2 Circle2 Distance Speed Collect Result_Dam  \
# 0                                                  5300
# 1                                                  9000
# 2                                                  5300
# 3                                                  5000
# 4                                                  9000
# ...                                                 ...
# 40501                                              9000
# 40502                                              5300
# 40503                                              5500
# 40504                                              9000
# 40505                                             12000
#
#        Stage2 Line2 Distance Speed Collect Result_Dam  \
# 0                                                5300
# 1                                                9000
# 2                                                5300
# 3                                                5000
# 4                                                9000
# ...                                               ...
# 40501                                            9000
# 40502                                            5300
# 40503                                            5500
# 40504                                            9000
# 40505                                           12000
#
#        Stage2 Line3 Distance Speed Collect Result_Dam  \
# 0                                                5300
# 1                                                9000
# 2                                                5300
# 3                                                5000
# 4                                                9000
# ...                                               ...
# 40501                                            9000
# 40502                                            5300
# 40503                                            5500
# 40504                                            9000
# 40505                                           12000
#
#        Stage2 Line4 Distance Speed Collect Result_Dam  \
# 0                                                5300
# 1                                                9000
# 2                                                5300
# 3                                                5000
# 4                                                9000
# ...                                               ...
# 40501                                            9000
# 40502                                            5300
# 40503                                            5500
# 40504                                            9000
# 40505                                           12000
#
#        Stage3 Circle2 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage3 Line2 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage3 Line4 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        THICKNESS 1 Collect Result_Dam  THICKNESS 2 Collect Result_Dam  \
# 0                                5800                           0.000
# 1                                   0                           0.000
# 2                                5800                           0.012
# 3                                   0                           0.000
# 4                                   0                           0.000
# ...                               ...                             ...
# 40501                               0                           0.000
# 40502                            5800                          -0.019
# 40503                            6000                           0.000
# 40504                               0                           0.000
# 40505                               0                           0.000
#
#        THICKNESS 3 Collect Result_Dam  WorkMode Collect Result_Dam  \
# 0                               0.000                        0.000
# 1                               0.000                        7.000
# 2                              -0.022                        0.003
# 3                               0.000                        7.000
# 4                               0.000                        7.000
# ...                               ...                          ...
# 40501                           0.000                        7.000
# 40502                          -0.021                       -0.118
# 40503                           0.000                        0.000
# 40504                           0.000                        7.000
# 40505                           0.000                        7.000
#
#        1st Pressure Collect Result_AutoClave  \
# 0                                      0.312
# 1                                      0.311
# 2                                      0.315
# 3                                      0.299
# 4                                      0.302
# ...                                      ...
# 40501                                  0.300
# 40502                                  0.305
# 40503                                  0.309
# 40504                                  0.302
# 40505                                  0.305
#
#        1st Pressure 1st Pressure Unit Time_AutoClave  \
# 0                                                240
# 1                                                241
# 2                                                241
# 3                                                241
# 4                                                240
# ...                                              ...
# 40501                                            241
# 40502                                            240
# 40503                                            241
# 40504                                            241
# 40505                                            300
#
#        2nd Pressure Collect Result_AutoClave  \
# 0                                      0.493
# 1                                      0.311
# 2                                      0.490
# 3                                      0.300
# 4                                      0.302
# ...                                      ...
# 40501                                  0.300
# 40502                                  0.493
# 40503                                  0.490
# 40504                                  0.303
# 40505                                  0.305
#
#        2nd Pressure Unit Time_AutoClave  \
# 0                                     1
# 1                                   121
# 2                                     1
# 3                                   121
# 4                                   120
# ...                                 ...
# 40501                               121
# 40502                                 1
# 40503                                 1
# 40504                               121
# 40505                                60
#
#        3rd Pressure Collect Result_AutoClave  \
# 0                                      0.499
# 1                                      0.498
# 2                                      0.498
# 3                                      0.500
# 4                                      0.498
# ...                                      ...
# 40501                                  0.500
# 40502                                  0.498
# 40503                                  0.498
# 40504                                  0.499
# 40505                                  0.498
#
#        3rd Pressure Unit Time_AutoClave  \
# 0                                   120
# 1                                   121
# 2                                   121
# 3                                   121
# 4                                   120
# ...                                 ...
# 40501                               121
# 40502                               120
# 40503                               121
# 40504                               121
# 40505                               120
#
#        Chamber Temp. Collect Result_AutoClave  \
# 0                                          54
# 1                                          54
# 2                                          56
# 3                                          54
# 4                                          47
# ...                                       ...
# 40501                                      54
# 40502                                      49
# 40503                                      48
# 40504                                      54
# 40505                                      47
#
#        DISCHARGED SPEED OF RESIN Collect Result_Fill1  \
# 0                                                10.6
# 1                                                10.6
# 2                                                10.6
# 3                                                10.6
# 4                                                10.6
# ...                                               ...
# 40501                                            10.6
# 40502                                            10.6
# 40503                                            10.6
# 40504                                            10.6
# 40505                                            10.9
#
#        DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill1  \
# 0                                                   12.7
# 1                                                   13.5
# 2                                                   13.5
# 3                                                   13.5
# 4                                                   13.5
# ...                                                  ...
# 40501                                               13.5
# 40502                                               13.5
# 40503                                               12.9
# 40504                                               13.5
# 40505                                               13.4
#
#        DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill1  \
# 0                                                    3.6
# 1                                                    3.6
# 2                                                    3.5
# 3                                                    3.6
# 4                                                    3.6
# ...                                                  ...
# 40501                                                3.6
# 40502                                                3.6
# 40503                                                3.6
# 40504                                                3.6
# 40505                                                5.0
#
#        DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill1  \
# 0                                                   12.6
# 1                                                   13.5
# 2                                                   13.4
# 3                                                   13.5
# 4                                                   13.5
# ...                                                  ...
# 40501                                               13.5
# 40502                                               13.5
# 40503                                               12.9
# 40504                                               13.4
# 40505                                               13.4
#
#        Dispense Volume(Stage1) Collect Result_Fill1  \
# 0                                             12.06
# 1                                             12.82
# 2                                             12.82
# 3                                             12.82
# 4                                             12.82
# ...                                             ...
# 40501                                         12.82
# 40502                                         12.82
# 40503                                         12.25
# 40504                                         12.82
# 40505                                         12.73
#
#        Dispense Volume(Stage2) Collect Result_Fill1  \
# 0                                              3.42
# 1                                              3.42
# 2                                              3.32
# 3                                              3.42
# 4                                              3.42
# ...                                             ...
# 40501                                          3.42
# 40502                                          3.42
# 40503                                          3.42
# 40504                                          3.42
# 40505                                          4.75
#
#        Dispense Volume(Stage3) Collect Result_Fill1  \
# 0                                             11.97
# 1                                             12.82
# 2                                             12.73
# 3                                             12.82
# 4                                             12.82
# ...                                             ...
# 40501                                         12.82
# 40502                                         12.82
# 40503                                         12.25
# 40504                                         12.73
# 40505                                         12.73
#
#        Machine Tact time Collect Result_Fill1  PalletID Collect Result_Fill1  \
# 0                                       128.0                           55.7
# 1                                        56.5                            7.0
# 2                                       128.0                           58.7
# 3                                        57.7                           12.0
# 4                                        89.9                            8.0
# ...                                       ...                            ...
# 40501                                    51.8                            1.0
# 40502                                   128.0                           58.7
# 40503                                   128.0                           56.2
# 40504                                    57.4                           13.0
# 40505                                    91.5                            3.0
#
#        WorkMode Collect Result_Fill1  \
# 0                                  1
# 1                                  7
# 2                                  1
# 3                                  7
# 4                                  7
# ...                              ...
# 40501                              7
# 40502                              1
# 40503                              1
# 40504                              7
# 40505                              7
#
#        CURE END POSITION X Collect Result_Fill2  \
# 0                                           240
# 1                                           240
# 2                                           240
# 3                                           240
# 4                                           240
# ...                                         ...
# 40501                                       240
# 40502                                       240
# 40503                                       240
# 40504                                       240
# 40505                                       240
#
#        CURE END POSITION Z Collect Result_Fill2  \
# 0                                            33
# 1                                            33
# 2                                            33
# 3                                            33
# 4                                            32
# ...                                         ...
# 40501                                        33
# 40502                                        33
# 40503                                        33
# 40504                                        33
# 40505                                        32
#
#        CURE SPEED Collect Result_Fill2  \
# 0                                   48
# 1                                   50
# 2                                   50
# 3                                   50
# 4                                   50
# ...                                ...
# 40501                               50
# 40502                               48
# 40503                               50
# 40504                               50
# 40505                               50
#
#        CURE STANDBY POSITION Z Collect Result_Fill2  \
# 0                                                33
# 1                                                33
# 2                                                33
# 3                                                33
# 4                                                33
# ...                                             ...
# 40501                                            33
# 40502                                            33
# 40503                                            33
# 40504                                            33
# 40505                                            32
#
#        Machine Tact time Collect Result_Fill2  PalletID Collect Result_Fill2  \
# 0                                     114.612                           19.9
# 1                                      19.600                            7.0
# 2                                     114.612                           19.8
# 3                                      19.900                           12.0
# 4                                      19.700                            8.0
# ...                                       ...                            ...
# 40501                                  19.200                            1.0
# 40502                                 114.612                           20.5
# 40503                                  85.000                           19.7
# 40504                                  20.100                           13.0
# 40505                                  19.400                            3.0
#
#        WorkMode Collect Result_Fill2  running_time_m  month  day  hour  \
# 0                                  1            40.0      4   25    11
# 1                                  0            30.0      9   19    14
# 2                                  1            40.0      3    5     9
# 3                                  0            40.0      9   25    15
# 4                                  0            40.0      6   27    13
# ...                              ...             ...    ...  ...   ...
# 40501                              0            40.0      9   14    15
# 40502                              1            40.0      4   10    14
# 40503                              1            40.0      2   22     8
# 40504                              0            40.0      7   25    11
# 40505                              0            30.0      5   31     1
#
#        out_of_hour  DIV Dispense Volume(Stage2)_Dam  \
# 0                0                        14.482759
# 1                0                        14.411765
# 2                0                         9.139785
# 3                0                        14.482759
# 4                0                        14.411765
# ...            ...                              ...
# 40501            0                        14.285714
# 40502            0                        14.406780
# 40503            0                        14.385965
# 40504            0                        14.411765
# 40505            1                        14.444444
#
#        DIV Dispense Volume(Stage3)_Dam  STD Dispense Volume_Fill1  target
# 0                            14.411765                   4.962530       0
# 1                            14.295302                   5.427093       0
# 2                             9.130435                   5.459032       0
# 3                            14.295302                   5.427093       0
# 4                            14.328358                   5.427093       0
# ...                                ...                        ...     ...
# 40501                        14.285714                   5.427093       0
# 40502                        14.411765                   5.427093       0
# 40503                        14.300000                   5.098003       0
# 40504                        14.477612                   5.401299       0
# 40505                        14.477612                   4.607255       1
#
# [40506 rows x 114 columns]

# %%
cat_features
# Out:
# ['Chamber Temp. Judge Value_AutoClave',
#  'Model.Suffix',
#  'Workorder',
#  'Dam X',
#  'Dam Y',
#  'Dam Z',
#  'Fill1 X',
#  'Fill1 Y',
#  'Fill1 Z',
#  'Fill2 X',
#  'Fill2 Y',
#  'Fill2 Z',
#  'Head Clean&Purge Position X Collect Result_Fill1',
#  'Head Clean&Purge Position Y Collect Result_Fill1',
#  'Head Clean&Purge Position Z Collect Result_Fill1',
#  'Head Clean&Purge Position X Collect Result_Dam',
#  'Head Clean&Purge Position Y Collect Result_Dam',
#  'Head Clean&Purge Position Z Collect Result_Dam',
#  'CURE  POSITION X Collect Result_Dam',
#  'CURE  POSITION Θ Collect Result_Dam',
#  'CURE  POSITION X Collect Result_Fill2',
#  'CURE  POSITION Z Collect Result_Fill2',
#  'HEAD NORMAL COORDINATE X AXIS(Stage) Collect Result_Dam',
#  'HEAD NORMAL COORDINATE Y AXIS(Stage) Collect Result_Dam',
#  'HEAD NORMAL COORDINATE Z AXIS(Stage) Collect Result_Dam',
#  'HEAD NORMAL COORDINATE X AXIS(Stage) Collect Result_Fill1',
#  'HEAD NORMAL COORDINATE Y AXIS(Stage) Collect Result_Fill1',
#  'HEAD NORMAL COORDINATE Z AXIS(Stage) Collect Result_Fill1',
#  'HEAD NORMAL COORDINATE X AXIS(Stage) Collect Result_Fill2',
#  'HEAD NORMAL COORDINATE Y AXIS(Stage) Collect Result_Fill2',
#  'HEAD NORMAL COORDINATE Z AXIS(Stage) Collect Result_Fill2',
#  'HEAD NORMAL COORDINATE AXIS(Stage1) Judge Value_Dam XYZ',
#  'Head Zero Position Collect Result_Dam XYZ',
#  'head_interactionDam',
#  'head_interactionFill1',
#  'head_interactionFill2',
#  'stage123_dam',
#  'clean_purge_dam',
#  'stage123_fill1',
#  'clean_purge_fill1',
#  'stage123_fill2',
#  'clean_purge_fill2',
#  'Mismatch_Dam_Fill1',
#  'Mismatch_Dam_Fill2',
#  'Mismatch_Fill1_Fill2',
#  'Mismatch_Receip_Dam_Fill1',
#  'Mismatch_Receip_Dam_Fill2',
#  'Mismatch_Receip_Fill1_Fill2',
#  'Mismatch_equipment_Dam_Fill1',
#  'Mismatch_equipment_Dam_Fill2',
#  'Mismatch_equipment_Fill1_Fill2',
#  'Time_Difference_AutoClave_Dam']

# %%
space = {
    'num_leaves': hp.quniform('num_leaves', 20, 150, 1),
    'max_depth': hp.quniform('max_depth', 5, 30, 1),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'n_estimators': 1000,
    'min_child_weight': hp.quniform('min_child_weight', 1, 10, 1),
    'subsample': hp.uniform('subsample', 0.5, 1.0),
    'colsample_bytree': hp.uniform('colsample_bytree', 0.5, 1.0)
}

def f1_eval_metric(y_true, y_pred):
    # LightGBM은 예측 확률로 전달하므로, 이를 이진 예측으로 변환해야 합니다.
    y_pred_binary = np.round(y_pred)  # 0.5 기준으로 이진화
    f1 = f1_score(y_true, y_pred_binary)
    return 'f1_score', f1, True  

# 목적 함수 정의
def objective(params):
    params['num_leaves'] = int(params['num_leaves'])
    params['max_depth'] = int(params['max_depth'])
    params['n_estimators'] = int(params['n_estimators'])

    model = lgb.LGBMClassifier(**params, class_weight = class_weights, random_state=SEED, verbose=-1)
    model.fit(x_train, y_train, eval_set=[(x_valid, y_valid)], eval_metric=f1_eval_metric,
              categorical_feature = cat_features,
              callbacks = [lgb.early_stopping(stopping_rounds = 100), lgb.log_evaluation(period = 0)])

    preds = model.predict(x_valid)
    score = f1_score(y_valid, preds)

    # Hyperopt가 최소화를 수행하므로, 음수의 accuracy를 반환합니다.
    return {'loss': -score, 'status': STATUS_OK}

# %%
# Trials 객체로 결과 기록
from hyperopt.early_stop import no_progress_loss
trials = Trials()
# 최적화 수행
best = fmin(fn=objective,
            space=space,
            algo=tpe.suggest,
            max_evals=300,
            trials=trials,
            rstate=np.random.default_rng(SEED),
            early_stop_fn=no_progress_loss(50))

# 최적 파라미터 출력
print("Best hyperparameters:", best)
# Out:
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [71]	valid_0's binary_logloss: 0.359643	valid_0's f1_score: 0.195081
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [138]	valid_0's binary_logloss: 0.315748	valid_0's f1_score: 0.203077
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [220]	valid_0's binary_logloss: 0.284729	valid_0's f1_score: 0.217801
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [251]	valid_0's binary_logloss: 0.363099	valid_0's f1_score: 0.205096
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [298]	valid_0's binary_logloss: 0.275064	valid_0's f1_score: 0.217865
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [36]	valid_0's binary_logloss: 0.364595	valid_0's f1_score: 0.200184
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [156]	valid_0's binary_logloss: 0.280227	valid_0's f1_score: 0.220541
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [314]	valid_0's binary_logloss: 0.327431	valid_0's f1_score: 0.222222
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [66]	valid_0's binary_logloss: 0.387428	valid_0's f1_score: 0.21685
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [142]	valid_0's binary_logloss: 0.321128	valid_0's f1_score: 0.206462
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [198]	valid_0's binary_logloss: 0.347249	valid_0's f1_score: 0.214674
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [44]	valid_0's binary_logloss: 0.342299	valid_0's f1_score: 0.197183
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [76]	valid_0's binary_logloss: 0.311868	valid_0's f1_score: 0.204589
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [339]	valid_0's binary_logloss: 0.280753	valid_0's f1_score: 0.21822
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [21]	valid_0's binary_logloss: 0.364006	valid_0's f1_score: 0.195652
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [26]	valid_0's binary_logloss: 0.379456	valid_0's f1_score: 0.192771
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [128]	valid_0's binary_logloss: 0.318687	valid_0's f1_score: 0.212766
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [206]	valid_0's binary_logloss: 0.292521	valid_0's f1_score: 0.204255
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [196]	valid_0's binary_logloss: 0.295331	valid_0's f1_score: 0.204708
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [134]	valid_0's binary_logloss: 0.30922	valid_0's f1_score: 0.204004
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [101]	valid_0's binary_logloss: 0.398975	valid_0's f1_score: 0.189557
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2]	valid_0's binary_logloss: 0.653594	valid_0's f1_score: 0.178763
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [146]	valid_0's binary_logloss: 0.321432	valid_0's f1_score: 0.197417
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [98]	valid_0's binary_logloss: 0.352904	valid_0's f1_score: 0.205722
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [193]	valid_0's binary_logloss: 0.324003	valid_0's f1_score: 0.211568
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [93]	valid_0's binary_logloss: 0.30374	valid_0's f1_score: 0.209237
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [166]	valid_0's binary_logloss: 0.35271	valid_0's f1_score: 0.20471
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [85]	valid_0's binary_logloss: 0.29089	valid_0's f1_score: 0.216441
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [352]	valid_0's binary_logloss: 0.298773	valid_0's f1_score: 0.210744
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [231]	valid_0's binary_logloss: 0.286506	valid_0's f1_score: 0.216506
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [294]	valid_0's binary_logloss: 0.293943	valid_0's f1_score: 0.213198
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [85]	valid_0's binary_logloss: 0.324337	valid_0's f1_score: 0.213894
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [170]	valid_0's binary_logloss: 0.323838	valid_0's f1_score: 0.200537
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [168]	valid_0's binary_logloss: 0.299288	valid_0's f1_score: 0.204926
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [295]	valid_0's binary_logloss: 0.285145	valid_0's f1_score: 0.240557
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.681609	valid_0's f1_score: 0.181306
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [262]	valid_0's binary_logloss: 0.297919	valid_0's f1_score: 0.213628
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [64]	valid_0's binary_logloss: 0.342036	valid_0's f1_score: 0.211368
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [58]	valid_0's binary_logloss: 0.329425	valid_0's f1_score: 0.196864
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [98]	valid_0's binary_logloss: 0.288423	valid_0's f1_score: 0.216274
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [53]	valid_0's binary_logloss: 0.35861	valid_0's f1_score: 0.211438
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [142]	valid_0's binary_logloss: 0.367829	valid_0's f1_score: 0.210976
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [161]	valid_0's binary_logloss: 0.318047	valid_0's f1_score: 0.209934
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [70]	valid_0's binary_logloss: 0.322374	valid_0's f1_score: 0.189608
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [47]	valid_0's binary_logloss: 0.342142	valid_0's f1_score: 0.202636
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [364]	valid_0's binary_logloss: 0.346549	valid_0's f1_score: 0.204025
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [28]	valid_0's binary_logloss: 0.348654	valid_0's f1_score: 0.191214
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [193]	valid_0's binary_logloss: 0.313744	valid_0's f1_score: 0.210261
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [99]	valid_0's binary_logloss: 0.311457	valid_0's f1_score: 0.208955
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [312]	valid_0's binary_logloss: 0.296861	valid_0's f1_score: 0.210634
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [56]	valid_0's binary_logloss: 0.312784	valid_0's f1_score: 0.208295
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [79]	valid_0's binary_logloss: 0.326748	valid_0's f1_score: 0.206522
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [283]	valid_0's binary_logloss: 0.301148	valid_0's f1_score: 0.217663
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [24]	valid_0's binary_logloss: 0.390967	valid_0's f1_score: 0.194161
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [227]	valid_0's binary_logloss: 0.332709	valid_0's f1_score: 0.19106
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [632]	valid_0's binary_logloss: 0.360158	valid_0's f1_score: 0.198433
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [49]	valid_0's binary_logloss: 0.369722	valid_0's f1_score: 0.199825
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [235]	valid_0's binary_logloss: 0.28538	valid_0's f1_score: 0.215983
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [277]	valid_0's binary_logloss: 0.357905	valid_0's f1_score: 0.201681
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [185]	valid_0's binary_logloss: 0.288866	valid_0's f1_score: 0.220273
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [60]	valid_0's binary_logloss: 0.322044	valid_0's f1_score: 0.200889
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [243]	valid_0's binary_logloss: 0.38199	valid_0's f1_score: 0.196124
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [37]	valid_0's binary_logloss: 0.348906	valid_0's f1_score: 0.202226
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [78]	valid_0's binary_logloss: 0.296472	valid_0's f1_score: 0.225235
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [85]	valid_0's binary_logloss: 0.290076	valid_0's f1_score: 0.219038
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [64]	valid_0's binary_logloss: 0.303928	valid_0's f1_score: 0.205645
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [86]	valid_0's binary_logloss: 0.281596	valid_0's f1_score: 0.217759
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [113]	valid_0's binary_logloss: 0.288176	valid_0's f1_score: 0.228453
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [159]	valid_0's binary_logloss: 0.2824	valid_0's f1_score: 0.209544
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [97]	valid_0's binary_logloss: 0.286301	valid_0's f1_score: 0.216387
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [105]	valid_0's binary_logloss: 0.289321	valid_0's f1_score: 0.219938
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [147]	valid_0's binary_logloss: 0.28458	valid_0's f1_score: 0.214133
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [155]	valid_0's binary_logloss: 0.289009	valid_0's f1_score: 0.214737
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [255]	valid_0's binary_logloss: 0.280218	valid_0's f1_score: 0.209581
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [274]	valid_0's binary_logloss: 0.285827	valid_0's f1_score: 0.219119
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [123]	valid_0's binary_logloss: 0.298434	valid_0's f1_score: 0.222694
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [128]	valid_0's binary_logloss: 0.305005	valid_0's f1_score: 0.217755
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [97]	valid_0's binary_logloss: 0.300587	valid_0's f1_score: 0.215582
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [84]	valid_0's binary_logloss: 0.28539	valid_0's f1_score: 0.219382
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [274]	valid_0's binary_logloss: 0.276408	valid_0's f1_score: 0.21575
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [54]	valid_0's binary_logloss: 0.309186	valid_0's f1_score: 0.205855
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [65]	valid_0's binary_logloss: 0.297625	valid_0's f1_score: 0.21074
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [491]	valid_0's binary_logloss: 0.287331	valid_0's f1_score: 0.222222
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [141]	valid_0's binary_logloss: 0.287434	valid_0's f1_score: 0.211297
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [53]	valid_0's binary_logloss: 0.31788	valid_0's f1_score: 0.218471
#  28%|██▊       | 85/300 [05:51<14:48,  4.13s/trial, best loss: -0.24055666003976142]
# Best hyperparameters: {'colsample_bytree': 0.8551988516394926, 'learning_rate': 0.06528685659002366, 'max_depth': 15.0, 'min_child_weight': 1.0, 'num_leaves': 104.0, 'subsample': 0.8971094808819405}

# %%
best['max_depth'] = int(best['max_depth'])
best['num_leaves'] = int(best['num_leaves'])
best['min_child_weight'] = int(best['min_child_weight'])
best['n_estimators'] = 1000
best
# Out:
# {'colsample_bytree': 0.8551988516394926,
#  'learning_rate': 0.06528685659002366,
#  'max_depth': 15,
#  'min_child_weight': 1,
#  'num_leaves': 104,
#  'subsample': 0.8971094808819405,
#  'n_estimators': 1000}

# %%
model = lgb.LGBMClassifier(**best, class_weight = class_weights, random_state=SEED, verbose=-1)
model.fit(x_train, y_train, eval_set=[(x_valid, y_valid)], eval_metric=f1_eval_metric,
          categorical_feature = cat_features,
          callbacks = [lgb.early_stopping(stopping_rounds = 100), lgb.log_evaluation(period = 0)]
         )

preds = model.predict(x_valid)
score = f1_score(y_valid, preds)
print(score)
# Out:
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [295]	valid_0's binary_logloss: 0.285145	valid_0's f1_score: 0.240557
# 0.24055666003976142

# %%
x_train = train.drop('target', axis=1)
y_train = train['target']

# %%
# class weight
SEED = 0
n_fold = 5
class_weights = compute_class_weight(classes=np.array([0, 1]), y=train['target'], class_weight='balanced')
class_weights = {i: weight for i, weight in enumerate(class_weights)}
class_weights
# Out:
# {0: 0.5307946325610651, 1: 8.618297872340426}

# %%
import pickle
from sklearn.metrics import roc_curve
import lightgbm as lgb
from sklearn.metrics import f1_score
from sklearn.model_selection import StratifiedKFold
import numpy as np

model_scores = []  # 모델에서 뽑아내는 score
models = []
val_scores = []  # f1 score로 측정한 validation score
best_thresholds = []
pred_list = []

num = 0
cv = StratifiedKFold(n_splits=n_fold, shuffle=True, random_state=SEED)

# 폴더 경로 설정
model_save_path = "data/"  # 모델을 저장할 디렉토리

for train_idx, valid_idx in cv.split(x_train, y_train):
    num += 1
    scores = []
    print('\n', num, '번째 fold', "="*50)
    
    # train valid split
    x_train_cv, x_valid_cv, y_train_cv, y_valid_cv = x_train.iloc[train_idx], x_train.iloc[valid_idx], y_train.iloc[train_idx], y_train.iloc[valid_idx]
    
    # model fitting
    model = lgb.LGBMClassifier(**best, class_weight=class_weights, random_state=SEED, verbose=-1)
    model.fit(x_train_cv, y_train_cv, eval_set=[(x_valid_cv, y_valid_cv)],
              eval_metric=f1_eval_metric, categorical_feature=cat_features,
              callbacks=[lgb.early_stopping(stopping_rounds=100), lgb.log_evaluation(period=0)])
    
    models.append(model)

    # 모델을 파일로 저장
    with open(f"{model_save_path}model_fold_{num}.pkl", "wb") as file:
        pickle.dump(model, file)
    
    # validation evaluate
    val_proba = model.predict_proba(x_valid_cv)[:, 1]
    
    # ROC Curve 계산
    fpr, tpr, thresholds = roc_curve(y_valid_cv, val_proba)
    f1_scores = []
    
    for thresh in thresholds:
        y_pred = [1 if y >= thresh else 0 for y in val_proba]
        f1 = f1_score(y_valid_cv, y_pred)
        f1_scores.append(f1)
    
    threshold = thresholds[np.argmax(f1_scores)]
    best_score = max(f1_scores)
    
    best_thresholds.append(threshold)
    val_scores.append(best_score)  # f1 score로 측정한 validation score
    
    # Final prediction
    pred = model.predict_proba(test.drop('target', axis=1))[:, 1]
    pred_list.append(pred)
# Out:
#  1 번째 fold ==================================================
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [153]	valid_0's binary_logloss: 0.32846	valid_0's f1_score: 0.23197
#
#  2 번째 fold ==================================================
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [214]	valid_0's binary_logloss: 0.298349	valid_0's f1_score: 0.229706
#
#  3 번째 fold ==================================================
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [470]	valid_0's binary_logloss: 0.269219	valid_0's f1_score: 0.273046
#
#  4 번째 fold ==================================================
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [478]	valid_0's binary_logloss: 0.270417	valid_0's f1_score: 0.246294
#
#  5 번째 fold ==================================================
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [133]	valid_0's binary_logloss: 0.340078	valid_0's f1_score: 0.231783

# %%
best_thresholds
# Out:
# [0.7191139178416153,
#  0.6861931817384156,
#  0.6860525175573299,
#  0.6343271277491745,
#  0.7497526673295842]

# %%
np.mean(best_thresholds)
# Out:
# 0.695087882443224

# %%
final_pred = np.where(sum(pred_list)/n_fold >= np.mean(best_thresholds), 1, 0)
print('cv f1 mean score :', np.mean(val_scores))
print('test에서 1로 예측된 수:', sum(final_pred))
# Out:
# cv f1 mean score : 0.2667551329260919
# test에서 1로 예측된 수: 306

# %%
# 제출 데이터 읽어오기 (df_test는 전처리된 데이터가 저장됨)
df_sub = pd.read_csv("submission.csv")
df_sub["target"] = final_pred
df_sub["target"] = df_sub["target"].apply(lambda x : 'AbNormal' if x==1 else 'Normal')
# 제출 파일 저장
df_sub.to_csv("submission.csv", index=False)

# %%
# from sklearn.inspection import permutation_importance
# import matplotlib.pyplot as plt
# all_importances = []

# # Compute permutation importance for each model on its corresponding validation set
# for model, (train_idx, valid_idx) in zip(models, cv.split(x_train, y_train)):
#     x_valid_cv, y_valid_cv = x_train.iloc[valid_idx], y_train.iloc[valid_idx]
    
#     # Permutation importance with F1 score as the evaluation metric
#     result = permutation_importance(model, x_valid_cv, y_valid_cv, scoring='f1', n_repeats=10, random_state=SEED)
#     all_importances.append(result.importances_mean)  # Take the mean importance across the repeats

# # Convert list to numpy array for easier averaging
# all_importances = np.array(all_importances)

# # Average the importances across all models
# mean_importances = np.mean(all_importances, axis=0)

# # Create a DataFrame for easier visualization
# feature_importance_df = pd.DataFrame({
#     'Feature': x_train_cv.columns,
#     'Importance': mean_importances
# })

# # Sort by importance and select top 30 features
# feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False).reset_index(drop=True).iloc[:30]

# # Visualize the top 30 feature importances
# plt.figure(figsize=(10, 6))
# plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'])
# plt.xlabel("Importance")
# plt.title("Feature Importance (Averaged Permutation Importance)")
# plt.gca().invert_yaxis()
# plt.show()

# %%
# # Create a DataFrame for easier visualization
# feature_importance_df = pd.DataFrame({
#     'Feature': x_train_cv.columns,
#     'Importance': mean_importances
# })



# # Sort by importance and select top 30 features
# feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False).reset_index(drop=True).iloc[-30:-1]

# # Visualize the top 30 feature importances
# plt.figure(figsize=(10, 6))
# plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'])
# plt.xlabel("Importance")
# plt.title("Feature Importance (Averaged Permutation Importance)")
# plt.gca().invert_yaxis()
# plt.show()

# %%
# feature_importance_df = pd.DataFrame({
#     'Feature': x_train_cv.columns,
#     'Importance': mean_importances
# })

# print(feature_importance_df.to_string())

# %% [markdown]
# ### 언더 샘플링

# %% [markdown]
# 데이타 불균형을 해결하기 위해 언더 샘플링을 진행합니다.

# %%
# normal_ratio = 1.0  # 1.0 means 1:1 ratio

# df_normal = train_data[train_data["target"] == "Normal"]
# df_abnormal = train_data[train_data["target"] == "AbNormal"]

# num_normal = len(df_normal)
# num_abnormal = len(df_abnormal)
# print(f"  Total: Normal: {num_normal}, AbNormal: {num_abnormal}")

# df_normal = df_normal.sample(n=int(num_abnormal * normal_ratio), replace=False, random_state=RANDOM_STATE)
# df_concat = pd.concat([df_normal, df_abnormal], axis=0).reset_index(drop=True)
# df_concat.value_counts("target")

# %% [markdown]
# ### 데이터 분할

# %%
# df_train, df_val = train_test_split(
#     df_concat,
#     test_size=0.3,
#     stratify=df_concat["target"],
#     random_state=RANDOM_STATE,
# )


# def print_stats(df: pd.DataFrame):
#     num_normal = len(df[df["target"] == "Normal"])
#     num_abnormal = len(df[df["target"] == "AbNormal"])

#     print(f"  Total: Normal: {num_normal}, AbNormal: {num_abnormal}" + f" ratio: {num_abnormal/num_normal}")


# # Print statistics
# print(f"  \tAbnormal\tNormal")
# print_stats(df_train)
# print_stats(df_val)

# %% [markdown]
# ## 3. 모델 학습

# %% [markdown]
# ### 모델 정의

# %%
# model = RandomForestClassifier(random_state=RANDOM_STATE)

# %% [markdown]
# ### 모델 학습

# %%
# features = []

# for col in df_train.columns:
#     try:
#         df_train[col] = df_train[col].astype(int)
#         features.append(col)
#     except:
#         continue

# train_x = df_train[features]
# train_y = df_train["target"]

# model.fit(train_x, train_y)

# %% [markdown]
# ## 4. 제출하기

# %% [markdown]
# ### 테스트 데이터 예측

# %% [markdown]
# 테스트 데이터 불러오기

# %%
# test_data = pd.read_csv(os.path.join(ROOT_DIR, "test.csv"))

# %%
# df_test_x = test_data[features]

# for col in df_test_x.columns:
#     try:
#         df_test_x.loc[:, col] = df_test_x[col].astype(int)
#     except:
#         continue

# %%
# test_pred = model.predict(df_test_x)
# test_pred

# %% [markdown]
# ### 제출 파일 작성

# %%
# # 제출 데이터 읽어오기 (df_test는 전처리된 데이터가 저장됨)
# df_sub = pd.read_csv("submission.csv")
# df_sub["target"] = test_pred

# # 제출 파일 저장
# df_sub.to_csv("submission.csv", index=False)

# %% [markdown]
# **우측 상단의 제출 버튼을 클릭해 결과를 확인하세요**
